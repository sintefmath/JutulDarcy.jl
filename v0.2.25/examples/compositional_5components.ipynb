# %% [markdown]
# # A more complex compositional model
# This example sets up a more complex compositional simulation with five
# different components. Other than that, the example is similar to the others
# that include wells and is therefore not commented in great detail.

# %%
using MultiComponentFlash

n2_ch4 = MolecularProperty(0.0161594, 4.58e6, 189.515, 9.9701e-05, 0.00854)
co2 = MolecularProperty(0.04401, 7.3866e6, 304.200, 9.2634e-05, 0.228)
c2_5 = MolecularProperty(0.0455725, 4.0955e6, 387.607, 2.1708e-04, 0.16733)
c6_13 = MolecularProperty(0.117740, 3.345e6, 597.497, 3.8116e-04, 0.38609)
c14_24 = MolecularProperty(0.248827, 1.768e6, 698.515, 7.2141e-04, 0.80784)

bic = [0.11883 0.00070981 0.00077754 0.01 0.011;
       0.00070981 0.15 0.15 0.15 0.15;
       0.00077754 0.15 0 0 0;
       0.01 0.15 0 0 0;
       0.011 0.15 0 0 0]

mixture = MultiComponentMixture([n2_ch4, co2, c2_5, c6_13, c14_24], A_ij = bic, names = ["N2-CH4", "CO2", "C2-5", "C6-13", "C14-24"])
eos = GenericCubicEOS(mixture, PengRobinson())

using Jutul, JutulDarcy, GLMakie
Darcy, bar, kg, meter, Kelvin, day = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day)
nx = ny = 20
nz = 2

dims = (nx, ny, nz)
g = CartesianMesh(dims, (1000.0, 1000.0, 1.0))
nc = number_of_cells(g)
K = repeat([0.05*Darcy], 1, nc)
res = reservoir_domain(g, porosity = 0.25, permeability = K, temperature = 387.45*Kelvin)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 20x20x2=800 cells with 18 data fields added:
#   800 Cells
#     :permeability => 1×800 Matrix{Float64}
#     :porosity => 800 Vector{Float64}
#     :rock_thermal_conductivity => 800 Vector{Float64}
#     :fluid_thermal_conductivity => 800 Vector{Float64}
#     :rock_density => 800 Vector{Float64}
#     :temperature => 800 Vector{Float64}
#     :cell_centroids => 3×800 Matrix{Float64}
#     :volumes => 800 Vector{Float64}
#   1920 Faces
#     :neighbors => 2×1920 Matrix{Int64}
#     :areas => 1920 Vector{Float64}
#     :normals => 3×1920 Matrix{Float64}
#     :face_centroids => 3×1920 Matrix{Float64}
#   3840 HalfFaces
#     :half_face_cells => 3840 Vector{Int64}
#     :half_face_faces => 3840 Vector{Int64}
#   960 BoundaryFaces
#     :boundary_areas => 960 Vector{Float64}
#     :boundary_centroids => 3×960 Matrix{Float64}
#     :boundary_normals => 3×960 Matrix{Float64}
#     :boundary_neighbors => 960 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in all layers

# %%
prod = setup_vertical_well(g, K, nx, ny, name = :Producer)
# Out:
# MultiSegmentWell [Producer] (3 nodes, 2 segments, 2 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in all layers

# %%
inj = setup_vertical_well(g, K, 1, 1, name = :Injector)

rhoLS = 1000.0*kg/meter^3
rhoVS = 100.0*kg/meter^3

rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
# Out:
# (LiquidPhase(), VaporPhase())

# %% [markdown]
# Define system and realize on grid

# %%
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod], block_backend = true);
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)

push!(model[:Reservoir].output_variables, :Saturations)

state0 = setup_reservoir_state(model, Pressure = 225*bar, OverallMoleFractions = [0.463, 0.01640, 0.20520, 0.19108, 0.12432]);

dt = repeat([2.0]*day, 365)
rate_target = TotalRateTarget(0.0015)
I_ctrl = InjectorControl(rate_target, [0, 1, 0, 0, 0], density = rhoVS)
bhp_target = BottomHolePressureTarget(100*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:55:47
#   Progress:  Solving step 2/365 (0.55% of time interval complete)
#   Stats:     8 iterations in 13.47 s (1.68 s each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:37:19
#   Progress:  Solving step 3/365 (0.82% of time interval complete)
#   Stats:     14 iterations in 13.57 s (969.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:22:25
#   Progress:  Solving step 5/365 (1.37% of time interval complete)
#   Stats:     21 iterations in 13.70 s (652.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   2%| |  ETA: 0:16:01
#   Progress:  Solving step 7/365 (1.92% of time interval complete)
#   Stats:     27 iterations in 13.82 s (511.70 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   2%| |  ETA: 0:12:28
#   Progress:  Solving step 9/365 (2.47% of time interval complete)
#   Stats:     33 iterations in 13.93 s (422.13 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   3%| |  ETA: 0:10:12
#   Progress:  Solving step 11/365 (3.01% of time interval complete)
#   Stats:     39 iterations in 14.05 s (360.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   4%| |  ETA: 0:08:00
#   Progress:  Solving step 14/365 (3.84% of time interval complete)
#   Stats:     45 iterations in 14.18 s (315.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   4%| |  ETA: 0:07:00
#   Progress:  Solving step 16/365 (4.38% of time interval complete)
#   Stats:     49 iterations in 14.29 s (291.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   5%| |  ETA: 0:05:54
#   Progress:  Solving step 19/365 (5.21% of time interval complete)
#   Stats:     55 iterations in 14.45 s (262.64 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   6%| |  ETA: 0:05:20
#   Progress:  Solving step 21/365 (5.75% of time interval complete)
#   Stats:     59 iterations in 14.56 s (246.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   6%|▏|  ETA: 0:04:53
#   Progress:  Solving step 23/365 (6.30% of time interval complete)
#   Stats:     63 iterations in 14.68 s (233.03 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   7%|▏|  ETA: 0:04:29
#   Progress:  Solving step 25/365 (6.85% of time interval complete)
#   Stats:     67 iterations in 14.81 s (221.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   7%|▏|  ETA: 0:04:10
#   Progress:  Solving step 27/365 (7.40% of time interval complete)
#   Stats:     71 iterations in 14.94 s (210.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   8%|▏|  ETA: 0:03:53
#   Progress:  Solving step 29/365 (7.95% of time interval complete)
#   Stats:     75 iterations in 15.08 s (201.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   8%|▏|  ETA: 0:03:38
#   Progress:  Solving step 31/365 (8.49% of time interval complete)
#   Stats:     79 iterations in 15.21 s (192.58 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   9%|▏|  ETA: 0:03:25
#   Progress:  Solving step 33/365 (9.04% of time interval complete)
#   Stats:     83 iterations in 15.36 s (185.09 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  10%|▏|  ETA: 0:03:13
#   Progress:  Solving step 35/365 (9.59% of time interval complete)
#   Stats:     87 iterations in 15.51 s (178.23 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  10%|▏|  ETA: 0:03:03
#   Progress:  Solving step 37/365 (10.14% of time interval complete)
#   Stats:     91 iterations in 15.65 s (172.00 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:02:54
#   Progress:  Solving step 39/365 (10.68% of time interval complete)
#   Stats:     95 iterations in 15.80 s (166.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:02:46
#   Progress:  Solving step 41/365 (11.23% of time interval complete)
#   Stats:     99 iterations in 15.95 s (161.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  12%|▏|  ETA: 0:02:38
#   Progress:  Solving step 43/365 (11.78% of time interval complete)
#   Stats:     103 iterations in 16.10 s (156.30 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  12%|▏|  ETA: 0:02:31
#   Progress:  Solving step 45/365 (12.33% of time interval complete)
#   Stats:     107 iterations in 16.25 s (151.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  13%|▏|  ETA: 0:02:25
#   Progress:  Solving step 47/365 (12.88% of time interval complete)
#   Stats:     111 iterations in 16.41 s (147.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  13%|▏|  ETA: 0:02:19
#   Progress:  Solving step 49/365 (13.42% of time interval complete)
#   Stats:     115 iterations in 16.57 s (144.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  14%|▏|  ETA: 0:02:14
#   Progress:  Solving step 51/365 (13.97% of time interval complete)
#   Stats:     119 iterations in 16.72 s (140.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  14%|▏|  ETA: 0:02:12
#   Progress:  Solving step 52/365 (14.25% of time interval complete)
#   Stats:     121 iterations in 16.88 s (139.50 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  15%|▏|  ETA: 0:02:07
#   Progress:  Solving step 54/365 (14.79% of time interval complete)
#   Stats:     125 iterations in 17.03 s (136.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  15%|▏|  ETA: 0:02:02
#   Progress:  Solving step 56/365 (15.34% of time interval complete)
#   Stats:     129 iterations in 17.17 s (133.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  16%|▏|  ETA: 0:01:58
#   Progress:  Solving step 58/365 (15.89% of time interval complete)
#   Stats:     133 iterations in 17.31 s (130.18 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  16%|▏|  ETA: 0:01:54
#   Progress:  Solving step 60/365 (16.44% of time interval complete)
#   Stats:     137 iterations in 17.46 s (127.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  17%|▏|  ETA: 0:01:51
#   Progress:  Solving step 62/365 (16.99% of time interval complete)
#   Stats:     141 iterations in 17.61 s (124.89 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  17%|▏|  ETA: 0:01:47
#   Progress:  Solving step 64/365 (17.53% of time interval complete)
#   Stats:     145 iterations in 17.75 s (122.43 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  18%|▏|  ETA: 0:01:44
#   Progress:  Solving step 66/365 (18.08% of time interval complete)
#   Stats:     149 iterations in 17.90 s (120.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  19%|▏|  ETA: 0:01:41
#   Progress:  Solving step 68/365 (18.63% of time interval complete)
#   Stats:     153 iterations in 18.04 s (117.91 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  19%|▎|  ETA: 0:01:38
#   Progress:  Solving step 70/365 (19.18% of time interval complete)
#   Stats:     157 iterations in 18.18 s (115.82 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  20%|▎|  ETA: 0:01:35
#   Progress:  Solving step 72/365 (19.73% of time interval complete)
#   Stats:     161 iterations in 18.33 s (113.86 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  20%|▎|  ETA: 0:01:32
#   Progress:  Solving step 74/365 (20.27% of time interval complete)
#   Stats:     165 iterations in 18.48 s (112.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  21%|▎|  ETA: 0:01:30
#   Progress:  Solving step 76/365 (20.82% of time interval complete)
#   Stats:     169 iterations in 18.63 s (110.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  21%|▎|  ETA: 0:01:28
#   Progress:  Solving step 78/365 (21.37% of time interval complete)
#   Stats:     173 iterations in 18.78 s (108.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  22%|▎|  ETA: 0:01:25
#   Progress:  Solving step 80/365 (21.92% of time interval complete)
#   Stats:     177 iterations in 18.93 s (106.94 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  22%|▎|  ETA: 0:01:23
#   Progress:  Solving step 82/365 (22.47% of time interval complete)
#   Stats:     181 iterations in 19.08 s (105.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  23%|▎|  ETA: 0:01:21
#   Progress:  Solving step 84/365 (23.01% of time interval complete)
#   Stats:     185 iterations in 19.22 s (103.91 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  23%|▎|  ETA: 0:01:19
#   Progress:  Solving step 86/365 (23.56% of time interval complete)
#   Stats:     189 iterations in 19.37 s (102.49 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  24%|▎|  ETA: 0:01:17
#   Progress:  Solving step 88/365 (24.11% of time interval complete)
#   Stats:     193 iterations in 19.52 s (101.15 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  25%|▎|  ETA: 0:01:16
#   Progress:  Solving step 90/365 (24.66% of time interval complete)
#   Stats:     197 iterations in 19.67 s (99.86 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  25%|▎|  ETA: 0:01:14
#   Progress:  Solving step 92/365 (25.21% of time interval complete)
#   Stats:     201 iterations in 19.82 s (98.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  26%|▎|  ETA: 0:01:12
#   Progress:  Solving step 94/365 (25.75% of time interval complete)
#   Stats:     205 iterations in 19.97 s (97.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  26%|▎|  ETA: 0:01:11
#   Progress:  Solving step 96/365 (26.30% of time interval complete)
#   Stats:     209 iterations in 20.12 s (96.26 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:09
#   Progress:  Solving step 98/365 (26.85% of time interval complete)
#   Stats:     214 iterations in 20.30 s (94.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:08
#   Progress:  Solving step 100/365 (27.40% of time interval complete)
#   Stats:     218 iterations in 20.45 s (93.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  28%|▎|  ETA: 0:01:06
#   Progress:  Solving step 102/365 (27.95% of time interval complete)
#   Stats:     222 iterations in 20.60 s (92.79 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  28%|▎|  ETA: 0:01:05
#   Progress:  Solving step 104/365 (28.49% of time interval complete)
#   Stats:     226 iterations in 20.75 s (91.81 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  29%|▎|  ETA: 0:01:03
#   Progress:  Solving step 106/365 (29.04% of time interval complete)
#   Stats:     230 iterations in 20.90 s (90.86 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  30%|▎|  ETA: 0:01:02
#   Progress:  Solving step 108/365 (29.59% of time interval complete)
#   Stats:     234 iterations in 21.05 s (89.94 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  30%|▎|  ETA: 0:01:01
#   Progress:  Solving step 110/365 (30.14% of time interval complete)
#   Stats:     238 iterations in 21.19 s (89.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  31%|▎|  ETA: 0:01:00
#   Progress:  Solving step 112/365 (30.68% of time interval complete)
#   Stats:     242 iterations in 21.34 s (88.19 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  31%|▎|  ETA: 0:00:58
#   Progress:  Solving step 114/365 (31.23% of time interval complete)
#   Stats:     246 iterations in 21.49 s (87.36 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  32%|▍|  ETA: 0:00:57
#   Progress:  Solving step 116/365 (31.78% of time interval complete)
#   Stats:     250 iterations in 21.64 s (86.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  32%|▍|  ETA: 0:00:56
#   Progress:  Solving step 118/365 (32.33% of time interval complete)
#   Stats:     254 iterations in 21.79 s (85.79 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  33%|▍|  ETA: 0:00:56
#   Progress:  Solving step 119/365 (32.60% of time interval complete)
#   Stats:     256 iterations in 21.96 s (85.77 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  33%|▍|  ETA: 0:00:55
#   Progress:  Solving step 121/365 (33.15% of time interval complete)
#   Stats:     260 iterations in 22.10 s (84.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  34%|▍|  ETA: 0:00:54
#   Progress:  Solving step 123/365 (33.70% of time interval complete)
#   Stats:     264 iterations in 22.24 s (84.24 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  34%|▍|  ETA: 0:00:53
#   Progress:  Solving step 125/365 (34.25% of time interval complete)
#   Stats:     268 iterations in 22.38 s (83.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  35%|▍|  ETA: 0:00:52
#   Progress:  Solving step 127/365 (34.79% of time interval complete)
#   Stats:     272 iterations in 22.52 s (82.81 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  35%|▍|  ETA: 0:00:51
#   Progress:  Solving step 129/365 (35.34% of time interval complete)
#   Stats:     276 iterations in 22.67 s (82.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  36%|▍|  ETA: 0:00:50
#   Progress:  Solving step 131/365 (35.89% of time interval complete)
#   Stats:     280 iterations in 22.81 s (81.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  36%|▍|  ETA: 0:00:49
#   Progress:  Solving step 133/365 (36.44% of time interval complete)
#   Stats:     284 iterations in 22.95 s (80.83 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  37%|▍|  ETA: 0:00:48
#   Progress:  Solving step 135/365 (36.99% of time interval complete)
#   Stats:     288 iterations in 23.10 s (80.20 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  37%|▍|  ETA: 0:00:47
#   Progress:  Solving step 137/365 (37.53% of time interval complete)
#   Stats:     292 iterations in 23.24 s (79.59 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  38%|▍|  ETA: 0:00:46
#   Progress:  Solving step 139/365 (38.08% of time interval complete)
#   Stats:     296 iterations in 23.39 s (79.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  39%|▍|  ETA: 0:00:45
#   Progress:  Solving step 141/365 (38.63% of time interval complete)
#   Stats:     300 iterations in 23.53 s (78.44 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  39%|▍|  ETA: 0:00:45
#   Progress:  Solving step 143/365 (39.18% of time interval complete)
#   Stats:     304 iterations in 23.68 s (77.90 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  40%|▍|  ETA: 0:00:44
#   Progress:  Solving step 145/365 (39.73% of time interval complete)
#   Stats:     308 iterations in 23.83 s (77.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  40%|▍|  ETA: 0:00:43
#   Progress:  Solving step 147/365 (40.27% of time interval complete)
#   Stats:     312 iterations in 23.98 s (76.86 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  41%|▍|  ETA: 0:00:42
#   Progress:  Solving step 149/365 (40.82% of time interval complete)
#   Stats:     316 iterations in 24.13 s (76.36 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  41%|▍|  ETA: 0:00:42
#   Progress:  Solving step 151/365 (41.37% of time interval complete)
#   Stats:     320 iterations in 24.28 s (75.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  42%|▍|  ETA: 0:00:41
#   Progress:  Solving step 153/365 (41.92% of time interval complete)
#   Stats:     324 iterations in 24.43 s (75.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  42%|▍|  ETA: 0:00:40
#   Progress:  Solving step 155/365 (42.47% of time interval complete)
#   Stats:     328 iterations in 24.57 s (74.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  43%|▍|  ETA: 0:00:40
#   Progress:  Solving step 157/365 (43.01% of time interval complete)
#   Stats:     332 iterations in 24.73 s (74.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  43%|▍|  ETA: 0:00:39
#   Progress:  Solving step 159/365 (43.56% of time interval complete)
#   Stats:     336 iterations in 24.88 s (74.04 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  44%|▌|  ETA: 0:00:38
#   Progress:  Solving step 161/365 (44.11% of time interval complete)
#   Stats:     340 iterations in 25.03 s (73.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  45%|▌|  ETA: 0:00:38
#   Progress:  Solving step 163/365 (44.66% of time interval complete)
#   Stats:     344 iterations in 25.18 s (73.19 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  45%|▌|  ETA: 0:00:37
#   Progress:  Solving step 165/365 (45.21% of time interval complete)
#   Stats:     348 iterations in 25.33 s (72.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  46%|▌|  ETA: 0:00:36
#   Progress:  Solving step 167/365 (45.75% of time interval complete)
#   Stats:     352 iterations in 25.48 s (72.38 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  46%|▌|  ETA: 0:00:36
#   Progress:  Solving step 169/365 (46.30% of time interval complete)
#   Stats:     356 iterations in 25.63 s (71.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  47%|▌|  ETA: 0:00:35
#   Progress:  Solving step 171/365 (46.85% of time interval complete)
#   Stats:     360 iterations in 25.79 s (71.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  47%|▌|  ETA: 0:00:34
#   Progress:  Solving step 173/365 (47.40% of time interval complete)
#   Stats:     364 iterations in 25.94 s (71.26 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  48%|▌|  ETA: 0:00:34
#   Progress:  Solving step 175/365 (47.95% of time interval complete)
#   Stats:     368 iterations in 26.09 s (70.90 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  48%|▌|  ETA: 0:00:33
#   Progress:  Solving step 177/365 (48.49% of time interval complete)
#   Stats:     372 iterations in 26.24 s (70.55 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  49%|▌|  ETA: 0:00:33
#   Progress:  Solving step 179/365 (49.04% of time interval complete)
#   Stats:     376 iterations in 26.40 s (70.22 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  49%|▌|  ETA: 0:00:32
#   Progress:  Solving step 181/365 (49.59% of time interval complete)
#   Stats:     380 iterations in 26.56 s (69.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  50%|▌|  ETA: 0:00:32
#   Progress:  Solving step 183/365 (50.14% of time interval complete)
#   Stats:     384 iterations in 26.71 s (69.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  51%|▌|  ETA: 0:00:31
#   Progress:  Solving step 185/365 (50.68% of time interval complete)
#   Stats:     388 iterations in 26.87 s (69.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  51%|▌|  ETA: 0:00:31
#   Progress:  Solving step 187/365 (51.23% of time interval complete)
#   Stats:     392 iterations in 27.10 s (69.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  52%|▌|  ETA: 0:00:30
#   Progress:  Solving step 189/365 (51.78% of time interval complete)
#   Stats:     396 iterations in 27.25 s (68.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  52%|▌|  ETA: 0:00:30
#   Progress:  Solving step 191/365 (52.33% of time interval complete)
#   Stats:     400 iterations in 27.40 s (68.50 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  53%|▌|  ETA: 0:00:29
#   Progress:  Solving step 193/365 (52.88% of time interval complete)
#   Stats:     404 iterations in 27.55 s (68.20 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  53%|▌|  ETA: 0:00:29
#   Progress:  Solving step 195/365 (53.42% of time interval complete)
#   Stats:     408 iterations in 27.70 s (67.90 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  54%|▌|  ETA: 0:00:28
#   Progress:  Solving step 197/365 (53.97% of time interval complete)
#   Stats:     412 iterations in 27.86 s (67.62 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  54%|▌|  ETA: 0:00:28
#   Progress:  Solving step 199/365 (54.52% of time interval complete)
#   Stats:     416 iterations in 28.01 s (67.34 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  55%|▌|  ETA: 0:00:27
#   Progress:  Solving step 201/365 (55.07% of time interval complete)
#   Stats:     420 iterations in 28.17 s (67.07 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  55%|▌|  ETA: 0:00:27
#   Progress:  Solving step 203/365 (55.62% of time interval complete)
#   Stats:     424 iterations in 28.32 s (66.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  56%|▌|  ETA: 0:00:26
#   Progress:  Solving step 205/365 (56.16% of time interval complete)
#   Stats:     428 iterations in 28.48 s (66.55 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  57%|▋|  ETA: 0:00:26
#   Progress:  Solving step 207/365 (56.71% of time interval complete)
#   Stats:     431 iterations in 28.61 s (66.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  57%|▋|  ETA: 0:00:25
#   Progress:  Solving step 210/365 (57.53% of time interval complete)
#   Stats:     434 iterations in 28.73 s (66.20 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  58%|▋|  ETA: 0:00:24
#   Progress:  Solving step 213/365 (58.36% of time interval complete)
#   Stats:     437 iterations in 28.86 s (66.03 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  59%|▋|  ETA: 0:00:24
#   Progress:  Solving step 216/365 (59.18% of time interval complete)
#   Stats:     440 iterations in 28.99 s (65.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  60%|▋|  ETA: 0:00:23
#   Progress:  Solving step 219/365 (60.00% of time interval complete)
#   Stats:     443 iterations in 29.12 s (65.74 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:22
#   Progress:  Solving step 222/365 (60.82% of time interval complete)
#   Stats:     446 iterations in 29.26 s (65.60 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:22
#   Progress:  Solving step 225/365 (61.64% of time interval complete)
#   Stats:     449 iterations in 29.40 s (65.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  62%|▋|  ETA: 0:00:21
#   Progress:  Solving step 227/365 (62.19% of time interval complete)
#   Stats:     451 iterations in 29.50 s (65.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:21
#   Progress:  Solving step 229/365 (62.74% of time interval complete)
#   Stats:     453 iterations in 29.61 s (65.36 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:20
#   Progress:  Solving step 231/365 (63.29% of time interval complete)
#   Stats:     455 iterations in 29.72 s (65.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:20
#   Progress:  Solving step 233/365 (63.84% of time interval complete)
#   Stats:     457 iterations in 29.83 s (65.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:19
#   Progress:  Solving step 235/365 (64.38% of time interval complete)
#   Stats:     459 iterations in 29.95 s (65.24 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:19
#   Progress:  Solving step 237/365 (64.93% of time interval complete)
#   Stats:     461 iterations in 30.06 s (65.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:19
#   Progress:  Solving step 239/365 (65.48% of time interval complete)
#   Stats:     463 iterations in 30.18 s (65.19 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:18
#   Progress:  Solving step 241/365 (66.03% of time interval complete)
#   Stats:     465 iterations in 30.30 s (65.17 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:18
#   Progress:  Solving step 243/365 (66.58% of time interval complete)
#   Stats:     467 iterations in 30.43 s (65.15 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:18
#   Progress:  Solving step 245/365 (67.12% of time interval complete)
#   Stats:     469 iterations in 30.55 s (65.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:17
#   Progress:  Solving step 247/365 (67.67% of time interval complete)
#   Stats:     471 iterations in 30.67 s (65.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:17
#   Progress:  Solving step 249/365 (68.22% of time interval complete)
#   Stats:     473 iterations in 30.79 s (65.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▋|  ETA: 0:00:16
#   Progress:  Solving step 251/365 (68.77% of time interval complete)
#   Stats:     475 iterations in 30.92 s (65.09 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:16
#   Progress:  Solving step 253/365 (69.32% of time interval complete)
#   Stats:     477 iterations in 31.03 s (65.06 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:16
#   Progress:  Solving step 255/365 (69.86% of time interval complete)
#   Stats:     479 iterations in 31.15 s (65.03 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:15
#   Progress:  Solving step 257/365 (70.41% of time interval complete)
#   Stats:     481 iterations in 31.26 s (64.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  71%|▊|  ETA: 0:00:15
#   Progress:  Solving step 259/365 (70.96% of time interval complete)
#   Stats:     483 iterations in 31.37 s (64.94 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  71%|▊|  ETA: 0:00:15
#   Progress:  Solving step 261/365 (71.51% of time interval complete)
#   Stats:     485 iterations in 31.47 s (64.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  72%|▊|  ETA: 0:00:14
#   Progress:  Solving step 264/365 (72.33% of time interval complete)
#   Stats:     488 iterations in 31.61 s (64.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  73%|▊|  ETA: 0:00:14
#   Progress:  Solving step 267/365 (73.15% of time interval complete)
#   Stats:     491 iterations in 31.76 s (64.68 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  74%|▊|  ETA: 0:00:13
#   Progress:  Solving step 270/365 (73.97% of time interval complete)
#   Stats:     494 iterations in 31.90 s (64.58 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  75%|▊|  ETA: 0:00:13
#   Progress:  Solving step 273/365 (74.79% of time interval complete)
#   Stats:     497 iterations in 32.04 s (64.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  75%|▊|  ETA: 0:00:12
#   Progress:  Solving step 276/365 (75.62% of time interval complete)
#   Stats:     500 iterations in 32.18 s (64.35 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  76%|▊|  ETA: 0:00:12
#   Progress:  Solving step 279/365 (76.44% of time interval complete)
#   Stats:     503 iterations in 32.31 s (64.23 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  77%|▊|  ETA: 0:00:11
#   Progress:  Solving step 282/365 (77.26% of time interval complete)
#   Stats:     506 iterations in 32.43 s (64.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  78%|▊|  ETA: 0:00:11
#   Progress:  Solving step 285/365 (78.08% of time interval complete)
#   Stats:     509 iterations in 32.56 s (63.97 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  79%|▊|  ETA: 0:00:10
#   Progress:  Solving step 288/365 (78.90% of time interval complete)
#   Stats:     512 iterations in 32.68 s (63.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  80%|▊|  ETA: 0:00:10
#   Progress:  Solving step 291/365 (79.73% of time interval complete)
#   Stats:     515 iterations in 32.81 s (63.70 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  80%|▊|  ETA: 0:00:09
#   Progress:  Solving step 294/365 (80.55% of time interval complete)
#   Stats:     518 iterations in 32.93 s (63.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  81%|▊|  ETA: 0:00:09
#   Progress:  Solving step 296/365 (81.10% of time interval complete)
#   Stats:     520 iterations in 33.08 s (63.62 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  82%|▉|  ETA: 0:00:09
#   Progress:  Solving step 299/365 (81.92% of time interval complete)
#   Stats:     524 iterations in 33.23 s (63.42 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  83%|▉|  ETA: 0:00:08
#   Progress:  Solving step 302/365 (82.74% of time interval complete)
#   Stats:     527 iterations in 33.35 s (63.28 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  83%|▉|  ETA: 0:00:08
#   Progress:  Solving step 305/365 (83.56% of time interval complete)
#   Stats:     530 iterations in 33.46 s (63.13 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  84%|▉|  ETA: 0:00:07
#   Progress:  Solving step 308/365 (84.38% of time interval complete)
#   Stats:     533 iterations in 33.57 s (62.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  85%|▉|  ETA: 0:00:07
#   Progress:  Solving step 311/365 (85.21% of time interval complete)
#   Stats:     536 iterations in 33.68 s (62.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  86%|▉|  ETA: 0:00:06
#   Progress:  Solving step 314/365 (86.03% of time interval complete)
#   Stats:     539 iterations in 33.79 s (62.70 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  87%|▉|  ETA: 0:00:06
#   Progress:  Solving step 317/365 (86.85% of time interval complete)
#   Stats:     542 iterations in 33.90 s (62.55 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  87%|▉|  ETA: 0:00:06
#   Progress:  Solving step 320/365 (87.67% of time interval complete)
#   Stats:     545 iterations in 34.02 s (62.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  88%|▉|  ETA: 0:00:05
#   Progress:  Solving step 323/365 (88.49% of time interval complete)
#   Stats:     548 iterations in 34.12 s (62.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  89%|▉|  ETA: 0:00:05
#   Progress:  Solving step 326/365 (89.32% of time interval complete)
#   Stats:     551 iterations in 34.24 s (62.13 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  90%|▉|  ETA: 0:00:04
#   Progress:  Solving step 329/365 (90.14% of time interval complete)
#   Stats:     554 iterations in 34.34 s (61.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  91%|▉|  ETA: 0:00:04
#   Progress:  Solving step 332/365 (90.96% of time interval complete)
#   Stats:     557 iterations in 34.45 s (61.85 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  92%|▉|  ETA: 0:00:04
#   Progress:  Solving step 335/365 (91.78% of time interval complete)
#   Stats:     560 iterations in 34.56 s (61.71 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  92%|▉|  ETA: 0:00:03
#   Progress:  Solving step 338/365 (92.60% of time interval complete)
#   Stats:     563 iterations in 34.67 s (61.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  93%|▉|  ETA: 0:00:03
#   Progress:  Solving step 341/365 (93.42% of time interval complete)
#   Stats:     566 iterations in 34.78 s (61.44 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  94%|█|  ETA: 0:00:03
#   Progress:  Solving step 344/365 (94.25% of time interval complete)
#   Stats:     569 iterations in 34.89 s (61.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  95%|█|  ETA: 0:00:02
#   Progress:  Solving step 347/365 (95.07% of time interval complete)
#   Stats:     572 iterations in 34.99 s (61.18 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  96%|█|  ETA: 0:00:02
#   Progress:  Solving step 350/365 (95.89% of time interval complete)
#   Stats:     575 iterations in 35.10 s (61.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  96%|█|  ETA: 0:00:01
#   Progress:  Solving step 353/365 (96.71% of time interval complete)
#   Stats:     578 iterations in 35.21 s (60.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  97%|█|  ETA: 0:00:01
#   Progress:  Solving step 356/365 (97.53% of time interval complete)
#   Stats:     581 iterations in 35.32 s (60.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  98%|█|  ETA: 0:00:01
#   Progress:  Solving step 359/365 (98.36% of time interval complete)
#   Stats:     584 iterations in 35.43 s (60.67 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  99%|█|  ETA: 0:00:00
#   Progress:  Solving step 362/365 (99.18% of time interval complete)
#   Stats:     587 iterations in 35.54 s (60.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  99%|█|  ETA: 0:00:00
#   Progress:  Solving step 365/365 (100.00% of time interval complete)
#   Stats:     590 iterations in 35.64 s (60.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps 100%|█| Time: 0:00:40
#   Progress:  Solved step 365/365
#   Stats:     591 iterations in 35.68 s (60.37 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │    Total │
# │                │ 365 steps │ 367 ministeps │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┤
# │ Newton         │   1.61918 │       1.61035 │  591 (0) │
# │ Linearization  │   2.62466 │       2.61035 │  958 (0) │
# │ Linear solver  │   3.17534 │       3.15804 │ 1159 (0) │
# │ Precond apply  │   6.35068 │       6.31608 │ 2318 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬─────────╮
# │ Timing type   │    Each │   Relative │   Total │
# │               │      ms │ Percentage │       s │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Properties    │ 32.3108 │    53.52 % │ 19.0957 │
# │ Equations     │  5.1989 │    13.96 % │  4.9806 │
# │ Assembly      │  4.0828 │    10.96 % │  3.9113 │
# │ Linear solve  │  2.5579 │     4.24 % │  1.5117 │
# │ Linear setup  │  2.7171 │     4.50 % │  1.6058 │
# │ Precond apply │  0.6952 │     4.52 % │  1.6115 │
# │ Update        │  1.1651 │     1.93 % │  0.6885 │
# │ Convergence   │  1.3691 │     3.68 % │  1.3116 │
# │ Input/Output  │  0.3119 │     0.32 % │  0.1145 │
# │ Other         │  1.4331 │     2.37 % │  0.8470 │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Total         │ 60.3689 │   100.00 % │ 35.6780 │
# ╰───────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 365 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :orat => Vector{Float64} of size (365,)
#        :N2-CH4_mass_rate => Vector{Float64} of size (365,)
#        :C6-13_mass_rate => Vector{Float64} of size (365,)
#        :C14-24_mass_rate => Vector{Float64} of size (365,)
#        :C2-5_mass_rate => Vector{Float64} of size (365,)
#        :bhp => Vector{Float64} of size (365,)
#        :lrat => Vector{Float64} of size (365,)
#        :CO2_mass_rate => Vector{Float64} of size (365,)
#        :mass_rate => Vector{Float64} of size (365,)
#        :rate => Vector{Float64} of size (365,)
#        :control => Vector{Symbol} of size (365,)
#        :grat => Vector{Float64} of size (365,)
#
#   states (Vector with 365 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (5, 800)
#     :OverallMoleFractions => Matrix{Float64} of size (5, 800)
#     :Saturations => Matrix{Float64} of size (2, 800)
#     :Pressure => Vector{Float64} of size (800,)
#     :VaporMassFractions => Matrix{Float64} of size (5, 800)
#     :TotalMasses => Matrix{Float64} of size (5, 800)
#
#   time (report time for each state)
#      Vector{Float64} of length 365
#
#   result (extended states, reports)
#      SimResult with 365 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 25 2024 16:06 after 35 seconds, 563 milliseconds, 583.5 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# ### CO2 mole fraction

# %%
sg = states[end][:OverallMoleFractions][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Gas saturation

# %%
sg = states[end][:Saturations][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Pressure

# %%
p = states[end][:Pressure]
fig, ax, p = plot_cell_data(g, p)
fig
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
