# %% [markdown]
# # Example demonstrating compositional flow
# This is a simple conceptual example demonstrating how to solve compositional
# flow. This example uses a two-component water-CO2 system. Note that the
# default Peng-Robinson is not accurate for this system without adjustments to
# the parameters. However, the example demonstrates the conceptual workflow for
# getting started with compositional simulation.
# ## Set up mixture
# We load the external flash package and define a two-component H2O-CO2 system.
# The constructor for each species takes in molecular weight, critical pressure,
# critical temperature, critical volume, acentric factor given as strict SI.
# This means, for instance, that molar masses are given in kg/mole and not
# g/mole or kg/kmol.

# %%
using MultiComponentFlash
h2o = MolecularProperty(0.018015268, 22.064e6, 647.096, 5.595e-05, 0.3442920843)
co2 = MolecularProperty(0.0440098, 7.3773e6, 304.1282, 9.412e-05, 0.22394)

bic = zeros(2, 2)

mixture = MultiComponentMixture([h2o, co2], A_ij = bic, names = ["H2O", "CO2"])
eos = GenericCubicEOS(mixture, PengRobinson())
# Out:
# MultiComponentFlash.GenericCubicEOS{MultiComponentFlash.PengRobinson, Float64, 2, Nothing}(MultiComponentFlash.PengRobinson(), MultiComponentFlash.MultiComponentMixture{Float64, 2}("UnnamedMixture", ["H2O", "CO2"], (MultiComponentFlash.MolecularProperty{Float64}(0.018015268, 2.2064e7, 647.096, 5.595e-5, 0.3442920843), MultiComponentFlash.MolecularProperty{Float64}(0.0440098, 7.3773e6, 304.1282, 9.412e-5, 0.22394)), [0.0 0.0; 0.0 0.0]), 2.414213562373095, -0.41421356237309515, 0.457235529, 0.077796074, nothing)

# %% [markdown]
# ## Set up domain and wells

# %%
using Jutul, JutulDarcy, GLMakie
nx = 50
ny = 1
nz = 20
dims = (nx, ny, nz)
g = CartesianMesh(dims, (100.0, 10.0, 10.0))
nc = number_of_cells(g)
Darcy, bar, kg, meter, Kelvin, day, sec = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day, :second)
K = repeat([0.1, 0.1, 0.001]*Darcy, 1, nc)
res = reservoir_domain(g, porosity = 0.3, permeability = K)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 50x1x20=1000 cells with 17 data fields added:
#   1000 Cells
#     :permeability => 3×1000 Matrix{Float64}
#     :porosity => 1000 Vector{Float64}
#     :rock_thermal_conductivity => 1000 Vector{Float64}
#     :fluid_thermal_conductivity => 1000 Vector{Float64}
#     :rock_density => 1000 Vector{Float64}
#     :cell_centroids => 3×1000 Matrix{Float64}
#     :volumes => 1000 Vector{Float64}
#   1930 Faces
#     :neighbors => 2×1930 Matrix{Int64}
#     :areas => 1930 Vector{Float64}
#     :normals => 3×1930 Matrix{Float64}
#     :face_centroids => 3×1930 Matrix{Float64}
#   3860 HalfFaces
#     :half_face_cells => 3860 Vector{Int64}
#     :half_face_faces => 3860 Vector{Int64}
#   2140 BoundaryFaces
#     :boundary_areas => 2140 Vector{Float64}
#     :boundary_centroids => 3×2140 Matrix{Float64}
#     :boundary_normals => 3×2140 Matrix{Float64}
#     :boundary_neighbors => 2140 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in top layer

# %%
prod = setup_well(g, K, [(nx, ny, 1)], name = :Producer)
# Out:
# MultiSegmentWell [Producer] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in bottom layer

# %%
inj = setup_well(g, K, [(1, 1, nz)], name = :Injector)
# Out:
# MultiSegmentWell [Injector] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# ## Define system and realize on grid

# %%
rhoLS = 844.23*kg/meter^3
rhoVS = 126.97*kg/meter^3
rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod]);
push!(model[:Reservoir].output_variables, :Saturations)
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)
T0 = repeat([303.15*Kelvin], 1, nc)
parameters[:Reservoir][:Temperature] = T0
state0 = setup_reservoir_state(model, Pressure = 50*bar, OverallMoleFractions = [1.0, 0.0]);

# %% [markdown]
# ## Define schedule
# 5 year (5*365.24 days) simulation period

# %%
dt0 = repeat([1]*day, 26)
dt1 = repeat([10.0]*day, 180)
dt = append!(dt0, dt1)
rate_target = TotalRateTarget(9.5066e-06*meter^3/sec)
I_ctrl = InjectorControl(rate_target, [0, 1], density = rhoVS)
bhp_target = BottomHolePressureTarget(50*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 4 years, 52.15 weeks as 206 report steps   1%  ETA: 0:17:21
#   Progress:  Solving step 2/206 (0.11% of time interval complete)
#   Stats:     6 iterations in 5.90 s (983.45 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps   5%  ETA: 0:03:04
#   Progress:  Solving step 11/206 (0.60% of time interval complete)
#   Stats:     28 iterations in 6.09 s (217.59 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  11%  ETA: 0:01:28
#   Progress:  Solving step 22/206 (1.20% of time interval complete)
#   Stats:     50 iterations in 6.20 s (123.93 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  16%  ETA: 0:00:56
#   Progress:  Solving step 33/206 (5.26% of time interval complete)
#   Stats:     80 iterations in 6.34 s (79.29 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  19%  ETA: 0:00:45
#   Progress:  Solving step 40/206 (9.09% of time interval complete)
#   Stats:     101 iterations in 6.46 s (64.01 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  22%  ETA: 0:00:38
#   Progress:  Solving step 46/206 (12.38% of time interval complete)
#   Stats:     117 iterations in 6.57 s (56.14 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  25%  ETA: 0:00:33
#   Progress:  Solving step 52/206 (15.66% of time interval complete)
#   Stats:     134 iterations in 6.69 s (49.90 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  28%  ETA: 0:00:29
#   Progress:  Solving step 57/206 (18.40% of time interval complete)
#   Stats:     149 iterations in 6.80 s (45.63 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  30%  ETA: 0:00:26
#   Progress:  Solving step 62/206 (21.14% of time interval complete)
#   Stats:     164 iterations in 6.92 s (42.17 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  32%  ETA: 0:00:24
#   Progress:  Solving step 67/206 (23.88% of time interval complete)
#   Stats:     178 iterations in 7.03 s (39.51 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  34%  ETA: 0:00:22
#   Progress:  Solving step 71/206 (26.07% of time interval complete)
#   Stats:     190 iterations in 7.14 s (37.56 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  36%  ETA: 0:00:20
#   Progress:  Solving step 75/206 (28.26% of time interval complete)
#   Stats:     203 iterations in 7.25 s (35.73 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  38%  ETA: 0:00:19
#   Progress:  Solving step 79/206 (30.45% of time interval complete)
#   Stats:     215 iterations in 7.36 s (34.25 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  40%  ETA: 0:00:18
#   Progress:  Solving step 83/206 (32.64% of time interval complete)
#   Stats:     230 iterations in 7.50 s (32.63 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  43%  ETA: 0:00:16
#   Progress:  Solving step 89/206 (35.93% of time interval complete)
#   Stats:     242 iterations in 7.62 s (31.50 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  45%  ETA: 0:00:14
#   Progress:  Solving step 94/206 (38.66% of time interval complete)
#   Stats:     252 iterations in 7.73 s (30.66 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  48%  ETA: 0:00:13
#   Progress:  Solving step 99/206 (41.40% of time interval complete)
#   Stats:     263 iterations in 7.84 s (29.79 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  50%  ETA: 0:00:12
#   Progress:  Solving step 104/206 (44.14% of time interval complete)
#   Stats:     273 iterations in 7.94 s (29.07 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  53%  ETA: 0:00:11
#   Progress:  Solving step 109/206 (46.88% of time interval complete)
#   Stats:     283 iterations in 8.04 s (28.40 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  56%  ETA: 0:00:10
#   Progress:  Solving step 115/206 (50.16% of time interval complete)
#   Stats:     294 iterations in 8.15 s (27.73 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  58%  ETA: 0:00:09
#   Progress:  Solving step 121/206 (53.45% of time interval complete)
#   Stats:     304 iterations in 8.25 s (27.15 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  61%  ETA: 0:00:08
#   Progress:  Solving step 127/206 (56.74% of time interval complete)
#   Stats:     316 iterations in 8.37 s (26.49 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  64%  ETA: 0:00:07
#   Progress:  Solving step 132/206 (59.47% of time interval complete)
#   Stats:     326 iterations in 8.48 s (26.01 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  66%  ETA: 0:00:07
#   Progress:  Solving step 137/206 (62.21% of time interval complete)
#   Stats:     336 iterations in 8.58 s (25.54 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  69%  ETA: 0:00:06
#   Progress:  Solving step 142/206 (64.95% of time interval complete)
#   Stats:     346 iterations in 8.69 s (25.10 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  71%  ETA: 0:00:05
#   Progress:  Solving step 147/206 (67.69% of time interval complete)
#   Stats:     356 iterations in 8.79 s (24.68 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  73%  ETA: 0:00:05
#   Progress:  Solving step 152/206 (70.43% of time interval complete)
#   Stats:     366 iterations in 8.89 s (24.29 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  76%  ETA: 0:00:04
#   Progress:  Solving step 157/206 (73.17% of time interval complete)
#   Stats:     376 iterations in 9.00 s (23.92 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  78%  ETA: 0:00:04
#   Progress:  Solving step 162/206 (75.90% of time interval complete)
#   Stats:     386 iterations in 9.10 s (23.57 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  81%  ETA: 0:00:03
#   Progress:  Solving step 167/206 (78.64% of time interval complete)
#   Stats:     396 iterations in 9.20 s (23.24 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  83%  ETA: 0:00:03
#   Progress:  Solving step 172/206 (81.38% of time interval complete)
#   Stats:     406 iterations in 9.30 s (22.91 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  86%  ETA: 0:00:02
#   Progress:  Solving step 177/206 (84.12% of time interval complete)
#   Stats:     416 iterations in 9.40 s (22.60 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  88%  ETA: 0:00:02
#   Progress:  Solving step 182/206 (86.86% of time interval complete)
#   Stats:     426 iterations in 9.51 s (22.31 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  90%  ETA: 0:00:01
#   Progress:  Solving step 187/206 (89.59% of time interval complete)
#   Stats:     436 iterations in 9.61 s (22.04 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  93%  ETA: 0:00:01
#   Progress:  Solving step 193/206 (92.88% of time interval complete)
#   Stats:     448 iterations in 9.72 s (21.70 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  96%  ETA: 0:00:01
#   Progress:  Solving step 199/206 (96.17% of time interval complete)
#   Stats:     460 iterations in 9.84 s (21.39 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  99%  ETA: 0:00:00
#   Progress:  Solving step 205/206 (99.45% of time interval complete)
#   Stats:     472 iterations in 9.95 s (21.09 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps 100% Time: 0:00:14
#   Progress:  Solved step 206/206
#   Stats:     476 iterations in 9.99 s (20.99 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │    Total │
# │                │ 206 steps │ 207 ministeps │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┤
# │ Newton         │   2.31068 │       2.29952 │  476 (0) │
# │ Linearization  │   3.31553 │       3.29952 │  683 (0) │
# │ Linear solver  │   9.96602 │       9.91787 │ 2053 (0) │
# │ Precond apply  │    19.932 │       19.8357 │ 4106 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬────────╮
# │ Timing type   │    Each │   Relative │  Total │
# │               │      ms │ Percentage │      s │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Properties    │  5.5108 │    26.25 % │ 2.6232 │
# │ Equations     │  5.1554 │    35.24 % │ 3.5212 │
# │ Assembly      │  1.8567 │    12.69 % │ 1.2681 │
# │ Linear solve  │  0.1997 │     0.95 % │ 0.0951 │
# │ Linear setup  │  1.1150 │     5.31 % │ 0.5307 │
# │ Precond apply │  0.0996 │     4.09 % │ 0.4091 │
# │ Update        │  0.6175 │     2.94 % │ 0.2939 │
# │ Convergence   │  1.5246 │    10.42 % │ 1.0413 │
# │ Input/Output  │  0.1495 │     0.31 % │ 0.0310 │
# │ Other         │  0.3771 │     1.80 % │ 0.1795 │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Total         │ 20.9936 │   100.00 % │ 9.9930 │
# ╰───────────────┴─────────┴────────────┴────────╯
# ReservoirSimResult with 206 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :H2O_mass_rate => Vector{Float64} of size (206,)
#        :lrat => Vector{Float64} of size (206,)
#        :orat => Vector{Float64} of size (206,)
#        :control => Vector{Symbol} of size (206,)
#        :bhp => Vector{Float64} of size (206,)
#        :CO2_mass_rate => Vector{Float64} of size (206,)
#        :mass_rate => Vector{Float64} of size (206,)
#        :rate => Vector{Float64} of size (206,)
#        :grat => Vector{Float64} of size (206,)
#
#   states (Vector with 206 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (2, 1000)
#     :OverallMoleFractions => Matrix{Float64} of size (2, 1000)
#     :Saturations => Matrix{Float64} of size (2, 1000)
#     :Pressure => Vector{Float64} of size (1000,)
#     :VaporMassFractions => Matrix{Float64} of size (2, 1000)
#     :TotalMasses => Matrix{Float64} of size (2, 1000)
#
#   time (report time for each state)
#      Vector{Float64} of length 206
#
#   result (extended states, reports)
#      SimResult with 206 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 25 2024 16:06 after 9 seconds, 962 milliseconds, 4.547 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# Note that this example is intended for static publication in the
# documentation. For interactive visualization you can use functions like
# `plot_interactive` to interactively visualize the states.

# %%
z = states[end][:OverallMoleFractions][2, :]
function plot_vertical(x, t)
    data = reshape(x, (nx, nz))
    data = data[:, end:-1:1]
    fig, ax, plot = heatmap(data)
    ax.title = t
    Colorbar(fig[1, 2], plot)
    fig
end
# Out:
# plot_vertical (generic function with 1 method)

# %% [markdown]
# ### Plot final CO2 mole fraction

# %%
plot_vertical(z, "CO2")
# Out:
# Figure()

# %% [markdown]
# ### Plot final vapor saturation

# %%
sg = states[end][:Saturations][2, :]
plot_vertical(sg, "Vapor saturation")
# Out:
# Figure()

# %% [markdown]
# ### Plot final pressure

# %%
p = states[end][:Pressure]
plot_vertical(p./bar, "Pressure [bar]")
# Out:
# Figure()

# %% [markdown]
# ### Plot in interactive viewer

# %%
plot_reservoir(model, states, step = length(dt), key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
