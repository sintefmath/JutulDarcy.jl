# %% [markdown]
# # Simulating Eclipse/DATA input files
# The DATA format is commonly used in reservoir simulation. JutulDarcy can set
# up cases on this format and includes a fully featured grid builder for
# corner-point grids. Once a case has been set up, it uses the same types as a
# regular JutulDarcy simulation, allowing modification and use of the case in
# differentiable workflows.
#
# We begin by loading the SPE9 dataset via the GeoEnergyIO package.

# %%
using JutulDarcy
pth = JutulDarcy.GeoEnergyIO.test_input_file_path("spe9", "SPE9_CP.DATA", base = "opm-tests")
# Out:
# "/home/runner/.julia/packages/GeoEnergyIO/n4JvC/src/../test/data/opm-tests/spe9/SPE9_CP.DATA"

# %% [markdown]
# ## Set up and run a simulation
# If we do not need the case, we could also have done:
# ws, states = simulate_data_file(pth)

# %%
case = setup_case_from_data_file(pth)
ws, states = simulate_reservoir(case)
# Out:
# Simulating 2 years, 24.22 weeks as 90 report steps   2%| |  ETA: 0:04:58
#   Progress:  Solving step 2/90 (2.22% of time interval complete)
#   Stats:     19 iterations in 5.45 s (286.64 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   3%| |  ETA: 0:03:21
#   Progress:  Solving step 3/90 (3.33% of time interval complete)
#   Stats:     25 iterations in 5.61 s (224.50 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   5%| |  ETA: 0:02:02
#   Progress:  Solving step 5/90 (5.56% of time interval complete)
#   Stats:     32 iterations in 5.81 s (181.64 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   8%|▏|  ETA: 0:01:27
#   Progress:  Solving step 7/90 (7.78% of time interval complete)
#   Stats:     39 iterations in 6.02 s (154.35 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   9%|▏|  ETA: 0:01:17
#   Progress:  Solving step 8/90 (8.89% of time interval complete)
#   Stats:     43 iterations in 6.14 s (142.87 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  11%|▏|  ETA: 0:01:01
#   Progress:  Solving step 10/90 (11.11% of time interval complete)
#   Stats:     49 iterations in 6.33 s (129.16 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  13%|▏|  ETA: 0:00:51
#   Progress:  Solving step 12/90 (13.33% of time interval complete)
#   Stats:     55 iterations in 6.52 s (118.49 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  15%|▏|  ETA: 0:00:44
#   Progress:  Solving step 14/90 (15.56% of time interval complete)
#   Stats:     63 iterations in 6.76 s (107.37 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  18%|▏|  ETA: 0:00:39
#   Progress:  Solving step 16/90 (17.78% of time interval complete)
#   Stats:     70 iterations in 6.98 s (99.65 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  24%|▎|  ETA: 0:00:29
#   Progress:  Solving step 22/90 (24.44% of time interval complete)
#   Stats:     88 iterations in 7.52 s (85.49 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  25%|▎|  ETA: 0:00:28
#   Progress:  Solving step 23/90 (25.56% of time interval complete)
#   Stats:     92 iterations in 7.64 s (83.03 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  27%|▎|  ETA: 0:00:25
#   Progress:  Solving step 25/90 (27.78% of time interval complete)
#   Stats:     99 iterations in 7.84 s (79.15 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  30%|▎|  ETA: 0:00:23
#   Progress:  Solving step 27/90 (30.00% of time interval complete)
#   Stats:     105 iterations in 8.02 s (76.36 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  32%|▍|  ETA: 0:00:21
#   Progress:  Solving step 29/90 (32.22% of time interval complete)
#   Stats:     111 iterations in 8.19 s (73.81 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  34%|▍|  ETA: 0:00:19
#   Progress:  Solving step 31/90 (34.44% of time interval complete)
#   Stats:     117 iterations in 8.37 s (71.57 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  35%|▍|  ETA: 0:00:19
#   Progress:  Solving step 32/90 (35.56% of time interval complete)
#   Stats:     124 iterations in 8.61 s (69.44 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  36%|▍|  ETA: 0:00:18
#   Progress:  Solving step 33/90 (36.67% of time interval complete)
#   Stats:     129 iterations in 8.76 s (67.91 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  37%|▍|  ETA: 0:00:18
#   Progress:  Solving step 34/90 (37.78% of time interval complete)
#   Stats:     133 iterations in 8.88 s (66.74 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  38%|▍|  ETA: 0:00:17
#   Progress:  Solving step 35/90 (38.89% of time interval complete)
#   Stats:     137 iterations in 8.99 s (65.65 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  40%|▍|  ETA: 0:00:17
#   Progress:  Solving step 36/90 (40.00% of time interval complete)
#   Stats:     142 iterations in 9.14 s (64.36 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  41%|▍|  ETA: 0:00:16
#   Progress:  Solving step 37/90 (41.11% of time interval complete)
#   Stats:     148 iterations in 9.32 s (62.94 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  42%|▍|  ETA: 0:00:16
#   Progress:  Solving step 38/90 (42.22% of time interval complete)
#   Stats:     156 iterations in 9.55 s (61.23 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  43%|▍|  ETA: 0:00:15
#   Progress:  Solving step 39/90 (43.33% of time interval complete)
#   Stats:     161 iterations in 9.70 s (60.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  44%|▌|  ETA: 0:00:15
#   Progress:  Solving step 40/90 (44.44% of time interval complete)
#   Stats:     166 iterations in 9.85 s (59.35 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  45%|▌|  ETA: 0:00:14
#   Progress:  Solving step 41/90 (45.56% of time interval complete)
#   Stats:     172 iterations in 10.04 s (58.35 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  46%|▌|  ETA: 0:00:14
#   Progress:  Solving step 42/90 (46.67% of time interval complete)
#   Stats:     176 iterations in 10.18 s (57.84 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  48%|▌|  ETA: 0:00:13
#   Progress:  Solving step 44/90 (48.89% of time interval complete)
#   Stats:     182 iterations in 10.37 s (57.00 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  51%|▌|  ETA: 0:00:12
#   Progress:  Solving step 46/90 (51.11% of time interval complete)
#   Stats:     189 iterations in 10.59 s (56.04 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  53%|▌|  ETA: 0:00:11
#   Progress:  Solving step 48/90 (53.33% of time interval complete)
#   Stats:     195 iterations in 10.78 s (55.27 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  54%|▌|  ETA: 0:00:11
#   Progress:  Solving step 49/90 (54.44% of time interval complete)
#   Stats:     199 iterations in 10.90 s (54.77 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  56%|▌|  ETA: 0:00:10
#   Progress:  Solving step 51/90 (56.67% of time interval complete)
#   Stats:     204 iterations in 11.05 s (54.18 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  58%|▋|  ETA: 0:00:09
#   Progress:  Solving step 53/90 (58.89% of time interval complete)
#   Stats:     210 iterations in 11.24 s (53.50 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  60%|▋|  ETA: 0:00:09
#   Progress:  Solving step 55/90 (61.11% of time interval complete)
#   Stats:     216 iterations in 11.42 s (52.85 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  63%|▋|  ETA: 0:00:08
#   Progress:  Solving step 57/90 (63.33% of time interval complete)
#   Stats:     221 iterations in 11.57 s (52.33 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  65%|▋|  ETA: 0:00:07
#   Progress:  Solving step 59/90 (65.56% of time interval complete)
#   Stats:     225 iterations in 11.69 s (51.97 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  67%|▋|  ETA: 0:00:07
#   Progress:  Solving step 61/90 (67.78% of time interval complete)
#   Stats:     231 iterations in 11.89 s (51.48 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  69%|▊|  ETA: 0:00:06
#   Progress:  Solving step 63/90 (70.00% of time interval complete)
#   Stats:     235 iterations in 12.01 s (51.13 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  71%|▊|  ETA: 0:00:06
#   Progress:  Solving step 65/90 (72.22% of time interval complete)
#   Stats:     240 iterations in 12.16 s (50.68 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  74%|▊|  ETA: 0:00:05
#   Progress:  Solving step 67/90 (74.44% of time interval complete)
#   Stats:     244 iterations in 12.29 s (50.36 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  76%|▊|  ETA: 0:00:04
#   Progress:  Solving step 69/90 (76.67% of time interval complete)
#   Stats:     248 iterations in 12.41 s (50.05 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  78%|▊|  ETA: 0:00:04
#   Progress:  Solving step 71/90 (78.89% of time interval complete)
#   Stats:     252 iterations in 12.54 s (49.74 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  80%|▊|  ETA: 0:00:04
#   Progress:  Solving step 73/90 (81.11% of time interval complete)
#   Stats:     256 iterations in 12.66 s (49.45 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  82%|▉|  ETA: 0:00:03
#   Progress:  Solving step 75/90 (83.33% of time interval complete)
#   Stats:     260 iterations in 12.78 s (49.16 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  85%|▉|  ETA: 0:00:03
#   Progress:  Solving step 77/90 (85.56% of time interval complete)
#   Stats:     264 iterations in 12.90 s (48.88 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  87%|▉|  ETA: 0:00:02
#   Progress:  Solving step 79/90 (87.78% of time interval complete)
#   Stats:     268 iterations in 13.03 s (48.60 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  89%|▉|  ETA: 0:00:02
#   Progress:  Solving step 81/90 (90.00% of time interval complete)
#   Stats:     272 iterations in 13.15 s (48.34 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  91%|▉|  ETA: 0:00:01
#   Progress:  Solving step 83/90 (92.22% of time interval complete)
#   Stats:     276 iterations in 13.28 s (48.13 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  93%|▉|  ETA: 0:00:01
#   Progress:  Solving step 85/90 (94.44% of time interval complete)
#   Stats:     281 iterations in 13.43 s (47.81 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  96%|█|  ETA: 0:00:01
#   Progress:  Solving step 87/90 (96.67% of time interval complete)
#   Stats:     285 iterations in 13.55 s (47.56 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  98%|█|  ETA: 0:00:00
#   Progress:  Solving step 89/90 (98.89% of time interval complete)
#   Stats:     290 iterations in 13.70 s (47.24 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps 100%|█| Time: 0:00:15
#   Progress:  Solved step 90/90
#   Stats:     294 iterations in 13.82 s (47.01 ms each)
# ╭────────────────┬──────────┬──────────────┬──────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │ Time per │    Total │
# │                │ 90 steps │ 95 ministeps │       ms │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┼──────────┤
# │ Newton         │  3.26667 │      3.09474 │  47.0099 │  294 (0) │
# │ Linearization  │  4.32222 │      4.09474 │  35.5293 │  389 (0) │
# │ Linear solver  │  11.8222 │         11.2 │  12.9896 │ 1064 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │  2.5046 │     5.33 % │  0.7364 │
# │ Equations      │ 10.3370 │    29.09 % │  4.0211 │
# │ Assembly       │  3.0813 │     8.67 % │  1.1986 │
# │ Linear solve   │ 10.3653 │    22.05 % │  3.0474 │
# │ Preconditioner │ 10.5078 │    22.35 % │  3.0893 │
# │ Update         │  1.9580 │     4.17 % │  0.5757 │
# │ Convergence    │  1.5126 │     4.26 % │  0.5884 │
# │ Input/Output   │  0.5551 │     0.38 % │  0.0527 │
# │ Other          │  1.7392 │     3.70 % │  0.5113 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 47.0099 │   100.00 % │ 13.8209 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 90 entries:
#
#   wells (26 present):
#     :INJE1
#     :PRODU25
#     :PRODU16
#     :PRODU20
#     :PRODU10
#     :PRODU12
#     :PRODU22
#     :PRODU14
#     :PRODU6
#     :PRODU7
#     :PRODU9
#     :PRODU24
#     :PRODU3
#     :PRODU23
#     :PRODU5
#     :PRODU11
#     :PRODU17
#     :PRODU4
#     :PRODU15
#     :PRODU2
#     :PRODU19
#     :PRODU21
#     :PRODU13
#     :PRODU8
#     :PRODU26
#     :PRODU18
#     Results per well:
#        :lrat => Vector{Float64} of size (90,)
#        :wrat => Vector{Float64} of size (90,)
#        :orat => Vector{Float64} of size (90,)
#        :control => Vector{Symbol} of size (90,)
#        :bhp => Vector{Float64} of size (90,)
#        :mass_rate => Vector{Float64} of size (90,)
#        :rate => Vector{Float64} of size (90,)
#        :grat => Vector{Float64} of size (90,)
#
#   states (Vector with 90 entries, reservoir variables for each state)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (9000,)
#     :Saturations => Matrix{Float64} of size (3, 9000)
#     :Pressure => Vector{Float64} of size (9000,)
#     :Rs => Vector{Float64} of size (9000,)
#     :ImmiscibleSaturation => Vector{Float64} of size (9000,)
#     :TotalMasses => Matrix{Float64} of size (3, 9000)
#
#   time (report time for each state)
#      Vector{Float64} of length 90
#
#   result (extended states, reports)
#      SimResult with 90 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at May. 06 2024 11:05 after 13 seconds, 768 milliseconds, 166.1 microseconds.

# %% [markdown]
# ## Show the input data
# The input data takes the form of a Dict:

# %%
case.input_data
# Out:
# Dict{String, Any} with 6 entries:
#   "RUNSPEC"  => OrderedDict{String, Any}("TITLE"=>"SPE 9", "DIMENS"=>[24, 25, 1…
#   "GRID"     => OrderedDict{String, Any}("cartDims"=>(24, 25, 15), "CURRENT_BOX…
#   "PROPS"    => OrderedDict{String, Any}("PVTW"=>Any[[2.48211e7, 1.0034, 4.3511…
#   "SUMMARY"  => OrderedDict{String, Any}()
#   "SCHEDULE" => Dict{String, Any}("STEPS"=>OrderedDict{String, Any}[OrderedDict…
#   "SOLUTION" => OrderedDict{String, Any}("EQUIL"=>Any[[2753.87, 2.48211e7, 3032…

# %% [markdown]
# We can also examine the RUNSPEC section

# %%
case.input_data["RUNSPEC"]
# Out:
# OrderedCollections.OrderedDict{String, Any} with 14 entries:
#   "TITLE"    => "SPE 9"
#   "DIMENS"   => [24, 25, 15]
#   "OIL"      => true
#   "WATER"    => true
#   "GAS"      => true
#   "DISGAS"   => true
#   "FIELD"    => true
#   "START"    => DateTime("2015-01-01T00:00:00")
#   "WELLDIMS" => [26, 5, 1, 26, 5, 10, 5, 4, 3, 0, 1, 1, 10, 201]
#   "TABDIMS"  => [1, 1, 40, 20, 1, 20, 20, 1, 1, -1  …  -1, 10, 10, 10, -1, 5, 5…
#   "EQLDIMS"  => [1, 100, 50, 1, 50]
#   "UNIFIN"   => true
#   "UNIFOUT"  => true
#   "MINPV"    => 2.83168e-8

# %% [markdown]
# ## Plot the simulation model
# These plot are interactive when run outside of the documentations.

# %%
using GLMakie
plot_reservoir(case.model, states)
# Out:
# Figure()

# %% [markdown]
# ## Plot the well responses

# %%
plot_well_results(ws)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
