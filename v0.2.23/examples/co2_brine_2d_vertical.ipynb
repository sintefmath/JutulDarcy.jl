# %% [markdown]
# # Example demonstrating compositional flow
# This is a simple conceptual example demonstrating how to solve compositional
# flow. This example uses a two-component water-CO2 system. Note that the
# default Peng-Robinson is not accurate for this system without adjustments to
# the parameters. However, the example demonstrates the conceptual workflow for
# getting started with compositional simulation.
# ## Set up mixture
# We load the external flash package and define a two-component H2O-CO2 system.
# The constructor for each species takes in molecular weight, critical pressure,
# critical temperature, critical volume, acentric factor given as strict SI.
# This means, for instance, that molar masses are given in kg/mole and not
# g/mole or kg/kmol.

# %%
using MultiComponentFlash
h2o = MolecularProperty(0.018015268, 22.064e6, 647.096, 5.595e-05, 0.3442920843)
co2 = MolecularProperty(0.0440098, 7.3773e6, 304.1282, 9.412e-05, 0.22394)

bic = zeros(2, 2)

mixture = MultiComponentMixture([h2o, co2], A_ij = bic, names = ["H2O", "CO2"])
eos = GenericCubicEOS(mixture, PengRobinson())
# Out:
# MultiComponentFlash.GenericCubicEOS{MultiComponentFlash.PengRobinson, Float64, 2, Nothing}(MultiComponentFlash.PengRobinson(), MultiComponentFlash.MultiComponentMixture{Float64, 2}("UnnamedMixture", ["H2O", "CO2"], (MultiComponentFlash.MolecularProperty{Float64}(0.018015268, 2.2064e7, 647.096, 5.595e-5, 0.3442920843), MultiComponentFlash.MolecularProperty{Float64}(0.0440098, 7.3773e6, 304.1282, 9.412e-5, 0.22394)), [0.0 0.0; 0.0 0.0]), 2.414213562373095, -0.41421356237309515, 0.457235529, 0.077796074, nothing)

# %% [markdown]
# ## Set up domain and wells

# %%
using Jutul, JutulDarcy, GLMakie
nx = 50
ny = 1
nz = 20
dims = (nx, ny, nz)
g = CartesianMesh(dims, (100.0, 10.0, 10.0))
nc = number_of_cells(g)
Darcy, bar, kg, meter, Kelvin, day, sec = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day, :second)
K = repeat([0.1, 0.1, 0.001]*Darcy, 1, nc)
res = reservoir_domain(g, porosity = 0.3, permeability = K)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 50x1x20=1000 cells with 17 data fields added:
#   1000 Cells
#     :permeability => 3×1000 Matrix{Float64}
#     :porosity => 1000 Vector{Float64}
#     :rock_thermal_conductivity => 1000 Vector{Float64}
#     :fluid_thermal_conductivity => 1000 Vector{Float64}
#     :rock_density => 1000 Vector{Float64}
#     :cell_centroids => 3×1000 Matrix{Float64}
#     :volumes => 1000 Vector{Float64}
#   1930 Faces
#     :neighbors => 2×1930 Matrix{Int64}
#     :areas => 1930 Vector{Float64}
#     :normals => 3×1930 Matrix{Float64}
#     :face_centroids => 3×1930 Matrix{Float64}
#   3860 HalfFaces
#     :half_face_cells => 3860 Vector{Int64}
#     :half_face_faces => 3860 Vector{Int64}
#   2140 BoundaryFaces
#     :boundary_areas => 2140 Vector{Float64}
#     :boundary_centroids => 3×2140 Matrix{Float64}
#     :boundary_normals => 3×2140 Matrix{Float64}
#     :boundary_neighbors => 2140 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in top layer

# %%
prod = setup_well(g, K, [(nx, ny, 1)], name = :Producer)
# Out:
# MultiSegmentWell [Producer] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in bottom layer

# %%
inj = setup_well(g, K, [(1, 1, nz)], name = :Injector)
# Out:
# MultiSegmentWell [Injector] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# ## Define system and realize on grid

# %%
rhoLS = 844.23*kg/meter^3
rhoVS = 126.97*kg/meter^3
rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod]);
push!(model[:Reservoir].output_variables, :Saturations)
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)
T0 = repeat([303.15*Kelvin], 1, nc)
parameters[:Reservoir][:Temperature] = T0
state0 = setup_reservoir_state(model, Pressure = 50*bar, OverallMoleFractions = [1.0, 0.0]);

# %% [markdown]
# ## Define schedule
# 5 year (5*365.24 days) simulation period

# %%
dt0 = repeat([1]*day, 26)
dt1 = repeat([10.0]*day, 180)
dt = append!(dt0, dt1)
rate_target = TotalRateTarget(9.5066e-06*meter^3/sec)
I_ctrl = InjectorControl(rate_target, [0, 1], density = rhoVS)
bhp_target = BottomHolePressureTarget(50*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 4 years, 52.15 weeks as 206 report steps   1%  ETA: 0:17:09
#   Progress:  Solving step 2/206 (0.11% of time interval complete)
#   Stats:     6 iterations in 5.90 s (983.56 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps   5%  ETA: 0:03:01
#   Progress:  Solving step 11/206 (0.60% of time interval complete)
#   Stats:     27 iterations in 6.00 s (222.34 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  11%  ETA: 0:01:26
#   Progress:  Solving step 22/206 (1.20% of time interval complete)
#   Stats:     49 iterations in 6.11 s (124.69 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  15%  ETA: 0:00:59
#   Progress:  Solving step 31/206 (4.16% of time interval complete)
#   Stats:     74 iterations in 6.24 s (84.26 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  18%  ETA: 0:00:47
#   Progress:  Solving step 38/206 (8.00% of time interval complete)
#   Stats:     95 iterations in 6.36 s (66.90 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  21%  ETA: 0:00:39
#   Progress:  Solving step 44/206 (11.28% of time interval complete)
#   Stats:     112 iterations in 6.46 s (57.70 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  24%  ETA: 0:00:34
#   Progress:  Solving step 50/206 (14.57% of time interval complete)
#   Stats:     130 iterations in 6.58 s (50.65 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  27%  ETA: 0:00:30
#   Progress:  Solving step 55/206 (17.31% of time interval complete)
#   Stats:     145 iterations in 6.74 s (46.49 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  29%  ETA: 0:00:27
#   Progress:  Solving step 60/206 (20.04% of time interval complete)
#   Stats:     160 iterations in 6.85 s (42.83 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  31%  ETA: 0:00:24
#   Progress:  Solving step 65/206 (22.78% of time interval complete)
#   Stats:     175 iterations in 6.97 s (39.84 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  33%  ETA: 0:00:22
#   Progress:  Solving step 69/206 (24.97% of time interval complete)
#   Stats:     187 iterations in 7.08 s (37.84 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  35%  ETA: 0:00:21
#   Progress:  Solving step 73/206 (27.16% of time interval complete)
#   Stats:     199 iterations in 7.18 s (36.10 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  37%  ETA: 0:00:19
#   Progress:  Solving step 77/206 (29.35% of time interval complete)
#   Stats:     211 iterations in 7.29 s (34.57 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  39%  ETA: 0:00:18
#   Progress:  Solving step 81/206 (31.54% of time interval complete)
#   Stats:     224 iterations in 7.42 s (33.10 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  41%  ETA: 0:00:17
#   Progress:  Solving step 85/206 (33.73% of time interval complete)
#   Stats:     235 iterations in 7.52 s (32.00 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  44%  ETA: 0:00:15
#   Progress:  Solving step 91/206 (37.02% of time interval complete)
#   Stats:     247 iterations in 7.64 s (30.92 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  47%  ETA: 0:00:13
#   Progress:  Solving step 97/206 (40.31% of time interval complete)
#   Stats:     259 iterations in 7.76 s (29.95 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  50%  ETA: 0:00:12
#   Progress:  Solving step 103/206 (43.59% of time interval complete)
#   Stats:     271 iterations in 7.87 s (29.05 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  53%  ETA: 0:00:11
#   Progress:  Solving step 109/206 (46.88% of time interval complete)
#   Stats:     283 iterations in 7.99 s (28.25 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  55%  ETA: 0:00:10
#   Progress:  Solving step 114/206 (49.62% of time interval complete)
#   Stats:     293 iterations in 8.10 s (27.64 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  58%  ETA: 0:00:09
#   Progress:  Solving step 120/206 (52.90% of time interval complete)
#   Stats:     305 iterations in 8.22 s (26.94 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  60%  ETA: 0:00:08
#   Progress:  Solving step 125/206 (55.64% of time interval complete)
#   Stats:     315 iterations in 8.32 s (26.40 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  63%  ETA: 0:00:07
#   Progress:  Solving step 130/206 (58.38% of time interval complete)
#   Stats:     325 iterations in 8.42 s (25.92 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  65%  ETA: 0:00:07
#   Progress:  Solving step 135/206 (61.12% of time interval complete)
#   Stats:     335 iterations in 8.53 s (25.48 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  68%  ETA: 0:00:06
#   Progress:  Solving step 140/206 (63.86% of time interval complete)
#   Stats:     345 iterations in 8.64 s (25.05 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  70%  ETA: 0:00:06
#   Progress:  Solving step 145/206 (66.59% of time interval complete)
#   Stats:     355 iterations in 8.75 s (24.65 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  72%  ETA: 0:00:05
#   Progress:  Solving step 150/206 (69.33% of time interval complete)
#   Stats:     365 iterations in 8.85 s (24.26 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  75%  ETA: 0:00:04
#   Progress:  Solving step 155/206 (72.07% of time interval complete)
#   Stats:     375 iterations in 8.96 s (23.89 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  77%  ETA: 0:00:04
#   Progress:  Solving step 160/206 (74.81% of time interval complete)
#   Stats:     385 iterations in 9.07 s (23.55 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  80%  ETA: 0:00:03
#   Progress:  Solving step 165/206 (77.55% of time interval complete)
#   Stats:     395 iterations in 9.17 s (23.22 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  82%  ETA: 0:00:03
#   Progress:  Solving step 170/206 (80.28% of time interval complete)
#   Stats:     405 iterations in 9.28 s (22.91 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  85%  ETA: 0:00:02
#   Progress:  Solving step 175/206 (83.02% of time interval complete)
#   Stats:     415 iterations in 9.38 s (22.60 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  87%  ETA: 0:00:02
#   Progress:  Solving step 180/206 (85.76% of time interval complete)
#   Stats:     425 iterations in 9.49 s (22.32 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  89%  ETA: 0:00:02
#   Progress:  Solving step 185/206 (88.50% of time interval complete)
#   Stats:     435 iterations in 9.63 s (22.14 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  92%  ETA: 0:00:01
#   Progress:  Solving step 190/206 (91.24% of time interval complete)
#   Stats:     445 iterations in 9.73 s (21.87 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  95%  ETA: 0:00:01
#   Progress:  Solving step 196/206 (94.52% of time interval complete)
#   Stats:     457 iterations in 9.85 s (21.56 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  98%  ETA: 0:00:00
#   Progress:  Solving step 202/206 (97.81% of time interval complete)
#   Stats:     469 iterations in 9.97 s (21.26 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps 100% Time: 0:00:14
#   Progress:  Solved step 206/206
#   Stats:     479 iterations in 10.07 s (21.02 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │ Time per │    Total │
# │                │ 206 steps │ 207 ministeps │       ms │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┼──────────┤
# │ Newton         │   2.32524 │       2.31401 │  21.0182 │  479 (0) │
# │ Linearization  │    3.3301 │       3.31401 │  14.6760 │  686 (0) │
# │ Linear solver  │   12.1214 │       12.0628 │   4.0319 │ 2497 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │  5.4055 │    25.72 % │  2.5892 │
# │ Equations      │  5.2971 │    36.09 % │  3.6338 │
# │ Assembly       │  1.7620 │    12.01 % │  1.2087 │
# │ Linear solve   │  1.3880 │     6.60 % │  0.6648 │
# │ Preconditioner │  0.9392 │     4.47 % │  0.4499 │
# │ Update         │  0.6030 │     2.87 % │  0.2889 │
# │ Convergence    │  1.4978 │    10.21 % │  1.0275 │
# │ Input/Output   │  0.1454 │     0.30 % │  0.0301 │
# │ Other          │  0.3650 │     1.74 % │  0.1748 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 21.0182 │   100.00 % │ 10.0677 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 206 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :lrat => Vector{Float64} of size (206,)
#        :orat => Vector{Float64} of size (206,)
#        :control => Vector{Symbol} of size (206,)
#        :bhp => Vector{Float64} of size (206,)
#        :mass_rate => Vector{Float64} of size (206,)
#        :rate => Vector{Float64} of size (206,)
#        :grat => Vector{Float64} of size (206,)
#
#   states (Vector with 206 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (2, 1000)
#     :OverallMoleFractions => Matrix{Float64} of size (2, 1000)
#     :Saturations => Matrix{Float64} of size (2, 1000)
#     :Pressure => Vector{Float64} of size (1000,)
#     :VaporMassFractions => Matrix{Float64} of size (2, 1000)
#     :TotalMasses => Matrix{Float64} of size (2, 1000)
#
#   time (report time for each state)
#      Vector{Float64} of length 206
#
#   result (extended states, reports)
#      SimResult with 206 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at May. 06 2024 11:05 after 10 seconds, 37 milliseconds, 642.7 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# Note that this example is intended for static publication in the
# documentation. For interactive visualization you can use functions like
# `plot_interactive` to interactively visualize the states.

# %%
z = states[end][:OverallMoleFractions][2, :]
function plot_vertical(x, t)
    data = reshape(x, (nx, nz))
    data = data[:, end:-1:1]
    fig, ax, plot = heatmap(data)
    ax.title = t
    Colorbar(fig[1, 2], plot)
    fig
end
# Out:
# plot_vertical (generic function with 1 method)

# %% [markdown]
# ### Plot final CO2 mole fraction

# %%
plot_vertical(z, "CO2")
# Out:
# Figure()

# %% [markdown]
# ### Plot final vapor saturation

# %%
sg = states[end][:Saturations][2, :]
plot_vertical(sg, "Vapor saturation")
# Out:
# Figure()

# %% [markdown]
# ### Plot final pressure

# %%
p = states[end][:Pressure]
plot_vertical(p./bar, "Pressure [bar]")
# Out:
# Figure()

# %% [markdown]
# ### Plot in interactive viewer

# %%
plot_reservoir(model, states, step = length(dt), key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
