# %% [markdown]
# # Norne: Real field black-oil model
# The Norne model is a real field model. The model has been adapted so that the
# input file only contains features present in JutulDarcy, with the most notable
# omissions being removal of hysteresis and threshold pressures between
# equilibriation reqgions. For more details, see the [OPM data
# webpage](https://opm-project.org/?page_id=559)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles, HYPRE
norne_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("NORNE_NOHYST")
case = setup_case_from_data_file(joinpath(norne_dir, "NORNE_NOHYST.DATA"))
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
# F-4H completion: Removed COMPDAT as (36, 68, 17) is not active in processed mesh.
# Rel. Perm. Scaling: Three-point scaling active.
# Transmissibility: Replaced 4615 negative half-transmissibilities (out of 265386, 1.74%) with their absolute value.
# Transmissibility: Replaced 2 non-finite half-transmissibilities (out of 265386, 0.0%) with zero.
# Transmissibility: Replaced 108 negative half-transmissibilities (out of 265386, 0.04%) with their absolute value.
# Transmissibility: Replaced 2 non-finite half-transmissibilities (out of 265386, 0.0%) with zero.
# Shutting D-1H: Well has no open perforations at step 137, shutting.
# ┌ Warning: Negative saturation in 215 cells for phase 2. Normalizing.
# └ @ JutulDarcy ~/work/JutulDarcy.jl/JutulDarcy.jl/src/init/init.jl:769
# Simulating 9 years, 3.545 weeks as 247 report steps   1%  ETA: 0:20:14
#   Progress:  Solving step 2/247 (0.75% of time interval complete)
#   Stats:     10 iterations in 7.85 s (784.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   1%  ETA: 0:15:40
#   Progress:  Solving step 3/247 (1.24% of time interval complete)
#   Stats:     19 iterations in 9.49 s (499.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:13:00
#   Progress:  Solving step 4/247 (1.69% of time interval complete)
#   Stats:     27 iterations in 10.76 s (398.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:11:08
#   Progress:  Solving step 5/247 (2.63% of time interval complete)
#   Stats:     33 iterations in 11.72 s (355.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:10:13
#   Progress:  Solving step 6/247 (3.47% of time interval complete)
#   Stats:     42 iterations in 13.17 s (313.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   3%  ETA: 0:09:24
#   Progress:  Solving step 7/247 (4.32% of time interval complete)
#   Stats:     49 iterations in 14.35 s (292.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   3%  ETA: 0:09:12
#   Progress:  Solving step 8/247 (4.35% of time interval complete)
#   Stats:     58 iterations in 16.39 s (282.52 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:08:18
#   Progress:  Solving step 9/247 (4.41% of time interval complete)
#   Stats:     60 iterations in 16.73 s (278.85 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:07:35
#   Progress:  Solving step 10/247 (5.07% of time interval complete)
#   Stats:     62 iterations in 17.09 s (275.65 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:07:17
#   Progress:  Solving step 11/247 (5.31% of time interval complete)
#   Stats:     69 iterations in 18.25 s (264.56 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   5%  ETA: 0:07:06
#   Progress:  Solving step 12/247 (6.07% of time interval complete)
#   Stats:     77 iterations in 19.61 s (254.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   5%  ETA: 0:07:00
#   Progress:  Solving step 13/247 (6.10% of time interval complete)
#   Stats:     87 iterations in 21.19 s (243.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:34
#   Progress:  Solving step 14/247 (6.25% of time interval complete)
#   Stats:     89 iterations in 21.56 s (242.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:20
#   Progress:  Solving step 15/247 (6.64% of time interval complete)
#   Stats:     94 iterations in 22.46 s (238.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:16
#   Progress:  Solving step 16/247 (6.91% of time interval complete)
#   Stats:     99 iterations in 23.90 s (241.44 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   7%  ETA: 0:06:07
#   Progress:  Solving step 17/247 (6.94% of time interval complete)
#   Stats:     106 iterations in 24.99 s (235.79 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   7%  ETA: 0:05:50
#   Progress:  Solving step 18/247 (7.16% of time interval complete)
#   Stats:     108 iterations in 25.35 s (234.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:44
#   Progress:  Solving step 19/247 (7.61% of time interval complete)
#   Stats:     115 iterations in 26.53 s (230.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:34
#   Progress:  Solving step 20/247 (8.09% of time interval complete)
#   Stats:     119 iterations in 27.25 s (229.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:39
#   Progress:  Solving step 21/247 (8.97% of time interval complete)
#   Stats:     130 iterations in 29.37 s (225.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   9%  ETA: 0:05:37
#   Progress:  Solving step 22/247 (9.00% of time interval complete)
#   Stats:     134 iterations in 30.74 s (229.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   9%  ETA: 0:05:24
#   Progress:  Solving step 23/247 (9.03% of time interval complete)
#   Stats:     136 iterations in 31.10 s (228.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:05:13
#   Progress:  Solving step 24/247 (9.54% of time interval complete)
#   Stats:     138 iterations in 31.48 s (228.12 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:05:13
#   Progress:  Solving step 25/247 (9.84% of time interval complete)
#   Stats:     146 iterations in 33.04 s (226.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:05:05
#   Progress:  Solving step 26/247 (9.93% of time interval complete)
#   Stats:     150 iterations in 33.71 s (224.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  11%  ETA: 0:05:04
#   Progress:  Solving step 27/247 (10.30% of time interval complete)
#   Stats:     158 iterations in 35.11 s (222.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  11%  ETA: 0:05:10
#   Progress:  Solving step 28/247 (10.42% of time interval complete)
#   Stats:     170 iterations in 37.38 s (219.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:05:05
#   Progress:  Solving step 29/247 (10.87% of time interval complete)
#   Stats:     176 iterations in 38.40 s (218.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:05:21
#   Progress:  Solving step 30/247 (11.78% of time interval complete)
#   Stats:     192 iterations in 41.49 s (216.10 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:05:27
#   Progress:  Solving step 31/247 (12.50% of time interval complete)
#   Stats:     205 iterations in 44.08 s (215.01 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  13%  ETA: 0:05:29
#   Progress:  Solving step 32/247 (12.71% of time interval complete)
#   Stats:     215 iterations in 45.99 s (213.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  13%  ETA: 0:05:23
#   Progress:  Solving step 33/247 (12.80% of time interval complete)
#   Stats:     220 iterations in 46.89 s (213.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  14%  ETA: 0:05:23
#   Progress:  Solving step 34/247 (13.25% of time interval complete)
#   Stats:     230 iterations in 48.71 s (211.77 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  14%  ETA: 0:05:51
#   Progress:  Solving step 35/247 (13.32% of time interval complete)
#   Stats:     257 iterations in 55.00 s (214.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:46
#   Progress:  Solving step 36/247 (13.65% of time interval complete)
#   Stats:     263 iterations in 56.07 s (213.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:49
#   Progress:  Solving step 37/247 (14.34% of time interval complete)
#   Stats:     276 iterations in 58.54 s (212.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:54
#   Progress:  Solving step 38/247 (14.49% of time interval complete)
#   Stats:     290 iterations in 61.39 s (211.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  16%  ETA: 0:05:58
#   Progress:  Solving step 39/247 (14.61% of time interval complete)
#   Stats:     302 iterations in 64.06 s (212.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  16%  ETA: 0:05:51
#   Progress:  Solving step 40/247 (15.16% of time interval complete)
#   Stats:     306 iterations in 64.80 s (211.77 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:57
#   Progress:  Solving step 41/247 (15.25% of time interval complete)
#   Stats:     323 iterations in 68.03 s (210.61 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:57
#   Progress:  Solving step 42/247 (15.31% of time interval complete)
#   Stats:     335 iterations in 70.15 s (209.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:50
#   Progress:  Solving step 43/247 (15.43% of time interval complete)
#   Stats:     338 iterations in 70.71 s (209.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  18%  ETA: 0:05:47
#   Progress:  Solving step 44/247 (16.33% of time interval complete)
#   Stats:     346 iterations in 72.13 s (208.45 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  18%  ETA: 0:05:54
#   Progress:  Solving step 45/247 (16.43% of time interval complete)
#   Stats:     360 iterations in 75.82 s (210.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:48
#   Progress:  Solving step 46/247 (16.46% of time interval complete)
#   Stats:     364 iterations in 76.57 s (210.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:40
#   Progress:  Solving step 47/247 (16.82% of time interval complete)
#   Stats:     366 iterations in 76.93 s (210.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:38
#   Progress:  Solving step 48/247 (16.91% of time interval complete)
#   Stats:     374 iterations in 78.55 s (210.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  20%  ETA: 0:05:32
#   Progress:  Solving step 49/247 (16.94% of time interval complete)
#   Stats:     377 iterations in 79.16 s (209.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  20%  ETA: 0:05:27
#   Progress:  Solving step 50/247 (17.27% of time interval complete)
#   Stats:     382 iterations in 80.02 s (209.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:30
#   Progress:  Solving step 51/247 (17.90% of time interval complete)
#   Stats:     392 iterations in 82.63 s (210.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:28
#   Progress:  Solving step 52/247 (18.18% of time interval complete)
#   Stats:     400 iterations in 84.27 s (210.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:22
#   Progress:  Solving step 53/247 (18.60% of time interval complete)
#   Stats:     403 iterations in 84.91 s (210.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  22%  ETA: 0:05:18
#   Progress:  Solving step 54/247 (19.11% of time interval complete)
#   Stats:     408 iterations in 85.89 s (210.52 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  22%  ETA: 0:05:16
#   Progress:  Solving step 55/247 (19.23% of time interval complete)
#   Stats:     415 iterations in 87.35 s (210.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:05:11
#   Progress:  Solving step 56/247 (19.99% of time interval complete)
#   Stats:     418 iterations in 87.96 s (210.44 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:05:11
#   Progress:  Solving step 57/247 (20.05% of time interval complete)
#   Stats:     429 iterations in 90.27 s (210.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:05:08
#   Progress:  Solving step 58/247 (20.11% of time interval complete)
#   Stats:     432 iterations in 91.47 s (211.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  24%  ETA: 0:05:03
#   Progress:  Solving step 59/247 (20.65% of time interval complete)
#   Stats:     435 iterations in 92.03 s (211.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  24%  ETA: 0:05:04
#   Progress:  Solving step 60/247 (20.68% of time interval complete)
#   Stats:     446 iterations in 94.21 s (211.24 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:59
#   Progress:  Solving step 61/247 (20.95% of time interval complete)
#   Stats:     449 iterations in 94.80 s (211.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:57
#   Progress:  Solving step 62/247 (21.01% of time interval complete)
#   Stats:     457 iterations in 96.46 s (211.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:53
#   Progress:  Solving step 63/247 (21.04% of time interval complete)
#   Stats:     460 iterations in 97.05 s (210.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  26%  ETA: 0:04:48
#   Progress:  Solving step 64/247 (21.32% of time interval complete)
#   Stats:     462 iterations in 97.46 s (210.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  26%  ETA: 0:04:45
#   Progress:  Solving step 65/247 (21.41% of time interval complete)
#   Stats:     467 iterations in 98.62 s (211.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:43
#   Progress:  Solving step 66/247 (21.89% of time interval complete)
#   Stats:     470 iterations in 99.84 s (212.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:42
#   Progress:  Solving step 67/247 (22.13% of time interval complete)
#   Stats:     480 iterations in 101.80 s (212.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:39
#   Progress:  Solving step 68/247 (22.16% of time interval complete)
#   Stats:     485 iterations in 102.57 s (211.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  28%  ETA: 0:04:36
#   Progress:  Solving step 69/247 (22.25% of time interval complete)
#   Stats:     491 iterations in 103.55 s (210.90 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  28%  ETA: 0:04:36
#   Progress:  Solving step 70/247 (22.80% of time interval complete)
#   Stats:     505 iterations in 105.98 s (209.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:44
#   Progress:  Solving step 71/247 (23.73% of time interval complete)
#   Stats:     529 iterations in 111.27 s (210.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:49
#   Progress:  Solving step 72/247 (24.67% of time interval complete)
#   Stats:     550 iterations in 115.36 s (209.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:50
#   Progress:  Solving step 73/247 (25.54% of time interval complete)
#   Stats:     566 iterations in 118.41 s (209.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  30%  ETA: 0:04:50
#   Progress:  Solving step 74/247 (25.57% of time interval complete)
#   Stats:     578 iterations in 120.78 s (208.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  30%  ETA: 0:04:46
#   Progress:  Solving step 75/247 (25.60% of time interval complete)
#   Stats:     582 iterations in 121.45 s (208.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:42
#   Progress:  Solving step 76/247 (26.48% of time interval complete)
#   Stats:     584 iterations in 121.95 s (208.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:46
#   Progress:  Solving step 77/247 (27.39% of time interval complete)
#   Stats:     601 iterations in 125.97 s (209.61 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:45
#   Progress:  Solving step 78/247 (28.14% of time interval complete)
#   Stats:     612 iterations in 128.22 s (209.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  32%  ETA: 0:04:44
#   Progress:  Solving step 79/247 (28.32% of time interval complete)
#   Stats:     623 iterations in 130.29 s (209.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  32%  ETA: 0:04:41
#   Progress:  Solving step 80/247 (28.56% of time interval complete)
#   Stats:     626 iterations in 131.09 s (209.41 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:38
#   Progress:  Solving step 81/247 (29.20% of time interval complete)
#   Stats:     630 iterations in 131.91 s (209.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:36
#   Progress:  Solving step 82/247 (29.23% of time interval complete)
#   Stats:     639 iterations in 133.69 s (209.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:34
#   Progress:  Solving step 83/247 (30.16% of time interval complete)
#   Stats:     642 iterations in 134.93 s (210.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  34%  ETA: 0:04:35
#   Progress:  Solving step 84/247 (30.19% of time interval complete)
#   Stats:     659 iterations in 138.34 s (209.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  34%  ETA: 0:04:31
#   Progress:  Solving step 85/247 (30.22% of time interval complete)
#   Stats:     662 iterations in 138.88 s (209.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:28
#   Progress:  Solving step 86/247 (30.74% of time interval complete)
#   Stats:     666 iterations in 139.66 s (209.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:29
#   Progress:  Solving step 87/247 (30.92% of time interval complete)
#   Stats:     680 iterations in 142.58 s (209.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:27
#   Progress:  Solving step 88/247 (30.95% of time interval complete)
#   Stats:     686 iterations in 144.32 s (210.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  36%  ETA: 0:04:23
#   Progress:  Solving step 89/247 (31.10% of time interval complete)
#   Stats:     688 iterations in 144.73 s (210.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  36%  ETA: 0:04:21
#   Progress:  Solving step 90/247 (31.34% of time interval complete)
#   Stats:     696 iterations in 146.22 s (210.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  37%  ETA: 0:04:19
#   Progress:  Solving step 91/247 (31.37% of time interval complete)
#   Stats:     703 iterations in 147.67 s (210.05 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  37%  ETA: 0:04:16
#   Progress:  Solving step 92/247 (31.70% of time interval complete)
#   Stats:     705 iterations in 148.06 s (210.01 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:04:14
#   Progress:  Solving step 93/247 (31.73% of time interval complete)
#   Stats:     714 iterations in 149.83 s (209.85 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:04:11
#   Progress:  Solving step 94/247 (32.00% of time interval complete)
#   Stats:     717 iterations in 150.41 s (209.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:04:11
#   Progress:  Solving step 95/247 (32.94% of time interval complete)
#   Stats:     726 iterations in 152.92 s (210.63 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  39%  ETA: 0:04:11
#   Progress:  Solving step 96/247 (33.85% of time interval complete)
#   Stats:     739 iterations in 155.75 s (210.76 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  39%  ETA: 0:04:10
#   Progress:  Solving step 97/247 (34.78% of time interval complete)
#   Stats:     749 iterations in 157.62 s (210.44 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:04:09
#   Progress:  Solving step 98/247 (35.72% of time interval complete)
#   Stats:     761 iterations in 159.83 s (210.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:04:14
#   Progress:  Solving step 99/247 (36.56% of time interval complete)
#   Stats:     790 iterations in 165.84 s (209.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:04:12
#   Progress:  Solving step 100/247 (37.50% of time interval complete)
#   Stats:     798 iterations in 167.53 s (209.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  41%  ETA: 0:04:11
#   Progress:  Solving step 101/247 (38.41% of time interval complete)
#   Stats:     808 iterations in 169.42 s (209.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  41%  ETA: 0:04:09
#   Progress:  Solving step 102/247 (39.31% of time interval complete)
#   Stats:     816 iterations in 171.11 s (209.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:04:07
#   Progress:  Solving step 103/247 (39.34% of time interval complete)
#   Stats:     823 iterations in 172.64 s (209.77 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:04:04
#   Progress:  Solving step 104/247 (39.49% of time interval complete)
#   Stats:     826 iterations in 173.21 s (209.69 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:04:01
#   Progress:  Solving step 105/247 (39.52% of time interval complete)
#   Stats:     831 iterations in 174.25 s (209.69 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  43%  ETA: 0:03:59
#   Progress:  Solving step 106/247 (39.86% of time interval complete)
#   Stats:     834 iterations in 175.51 s (210.45 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  43%  ETA: 0:03:57
#   Progress:  Solving step 107/247 (39.89% of time interval complete)
#   Stats:     843 iterations in 177.27 s (210.28 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:55
#   Progress:  Solving step 108/247 (40.25% of time interval complete)
#   Stats:     849 iterations in 178.24 s (209.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:59
#   Progress:  Solving step 109/247 (40.28% of time interval complete)
#   Stats:     883 iterations in 184.41 s (208.84 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:56
#   Progress:  Solving step 110/247 (40.31% of time interval complete)
#   Stats:     886 iterations in 185.63 s (209.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  45%  ETA: 0:03:53
#   Progress:  Solving step 111/247 (40.67% of time interval complete)
#   Stats:     889 iterations in 186.16 s (209.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  45%  ETA: 0:03:53
#   Progress:  Solving step 112/247 (40.70% of time interval complete)
#   Stats:     906 iterations in 189.37 s (209.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:50
#   Progress:  Solving step 113/247 (41.12% of time interval complete)
#   Stats:     908 iterations in 189.77 s (209.00 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:49
#   Progress:  Solving step 114/247 (41.18% of time interval complete)
#   Stats:     920 iterations in 192.14 s (208.84 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:46
#   Progress:  Solving step 115/247 (41.46% of time interval complete)
#   Stats:     924 iterations in 192.84 s (208.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  47%  ETA: 0:03:46
#   Progress:  Solving step 116/247 (41.64% of time interval complete)
#   Stats:     936 iterations in 195.71 s (209.09 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  47%  ETA: 0:03:44
#   Progress:  Solving step 117/247 (42.12% of time interval complete)
#   Stats:     943 iterations in 197.08 s (208.99 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:42
#   Progress:  Solving step 118/247 (42.39% of time interval complete)
#   Stats:     952 iterations in 198.92 s (208.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:40
#   Progress:  Solving step 119/247 (43.03% of time interval complete)
#   Stats:     958 iterations in 199.91 s (208.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:39
#   Progress:  Solving step 120/247 (43.96% of time interval complete)
#   Stats:     970 iterations in 202.17 s (208.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  49%  ETA: 0:03:38
#   Progress:  Solving step 121/247 (44.87% of time interval complete)
#   Stats:     986 iterations in 205.22 s (208.14 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  49%  ETA: 0:03:37
#   Progress:  Solving step 122/247 (45.71% of time interval complete)
#   Stats:     995 iterations in 207.72 s (208.76 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:35
#   Progress:  Solving step 123/247 (45.80% of time interval complete)
#   Stats:     1003 iterations in 209.29 s (208.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:33
#   Progress:  Solving step 124/247 (46.74% of time interval complete)
#   Stats:     1008 iterations in 210.15 s (208.48 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:33
#   Progress:  Solving step 125/247 (47.07% of time interval complete)
#   Stats:     1024 iterations in 213.43 s (208.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  51%  ETA: 0:03:30
#   Progress:  Solving step 126/247 (47.10% of time interval complete)
#   Stats:     1028 iterations in 214.19 s (208.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  51%  ETA: 0:03:27
#   Progress:  Solving step 127/247 (47.58% of time interval complete)
#   Stats:     1031 iterations in 214.81 s (208.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:26
#   Progress:  Solving step 128/247 (48.52% of time interval complete)
#   Stats:     1042 iterations in 217.48 s (208.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:25
#   Progress:  Solving step 129/247 (49.43% of time interval complete)
#   Stats:     1052 iterations in 219.18 s (208.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:23
#   Progress:  Solving step 130/247 (50.36% of time interval complete)
#   Stats:     1061 iterations in 220.82 s (208.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  53%  ETA: 0:03:21
#   Progress:  Solving step 131/247 (51.27% of time interval complete)
#   Stats:     1068 iterations in 222.10 s (207.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  53%  ETA: 0:03:19
#   Progress:  Solving step 132/247 (51.48% of time interval complete)
#   Stats:     1075 iterations in 223.63 s (208.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:03:17
#   Progress:  Solving step 133/247 (51.57% of time interval complete)
#   Stats:     1079 iterations in 225.07 s (208.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:03:15
#   Progress:  Solving step 134/247 (51.69% of time interval complete)
#   Stats:     1084 iterations in 225.94 s (208.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:03:12
#   Progress:  Solving step 135/247 (52.20% of time interval complete)
#   Stats:     1089 iterations in 226.82 s (208.28 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  55%  ETA: 0:03:11
#   Progress:  Solving step 136/247 (52.60% of time interval complete)
#   Stats:     1100 iterations in 228.86 s (208.05 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  55%  ETA: 0:03:09
#   Progress:  Solving step 137/247 (53.14% of time interval complete)
#   Stats:     1108 iterations in 230.51 s (208.04 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:03:08
#   Progress:  Solving step 138/247 (53.17% of time interval complete)
#   Stats:     1122 iterations in 233.32 s (207.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:03:06
#   Progress:  Solving step 139/247 (53.56% of time interval complete)
#   Stats:     1124 iterations in 233.83 s (208.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:03:06
#   Progress:  Solving step 140/247 (54.05% of time interval complete)
#   Stats:     1143 iterations in 238.23 s (208.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  57%  ETA: 0:03:04
#   Progress:  Solving step 141/247 (54.23% of time interval complete)
#   Stats:     1150 iterations in 239.57 s (208.32 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  57%  ETA: 0:03:01
#   Progress:  Solving step 142/247 (54.44% of time interval complete)
#   Stats:     1154 iterations in 240.24 s (208.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:59
#   Progress:  Solving step 143/247 (54.98% of time interval complete)
#   Stats:     1161 iterations in 241.53 s (208.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:58
#   Progress:  Solving step 144/247 (55.43% of time interval complete)
#   Stats:     1177 iterations in 244.41 s (207.65 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:57
#   Progress:  Solving step 145/247 (55.89% of time interval complete)
#   Stats:     1186 iterations in 246.84 s (208.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  59%  ETA: 0:02:56
#   Progress:  Solving step 146/247 (56.58% of time interval complete)
#   Stats:     1196 iterations in 248.74 s (207.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  59%  ETA: 0:02:54
#   Progress:  Solving step 147/247 (56.82% of time interval complete)
#   Stats:     1204 iterations in 250.34 s (207.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:52
#   Progress:  Solving step 148/247 (56.85% of time interval complete)
#   Stats:     1210 iterations in 251.41 s (207.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:49
#   Progress:  Solving step 149/247 (57.16% of time interval complete)
#   Stats:     1213 iterations in 251.91 s (207.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:49
#   Progress:  Solving step 150/247 (57.40% of time interval complete)
#   Stats:     1231 iterations in 255.35 s (207.44 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  61%  ETA: 0:02:47
#   Progress:  Solving step 151/247 (57.76% of time interval complete)
#   Stats:     1241 iterations in 257.91 s (207.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  61%  ETA: 0:02:46
#   Progress:  Solving step 152/247 (58.15% of time interval complete)
#   Stats:     1256 iterations in 260.74 s (207.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:44
#   Progress:  Solving step 153/247 (58.61% of time interval complete)
#   Stats:     1262 iterations in 262.00 s (207.61 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:43
#   Progress:  Solving step 154/247 (58.76% of time interval complete)
#   Stats:     1279 iterations in 265.02 s (207.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:41
#   Progress:  Solving step 155/247 (58.79% of time interval complete)
#   Stats:     1284 iterations in 265.83 s (207.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  63%  ETA: 0:02:39
#   Progress:  Solving step 156/247 (59.54% of time interval complete)
#   Stats:     1286 iterations in 266.17 s (206.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  63%  ETA: 0:02:38
#   Progress:  Solving step 157/247 (60.45% of time interval complete)
#   Stats:     1303 iterations in 269.87 s (207.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  64%  ETA: 0:02:36
#   Progress:  Solving step 158/247 (61.38% of time interval complete)
#   Stats:     1311 iterations in 271.29 s (206.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  64%  ETA: 0:02:34
#   Progress:  Solving step 159/247 (61.44% of time interval complete)
#   Stats:     1320 iterations in 273.02 s (206.83 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:32
#   Progress:  Solving step 160/247 (62.29% of time interval complete)
#   Stats:     1323 iterations in 273.55 s (206.77 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:30
#   Progress:  Solving step 161/247 (62.56% of time interval complete)
#   Stats:     1334 iterations in 275.47 s (206.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:29
#   Progress:  Solving step 162/247 (63.22% of time interval complete)
#   Stats:     1340 iterations in 277.34 s (206.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  66%  ETA: 0:02:28
#   Progress:  Solving step 163/247 (63.50% of time interval complete)
#   Stats:     1355 iterations in 280.30 s (206.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  66%  ETA: 0:02:25
#   Progress:  Solving step 164/247 (63.56% of time interval complete)
#   Stats:     1359 iterations in 281.09 s (206.84 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:23
#   Progress:  Solving step 165/247 (64.16% of time interval complete)
#   Stats:     1362 iterations in 281.68 s (206.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:23
#   Progress:  Solving step 166/247 (64.19% of time interval complete)
#   Stats:     1386 iterations in 286.01 s (206.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:20
#   Progress:  Solving step 167/247 (64.43% of time interval complete)
#   Stats:     1389 iterations in 286.49 s (206.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  68%  ETA: 0:02:20
#   Progress:  Solving step 168/247 (64.49% of time interval complete)
#   Stats:     1406 iterations in 290.48 s (206.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  68%  ETA: 0:02:17
#   Progress:  Solving step 169/247 (64.52% of time interval complete)
#   Stats:     1409 iterations in 291.09 s (206.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:15
#   Progress:  Solving step 170/247 (64.61% of time interval complete)
#   Stats:     1411 iterations in 291.50 s (206.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:13
#   Progress:  Solving step 171/247 (65.07% of time interval complete)
#   Stats:     1416 iterations in 292.49 s (206.56 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:11
#   Progress:  Solving step 172/247 (65.73% of time interval complete)
#   Stats:     1427 iterations in 294.74 s (206.55 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  70%  ETA: 0:02:13
#   Progress:  Solving step 173/247 (66.00% of time interval complete)
#   Stats:     1468 iterations in 302.89 s (206.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  70%  ETA: 0:02:10
#   Progress:  Solving step 174/247 (66.52% of time interval complete)
#   Stats:     1471 iterations in 303.45 s (206.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:02:08
#   Progress:  Solving step 175/247 (66.91% of time interval complete)
#   Stats:     1478 iterations in 304.58 s (206.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:02:06
#   Progress:  Solving step 176/247 (67.12% of time interval complete)
#   Stats:     1482 iterations in 305.31 s (206.01 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:02:04
#   Progress:  Solving step 177/247 (67.15% of time interval complete)
#   Stats:     1485 iterations in 305.81 s (205.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  72%  ETA: 0:02:01
#   Progress:  Solving step 178/247 (67.42% of time interval complete)
#   Stats:     1487 iterations in 306.15 s (205.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  72%  ETA: 0:02:00
#   Progress:  Solving step 179/247 (67.84% of time interval complete)
#   Stats:     1493 iterations in 307.24 s (205.79 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:58
#   Progress:  Solving step 180/247 (68.39% of time interval complete)
#   Stats:     1507 iterations in 310.67 s (206.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:56
#   Progress:  Solving step 181/247 (68.42% of time interval complete)
#   Stats:     1513 iterations in 311.83 s (206.10 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:54
#   Progress:  Solving step 182/247 (68.78% of time interval complete)
#   Stats:     1516 iterations in 312.42 s (206.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  74%  ETA: 0:01:53
#   Progress:  Solving step 183/247 (69.66% of time interval complete)
#   Stats:     1529 iterations in 315.04 s (206.04 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  74%  ETA: 0:01:51
#   Progress:  Solving step 184/247 (70.59% of time interval complete)
#   Stats:     1543 iterations in 317.76 s (205.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:50
#   Progress:  Solving step 185/247 (71.50% of time interval complete)
#   Stats:     1554 iterations in 320.76 s (206.41 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:48
#   Progress:  Solving step 186/247 (72.43% of time interval complete)
#   Stats:     1562 iterations in 322.35 s (206.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:47
#   Progress:  Solving step 187/247 (73.34% of time interval complete)
#   Stats:     1570 iterations in 323.97 s (206.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  76%  ETA: 0:01:45
#   Progress:  Solving step 188/247 (73.40% of time interval complete)
#   Stats:     1578 iterations in 325.55 s (206.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  76%  ETA: 0:01:43
#   Progress:  Solving step 189/247 (74.06% of time interval complete)
#   Stats:     1580 iterations in 325.94 s (206.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:41
#   Progress:  Solving step 190/247 (74.28% of time interval complete)
#   Stats:     1590 iterations in 327.84 s (206.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:39
#   Progress:  Solving step 191/247 (74.70% of time interval complete)
#   Stats:     1596 iterations in 329.69 s (206.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:37
#   Progress:  Solving step 192/247 (74.73% of time interval complete)
#   Stats:     1600 iterations in 330.57 s (206.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  78%  ETA: 0:01:35
#   Progress:  Solving step 193/247 (75.21% of time interval complete)
#   Stats:     1602 iterations in 330.98 s (206.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  78%  ETA: 0:01:33
#   Progress:  Solving step 194/247 (75.79% of time interval complete)
#   Stats:     1611 iterations in 332.78 s (206.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:31
#   Progress:  Solving step 195/247 (76.12% of time interval complete)
#   Stats:     1615 iterations in 333.59 s (206.56 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:31
#   Progress:  Solving step 196/247 (77.05% of time interval complete)
#   Stats:     1653 iterations in 340.61 s (206.05 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:30
#   Progress:  Solving step 197/247 (77.96% of time interval complete)
#   Stats:     1679 iterations in 346.36 s (206.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  80%  ETA: 0:01:29
#   Progress:  Solving step 198/247 (78.89% of time interval complete)
#   Stats:     1687 iterations in 347.81 s (206.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  80%  ETA: 0:01:27
#   Progress:  Solving step 199/247 (79.23% of time interval complete)
#   Stats:     1694 iterations in 349.09 s (206.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:25
#   Progress:  Solving step 200/247 (79.65% of time interval complete)
#   Stats:     1698 iterations in 349.84 s (206.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:23
#   Progress:  Solving step 201/247 (79.83% of time interval complete)
#   Stats:     1702 iterations in 350.55 s (205.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:21
#   Progress:  Solving step 202/247 (80.68% of time interval complete)
#   Stats:     1710 iterations in 351.92 s (205.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  82%  ETA: 0:01:19
#   Progress:  Solving step 203/247 (81.34% of time interval complete)
#   Stats:     1721 iterations in 354.59 s (206.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  82%  ETA: 0:01:17
#   Progress:  Solving step 204/247 (81.37% of time interval complete)
#   Stats:     1727 iterations in 355.62 s (205.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:15
#   Progress:  Solving step 205/247 (81.61% of time interval complete)
#   Stats:     1729 iterations in 355.96 s (205.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:13
#   Progress:  Solving step 206/247 (82.31% of time interval complete)
#   Stats:     1734 iterations in 356.84 s (205.79 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:11
#   Progress:  Solving step 207/247 (82.52% of time interval complete)
#   Stats:     1741 iterations in 358.07 s (205.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  84%  ETA: 0:01:09
#   Progress:  Solving step 208/247 (83.45% of time interval complete)
#   Stats:     1744 iterations in 358.57 s (205.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  84%  ETA: 0:01:08
#   Progress:  Solving step 209/247 (83.48% of time interval complete)
#   Stats:     1758 iterations in 361.69 s (205.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:06
#   Progress:  Solving step 210/247 (84.21% of time interval complete)
#   Stats:     1760 iterations in 362.05 s (205.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:04
#   Progress:  Solving step 211/247 (84.36% of time interval complete)
#   Stats:     1768 iterations in 363.41 s (205.55 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:02
#   Progress:  Solving step 212/247 (84.63% of time interval complete)
#   Stats:     1775 iterations in 364.63 s (205.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  86%  ETA: 0:01:01
#   Progress:  Solving step 213/247 (84.81% of time interval complete)
#   Stats:     1782 iterations in 365.91 s (205.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  86%  ETA: 0:00:59
#   Progress:  Solving step 214/247 (85.21% of time interval complete)
#   Stats:     1786 iterations in 366.64 s (205.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  87%  ETA: 0:00:57
#   Progress:  Solving step 215/247 (85.30% of time interval complete)
#   Stats:     1795 iterations in 368.17 s (205.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  87%  ETA: 0:00:55
#   Progress:  Solving step 216/247 (85.36% of time interval complete)
#   Stats:     1797 iterations in 368.51 s (205.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:53
#   Progress:  Solving step 217/247 (85.39% of time interval complete)
#   Stats:     1800 iterations in 369.14 s (205.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:51
#   Progress:  Solving step 218/247 (86.23% of time interval complete)
#   Stats:     1803 iterations in 370.32 s (205.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:50
#   Progress:  Solving step 219/247 (86.62% of time interval complete)
#   Stats:     1815 iterations in 372.69 s (205.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  89%  ETA: 0:00:48
#   Progress:  Solving step 220/247 (87.14% of time interval complete)
#   Stats:     1821 iterations in 373.77 s (205.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  89%  ETA: 0:00:46
#   Progress:  Solving step 221/247 (88.07% of time interval complete)
#   Stats:     1826 iterations in 374.65 s (205.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:44
#   Progress:  Solving step 222/247 (88.98% of time interval complete)
#   Stats:     1834 iterations in 376.02 s (205.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:43
#   Progress:  Solving step 223/247 (89.01% of time interval complete)
#   Stats:     1841 iterations in 377.43 s (205.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:41
#   Progress:  Solving step 224/247 (89.86% of time interval complete)
#   Stats:     1844 iterations in 377.99 s (204.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  91%  ETA: 0:00:39
#   Progress:  Solving step 225/247 (89.92% of time interval complete)
#   Stats:     1855 iterations in 380.64 s (205.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  91%  ETA: 0:00:37
#   Progress:  Solving step 226/247 (90.43% of time interval complete)
#   Stats:     1858 iterations in 381.15 s (205.14 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:36
#   Progress:  Solving step 227/247 (90.85% of time interval complete)
#   Stats:     1868 iterations in 383.17 s (205.12 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:34
#   Progress:  Solving step 228/247 (91.55% of time interval complete)
#   Stats:     1874 iterations in 384.37 s (205.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:32
#   Progress:  Solving step 229/247 (91.70% of time interval complete)
#   Stats:     1881 iterations in 385.76 s (205.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  93%  ETA: 0:00:31
#   Progress:  Solving step 230/247 (92.63% of time interval complete)
#   Stats:     1886 iterations in 387.31 s (205.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  93%  ETA: 0:00:29
#   Progress:  Solving step 231/247 (93.36% of time interval complete)
#   Stats:     1902 iterations in 390.43 s (205.28 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:27
#   Progress:  Solving step 232/247 (93.54% of time interval complete)
#   Stats:     1910 iterations in 392.07 s (205.27 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:25
#   Progress:  Solving step 233/247 (94.47% of time interval complete)
#   Stats:     1915 iterations in 392.87 s (205.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:24
#   Progress:  Solving step 234/247 (95.38% of time interval complete)
#   Stats:     1927 iterations in 395.40 s (205.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  95%  ETA: 0:00:22
#   Progress:  Solving step 235/247 (96.32% of time interval complete)
#   Stats:     1936 iterations in 397.76 s (205.46 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  95%  ETA: 0:00:20
#   Progress:  Solving step 236/247 (96.74% of time interval complete)
#   Stats:     1943 iterations in 399.03 s (205.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:19
#   Progress:  Solving step 237/247 (96.77% of time interval complete)
#   Stats:     1946 iterations in 399.61 s (205.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:17
#   Progress:  Solving step 238/247 (97.25% of time interval complete)
#   Stats:     1948 iterations in 399.97 s (205.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:15
#   Progress:  Solving step 239/247 (97.64% of time interval complete)
#   Stats:     1958 iterations in 401.91 s (205.27 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  97%  ETA: 0:00:14
#   Progress:  Solving step 240/247 (98.16% of time interval complete)
#   Stats:     1964 iterations in 403.24 s (205.32 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  97%  ETA: 0:00:12
#   Progress:  Solving step 241/247 (98.43% of time interval complete)
#   Stats:     1969 iterations in 405.10 s (205.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:10
#   Progress:  Solving step 242/247 (98.58% of time interval complete)
#   Stats:     1972 iterations in 405.70 s (205.73 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:08
#   Progress:  Solving step 243/247 (99.09% of time interval complete)
#   Stats:     1974 iterations in 406.18 s (205.76 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:07
#   Progress:  Solving step 244/247 (99.34% of time interval complete)
#   Stats:     1985 iterations in 408.41 s (205.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:05
#   Progress:  Solving step 245/247 (99.40% of time interval complete)
#   Stats:     1989 iterations in 409.22 s (205.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:03
#   Progress:  Solving step 246/247 (99.58% of time interval complete)
#   Stats:     1992 iterations in 409.82 s (205.73 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:02
#   Progress:  Solving step 247/247 (100.00% of time interval complete)
#   Stats:     2000 iterations in 411.38 s (205.69 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps 100% Time: 0:06:55
#   Progress:  Solved step 247/247
#   Stats:     2006 iterations in 412.70 s (205.73 ms each)
# ╭────────────────┬───────────┬───────────────┬─────────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │       Total │
# │                │ 247 steps │ 465 ministeps │    (wasted) │
# ├────────────────┼───────────┼───────────────┼─────────────┤
# │ Newton         │   8.12146 │       4.31398 │   2006 (45) │
# │ Linearization  │    10.004 │       5.31398 │   2471 (48) │
# │ Linear solver  │   28.5101 │       15.1441 │  7042 (157) │
# │ Precond apply  │   57.0202 │       30.2882 │ 14084 (314) │
# ╰────────────────┴───────────┴───────────────┴─────────────╯
# ╭───────────────┬──────────┬────────────┬──────────╮
# │ Timing type   │     Each │   Relative │    Total │
# │               │       ms │ Percentage │        s │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Properties    │  18.5000 │     8.99 % │  37.1109 │
# │ Equations     │  27.3918 │    16.40 % │  67.6851 │
# │ Assembly      │  19.3740 │    11.60 % │  47.8730 │
# │ Linear solve  │  13.6040 │     6.61 % │  27.2895 │
# │ Linear setup  │  58.5007 │    28.44 % │ 117.3523 │
# │ Precond apply │   6.6746 │    22.78 % │  94.0050 │
# │ Update        │   3.2727 │     1.59 % │   6.5650 │
# │ Convergence   │   1.4132 │     0.85 % │   3.4919 │
# │ Input/Output  │   7.1227 │     0.80 % │   3.3121 │
# │ Other         │   3.9969 │     1.94 % │   8.0177 │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Total         │ 205.7341 │   100.00 % │ 412.7026 │
# ╰───────────────┴──────────┴────────────┴──────────╯
# ReservoirSimResult with 462 entries:
#
#   wells (36 present):
#     :B-4H
#     :F-4H
#     :D-4H
#     :F-2H
#     :D-2H
#     :B-1H
#     :C-4H
#     :C-1H
#     :B-2H
#     :E-1H
#     :B-4BH
#     :D-3AH
#     :D-3BH
#     :C-3H
#     :E-3H
#     :K-3H
#     :E-4AH
#     :D-1H
#     :B-1AH
#     :E-3CH
#     :E-4H
#     :E-2H
#     :E-2AH
#     :C-4AH
#     :B-1BH
#     :C-2H
#     :B-4DH
#     :D-3H
#     :E-3AH
#     :D-4AH
#     :B-3H
#     :F-3H
#     :E-3BH
#     :D-1CH
#     :F-1H
#     :B-4AH
#     Results per well:
#        :wrat => Vector{Float64} of size (462,)
#        :Aqueous_mass_rate => Vector{Float64} of size (462,)
#        :orat => Vector{Float64} of size (462,)
#        :bhp => Vector{Float64} of size (462,)
#        :lrat => Vector{Float64} of size (462,)
#        :mass_rate => Vector{Float64} of size (462,)
#        :rate => Vector{Float64} of size (462,)
#        :Vapor_mass_rate => Vector{Float64} of size (462,)
#        :control => Vector{Symbol} of size (462,)
#        :Liquid_mass_rate => Vector{Float64} of size (462,)
#        :grat => Vector{Float64} of size (462,)
#
#   states (Vector with 462 entries, reservoir variables for each state)
#     :Rv => Vector{Float64} of size (44417,)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (44417,)
#     :Saturations => Matrix{Float64} of size (3, 44417)
#     :Pressure => Vector{Float64} of size (44417,)
#     :Rs => Vector{Float64} of size (44417,)
#     :ImmiscibleSaturation => Vector{Float64} of size (44417,)
#     :TotalMasses => Matrix{Float64} of size (3, 44417)
#
#   time (report time for each state)
#      Vector{Float64} of length 462
#
#   result (extended states, reports)
#      SimResult with 247 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 02 2024 14:08 after 6 minutes, 49 seconds, 390.6 milliseconds.

# %% [markdown]
# ## Plot the reservoir solution

# %%
fig = plot_reservoir(case.model, states, step = 247, key = :Saturations)
ax = fig.current_axis[]
ax.azimuth[] = -3.0
ax.elevation[] = 0.5
fig
# Out:
# Figure()

# %% [markdown]
# ## Plot the reservoir static properties

# %%
fig = plot_reservoir(case.model, key = :porosity)
ax = fig.current_axis[]
ax.azimuth[] = -3.0
ax.elevation[] = 0.5
fig
# Out:
# Figure()

# %% [markdown]
# ## Load reference and set up plotting

# %%
csv_path = joinpath(norne_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat] + well[:grat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response")
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :grat
        ys = si_unit(:day)/1e6
        yl = "Surface gas rate / 10⁶ m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        grat_ref = data[:, findfirst(x -> x == "$well_name:grat", vec(header))]
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = grat_ref + orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "OPM Flow"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Injector bhp

# %%
plot_well_comparison(:bhp, inj, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Gas injection rates

# %%
plot_well_comparison(:grat, inj, "Gas surface injection rate")
# Out:
# Figure()

# %% [markdown]
# ## Water injection rates

# %%
plot_well_comparison(:wrat, inj, "Water surface injection rate")
# Out:
# Figure()

# %% [markdown]
# ## Producer bhp

# %%
plot_well_comparison(:bhp, prod, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Oil production rates

# %%
plot_well_comparison(:orat, prod, "Oil surface production rate")
# Out:
# Figure()

# %% [markdown]
# ## Gas production rates

# %%
plot_well_comparison(:grat, prod, "Gas surface production rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
