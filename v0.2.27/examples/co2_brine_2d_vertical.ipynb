# %% [markdown]
# # Example demonstrating compositional flow
# This is a simple conceptual example demonstrating how to solve compositional
# flow. This example uses a two-component water-CO2 system. Note that the
# default Peng-Robinson is not accurate for this system without adjustments to
# the parameters. However, the example demonstrates the conceptual workflow for
# getting started with compositional simulation.
# ## Set up mixture
# We load the external flash package and define a two-component H2O-CO2 system.
# The constructor for each species takes in molecular weight, critical pressure,
# critical temperature, critical volume, acentric factor given as strict SI.
# This means, for instance, that molar masses are given in kg/mole and not
# g/mole or kg/kmol.

# %%
using MultiComponentFlash
h2o = MolecularProperty(0.018015268, 22.064e6, 647.096, 5.595e-05, 0.3442920843)
co2 = MolecularProperty(0.0440098, 7.3773e6, 304.1282, 9.412e-05, 0.22394)

bic = zeros(2, 2)

mixture = MultiComponentMixture([h2o, co2], A_ij = bic, names = ["H2O", "CO2"])
eos = GenericCubicEOS(mixture, PengRobinson())
# Out:
# MultiComponentFlash.GenericCubicEOS{MultiComponentFlash.PengRobinson, Float64, 2, Nothing}(MultiComponentFlash.PengRobinson(), MultiComponentFlash.MultiComponentMixture{Float64, 2}("UnnamedMixture", ["H2O", "CO2"], (MultiComponentFlash.MolecularProperty{Float64}(0.018015268, 2.2064e7, 647.096, 5.595e-5, 0.3442920843), MultiComponentFlash.MolecularProperty{Float64}(0.0440098, 7.3773e6, 304.1282, 9.412e-5, 0.22394)), [0.0 0.0; 0.0 0.0]), 2.414213562373095, -0.41421356237309515, 0.457235529, 0.077796074, nothing)

# %% [markdown]
# ## Set up domain and wells

# %%
using Jutul, JutulDarcy, GLMakie
nx = 50
ny = 1
nz = 20
dims = (nx, ny, nz)
g = CartesianMesh(dims, (100.0, 10.0, 10.0))
nc = number_of_cells(g)
Darcy, bar, kg, meter, Kelvin, day, sec = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day, :second)
K = repeat([0.1, 0.1, 0.001]*Darcy, 1, nc)
res = reservoir_domain(g, porosity = 0.3, permeability = K)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 50x1x20=1000 cells with 17 data fields added:
#   1000 Cells
#     :permeability => 3×1000 Matrix{Float64}
#     :porosity => 1000 Vector{Float64}
#     :rock_thermal_conductivity => 1000 Vector{Float64}
#     :fluid_thermal_conductivity => 1000 Vector{Float64}
#     :rock_density => 1000 Vector{Float64}
#     :cell_centroids => 3×1000 Matrix{Float64}
#     :volumes => 1000 Vector{Float64}
#   1930 Faces
#     :neighbors => 2×1930 Matrix{Int64}
#     :areas => 1930 Vector{Float64}
#     :normals => 3×1930 Matrix{Float64}
#     :face_centroids => 3×1930 Matrix{Float64}
#   3860 HalfFaces
#     :half_face_cells => 3860 Vector{Int64}
#     :half_face_faces => 3860 Vector{Int64}
#   2140 BoundaryFaces
#     :boundary_areas => 2140 Vector{Float64}
#     :boundary_centroids => 3×2140 Matrix{Float64}
#     :boundary_normals => 3×2140 Matrix{Float64}
#     :boundary_neighbors => 2140 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in top layer

# %%
prod = setup_well(g, K, [(nx, ny, 1)], name = :Producer)
# Out:
# MultiSegmentWell [Producer] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in bottom layer

# %%
inj = setup_well(g, K, [(1, 1, nz)], name = :Injector)
# Out:
# MultiSegmentWell [Injector] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# ## Define system and realize on grid

# %%
rhoLS = 844.23*kg/meter^3
rhoVS = 126.97*kg/meter^3
rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod]);
push!(model[:Reservoir].output_variables, :Saturations)
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)
T0 = repeat([303.15*Kelvin], 1, nc)
parameters[:Reservoir][:Temperature] = T0
state0 = setup_reservoir_state(model, Pressure = 50*bar, OverallMoleFractions = [1.0, 0.0]);

# %% [markdown]
# ## Define schedule
# 5 year (5*365.24 days) simulation period

# %%
dt0 = repeat([1]*day, 26)
dt1 = repeat([10.0]*day, 180)
dt = append!(dt0, dt1)
rate_target = TotalRateTarget(9.5066e-06*meter^3/sec)
I_ctrl = InjectorControl(rate_target, [0, 1], density = rhoVS)
bhp_target = BottomHolePressureTarget(50*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 4 years, 52.15 weeks as 206 report steps   1%  ETA: 0:18:19
#   Progress:  Solving step 2/206 (0.11% of time interval complete)
#   Stats:     6 iterations in 6.30 s (1.05 s each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps   5%  ETA: 0:03:33
#   Progress:  Solving step 10/206 (0.55% of time interval complete)
#   Stats:     26 iterations in 6.40 s (246.03 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  10%  ETA: 0:01:37
#   Progress:  Solving step 21/206 (1.15% of time interval complete)
#   Stats:     48 iterations in 6.50 s (135.51 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  14%  ETA: 0:01:06
#   Progress:  Solving step 30/206 (3.61% of time interval complete)
#   Stats:     71 iterations in 6.70 s (94.31 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  17%  ETA: 0:00:53
#   Progress:  Solving step 36/206 (6.90% of time interval complete)
#   Stats:     89 iterations in 6.80 s (76.40 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  20%  ETA: 0:00:45
#   Progress:  Solving step 42/206 (10.19% of time interval complete)
#   Stats:     107 iterations in 6.91 s (64.57 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  23%  ETA: 0:00:38
#   Progress:  Solving step 48/206 (13.47% of time interval complete)
#   Stats:     122 iterations in 7.01 s (57.49 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  26%  ETA: 0:00:33
#   Progress:  Solving step 54/206 (16.76% of time interval complete)
#   Stats:     140 iterations in 7.15 s (51.04 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  29%  ETA: 0:00:29
#   Progress:  Solving step 59/206 (19.50% of time interval complete)
#   Stats:     155 iterations in 7.26 s (46.85 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  31%  ETA: 0:00:26
#   Progress:  Solving step 64/206 (22.23% of time interval complete)
#   Stats:     169 iterations in 7.38 s (43.66 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  33%  ETA: 0:00:24
#   Progress:  Solving step 68/206 (24.42% of time interval complete)
#   Stats:     181 iterations in 7.48 s (41.32 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  35%  ETA: 0:00:23
#   Progress:  Solving step 72/206 (26.62% of time interval complete)
#   Stats:     193 iterations in 7.58 s (39.30 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  37%  ETA: 0:00:21
#   Progress:  Solving step 76/206 (28.81% of time interval complete)
#   Stats:     206 iterations in 7.71 s (37.41 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  39%  ETA: 0:00:19
#   Progress:  Solving step 80/206 (31.00% of time interval complete)
#   Stats:     218 iterations in 7.82 s (35.89 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  40%  ETA: 0:00:18
#   Progress:  Solving step 83/206 (32.64% of time interval complete)
#   Stats:     230 iterations in 7.94 s (34.53 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  43%  ETA: 0:00:17
#   Progress:  Solving step 89/206 (35.93% of time interval complete)
#   Stats:     242 iterations in 8.06 s (33.32 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  45%  ETA: 0:00:15
#   Progress:  Solving step 94/206 (38.66% of time interval complete)
#   Stats:     252 iterations in 8.17 s (32.42 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  48%  ETA: 0:00:14
#   Progress:  Solving step 99/206 (41.40% of time interval complete)
#   Stats:     263 iterations in 8.28 s (31.50 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  50%  ETA: 0:00:13
#   Progress:  Solving step 104/206 (44.14% of time interval complete)
#   Stats:     273 iterations in 8.39 s (30.74 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  53%  ETA: 0:00:12
#   Progress:  Solving step 109/206 (46.88% of time interval complete)
#   Stats:     283 iterations in 8.50 s (30.03 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  56%  ETA: 0:00:10
#   Progress:  Solving step 115/206 (50.16% of time interval complete)
#   Stats:     294 iterations in 8.62 s (29.31 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  58%  ETA: 0:00:09
#   Progress:  Solving step 121/206 (53.45% of time interval complete)
#   Stats:     304 iterations in 8.73 s (28.71 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  61%  ETA: 0:00:09
#   Progress:  Solving step 126/206 (56.19% of time interval complete)
#   Stats:     314 iterations in 8.85 s (28.17 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  63%  ETA: 0:00:08
#   Progress:  Solving step 131/206 (58.93% of time interval complete)
#   Stats:     324 iterations in 8.95 s (27.63 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  66%  ETA: 0:00:07
#   Progress:  Solving step 136/206 (61.66% of time interval complete)
#   Stats:     334 iterations in 9.06 s (27.12 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  68%  ETA: 0:00:06
#   Progress:  Solving step 141/206 (64.40% of time interval complete)
#   Stats:     344 iterations in 9.16 s (26.64 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  71%  ETA: 0:00:06
#   Progress:  Solving step 146/206 (67.14% of time interval complete)
#   Stats:     354 iterations in 9.27 s (26.18 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  73%  ETA: 0:00:05
#   Progress:  Solving step 151/206 (69.88% of time interval complete)
#   Stats:     364 iterations in 9.37 s (25.75 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  75%  ETA: 0:00:05
#   Progress:  Solving step 156/206 (72.62% of time interval complete)
#   Stats:     374 iterations in 9.48 s (25.35 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  78%  ETA: 0:00:04
#   Progress:  Solving step 161/206 (75.36% of time interval complete)
#   Stats:     384 iterations in 9.59 s (24.97 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  80%  ETA: 0:00:03
#   Progress:  Solving step 166/206 (78.09% of time interval complete)
#   Stats:     394 iterations in 9.70 s (24.61 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  83%  ETA: 0:00:03
#   Progress:  Solving step 171/206 (80.83% of time interval complete)
#   Stats:     404 iterations in 9.80 s (24.26 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  85%  ETA: 0:00:03
#   Progress:  Solving step 176/206 (83.57% of time interval complete)
#   Stats:     414 iterations in 9.91 s (23.94 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  87%  ETA: 0:00:02
#   Progress:  Solving step 181/206 (86.31% of time interval complete)
#   Stats:     424 iterations in 10.02 s (23.62 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  90%  ETA: 0:00:02
#   Progress:  Solving step 186/206 (89.05% of time interval complete)
#   Stats:     434 iterations in 10.12 s (23.32 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  92%  ETA: 0:00:01
#   Progress:  Solving step 191/206 (91.79% of time interval complete)
#   Stats:     444 iterations in 10.22 s (23.03 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  95%  ETA: 0:00:01
#   Progress:  Solving step 196/206 (94.52% of time interval complete)
#   Stats:     454 iterations in 10.33 s (22.75 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  97%  ETA: 0:00:00
#   Progress:  Solving step 201/206 (97.26% of time interval complete)
#   Stats:     464 iterations in 10.43 s (22.48 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  99%  ETA: 0:00:00
#   Progress:  Solving step 206/206 (100.00% of time interval complete)
#   Stats:     474 iterations in 10.53 s (22.22 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps 100% Time: 0:00:15
#   Progress:  Solved step 206/206
#   Stats:     476 iterations in 10.55 s (22.17 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │    Total │
# │                │ 206 steps │ 207 ministeps │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┤
# │ Newton         │   2.31068 │       2.29952 │  476 (0) │
# │ Linearization  │   3.31553 │       3.29952 │  683 (0) │
# │ Linear solver  │   9.96602 │       9.91787 │ 2053 (0) │
# │ Precond apply  │    19.932 │       19.8357 │ 4106 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬─────────╮
# │ Timing type   │    Each │   Relative │   Total │
# │               │      ms │ Percentage │       s │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Properties    │  5.5847 │    25.19 % │  2.6583 │
# │ Equations     │  5.4770 │    35.44 % │  3.7408 │
# │ Assembly      │  1.8918 │    12.24 % │  1.2921 │
# │ Linear solve  │  0.2247 │     1.01 % │  0.1070 │
# │ Linear setup  │  1.0273 │     4.63 % │  0.4890 │
# │ Precond apply │  0.1008 │     3.92 % │  0.4140 │
# │ Update        │  0.6949 │     3.13 % │  0.3308 │
# │ Convergence   │  1.6210 │    10.49 % │  1.1072 │
# │ Input/Output  │  0.1653 │     0.32 % │  0.0342 │
# │ Other         │  0.8007 │     3.61 % │  0.3811 │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Total         │ 22.1732 │   100.00 % │ 10.5545 │
# ╰───────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 206 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :H2O_mass_rate => Vector{Float64} of size (206,)
#        :lrat => Vector{Float64} of size (206,)
#        :orat => Vector{Float64} of size (206,)
#        :control => Vector{Symbol} of size (206,)
#        :bhp => Vector{Float64} of size (206,)
#        :CO2_mass_rate => Vector{Float64} of size (206,)
#        :mass_rate => Vector{Float64} of size (206,)
#        :rate => Vector{Float64} of size (206,)
#        :grat => Vector{Float64} of size (206,)
#
#   states (Vector with 206 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (2, 1000)
#     :OverallMoleFractions => Matrix{Float64} of size (2, 1000)
#     :Saturations => Matrix{Float64} of size (2, 1000)
#     :Pressure => Vector{Float64} of size (1000,)
#     :VaporMassFractions => Matrix{Float64} of size (2, 1000)
#     :TotalMasses => Matrix{Float64} of size (2, 1000)
#
#   time (report time for each state)
#      Vector{Float64} of length 206
#
#   result (extended states, reports)
#      SimResult with 206 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 02 2024 14:08 after 10 seconds, 520 milliseconds, 239.4 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# Note that this example is intended for static publication in the
# documentation. For interactive visualization you can use functions like
# `plot_interactive` to interactively visualize the states.

# %%
z = states[end][:OverallMoleFractions][2, :]
function plot_vertical(x, t)
    data = reshape(x, (nx, nz))
    data = data[:, end:-1:1]
    fig, ax, plot = heatmap(data)
    ax.title = t
    Colorbar(fig[1, 2], plot)
    fig
end
# Out:
# plot_vertical (generic function with 1 method)

# %% [markdown]
# ### Plot final CO2 mole fraction

# %%
plot_vertical(z, "CO2")
# Out:
# Figure()

# %% [markdown]
# ### Plot final vapor saturation

# %%
sg = states[end][:Saturations][2, :]
plot_vertical(sg, "Vapor saturation")
# Out:
# Figure()

# %% [markdown]
# ### Plot final pressure

# %%
p = states[end][:Pressure]
plot_vertical(p./bar, "Pressure [bar]")
# Out:
# Figure()

# %% [markdown]
# ### Plot in interactive viewer

# %%
plot_reservoir(model, states, step = length(dt), key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
