# %% [markdown]
# # Norne: Real field black-oil model
# The Norne model is a real field model. The model has been adapted so that the
# input file only contains features present in JutulDarcy, with the most notable
# omissions being removal of hysteresis and threshold pressures between
# equilibriation reqgions. For more details, see the [OPM data
# webpage](https://opm-project.org/?page_id=559)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles, HYPRE
norne_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("NORNE_NOHYST")
case = setup_case_from_data_file(joinpath(norne_dir, "NORNE_NOHYST.DATA"))
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
# F-4H completion: Removed COMPDAT as (36, 68, 17) is not active in processed mesh.
# Rel. Perm. Scaling: Three-point scaling active.
# Transmissibility: Replaced 4615 negative half-transmissibilities (out of 265386, 1.74%) with their absolute value.
# Transmissibility: Replaced 2 non-finite half-transmissibilities (out of 265386, 0.0%) with zero.
# Transmissibility: Replaced 108 negative half-transmissibilities (out of 265386, 0.04%) with their absolute value.
# Transmissibility: Replaced 2 non-finite half-transmissibilities (out of 265386, 0.0%) with zero.
# Shutting D-1H: Well has no open perforations at step 137, shutting.
# ┌ Warning: Negative saturation in 215 cells for phase 2. Normalizing.
# └ @ JutulDarcy ~/work/JutulDarcy.jl/JutulDarcy.jl/src/init/init.jl:755
# Simulating 9 years, 3.545 weeks as 247 report steps   1%  ETA: 0:19:43
#   Progress:  Solving step 2/247 (0.75% of time interval complete)
#   Stats:     10 iterations in 7.49 s (748.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   1%  ETA: 0:15:06
#   Progress:  Solving step 3/247 (1.24% of time interval complete)
#   Stats:     19 iterations in 8.97 s (472.01 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:12:27
#   Progress:  Solving step 4/247 (1.69% of time interval complete)
#   Stats:     27 iterations in 10.12 s (374.89 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:10:53
#   Progress:  Solving step 5/247 (2.63% of time interval complete)
#   Stats:     35 iterations in 11.30 s (322.85 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:09:56
#   Progress:  Solving step 6/247 (3.47% of time interval complete)
#   Stats:     44 iterations in 12.66 s (287.63 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   3%  ETA: 0:09:08
#   Progress:  Solving step 7/247 (4.32% of time interval complete)
#   Stats:     51 iterations in 13.79 s (270.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   3%  ETA: 0:08:52
#   Progress:  Solving step 8/247 (4.35% of time interval complete)
#   Stats:     59 iterations in 15.59 s (264.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:07:59
#   Progress:  Solving step 9/247 (4.41% of time interval complete)
#   Stats:     61 iterations in 15.91 s (260.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:07:17
#   Progress:  Solving step 10/247 (5.07% of time interval complete)
#   Stats:     63 iterations in 16.23 s (257.54 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:06:59
#   Progress:  Solving step 11/247 (5.31% of time interval complete)
#   Stats:     70 iterations in 17.32 s (247.46 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   5%  ETA: 0:06:49
#   Progress:  Solving step 12/247 (6.07% of time interval complete)
#   Stats:     78 iterations in 18.63 s (238.84 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   5%  ETA: 0:06:42
#   Progress:  Solving step 13/247 (6.10% of time interval complete)
#   Stats:     88 iterations in 20.11 s (228.58 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:18
#   Progress:  Solving step 14/247 (6.25% of time interval complete)
#   Stats:     90 iterations in 20.46 s (227.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:02
#   Progress:  Solving step 15/247 (6.64% of time interval complete)
#   Stats:     94 iterations in 21.17 s (225.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:01
#   Progress:  Solving step 16/247 (6.91% of time interval complete)
#   Stats:     100 iterations in 22.77 s (227.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   7%  ETA: 0:05:53
#   Progress:  Solving step 17/247 (6.94% of time interval complete)
#   Stats:     107 iterations in 23.81 s (222.53 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   7%  ETA: 0:05:36
#   Progress:  Solving step 18/247 (7.16% of time interval complete)
#   Stats:     109 iterations in 24.15 s (221.53 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:28
#   Progress:  Solving step 19/247 (7.61% of time interval complete)
#   Stats:     115 iterations in 25.10 s (218.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:21
#   Progress:  Solving step 20/247 (8.09% of time interval complete)
#   Stats:     121 iterations in 26.01 s (214.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:25
#   Progress:  Solving step 21/247 (8.97% of time interval complete)
#   Stats:     132 iterations in 27.95 s (211.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   9%  ETA: 0:05:17
#   Progress:  Solving step 22/247 (9.00% of time interval complete)
#   Stats:     136 iterations in 28.71 s (211.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   9%  ETA: 0:05:11
#   Progress:  Solving step 23/247 (9.03% of time interval complete)
#   Stats:     138 iterations in 29.62 s (214.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:05:00
#   Progress:  Solving step 24/247 (9.54% of time interval complete)
#   Stats:     140 iterations in 29.96 s (214.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:04:56
#   Progress:  Solving step 25/247 (9.84% of time interval complete)
#   Stats:     146 iterations in 31.09 s (212.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:04:49
#   Progress:  Solving step 26/247 (9.93% of time interval complete)
#   Stats:     150 iterations in 31.73 s (211.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  11%  ETA: 0:04:48
#   Progress:  Solving step 27/247 (10.30% of time interval complete)
#   Stats:     158 iterations in 33.05 s (209.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  11%  ETA: 0:04:55
#   Progress:  Solving step 28/247 (10.42% of time interval complete)
#   Stats:     170 iterations in 35.35 s (207.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:04:50
#   Progress:  Solving step 29/247 (10.87% of time interval complete)
#   Stats:     176 iterations in 36.29 s (206.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:04:59
#   Progress:  Solving step 30/247 (11.78% of time interval complete)
#   Stats:     187 iterations in 38.99 s (208.49 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:05:05
#   Progress:  Solving step 31/247 (12.50% of time interval complete)
#   Stats:     200 iterations in 41.43 s (207.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  13%  ETA: 0:05:08
#   Progress:  Solving step 32/247 (12.71% of time interval complete)
#   Stats:     211 iterations in 43.43 s (205.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  13%  ETA: 0:05:02
#   Progress:  Solving step 33/247 (12.80% of time interval complete)
#   Stats:     215 iterations in 44.12 s (205.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  14%  ETA: 0:05:00
#   Progress:  Solving step 34/247 (13.25% of time interval complete)
#   Stats:     223 iterations in 45.47 s (203.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  14%  ETA: 0:05:50
#   Progress:  Solving step 35/247 (13.32% of time interval complete)
#   Stats:     270 iterations in 55.32 s (204.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:45
#   Progress:  Solving step 36/247 (13.65% of time interval complete)
#   Stats:     276 iterations in 56.35 s (204.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:47
#   Progress:  Solving step 37/247 (14.34% of time interval complete)
#   Stats:     288 iterations in 58.61 s (203.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:46
#   Progress:  Solving step 38/247 (14.49% of time interval complete)
#   Stats:     298 iterations in 60.51 s (203.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  16%  ETA: 0:05:52
#   Progress:  Solving step 39/247 (14.61% of time interval complete)
#   Stats:     313 iterations in 63.50 s (202.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  16%  ETA: 0:05:45
#   Progress:  Solving step 40/247 (15.16% of time interval complete)
#   Stats:     317 iterations in 64.19 s (202.48 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:51
#   Progress:  Solving step 41/247 (15.25% of time interval complete)
#   Stats:     335 iterations in 67.37 s (201.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:52
#   Progress:  Solving step 42/247 (15.31% of time interval complete)
#   Stats:     349 iterations in 69.69 s (199.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:46
#   Progress:  Solving step 43/247 (15.43% of time interval complete)
#   Stats:     353 iterations in 70.39 s (199.41 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  18%  ETA: 0:05:44
#   Progress:  Solving step 44/247 (16.33% of time interval complete)
#   Stats:     362 iterations in 71.99 s (198.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  18%  ETA: 0:05:52
#   Progress:  Solving step 45/247 (16.43% of time interval complete)
#   Stats:     379 iterations in 75.90 s (200.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:46
#   Progress:  Solving step 46/247 (16.46% of time interval complete)
#   Stats:     383 iterations in 76.59 s (199.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:38
#   Progress:  Solving step 47/247 (16.82% of time interval complete)
#   Stats:     385 iterations in 76.91 s (199.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:36
#   Progress:  Solving step 48/247 (16.91% of time interval complete)
#   Stats:     393 iterations in 78.42 s (199.53 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  20%  ETA: 0:05:29
#   Progress:  Solving step 49/247 (16.94% of time interval complete)
#   Stats:     396 iterations in 78.96 s (199.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  20%  ETA: 0:05:24
#   Progress:  Solving step 50/247 (17.27% of time interval complete)
#   Stats:     400 iterations in 79.61 s (199.04 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:26
#   Progress:  Solving step 51/247 (17.90% of time interval complete)
#   Stats:     410 iterations in 82.13 s (200.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:24
#   Progress:  Solving step 52/247 (18.18% of time interval complete)
#   Stats:     418 iterations in 83.70 s (200.24 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:18
#   Progress:  Solving step 53/247 (18.60% of time interval complete)
#   Stats:     421 iterations in 84.28 s (200.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  22%  ETA: 0:05:14
#   Progress:  Solving step 54/247 (19.11% of time interval complete)
#   Stats:     426 iterations in 85.19 s (199.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  22%  ETA: 0:05:14
#   Progress:  Solving step 55/247 (19.23% of time interval complete)
#   Stats:     439 iterations in 87.45 s (199.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:05:09
#   Progress:  Solving step 56/247 (19.99% of time interval complete)
#   Stats:     442 iterations in 88.02 s (199.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:05:12
#   Progress:  Solving step 57/247 (20.05% of time interval complete)
#   Stats:     457 iterations in 90.90 s (198.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:05:09
#   Progress:  Solving step 58/247 (20.11% of time interval complete)
#   Stats:     460 iterations in 92.03 s (200.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  24%  ETA: 0:05:04
#   Progress:  Solving step 59/247 (20.65% of time interval complete)
#   Stats:     463 iterations in 92.58 s (199.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  24%  ETA: 0:05:03
#   Progress:  Solving step 60/247 (20.68% of time interval complete)
#   Stats:     474 iterations in 94.62 s (199.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:58
#   Progress:  Solving step 61/247 (20.95% of time interval complete)
#   Stats:     477 iterations in 95.15 s (199.48 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:56
#   Progress:  Solving step 62/247 (21.01% of time interval complete)
#   Stats:     484 iterations in 96.48 s (199.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:52
#   Progress:  Solving step 63/247 (21.04% of time interval complete)
#   Stats:     488 iterations in 97.17 s (199.12 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  26%  ETA: 0:04:47
#   Progress:  Solving step 64/247 (21.32% of time interval complete)
#   Stats:     490 iterations in 97.63 s (199.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  26%  ETA: 0:04:47
#   Progress:  Solving step 65/247 (21.41% of time interval complete)
#   Stats:     497 iterations in 99.60 s (200.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:42
#   Progress:  Solving step 66/247 (21.89% of time interval complete)
#   Stats:     500 iterations in 100.13 s (200.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:41
#   Progress:  Solving step 67/247 (22.13% of time interval complete)
#   Stats:     509 iterations in 101.86 s (200.12 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:38
#   Progress:  Solving step 68/247 (22.16% of time interval complete)
#   Stats:     516 iterations in 102.85 s (199.32 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  28%  ETA: 0:04:34
#   Progress:  Solving step 69/247 (22.25% of time interval complete)
#   Stats:     520 iterations in 103.53 s (199.10 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  28%  ETA: 0:04:35
#   Progress:  Solving step 70/247 (22.80% of time interval complete)
#   Stats:     534 iterations in 105.87 s (198.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:42
#   Progress:  Solving step 71/247 (23.73% of time interval complete)
#   Stats:     558 iterations in 110.90 s (198.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:47
#   Progress:  Solving step 72/247 (24.67% of time interval complete)
#   Stats:     582 iterations in 115.17 s (197.89 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:48
#   Progress:  Solving step 73/247 (25.54% of time interval complete)
#   Stats:     598 iterations in 118.13 s (197.55 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  30%  ETA: 0:04:49
#   Progress:  Solving step 74/247 (25.57% of time interval complete)
#   Stats:     610 iterations in 120.86 s (198.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  30%  ETA: 0:04:45
#   Progress:  Solving step 75/247 (25.60% of time interval complete)
#   Stats:     613 iterations in 121.33 s (197.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:40
#   Progress:  Solving step 76/247 (26.48% of time interval complete)
#   Stats:     615 iterations in 121.68 s (197.85 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:42
#   Progress:  Solving step 77/247 (27.39% of time interval complete)
#   Stats:     632 iterations in 124.91 s (197.64 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:42
#   Progress:  Solving step 78/247 (28.14% of time interval complete)
#   Stats:     645 iterations in 127.35 s (197.45 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  32%  ETA: 0:04:42
#   Progress:  Solving step 79/247 (28.32% of time interval complete)
#   Stats:     655 iterations in 129.84 s (198.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  32%  ETA: 0:04:39
#   Progress:  Solving step 80/247 (28.56% of time interval complete)
#   Stats:     659 iterations in 130.58 s (198.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:35
#   Progress:  Solving step 81/247 (29.20% of time interval complete)
#   Stats:     663 iterations in 131.33 s (198.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:33
#   Progress:  Solving step 82/247 (29.23% of time interval complete)
#   Stats:     671 iterations in 132.86 s (198.00 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:30
#   Progress:  Solving step 83/247 (30.16% of time interval complete)
#   Stats:     675 iterations in 133.55 s (197.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  34%  ETA: 0:04:31
#   Progress:  Solving step 84/247 (30.19% of time interval complete)
#   Stats:     692 iterations in 136.68 s (197.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  34%  ETA: 0:04:28
#   Progress:  Solving step 85/247 (30.22% of time interval complete)
#   Stats:     696 iterations in 137.42 s (197.44 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:25
#   Progress:  Solving step 86/247 (30.74% of time interval complete)
#   Stats:     700 iterations in 138.71 s (198.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:25
#   Progress:  Solving step 87/247 (30.92% of time interval complete)
#   Stats:     712 iterations in 140.94 s (197.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:22
#   Progress:  Solving step 88/247 (30.95% of time interval complete)
#   Stats:     717 iterations in 141.83 s (197.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  36%  ETA: 0:04:18
#   Progress:  Solving step 89/247 (31.10% of time interval complete)
#   Stats:     720 iterations in 142.34 s (197.69 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  36%  ETA: 0:04:17
#   Progress:  Solving step 90/247 (31.34% of time interval complete)
#   Stats:     730 iterations in 144.15 s (197.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  37%  ETA: 0:04:15
#   Progress:  Solving step 91/247 (31.37% of time interval complete)
#   Stats:     737 iterations in 145.73 s (197.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  37%  ETA: 0:04:13
#   Progress:  Solving step 92/247 (31.70% of time interval complete)
#   Stats:     740 iterations in 146.89 s (198.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:04:11
#   Progress:  Solving step 93/247 (31.73% of time interval complete)
#   Stats:     749 iterations in 148.55 s (198.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:04:08
#   Progress:  Solving step 94/247 (32.00% of time interval complete)
#   Stats:     752 iterations in 149.08 s (198.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:04:07
#   Progress:  Solving step 95/247 (32.94% of time interval complete)
#   Stats:     762 iterations in 150.92 s (198.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  39%  ETA: 0:04:07
#   Progress:  Solving step 96/247 (33.85% of time interval complete)
#   Stats:     775 iterations in 153.53 s (198.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  39%  ETA: 0:04:06
#   Progress:  Solving step 97/247 (34.78% of time interval complete)
#   Stats:     784 iterations in 155.97 s (198.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:04:06
#   Progress:  Solving step 98/247 (35.72% of time interval complete)
#   Stats:     798 iterations in 158.38 s (198.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:04:05
#   Progress:  Solving step 99/247 (36.56% of time interval complete)
#   Stats:     810 iterations in 160.54 s (198.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:04:03
#   Progress:  Solving step 100/247 (37.50% of time interval complete)
#   Stats:     819 iterations in 162.31 s (198.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  41%  ETA: 0:04:02
#   Progress:  Solving step 101/247 (38.41% of time interval complete)
#   Stats:     829 iterations in 164.20 s (198.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  41%  ETA: 0:04:00
#   Progress:  Solving step 102/247 (39.31% of time interval complete)
#   Stats:     836 iterations in 165.78 s (198.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:03:59
#   Progress:  Solving step 103/247 (39.34% of time interval complete)
#   Stats:     843 iterations in 167.89 s (199.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:03:56
#   Progress:  Solving step 104/247 (39.49% of time interval complete)
#   Stats:     847 iterations in 168.53 s (198.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:03:54
#   Progress:  Solving step 105/247 (39.52% of time interval complete)
#   Stats:     851 iterations in 169.32 s (198.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  43%  ETA: 0:03:51
#   Progress:  Solving step 106/247 (39.86% of time interval complete)
#   Stats:     854 iterations in 169.88 s (198.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  43%  ETA: 0:03:49
#   Progress:  Solving step 107/247 (39.89% of time interval complete)
#   Stats:     863 iterations in 171.59 s (198.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:46
#   Progress:  Solving step 108/247 (40.25% of time interval complete)
#   Stats:     869 iterations in 172.49 s (198.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:51
#   Progress:  Solving step 109/247 (40.28% of time interval complete)
#   Stats:     905 iterations in 179.13 s (197.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:48
#   Progress:  Solving step 110/247 (40.31% of time interval complete)
#   Stats:     909 iterations in 179.79 s (197.79 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  45%  ETA: 0:03:45
#   Progress:  Solving step 111/247 (40.67% of time interval complete)
#   Stats:     912 iterations in 180.31 s (197.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  45%  ETA: 0:03:45
#   Progress:  Solving step 112/247 (40.70% of time interval complete)
#   Stats:     930 iterations in 183.46 s (197.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:42
#   Progress:  Solving step 113/247 (41.12% of time interval complete)
#   Stats:     932 iterations in 183.85 s (197.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:42
#   Progress:  Solving step 114/247 (41.18% of time interval complete)
#   Stats:     944 iterations in 186.75 s (197.83 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:39
#   Progress:  Solving step 115/247 (41.46% of time interval complete)
#   Stats:     948 iterations in 187.42 s (197.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  47%  ETA: 0:03:38
#   Progress:  Solving step 116/247 (41.64% of time interval complete)
#   Stats:     961 iterations in 189.60 s (197.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  47%  ETA: 0:03:36
#   Progress:  Solving step 117/247 (42.12% of time interval complete)
#   Stats:     967 iterations in 190.72 s (197.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:35
#   Progress:  Solving step 118/247 (42.39% of time interval complete)
#   Stats:     977 iterations in 192.64 s (197.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:32
#   Progress:  Solving step 119/247 (43.03% of time interval complete)
#   Stats:     983 iterations in 193.59 s (196.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:32
#   Progress:  Solving step 120/247 (43.96% of time interval complete)
#   Stats:     995 iterations in 196.50 s (197.49 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  49%  ETA: 0:03:31
#   Progress:  Solving step 121/247 (44.87% of time interval complete)
#   Stats:     1009 iterations in 199.16 s (197.38 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  49%  ETA: 0:03:30
#   Progress:  Solving step 122/247 (45.71% of time interval complete)
#   Stats:     1018 iterations in 200.96 s (197.41 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:28
#   Progress:  Solving step 123/247 (45.80% of time interval complete)
#   Stats:     1026 iterations in 202.44 s (197.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:25
#   Progress:  Solving step 124/247 (46.74% of time interval complete)
#   Stats:     1031 iterations in 203.27 s (197.16 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:26
#   Progress:  Solving step 125/247 (47.07% of time interval complete)
#   Stats:     1047 iterations in 207.22 s (197.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  51%  ETA: 0:03:23
#   Progress:  Solving step 126/247 (47.10% of time interval complete)
#   Stats:     1051 iterations in 207.92 s (197.83 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  51%  ETA: 0:03:21
#   Progress:  Solving step 127/247 (47.58% of time interval complete)
#   Stats:     1054 iterations in 208.42 s (197.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:19
#   Progress:  Solving step 128/247 (48.52% of time interval complete)
#   Stats:     1065 iterations in 210.35 s (197.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:18
#   Progress:  Solving step 129/247 (49.43% of time interval complete)
#   Stats:     1075 iterations in 212.02 s (197.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:16
#   Progress:  Solving step 130/247 (50.36% of time interval complete)
#   Stats:     1084 iterations in 213.63 s (197.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  53%  ETA: 0:03:15
#   Progress:  Solving step 131/247 (51.27% of time interval complete)
#   Stats:     1092 iterations in 215.75 s (197.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  53%  ETA: 0:03:13
#   Progress:  Solving step 132/247 (51.48% of time interval complete)
#   Stats:     1100 iterations in 217.28 s (197.53 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:03:10
#   Progress:  Solving step 133/247 (51.57% of time interval complete)
#   Stats:     1104 iterations in 217.97 s (197.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:03:08
#   Progress:  Solving step 134/247 (51.69% of time interval complete)
#   Stats:     1110 iterations in 219.05 s (197.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:03:06
#   Progress:  Solving step 135/247 (52.20% of time interval complete)
#   Stats:     1115 iterations in 219.89 s (197.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  55%  ETA: 0:03:05
#   Progress:  Solving step 136/247 (52.60% of time interval complete)
#   Stats:     1128 iterations in 222.18 s (196.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  55%  ETA: 0:03:03
#   Progress:  Solving step 137/247 (53.14% of time interval complete)
#   Stats:     1134 iterations in 223.30 s (196.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:03:02
#   Progress:  Solving step 138/247 (53.17% of time interval complete)
#   Stats:     1146 iterations in 226.25 s (197.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:02:59
#   Progress:  Solving step 139/247 (53.56% of time interval complete)
#   Stats:     1148 iterations in 226.63 s (197.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:03:00
#   Progress:  Solving step 140/247 (54.05% of time interval complete)
#   Stats:     1169 iterations in 230.47 s (197.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  57%  ETA: 0:02:58
#   Progress:  Solving step 141/247 (54.23% of time interval complete)
#   Stats:     1176 iterations in 231.70 s (197.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  57%  ETA: 0:02:55
#   Progress:  Solving step 142/247 (54.44% of time interval complete)
#   Stats:     1180 iterations in 232.31 s (196.87 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:53
#   Progress:  Solving step 143/247 (54.98% of time interval complete)
#   Stats:     1187 iterations in 233.58 s (196.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:53
#   Progress:  Solving step 144/247 (55.43% of time interval complete)
#   Stats:     1203 iterations in 236.99 s (197.00 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:51
#   Progress:  Solving step 145/247 (55.89% of time interval complete)
#   Stats:     1213 iterations in 238.72 s (196.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  59%  ETA: 0:02:50
#   Progress:  Solving step 146/247 (56.58% of time interval complete)
#   Stats:     1224 iterations in 240.61 s (196.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  59%  ETA: 0:02:48
#   Progress:  Solving step 147/247 (56.82% of time interval complete)
#   Stats:     1232 iterations in 242.05 s (196.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:46
#   Progress:  Solving step 148/247 (56.85% of time interval complete)
#   Stats:     1238 iterations in 243.00 s (196.28 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:43
#   Progress:  Solving step 149/247 (57.16% of time interval complete)
#   Stats:     1241 iterations in 243.49 s (196.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:43
#   Progress:  Solving step 150/247 (57.40% of time interval complete)
#   Stats:     1259 iterations in 247.52 s (196.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  61%  ETA: 0:02:42
#   Progress:  Solving step 151/247 (57.76% of time interval complete)
#   Stats:     1273 iterations in 250.04 s (196.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  61%  ETA: 0:02:42
#   Progress:  Solving step 152/247 (58.15% of time interval complete)
#   Stats:     1292 iterations in 253.65 s (196.32 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:40
#   Progress:  Solving step 153/247 (58.61% of time interval complete)
#   Stats:     1299 iterations in 255.07 s (196.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:39
#   Progress:  Solving step 154/247 (58.76% of time interval complete)
#   Stats:     1315 iterations in 258.54 s (196.61 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:37
#   Progress:  Solving step 155/247 (58.79% of time interval complete)
#   Stats:     1320 iterations in 259.33 s (196.46 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  63%  ETA: 0:02:34
#   Progress:  Solving step 156/247 (59.54% of time interval complete)
#   Stats:     1322 iterations in 259.65 s (196.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  63%  ETA: 0:02:33
#   Progress:  Solving step 157/247 (60.45% of time interval complete)
#   Stats:     1340 iterations in 262.57 s (195.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  64%  ETA: 0:02:32
#   Progress:  Solving step 158/247 (61.38% of time interval complete)
#   Stats:     1348 iterations in 263.91 s (195.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  64%  ETA: 0:02:30
#   Progress:  Solving step 159/247 (61.44% of time interval complete)
#   Stats:     1357 iterations in 265.64 s (195.76 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:28
#   Progress:  Solving step 160/247 (62.29% of time interval complete)
#   Stats:     1360 iterations in 266.75 s (196.14 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:26
#   Progress:  Solving step 161/247 (62.56% of time interval complete)
#   Stats:     1372 iterations in 268.68 s (195.83 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:24
#   Progress:  Solving step 162/247 (63.22% of time interval complete)
#   Stats:     1378 iterations in 269.74 s (195.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  66%  ETA: 0:02:23
#   Progress:  Solving step 163/247 (63.50% of time interval complete)
#   Stats:     1395 iterations in 272.82 s (195.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  66%  ETA: 0:02:21
#   Progress:  Solving step 164/247 (63.56% of time interval complete)
#   Stats:     1401 iterations in 274.01 s (195.58 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:19
#   Progress:  Solving step 165/247 (64.16% of time interval complete)
#   Stats:     1404 iterations in 274.52 s (195.52 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:21
#   Progress:  Solving step 166/247 (64.19% of time interval complete)
#   Stats:     1446 iterations in 282.46 s (195.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:18
#   Progress:  Solving step 167/247 (64.43% of time interval complete)
#   Stats:     1449 iterations in 282.90 s (195.24 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  68%  ETA: 0:02:17
#   Progress:  Solving step 168/247 (64.49% of time interval complete)
#   Stats:     1468 iterations in 286.19 s (194.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  68%  ETA: 0:02:15
#   Progress:  Solving step 169/247 (64.52% of time interval complete)
#   Stats:     1471 iterations in 286.80 s (194.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:13
#   Progress:  Solving step 170/247 (64.61% of time interval complete)
#   Stats:     1473 iterations in 287.16 s (194.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:11
#   Progress:  Solving step 171/247 (65.07% of time interval complete)
#   Stats:     1478 iterations in 288.80 s (195.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:09
#   Progress:  Solving step 172/247 (65.73% of time interval complete)
#   Stats:     1488 iterations in 290.73 s (195.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  70%  ETA: 0:02:11
#   Progress:  Solving step 173/247 (66.00% of time interval complete)
#   Stats:     1547 iterations in 301.08 s (194.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  70%  ETA: 0:02:09
#   Progress:  Solving step 174/247 (66.52% of time interval complete)
#   Stats:     1552 iterations in 301.96 s (194.56 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:02:08
#   Progress:  Solving step 175/247 (66.91% of time interval complete)
#   Stats:     1562 iterations in 304.27 s (194.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:02:06
#   Progress:  Solving step 176/247 (67.12% of time interval complete)
#   Stats:     1570 iterations in 305.56 s (194.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:02:04
#   Progress:  Solving step 177/247 (67.15% of time interval complete)
#   Stats:     1573 iterations in 306.03 s (194.55 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  72%  ETA: 0:02:01
#   Progress:  Solving step 178/247 (67.42% of time interval complete)
#   Stats:     1575 iterations in 306.35 s (194.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  72%  ETA: 0:01:59
#   Progress:  Solving step 179/247 (67.84% of time interval complete)
#   Stats:     1581 iterations in 307.29 s (194.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:58
#   Progress:  Solving step 180/247 (68.39% of time interval complete)
#   Stats:     1595 iterations in 309.80 s (194.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:56
#   Progress:  Solving step 181/247 (68.42% of time interval complete)
#   Stats:     1604 iterations in 311.37 s (194.12 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:54
#   Progress:  Solving step 182/247 (68.78% of time interval complete)
#   Stats:     1607 iterations in 311.88 s (194.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  74%  ETA: 0:01:53
#   Progress:  Solving step 183/247 (69.66% of time interval complete)
#   Stats:     1620 iterations in 315.04 s (194.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  74%  ETA: 0:01:51
#   Progress:  Solving step 184/247 (70.59% of time interval complete)
#   Stats:     1631 iterations in 317.06 s (194.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:49
#   Progress:  Solving step 185/247 (71.50% of time interval complete)
#   Stats:     1641 iterations in 319.06 s (194.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:48
#   Progress:  Solving step 186/247 (72.43% of time interval complete)
#   Stats:     1649 iterations in 320.57 s (194.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:46
#   Progress:  Solving step 187/247 (73.34% of time interval complete)
#   Stats:     1658 iterations in 322.15 s (194.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  76%  ETA: 0:01:44
#   Progress:  Solving step 188/247 (73.40% of time interval complete)
#   Stats:     1668 iterations in 324.62 s (194.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  76%  ETA: 0:01:42
#   Progress:  Solving step 189/247 (74.06% of time interval complete)
#   Stats:     1671 iterations in 325.14 s (194.58 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:40
#   Progress:  Solving step 190/247 (74.28% of time interval complete)
#   Stats:     1681 iterations in 326.92 s (194.48 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:39
#   Progress:  Solving step 191/247 (74.70% of time interval complete)
#   Stats:     1688 iterations in 328.11 s (194.38 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:37
#   Progress:  Solving step 192/247 (74.73% of time interval complete)
#   Stats:     1693 iterations in 329.11 s (194.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  78%  ETA: 0:01:35
#   Progress:  Solving step 193/247 (75.21% of time interval complete)
#   Stats:     1696 iterations in 329.66 s (194.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  78%  ETA: 0:01:33
#   Progress:  Solving step 194/247 (75.79% of time interval complete)
#   Stats:     1708 iterations in 331.95 s (194.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:31
#   Progress:  Solving step 195/247 (76.12% of time interval complete)
#   Stats:     1716 iterations in 334.11 s (194.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:32
#   Progress:  Solving step 196/247 (77.05% of time interval complete)
#   Stats:     1773 iterations in 344.09 s (194.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:31
#   Progress:  Solving step 197/247 (77.96% of time interval complete)
#   Stats:     1796 iterations in 348.24 s (193.90 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  80%  ETA: 0:01:29
#   Progress:  Solving step 198/247 (78.89% of time interval complete)
#   Stats:     1804 iterations in 350.22 s (194.14 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  80%  ETA: 0:01:27
#   Progress:  Solving step 199/247 (79.23% of time interval complete)
#   Stats:     1811 iterations in 351.44 s (194.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:25
#   Progress:  Solving step 200/247 (79.65% of time interval complete)
#   Stats:     1815 iterations in 352.13 s (194.01 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:23
#   Progress:  Solving step 201/247 (79.83% of time interval complete)
#   Stats:     1819 iterations in 352.78 s (193.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:21
#   Progress:  Solving step 202/247 (80.68% of time interval complete)
#   Stats:     1826 iterations in 353.88 s (193.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  82%  ETA: 0:01:19
#   Progress:  Solving step 203/247 (81.34% of time interval complete)
#   Stats:     1837 iterations in 355.64 s (193.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  82%  ETA: 0:01:17
#   Progress:  Solving step 204/247 (81.37% of time interval complete)
#   Stats:     1843 iterations in 356.75 s (193.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:16
#   Progress:  Solving step 205/247 (81.61% of time interval complete)
#   Stats:     1845 iterations in 357.74 s (193.90 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:14
#   Progress:  Solving step 206/247 (82.31% of time interval complete)
#   Stats:     1850 iterations in 358.58 s (193.83 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:12
#   Progress:  Solving step 207/247 (82.52% of time interval complete)
#   Stats:     1857 iterations in 359.74 s (193.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  84%  ETA: 0:01:10
#   Progress:  Solving step 208/247 (83.45% of time interval complete)
#   Stats:     1861 iterations in 360.37 s (193.64 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  84%  ETA: 0:01:08
#   Progress:  Solving step 209/247 (83.48% of time interval complete)
#   Stats:     1874 iterations in 362.45 s (193.41 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:06
#   Progress:  Solving step 210/247 (84.21% of time interval complete)
#   Stats:     1877 iterations in 362.93 s (193.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:04
#   Progress:  Solving step 211/247 (84.36% of time interval complete)
#   Stats:     1887 iterations in 364.62 s (193.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:03
#   Progress:  Solving step 212/247 (84.63% of time interval complete)
#   Stats:     1894 iterations in 366.42 s (193.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  86%  ETA: 0:01:01
#   Progress:  Solving step 213/247 (84.81% of time interval complete)
#   Stats:     1901 iterations in 367.64 s (193.39 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  86%  ETA: 0:00:59
#   Progress:  Solving step 214/247 (85.21% of time interval complete)
#   Stats:     1905 iterations in 368.33 s (193.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  87%  ETA: 0:00:57
#   Progress:  Solving step 215/247 (85.30% of time interval complete)
#   Stats:     1913 iterations in 369.64 s (193.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  87%  ETA: 0:00:55
#   Progress:  Solving step 216/247 (85.36% of time interval complete)
#   Stats:     1915 iterations in 370.01 s (193.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:53
#   Progress:  Solving step 217/247 (85.39% of time interval complete)
#   Stats:     1917 iterations in 370.32 s (193.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:51
#   Progress:  Solving step 218/247 (86.23% of time interval complete)
#   Stats:     1920 iterations in 370.76 s (193.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:50
#   Progress:  Solving step 219/247 (86.62% of time interval complete)
#   Stats:     1931 iterations in 372.97 s (193.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  89%  ETA: 0:00:48
#   Progress:  Solving step 220/247 (87.14% of time interval complete)
#   Stats:     1937 iterations in 374.03 s (193.10 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  89%  ETA: 0:00:46
#   Progress:  Solving step 221/247 (88.07% of time interval complete)
#   Stats:     1943 iterations in 375.00 s (193.00 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:44
#   Progress:  Solving step 222/247 (88.98% of time interval complete)
#   Stats:     1952 iterations in 376.37 s (192.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:43
#   Progress:  Solving step 223/247 (89.01% of time interval complete)
#   Stats:     1959 iterations in 377.69 s (192.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:41
#   Progress:  Solving step 224/247 (89.86% of time interval complete)
#   Stats:     1962 iterations in 378.23 s (192.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  91%  ETA: 0:00:39
#   Progress:  Solving step 225/247 (89.92% of time interval complete)
#   Stats:     1974 iterations in 380.19 s (192.60 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  91%  ETA: 0:00:37
#   Progress:  Solving step 226/247 (90.43% of time interval complete)
#   Stats:     1977 iterations in 381.35 s (192.89 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:36
#   Progress:  Solving step 227/247 (90.85% of time interval complete)
#   Stats:     1986 iterations in 383.14 s (192.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:34
#   Progress:  Solving step 228/247 (91.55% of time interval complete)
#   Stats:     1992 iterations in 384.19 s (192.87 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:32
#   Progress:  Solving step 229/247 (91.70% of time interval complete)
#   Stats:     1998 iterations in 385.33 s (192.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  93%  ETA: 0:00:30
#   Progress:  Solving step 230/247 (92.63% of time interval complete)
#   Stats:     2003 iterations in 386.13 s (192.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  93%  ETA: 0:00:29
#   Progress:  Solving step 231/247 (93.36% of time interval complete)
#   Stats:     2017 iterations in 388.68 s (192.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:27
#   Progress:  Solving step 232/247 (93.54% of time interval complete)
#   Stats:     2023 iterations in 389.86 s (192.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:25
#   Progress:  Solving step 233/247 (94.47% of time interval complete)
#   Stats:     2028 iterations in 391.33 s (192.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:24
#   Progress:  Solving step 234/247 (95.38% of time interval complete)
#   Stats:     2042 iterations in 393.95 s (192.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  95%  ETA: 0:00:22
#   Progress:  Solving step 235/247 (96.32% of time interval complete)
#   Stats:     2050 iterations in 395.40 s (192.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  95%  ETA: 0:00:20
#   Progress:  Solving step 236/247 (96.74% of time interval complete)
#   Stats:     2057 iterations in 396.63 s (192.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:19
#   Progress:  Solving step 237/247 (96.77% of time interval complete)
#   Stats:     2060 iterations in 397.20 s (192.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:17
#   Progress:  Solving step 238/247 (97.25% of time interval complete)
#   Stats:     2062 iterations in 397.53 s (192.79 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:15
#   Progress:  Solving step 239/247 (97.64% of time interval complete)
#   Stats:     2073 iterations in 400.42 s (193.16 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  97%  ETA: 0:00:13
#   Progress:  Solving step 240/247 (98.16% of time interval complete)
#   Stats:     2079 iterations in 401.69 s (193.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  97%  ETA: 0:00:12
#   Progress:  Solving step 241/247 (98.43% of time interval complete)
#   Stats:     2084 iterations in 402.76 s (193.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:10
#   Progress:  Solving step 242/247 (98.58% of time interval complete)
#   Stats:     2087 iterations in 403.34 s (193.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:08
#   Progress:  Solving step 243/247 (99.09% of time interval complete)
#   Stats:     2089 iterations in 403.75 s (193.27 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:07
#   Progress:  Solving step 244/247 (99.34% of time interval complete)
#   Stats:     2099 iterations in 405.65 s (193.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:05
#   Progress:  Solving step 245/247 (99.40% of time interval complete)
#   Stats:     2103 iterations in 406.50 s (193.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:03
#   Progress:  Solving step 246/247 (99.58% of time interval complete)
#   Stats:     2106 iterations in 407.07 s (193.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:02
#   Progress:  Solving step 247/247 (100.00% of time interval complete)
#   Stats:     2113 iterations in 408.38 s (193.27 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps 100% Time: 0:06:53
#   Progress:  Solved step 247/247
#   Stats:     2119 iterations in 410.43 s (193.69 ms each)
# ╭────────────────┬───────────┬───────────────┬─────────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │       Total │
# │                │ 247 steps │ 479 ministeps │    (wasted) │
# ├────────────────┼───────────┼───────────────┼─────────────┤
# │ Newton         │   8.57895 │        4.4238 │   2119 (90) │
# │ Linearization  │   10.5182 │        5.4238 │   2598 (96) │
# │ Linear solver  │   30.5628 │       15.7599 │  7549 (387) │
# │ Precond apply  │   61.1255 │       31.5198 │ 15098 (774) │
# ╰────────────────┴───────────┴───────────────┴─────────────╯
# ╭───────────────┬──────────┬────────────┬──────────╮
# │ Timing type   │     Each │   Relative │    Total │
# │               │       ms │ Percentage │        s │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Properties    │  20.4604 │    10.56 % │  43.3555 │
# │ Equations     │  26.5599 │    16.81 % │  69.0026 │
# │ Assembly      │  10.8409 │     6.86 % │  28.1647 │
# │ Linear solve  │  13.3978 │     6.92 % │  28.3900 │
# │ Linear setup  │  56.6884 │    29.27 % │ 120.1226 │
# │ Precond apply │   6.7189 │    24.72 % │ 101.4414 │
# │ Update        │   3.1860 │     1.64 % │   6.7512 │
# │ Convergence   │   1.7023 │     1.08 % │   4.4227 │
# │ Input/Output  │   4.4435 │     0.52 % │   2.1285 │
# │ Other         │   3.1386 │     1.62 % │   6.6506 │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Total         │ 193.6903 │   100.00 % │ 410.4298 │
# ╰───────────────┴──────────┴────────────┴──────────╯
# ReservoirSimResult with 473 entries:
#
#   wells (36 present):
#     :B-4H
#     :F-4H
#     :D-4H
#     :F-2H
#     :D-2H
#     :B-1H
#     :C-4H
#     :C-1H
#     :B-2H
#     :E-1H
#     :B-4BH
#     :D-3AH
#     :D-3BH
#     :C-3H
#     :E-3H
#     :K-3H
#     :E-4AH
#     :D-1H
#     :B-1AH
#     :E-3CH
#     :E-4H
#     :E-2H
#     :E-2AH
#     :C-4AH
#     :B-1BH
#     :C-2H
#     :B-4DH
#     :D-3H
#     :E-3AH
#     :D-4AH
#     :B-3H
#     :F-3H
#     :E-3BH
#     :D-1CH
#     :F-1H
#     :B-4AH
#     Results per well:
#        :wrat => Vector{Float64} of size (473,)
#        :Aqueous_mass_rate => Vector{Float64} of size (473,)
#        :orat => Vector{Float64} of size (473,)
#        :bhp => Vector{Float64} of size (473,)
#        :lrat => Vector{Float64} of size (473,)
#        :mass_rate => Vector{Float64} of size (473,)
#        :rate => Vector{Float64} of size (473,)
#        :Vapor_mass_rate => Vector{Float64} of size (473,)
#        :control => Vector{Symbol} of size (473,)
#        :Liquid_mass_rate => Vector{Float64} of size (473,)
#        :grat => Vector{Float64} of size (473,)
#
#   states (Vector with 473 entries, reservoir variables for each state)
#     :Rv => Vector{Float64} of size (44417,)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (44417,)
#     :Saturations => Matrix{Float64} of size (3, 44417)
#     :Pressure => Vector{Float64} of size (44417,)
#     :Rs => Vector{Float64} of size (44417,)
#     :ImmiscibleSaturation => Vector{Float64} of size (44417,)
#     :TotalMasses => Matrix{Float64} of size (3, 44417)
#
#   time (report time for each state)
#      Vector{Float64} of length 473
#
#   result (extended states, reports)
#      SimResult with 247 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 27 2024 20:06 after 6 minutes, 48 seconds, 301.4 milliseconds.

# %% [markdown]
# ## Plot the reservoir solution

# %%
fig = plot_reservoir(case.model, states, step = 247, key = :Saturations)
ax = fig.current_axis[]
ax.azimuth[] = -3.0
ax.elevation[] = 0.5
fig
# Out:
# Figure()

# %% [markdown]
# ## Plot the reservoir static properties

# %%
fig = plot_reservoir(case.model, key = :porosity)
ax = fig.current_axis[]
ax.azimuth[] = -3.0
ax.elevation[] = 0.5
fig
# Out:
# Figure()

# %% [markdown]
# ## Load reference and set up plotting

# %%
csv_path = joinpath(norne_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat] + well[:grat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response")
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :grat
        ys = si_unit(:day)/1e6
        yl = "Surface gas rate / 10⁶ m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        grat_ref = data[:, findfirst(x -> x == "$well_name:grat", vec(header))]
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = grat_ref + orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "OPM Flow"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Injector bhp

# %%
plot_well_comparison(:bhp, inj, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Gas injection rates

# %%
plot_well_comparison(:grat, inj, "Gas surface injection rate")
# Out:
# Figure()

# %% [markdown]
# ## Water injection rates

# %%
plot_well_comparison(:wrat, inj, "Water surface injection rate")
# Out:
# Figure()

# %% [markdown]
# ## Producer bhp

# %%
plot_well_comparison(:bhp, prod, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Oil production rates

# %%
plot_well_comparison(:orat, prod, "Oil surface production rate")
# Out:
# Figure()

# %% [markdown]
# ## Gas production rates

# %%
plot_well_comparison(:grat, prod, "Gas surface production rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
