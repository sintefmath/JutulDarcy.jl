# %% [markdown]
# # A more complex compositional model
# This example sets up a more complex compositional simulation with five
# different components. Other than that, the example is similar to the others
# that include wells and is therefore not commented in great detail.

# %%
using MultiComponentFlash

n2_ch4 = MolecularProperty(0.0161594, 4.58e6, 189.515, 9.9701e-05, 0.00854)
co2 = MolecularProperty(0.04401, 7.3866e6, 304.200, 9.2634e-05, 0.228)
c2_5 = MolecularProperty(0.0455725, 4.0955e6, 387.607, 2.1708e-04, 0.16733)
c6_13 = MolecularProperty(0.117740, 3.345e6, 597.497, 3.8116e-04, 0.38609)
c14_24 = MolecularProperty(0.248827, 1.768e6, 698.515, 7.2141e-04, 0.80784)

bic = [0.11883 0.00070981 0.00077754 0.01 0.011;
       0.00070981 0.15 0.15 0.15 0.15;
       0.00077754 0.15 0 0 0;
       0.01 0.15 0 0 0;
       0.011 0.15 0 0 0]

mixture = MultiComponentMixture([n2_ch4, co2, c2_5, c6_13, c14_24], A_ij = bic, names = ["N2-CH4", "CO2", "C2-5", "C6-13", "C14-24"])
eos = GenericCubicEOS(mixture, PengRobinson())

using Jutul, JutulDarcy, GLMakie
Darcy, bar, kg, meter, Kelvin, day = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day)
nx = ny = 20
nz = 2

dims = (nx, ny, nz)
g = CartesianMesh(dims, (1000.0, 1000.0, 1.0))
nc = number_of_cells(g)
K = repeat([0.05*Darcy], 1, nc)
res = reservoir_domain(g, porosity = 0.25, permeability = K, temperature = 387.45*Kelvin)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 20x20x2=800 cells with 18 data fields added:
#   800 Cells
#     :permeability => 1×800 Matrix{Float64}
#     :porosity => 800 Vector{Float64}
#     :rock_thermal_conductivity => 800 Vector{Float64}
#     :fluid_thermal_conductivity => 800 Vector{Float64}
#     :rock_density => 800 Vector{Float64}
#     :temperature => 800 Vector{Float64}
#     :cell_centroids => 3×800 Matrix{Float64}
#     :volumes => 800 Vector{Float64}
#   1920 Faces
#     :neighbors => 2×1920 Matrix{Int64}
#     :areas => 1920 Vector{Float64}
#     :normals => 3×1920 Matrix{Float64}
#     :face_centroids => 3×1920 Matrix{Float64}
#   3840 HalfFaces
#     :half_face_cells => 3840 Vector{Int64}
#     :half_face_faces => 3840 Vector{Int64}
#   960 BoundaryFaces
#     :boundary_areas => 960 Vector{Float64}
#     :boundary_centroids => 3×960 Matrix{Float64}
#     :boundary_normals => 3×960 Matrix{Float64}
#     :boundary_neighbors => 960 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in all layers

# %%
prod = setup_vertical_well(g, K, nx, ny, name = :Producer)
# Out:
# MultiSegmentWell [Producer] (3 nodes, 2 segments, 2 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in all layers

# %%
inj = setup_vertical_well(g, K, 1, 1, name = :Injector)

rhoLS = 1000.0*kg/meter^3
rhoVS = 100.0*kg/meter^3

rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
# Out:
# (LiquidPhase(), VaporPhase())

# %% [markdown]
# Define system and realize on grid

# %%
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod], block_backend = true);
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)

push!(model[:Reservoir].output_variables, :Saturations)

state0 = setup_reservoir_state(model, Pressure = 225*bar, OverallMoleFractions = [0.463, 0.01640, 0.20520, 0.19108, 0.12432]);

dt = repeat([2.0]*day, 365)
rate_target = TotalRateTarget(0.0015)
I_ctrl = InjectorControl(rate_target, [0, 1, 0, 0, 0], density = rhoVS)
bhp_target = BottomHolePressureTarget(100*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:58:45
#   Progress:  Solving step 2/365 (0.55% of time interval complete)
#   Stats:     9 iterations in 14.59 s (1.62 s each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:39:17
#   Progress:  Solving step 3/365 (0.82% of time interval complete)
#   Stats:     15 iterations in 14.70 s (979.83 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:23:35
#   Progress:  Solving step 5/365 (1.37% of time interval complete)
#   Stats:     22 iterations in 14.82 s (673.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   2%| |  ETA: 0:16:51
#   Progress:  Solving step 7/365 (1.92% of time interval complete)
#   Stats:     28 iterations in 14.94 s (533.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   2%| |  ETA: 0:13:07
#   Progress:  Solving step 9/365 (2.47% of time interval complete)
#   Stats:     34 iterations in 15.05 s (442.60 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   3%| |  ETA: 0:10:44
#   Progress:  Solving step 11/365 (3.01% of time interval complete)
#   Stats:     40 iterations in 15.17 s (379.15 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   4%| |  ETA: 0:09:05
#   Progress:  Solving step 13/365 (3.56% of time interval complete)
#   Stats:     46 iterations in 15.29 s (332.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   4%| |  ETA: 0:07:53
#   Progress:  Solving step 15/365 (4.11% of time interval complete)
#   Stats:     52 iterations in 15.42 s (296.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   5%| |  ETA: 0:06:58
#   Progress:  Solving step 17/365 (4.66% of time interval complete)
#   Stats:     58 iterations in 15.56 s (268.28 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   5%| |  ETA: 0:06:14
#   Progress:  Solving step 19/365 (5.21% of time interval complete)
#   Stats:     64 iterations in 15.71 s (245.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   6%| |  ETA: 0:05:39
#   Progress:  Solving step 21/365 (5.75% of time interval complete)
#   Stats:     68 iterations in 15.83 s (232.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   6%|▏|  ETA: 0:05:09
#   Progress:  Solving step 23/365 (6.30% of time interval complete)
#   Stats:     72 iterations in 15.95 s (221.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   7%|▏|  ETA: 0:04:44
#   Progress:  Solving step 25/365 (6.85% of time interval complete)
#   Stats:     76 iterations in 16.07 s (211.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   7%|▏|  ETA: 0:04:23
#   Progress:  Solving step 27/365 (7.40% of time interval complete)
#   Stats:     80 iterations in 16.20 s (202.53 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   8%|▏|  ETA: 0:04:05
#   Progress:  Solving step 29/365 (7.95% of time interval complete)
#   Stats:     84 iterations in 16.34 s (194.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   8%|▏|  ETA: 0:03:50
#   Progress:  Solving step 31/365 (8.49% of time interval complete)
#   Stats:     88 iterations in 16.48 s (187.23 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   9%|▏|  ETA: 0:03:36
#   Progress:  Solving step 33/365 (9.04% of time interval complete)
#   Stats:     92 iterations in 16.62 s (180.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  10%|▏|  ETA: 0:03:24
#   Progress:  Solving step 35/365 (9.59% of time interval complete)
#   Stats:     96 iterations in 16.75 s (174.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  10%|▏|  ETA: 0:03:13
#   Progress:  Solving step 37/365 (10.14% of time interval complete)
#   Stats:     100 iterations in 16.89 s (168.91 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:03:03
#   Progress:  Solving step 39/365 (10.68% of time interval complete)
#   Stats:     104 iterations in 17.03 s (163.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:02:59
#   Progress:  Solving step 40/365 (10.96% of time interval complete)
#   Stats:     106 iterations in 17.16 s (161.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:02:50
#   Progress:  Solving step 42/365 (11.51% of time interval complete)
#   Stats:     110 iterations in 17.30 s (157.24 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  12%|▏|  ETA: 0:02:43
#   Progress:  Solving step 44/365 (12.05% of time interval complete)
#   Stats:     114 iterations in 17.44 s (152.98 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  13%|▏|  ETA: 0:02:36
#   Progress:  Solving step 46/365 (12.60% of time interval complete)
#   Stats:     118 iterations in 17.58 s (149.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  13%|▏|  ETA: 0:02:29
#   Progress:  Solving step 48/365 (13.15% of time interval complete)
#   Stats:     122 iterations in 17.73 s (145.29 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  14%|▏|  ETA: 0:02:23
#   Progress:  Solving step 50/365 (13.70% of time interval complete)
#   Stats:     126 iterations in 17.87 s (141.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  14%|▏|  ETA: 0:02:18
#   Progress:  Solving step 52/365 (14.25% of time interval complete)
#   Stats:     130 iterations in 18.01 s (138.53 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  15%|▏|  ETA: 0:02:13
#   Progress:  Solving step 54/365 (14.79% of time interval complete)
#   Stats:     134 iterations in 18.15 s (135.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  15%|▏|  ETA: 0:02:08
#   Progress:  Solving step 56/365 (15.34% of time interval complete)
#   Stats:     138 iterations in 18.29 s (132.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  16%|▏|  ETA: 0:02:03
#   Progress:  Solving step 58/365 (15.89% of time interval complete)
#   Stats:     142 iterations in 18.44 s (129.83 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  16%|▏|  ETA: 0:01:59
#   Progress:  Solving step 60/365 (16.44% of time interval complete)
#   Stats:     146 iterations in 18.58 s (127.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  17%|▏|  ETA: 0:01:55
#   Progress:  Solving step 62/365 (16.99% of time interval complete)
#   Stats:     150 iterations in 18.72 s (124.82 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  17%|▏|  ETA: 0:01:52
#   Progress:  Solving step 64/365 (17.53% of time interval complete)
#   Stats:     154 iterations in 18.87 s (122.53 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  18%|▏|  ETA: 0:01:48
#   Progress:  Solving step 66/365 (18.08% of time interval complete)
#   Stats:     158 iterations in 19.02 s (120.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  19%|▏|  ETA: 0:01:45
#   Progress:  Solving step 68/365 (18.63% of time interval complete)
#   Stats:     162 iterations in 19.17 s (118.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  19%|▎|  ETA: 0:01:42
#   Progress:  Solving step 70/365 (19.18% of time interval complete)
#   Stats:     166 iterations in 19.31 s (116.34 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  20%|▎|  ETA: 0:01:39
#   Progress:  Solving step 72/365 (19.73% of time interval complete)
#   Stats:     170 iterations in 19.46 s (114.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  20%|▎|  ETA: 0:01:36
#   Progress:  Solving step 74/365 (20.27% of time interval complete)
#   Stats:     174 iterations in 19.60 s (112.67 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  21%|▎|  ETA: 0:01:34
#   Progress:  Solving step 76/365 (20.82% of time interval complete)
#   Stats:     178 iterations in 19.75 s (110.93 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  21%|▎|  ETA: 0:01:31
#   Progress:  Solving step 78/365 (21.37% of time interval complete)
#   Stats:     182 iterations in 19.89 s (109.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  22%|▎|  ETA: 0:01:29
#   Progress:  Solving step 80/365 (21.92% of time interval complete)
#   Stats:     186 iterations in 20.03 s (107.69 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  22%|▎|  ETA: 0:01:26
#   Progress:  Solving step 82/365 (22.47% of time interval complete)
#   Stats:     190 iterations in 20.17 s (106.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  23%|▎|  ETA: 0:01:24
#   Progress:  Solving step 84/365 (23.01% of time interval complete)
#   Stats:     194 iterations in 20.31 s (104.70 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  23%|▎|  ETA: 0:01:22
#   Progress:  Solving step 86/365 (23.56% of time interval complete)
#   Stats:     198 iterations in 20.45 s (103.30 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  24%|▎|  ETA: 0:01:20
#   Progress:  Solving step 88/365 (24.11% of time interval complete)
#   Stats:     202 iterations in 20.65 s (102.22 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  25%|▎|  ETA: 0:01:18
#   Progress:  Solving step 90/365 (24.66% of time interval complete)
#   Stats:     206 iterations in 20.79 s (100.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  25%|▎|  ETA: 0:01:17
#   Progress:  Solving step 92/365 (25.21% of time interval complete)
#   Stats:     210 iterations in 20.93 s (99.67 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  26%|▎|  ETA: 0:01:15
#   Progress:  Solving step 94/365 (25.75% of time interval complete)
#   Stats:     214 iterations in 21.07 s (98.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  26%|▎|  ETA: 0:01:13
#   Progress:  Solving step 96/365 (26.30% of time interval complete)
#   Stats:     218 iterations in 21.21 s (97.29 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:12
#   Progress:  Solving step 98/365 (26.85% of time interval complete)
#   Stats:     223 iterations in 21.38 s (95.89 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:10
#   Progress:  Solving step 100/365 (27.40% of time interval complete)
#   Stats:     227 iterations in 21.52 s (94.82 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  28%|▎|  ETA: 0:01:08
#   Progress:  Solving step 102/365 (27.95% of time interval complete)
#   Stats:     231 iterations in 21.66 s (93.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  28%|▎|  ETA: 0:01:07
#   Progress:  Solving step 104/365 (28.49% of time interval complete)
#   Stats:     235 iterations in 21.80 s (92.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  29%|▎|  ETA: 0:01:06
#   Progress:  Solving step 106/365 (29.04% of time interval complete)
#   Stats:     239 iterations in 21.94 s (91.81 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  30%|▎|  ETA: 0:01:04
#   Progress:  Solving step 108/365 (29.59% of time interval complete)
#   Stats:     243 iterations in 22.08 s (90.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  30%|▎|  ETA: 0:01:03
#   Progress:  Solving step 110/365 (30.14% of time interval complete)
#   Stats:     247 iterations in 22.22 s (89.97 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  31%|▎|  ETA: 0:01:02
#   Progress:  Solving step 112/365 (30.68% of time interval complete)
#   Stats:     251 iterations in 22.37 s (89.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  31%|▎|  ETA: 0:01:00
#   Progress:  Solving step 114/365 (31.23% of time interval complete)
#   Stats:     255 iterations in 22.51 s (88.28 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  32%|▍|  ETA: 0:00:59
#   Progress:  Solving step 116/365 (31.78% of time interval complete)
#   Stats:     259 iterations in 22.66 s (87.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  32%|▍|  ETA: 0:00:58
#   Progress:  Solving step 118/365 (32.33% of time interval complete)
#   Stats:     263 iterations in 22.80 s (86.71 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  33%|▍|  ETA: 0:00:57
#   Progress:  Solving step 120/365 (32.88% of time interval complete)
#   Stats:     267 iterations in 22.95 s (85.96 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  33%|▍|  ETA: 0:00:56
#   Progress:  Solving step 122/365 (33.42% of time interval complete)
#   Stats:     271 iterations in 23.10 s (85.23 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  34%|▍|  ETA: 0:00:55
#   Progress:  Solving step 124/365 (33.97% of time interval complete)
#   Stats:     275 iterations in 23.24 s (84.52 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  34%|▍|  ETA: 0:00:54
#   Progress:  Solving step 126/365 (34.52% of time interval complete)
#   Stats:     279 iterations in 23.39 s (83.83 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  35%|▍|  ETA: 0:00:53
#   Progress:  Solving step 128/365 (35.07% of time interval complete)
#   Stats:     283 iterations in 23.53 s (83.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  36%|▍|  ETA: 0:00:52
#   Progress:  Solving step 130/365 (35.62% of time interval complete)
#   Stats:     287 iterations in 23.68 s (82.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  36%|▍|  ETA: 0:00:51
#   Progress:  Solving step 132/365 (36.16% of time interval complete)
#   Stats:     291 iterations in 23.83 s (81.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  37%|▍|  ETA: 0:00:50
#   Progress:  Solving step 134/365 (36.71% of time interval complete)
#   Stats:     295 iterations in 23.97 s (81.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  37%|▍|  ETA: 0:00:49
#   Progress:  Solving step 136/365 (37.26% of time interval complete)
#   Stats:     299 iterations in 24.16 s (80.81 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  38%|▍|  ETA: 0:00:48
#   Progress:  Solving step 138/365 (37.81% of time interval complete)
#   Stats:     303 iterations in 24.30 s (80.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  38%|▍|  ETA: 0:00:47
#   Progress:  Solving step 140/365 (38.36% of time interval complete)
#   Stats:     307 iterations in 24.44 s (79.62 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  39%|▍|  ETA: 0:00:46
#   Progress:  Solving step 142/365 (38.90% of time interval complete)
#   Stats:     311 iterations in 24.58 s (79.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  39%|▍|  ETA: 0:00:46
#   Progress:  Solving step 144/365 (39.45% of time interval complete)
#   Stats:     315 iterations in 24.72 s (78.49 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  40%|▍|  ETA: 0:00:45
#   Progress:  Solving step 146/365 (40.00% of time interval complete)
#   Stats:     319 iterations in 24.86 s (77.95 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  40%|▍|  ETA: 0:00:44
#   Progress:  Solving step 148/365 (40.55% of time interval complete)
#   Stats:     323 iterations in 25.01 s (77.42 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  41%|▍|  ETA: 0:00:43
#   Progress:  Solving step 150/365 (41.10% of time interval complete)
#   Stats:     327 iterations in 25.15 s (76.91 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  42%|▍|  ETA: 0:00:42
#   Progress:  Solving step 152/365 (41.64% of time interval complete)
#   Stats:     331 iterations in 25.29 s (76.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  42%|▍|  ETA: 0:00:42
#   Progress:  Solving step 154/365 (42.19% of time interval complete)
#   Stats:     335 iterations in 25.43 s (75.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  43%|▍|  ETA: 0:00:41
#   Progress:  Solving step 156/365 (42.74% of time interval complete)
#   Stats:     339 iterations in 25.58 s (75.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  43%|▍|  ETA: 0:00:40
#   Progress:  Solving step 158/365 (43.29% of time interval complete)
#   Stats:     343 iterations in 25.73 s (75.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  44%|▍|  ETA: 0:00:40
#   Progress:  Solving step 160/365 (43.84% of time interval complete)
#   Stats:     347 iterations in 25.87 s (74.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  44%|▌|  ETA: 0:00:39
#   Progress:  Solving step 162/365 (44.38% of time interval complete)
#   Stats:     351 iterations in 26.02 s (74.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  45%|▌|  ETA: 0:00:38
#   Progress:  Solving step 164/365 (44.93% of time interval complete)
#   Stats:     355 iterations in 26.17 s (73.72 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  45%|▌|  ETA: 0:00:38
#   Progress:  Solving step 166/365 (45.48% of time interval complete)
#   Stats:     359 iterations in 26.32 s (73.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  46%|▌|  ETA: 0:00:37
#   Progress:  Solving step 168/365 (46.03% of time interval complete)
#   Stats:     363 iterations in 26.47 s (72.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  46%|▌|  ETA: 0:00:36
#   Progress:  Solving step 170/365 (46.58% of time interval complete)
#   Stats:     367 iterations in 26.62 s (72.53 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  47%|▌|  ETA: 0:00:36
#   Progress:  Solving step 172/365 (47.12% of time interval complete)
#   Stats:     371 iterations in 26.77 s (72.15 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  48%|▌|  ETA: 0:00:35
#   Progress:  Solving step 174/365 (47.67% of time interval complete)
#   Stats:     375 iterations in 26.92 s (71.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  48%|▌|  ETA: 0:00:34
#   Progress:  Solving step 176/365 (48.22% of time interval complete)
#   Stats:     379 iterations in 27.07 s (71.42 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  49%|▌|  ETA: 0:00:34
#   Progress:  Solving step 178/365 (48.77% of time interval complete)
#   Stats:     383 iterations in 27.22 s (71.07 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  49%|▌|  ETA: 0:00:33
#   Progress:  Solving step 180/365 (49.32% of time interval complete)
#   Stats:     387 iterations in 27.37 s (70.73 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  50%|▌|  ETA: 0:00:33
#   Progress:  Solving step 182/365 (49.86% of time interval complete)
#   Stats:     391 iterations in 27.52 s (70.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  50%|▌|  ETA: 0:00:32
#   Progress:  Solving step 184/365 (50.41% of time interval complete)
#   Stats:     395 iterations in 27.68 s (70.06 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  51%|▌|  ETA: 0:00:32
#   Progress:  Solving step 185/365 (50.68% of time interval complete)
#   Stats:     397 iterations in 27.80 s (70.02 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  51%|▌|  ETA: 0:00:31
#   Progress:  Solving step 187/365 (51.23% of time interval complete)
#   Stats:     401 iterations in 27.95 s (69.69 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  52%|▌|  ETA: 0:00:31
#   Progress:  Solving step 189/365 (51.78% of time interval complete)
#   Stats:     405 iterations in 28.09 s (69.36 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  52%|▌|  ETA: 0:00:30
#   Progress:  Solving step 191/365 (52.33% of time interval complete)
#   Stats:     409 iterations in 28.24 s (69.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  53%|▌|  ETA: 0:00:30
#   Progress:  Solving step 193/365 (52.88% of time interval complete)
#   Stats:     413 iterations in 28.39 s (68.74 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  53%|▌|  ETA: 0:00:29
#   Progress:  Solving step 195/365 (53.42% of time interval complete)
#   Stats:     417 iterations in 28.54 s (68.44 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  54%|▌|  ETA: 0:00:29
#   Progress:  Solving step 197/365 (53.97% of time interval complete)
#   Stats:     421 iterations in 28.69 s (68.15 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  54%|▌|  ETA: 0:00:28
#   Progress:  Solving step 199/365 (54.52% of time interval complete)
#   Stats:     425 iterations in 28.84 s (67.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  55%|▌|  ETA: 0:00:28
#   Progress:  Solving step 201/365 (55.07% of time interval complete)
#   Stats:     429 iterations in 29.00 s (67.59 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  55%|▌|  ETA: 0:00:27
#   Progress:  Solving step 203/365 (55.62% of time interval complete)
#   Stats:     433 iterations in 29.15 s (67.32 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  56%|▌|  ETA: 0:00:27
#   Progress:  Solving step 205/365 (56.16% of time interval complete)
#   Stats:     437 iterations in 29.31 s (67.07 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  57%|▋|  ETA: 0:00:26
#   Progress:  Solving step 207/365 (56.71% of time interval complete)
#   Stats:     441 iterations in 29.47 s (66.82 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  57%|▋|  ETA: 0:00:26
#   Progress:  Solving step 209/365 (57.26% of time interval complete)
#   Stats:     445 iterations in 29.63 s (66.58 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  58%|▋|  ETA: 0:00:25
#   Progress:  Solving step 211/365 (57.81% of time interval complete)
#   Stats:     449 iterations in 29.79 s (66.35 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  58%|▋|  ETA: 0:00:25
#   Progress:  Solving step 213/365 (58.36% of time interval complete)
#   Stats:     453 iterations in 29.96 s (66.13 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  59%|▋|  ETA: 0:00:25
#   Progress:  Solving step 215/365 (58.90% of time interval complete)
#   Stats:     457 iterations in 30.13 s (65.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  59%|▋|  ETA: 0:00:24
#   Progress:  Solving step 217/365 (59.45% of time interval complete)
#   Stats:     461 iterations in 30.30 s (65.72 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  60%|▋|  ETA: 0:00:24
#   Progress:  Solving step 219/365 (60.00% of time interval complete)
#   Stats:     465 iterations in 30.47 s (65.52 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  60%|▋|  ETA: 0:00:23
#   Progress:  Solving step 221/365 (60.55% of time interval complete)
#   Stats:     469 iterations in 30.64 s (65.34 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:23
#   Progress:  Solving step 223/365 (61.10% of time interval complete)
#   Stats:     473 iterations in 30.82 s (65.17 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:22
#   Progress:  Solving step 225/365 (61.64% of time interval complete)
#   Stats:     477 iterations in 31.01 s (65.02 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  62%|▋|  ETA: 0:00:22
#   Progress:  Solving step 227/365 (62.19% of time interval complete)
#   Stats:     481 iterations in 31.21 s (64.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:22
#   Progress:  Solving step 229/365 (62.74% of time interval complete)
#   Stats:     485 iterations in 31.41 s (64.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:21
#   Progress:  Solving step 230/365 (63.01% of time interval complete)
#   Stats:     487 iterations in 31.51 s (64.71 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:21
#   Progress:  Solving step 231/365 (63.29% of time interval complete)
#   Stats:     489 iterations in 31.62 s (64.66 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:21
#   Progress:  Solving step 232/365 (63.56% of time interval complete)
#   Stats:     491 iterations in 31.73 s (64.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:21
#   Progress:  Solving step 233/365 (63.84% of time interval complete)
#   Stats:     493 iterations in 31.83 s (64.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:21
#   Progress:  Solving step 234/365 (64.11% of time interval complete)
#   Stats:     495 iterations in 31.99 s (64.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:21
#   Progress:  Solving step 235/365 (64.38% of time interval complete)
#   Stats:     497 iterations in 32.10 s (64.58 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:20
#   Progress:  Solving step 236/365 (64.66% of time interval complete)
#   Stats:     499 iterations in 32.21 s (64.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:20
#   Progress:  Solving step 237/365 (64.93% of time interval complete)
#   Stats:     501 iterations in 32.32 s (64.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:20
#   Progress:  Solving step 238/365 (65.21% of time interval complete)
#   Stats:     503 iterations in 32.43 s (64.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:20
#   Progress:  Solving step 239/365 (65.48% of time interval complete)
#   Stats:     505 iterations in 32.54 s (64.44 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:20
#   Progress:  Solving step 240/365 (65.75% of time interval complete)
#   Stats:     507 iterations in 32.65 s (64.40 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:19
#   Progress:  Solving step 241/365 (66.03% of time interval complete)
#   Stats:     509 iterations in 32.76 s (64.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:19
#   Progress:  Solving step 242/365 (66.30% of time interval complete)
#   Stats:     511 iterations in 32.88 s (64.35 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:19
#   Progress:  Solving step 243/365 (66.58% of time interval complete)
#   Stats:     513 iterations in 33.00 s (64.32 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:19
#   Progress:  Solving step 244/365 (66.85% of time interval complete)
#   Stats:     515 iterations in 33.11 s (64.29 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:19
#   Progress:  Solving step 245/365 (67.12% of time interval complete)
#   Stats:     517 iterations in 33.23 s (64.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:19
#   Progress:  Solving step 246/365 (67.40% of time interval complete)
#   Stats:     519 iterations in 33.34 s (64.24 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:18
#   Progress:  Solving step 247/365 (67.67% of time interval complete)
#   Stats:     521 iterations in 33.46 s (64.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:18
#   Progress:  Solving step 248/365 (67.95% of time interval complete)
#   Stats:     523 iterations in 33.57 s (64.19 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:18
#   Progress:  Solving step 249/365 (68.22% of time interval complete)
#   Stats:     525 iterations in 33.69 s (64.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:18
#   Progress:  Solving step 250/365 (68.49% of time interval complete)
#   Stats:     527 iterations in 33.80 s (64.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▋|  ETA: 0:00:18
#   Progress:  Solving step 251/365 (68.77% of time interval complete)
#   Stats:     529 iterations in 33.91 s (64.11 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:18
#   Progress:  Solving step 252/365 (69.04% of time interval complete)
#   Stats:     531 iterations in 34.02 s (64.07 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:17
#   Progress:  Solving step 253/365 (69.32% of time interval complete)
#   Stats:     533 iterations in 34.13 s (64.04 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:17
#   Progress:  Solving step 254/365 (69.59% of time interval complete)
#   Stats:     535 iterations in 34.24 s (64.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:17
#   Progress:  Solving step 255/365 (69.86% of time interval complete)
#   Stats:     537 iterations in 34.35 s (63.97 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:17
#   Progress:  Solving step 256/365 (70.14% of time interval complete)
#   Stats:     539 iterations in 34.46 s (63.93 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:17
#   Progress:  Solving step 257/365 (70.41% of time interval complete)
#   Stats:     541 iterations in 34.56 s (63.89 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:17
#   Progress:  Solving step 258/365 (70.68% of time interval complete)
#   Stats:     543 iterations in 34.66 s (63.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  71%|▊|  ETA: 0:00:16
#   Progress:  Solving step 260/365 (71.23% of time interval complete)
#   Stats:     547 iterations in 34.86 s (63.74 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  72%|▊|  ETA: 0:00:16
#   Progress:  Solving step 262/365 (71.78% of time interval complete)
#   Stats:     551 iterations in 35.06 s (63.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  72%|▊|  ETA: 0:00:15
#   Progress:  Solving step 264/365 (72.33% of time interval complete)
#   Stats:     555 iterations in 35.25 s (63.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  73%|▊|  ETA: 0:00:15
#   Progress:  Solving step 266/365 (72.88% of time interval complete)
#   Stats:     559 iterations in 35.43 s (63.38 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  73%|▊|  ETA: 0:00:15
#   Progress:  Solving step 268/365 (73.42% of time interval complete)
#   Stats:     563 iterations in 35.61 s (63.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  74%|▊|  ETA: 0:00:14
#   Progress:  Solving step 270/365 (73.97% of time interval complete)
#   Stats:     567 iterations in 35.79 s (63.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  74%|▊|  ETA: 0:00:14
#   Progress:  Solving step 272/365 (74.52% of time interval complete)
#   Stats:     571 iterations in 35.96 s (62.98 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  75%|▊|  ETA: 0:00:14
#   Progress:  Solving step 274/365 (75.07% of time interval complete)
#   Stats:     575 iterations in 36.14 s (62.85 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  75%|▊|  ETA: 0:00:13
#   Progress:  Solving step 276/365 (75.62% of time interval complete)
#   Stats:     579 iterations in 36.31 s (62.70 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  76%|▊|  ETA: 0:00:13
#   Progress:  Solving step 278/365 (76.16% of time interval complete)
#   Stats:     583 iterations in 36.47 s (62.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  77%|▊|  ETA: 0:00:13
#   Progress:  Solving step 280/365 (76.71% of time interval complete)
#   Stats:     587 iterations in 36.64 s (62.42 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  77%|▊|  ETA: 0:00:12
#   Progress:  Solving step 282/365 (77.26% of time interval complete)
#   Stats:     591 iterations in 36.80 s (62.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  77%|▊|  ETA: 0:00:12
#   Progress:  Solving step 283/365 (77.53% of time interval complete)
#   Stats:     593 iterations in 36.93 s (62.28 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  78%|▊|  ETA: 0:00:12
#   Progress:  Solving step 285/365 (78.08% of time interval complete)
#   Stats:     597 iterations in 37.09 s (62.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  78%|▊|  ETA: 0:00:12
#   Progress:  Solving step 287/365 (78.63% of time interval complete)
#   Stats:     601 iterations in 37.24 s (61.96 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  79%|▊|  ETA: 0:00:11
#   Progress:  Solving step 289/365 (79.18% of time interval complete)
#   Stats:     605 iterations in 37.39 s (61.81 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  80%|▊|  ETA: 0:00:11
#   Progress:  Solving step 291/365 (79.73% of time interval complete)
#   Stats:     609 iterations in 37.54 s (61.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  80%|▊|  ETA: 0:00:11
#   Progress:  Solving step 293/365 (80.27% of time interval complete)
#   Stats:     613 iterations in 37.70 s (61.49 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  81%|▊|  ETA: 0:00:10
#   Progress:  Solving step 295/365 (80.82% of time interval complete)
#   Stats:     617 iterations in 37.84 s (61.34 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  81%|▊|  ETA: 0:00:10
#   Progress:  Solving step 297/365 (81.37% of time interval complete)
#   Stats:     621 iterations in 37.99 s (61.18 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  82%|▉|  ETA: 0:00:10
#   Progress:  Solving step 299/365 (81.92% of time interval complete)
#   Stats:     625 iterations in 38.14 s (61.03 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  82%|▉|  ETA: 0:00:09
#   Progress:  Solving step 301/365 (82.47% of time interval complete)
#   Stats:     629 iterations in 38.29 s (60.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  83%|▉|  ETA: 0:00:09
#   Progress:  Solving step 303/365 (83.01% of time interval complete)
#   Stats:     633 iterations in 38.43 s (60.72 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  83%|▉|  ETA: 0:00:09
#   Progress:  Solving step 305/365 (83.56% of time interval complete)
#   Stats:     637 iterations in 38.58 s (60.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  84%|▉|  ETA: 0:00:08
#   Progress:  Solving step 307/365 (84.11% of time interval complete)
#   Stats:     641 iterations in 38.73 s (60.42 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  84%|▉|  ETA: 0:00:08
#   Progress:  Solving step 309/365 (84.66% of time interval complete)
#   Stats:     645 iterations in 38.88 s (60.28 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  85%|▉|  ETA: 0:00:08
#   Progress:  Solving step 311/365 (85.21% of time interval complete)
#   Stats:     649 iterations in 39.03 s (60.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  86%|▉|  ETA: 0:00:07
#   Progress:  Solving step 313/365 (85.75% of time interval complete)
#   Stats:     653 iterations in 39.18 s (59.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  86%|▉|  ETA: 0:00:07
#   Progress:  Solving step 315/365 (86.30% of time interval complete)
#   Stats:     657 iterations in 39.32 s (59.85 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  87%|▉|  ETA: 0:00:07
#   Progress:  Solving step 317/365 (86.85% of time interval complete)
#   Stats:     661 iterations in 39.47 s (59.71 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  87%|▉|  ETA: 0:00:07
#   Progress:  Solving step 319/365 (87.40% of time interval complete)
#   Stats:     665 iterations in 39.61 s (59.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  88%|▉|  ETA: 0:00:06
#   Progress:  Solving step 321/365 (87.95% of time interval complete)
#   Stats:     669 iterations in 39.76 s (59.43 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  88%|▉|  ETA: 0:00:06
#   Progress:  Solving step 323/365 (88.49% of time interval complete)
#   Stats:     673 iterations in 39.90 s (59.29 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  89%|▉|  ETA: 0:00:06
#   Progress:  Solving step 325/365 (89.04% of time interval complete)
#   Stats:     677 iterations in 40.05 s (59.15 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  89%|▉|  ETA: 0:00:05
#   Progress:  Solving step 327/365 (89.59% of time interval complete)
#   Stats:     681 iterations in 40.19 s (59.02 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  90%|▉|  ETA: 0:00:05
#   Progress:  Solving step 329/365 (90.14% of time interval complete)
#   Stats:     685 iterations in 40.33 s (58.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  90%|▉|  ETA: 0:00:05
#   Progress:  Solving step 331/365 (90.68% of time interval complete)
#   Stats:     689 iterations in 40.48 s (58.75 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  91%|▉|  ETA: 0:00:05
#   Progress:  Solving step 333/365 (91.23% of time interval complete)
#   Stats:     693 iterations in 40.61 s (58.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  91%|▉|  ETA: 0:00:04
#   Progress:  Solving step 334/365 (91.51% of time interval complete)
#   Stats:     695 iterations in 40.73 s (58.60 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  92%|▉|  ETA: 0:00:04
#   Progress:  Solving step 336/365 (92.05% of time interval complete)
#   Stats:     699 iterations in 40.87 s (58.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  92%|▉|  ETA: 0:00:04
#   Progress:  Solving step 338/365 (92.60% of time interval complete)
#   Stats:     703 iterations in 41.01 s (58.33 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  93%|▉|  ETA: 0:00:04
#   Progress:  Solving step 340/365 (93.15% of time interval complete)
#   Stats:     707 iterations in 41.14 s (58.19 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  93%|▉|  ETA: 0:00:03
#   Progress:  Solving step 342/365 (93.70% of time interval complete)
#   Stats:     711 iterations in 41.28 s (58.06 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  94%|█|  ETA: 0:00:03
#   Progress:  Solving step 344/365 (94.25% of time interval complete)
#   Stats:     715 iterations in 41.41 s (57.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  95%|█|  ETA: 0:00:03
#   Progress:  Solving step 346/365 (94.79% of time interval complete)
#   Stats:     719 iterations in 41.55 s (57.79 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  95%|█|  ETA: 0:00:02
#   Progress:  Solving step 348/365 (95.34% of time interval complete)
#   Stats:     723 iterations in 41.68 s (57.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  96%|█|  ETA: 0:00:02
#   Progress:  Solving step 350/365 (95.89% of time interval complete)
#   Stats:     727 iterations in 41.82 s (57.52 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  96%|█|  ETA: 0:00:02
#   Progress:  Solving step 352/365 (96.44% of time interval complete)
#   Stats:     731 iterations in 41.95 s (57.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  97%|█|  ETA: 0:00:02
#   Progress:  Solving step 354/365 (96.99% of time interval complete)
#   Stats:     735 iterations in 42.08 s (57.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  97%|█|  ETA: 0:00:01
#   Progress:  Solving step 356/365 (97.53% of time interval complete)
#   Stats:     739 iterations in 42.21 s (57.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  98%|█|  ETA: 0:00:01
#   Progress:  Solving step 358/365 (98.08% of time interval complete)
#   Stats:     743 iterations in 42.35 s (57.00 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  98%|█|  ETA: 0:00:01
#   Progress:  Solving step 360/365 (98.63% of time interval complete)
#   Stats:     747 iterations in 42.49 s (56.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  99%|█|  ETA: 0:00:01
#   Progress:  Solving step 362/365 (99.18% of time interval complete)
#   Stats:     751 iterations in 42.63 s (56.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  99%|█|  ETA: 0:00:00
#   Progress:  Solving step 364/365 (99.73% of time interval complete)
#   Stats:     755 iterations in 42.76 s (56.64 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps 100%|█| Time: 0:00:47
#   Progress:  Solved step 365/365
#   Stats:     759 iterations in 42.90 s (56.52 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │    Total │
# │                │ 365 steps │ 367 ministeps │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┤
# │ Newton         │   2.07945 │       2.06812 │  759 (0) │
# │ Linearization  │   3.08493 │       3.06812 │ 1126 (0) │
# │ Linear solver  │   4.09315 │       4.07084 │ 1494 (0) │
# │ Precond apply  │    8.1863 │       8.14169 │ 2988 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬─────────╮
# │ Timing type   │    Each │   Relative │   Total │
# │               │      ms │ Percentage │       s │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Properties    │ 32.7889 │    58.01 % │ 24.8868 │
# │ Equations     │  4.2772 │    11.23 % │  4.8161 │
# │ Assembly      │  3.8701 │    10.16 % │  4.3577 │
# │ Linear solve  │  1.9880 │     3.52 % │  1.5089 │
# │ Linear setup  │  2.4659 │     4.36 % │  1.8716 │
# │ Precond apply │  0.5921 │     4.12 % │  1.7693 │
# │ Update        │  0.9245 │     1.64 % │  0.7017 │
# │ Convergence   │  1.2347 │     3.24 % │  1.3903 │
# │ Input/Output  │  0.1291 │     0.11 % │  0.0474 │
# │ Other         │  2.0436 │     3.62 % │  1.5511 │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Total         │ 56.5229 │   100.00 % │ 42.9009 │
# ╰───────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 365 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :orat => Vector{Float64} of size (365,)
#        :N2-CH4_mass_rate => Vector{Float64} of size (365,)
#        :C6-13_mass_rate => Vector{Float64} of size (365,)
#        :C14-24_mass_rate => Vector{Float64} of size (365,)
#        :C2-5_mass_rate => Vector{Float64} of size (365,)
#        :bhp => Vector{Float64} of size (365,)
#        :lrat => Vector{Float64} of size (365,)
#        :CO2_mass_rate => Vector{Float64} of size (365,)
#        :mass_rate => Vector{Float64} of size (365,)
#        :rate => Vector{Float64} of size (365,)
#        :control => Vector{Symbol} of size (365,)
#        :grat => Vector{Float64} of size (365,)
#
#   states (Vector with 365 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (5, 800)
#     :OverallMoleFractions => Matrix{Float64} of size (5, 800)
#     :Saturations => Matrix{Float64} of size (2, 800)
#     :Pressure => Vector{Float64} of size (800,)
#     :VaporMassFractions => Matrix{Float64} of size (5, 800)
#     :TotalMasses => Matrix{Float64} of size (5, 800)
#
#   time (report time for each state)
#      Vector{Float64} of length 365
#
#   result (extended states, reports)
#      SimResult with 365 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 31 2024 20:08 after 42 seconds, 853 milliseconds, 490.1 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# ### CO2 mole fraction

# %%
sg = states[end][:OverallMoleFractions][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Gas saturation

# %%
sg = states[end][:Saturations][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Pressure

# %%
p = states[end][:Pressure]
fig, ax, p = plot_cell_data(g, p)
fig
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
