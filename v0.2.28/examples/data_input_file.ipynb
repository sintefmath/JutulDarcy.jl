# %% [markdown]
# # Simulating Eclipse/DATA input files
# The DATA format is commonly used in reservoir simulation. JutulDarcy can set
# up cases on this format and includes a fully featured grid builder for
# corner-point grids. Once a case has been set up, it uses the same types as a
# regular JutulDarcy simulation, allowing modification and use of the case in
# differentiable workflows.
#
# We begin by loading the SPE9 dataset via the GeoEnergyIO package.

# %%
using JutulDarcy
pth = JutulDarcy.GeoEnergyIO.test_input_file_path("SPE9", "SPE9.DATA")
# Out:
# "/home/runner/.julia/artifacts/c1063fdc96b21cbc18ea8a3bd1a1281aa04ffa3f/SPE9.DATA"

# %% [markdown]
# ## Set up and run a simulation
# If we do not need the case, we could also have done:
# ws, states = simulate_data_file(pth)

# %%
case = setup_case_from_data_file(pth)
ws, states = simulate_reservoir(case)
# Out:
# PVT: Fixing table for low pressure conditions.
# Simulating 2 years, 24.22 weeks as 90 report steps   2%| |  ETA: 0:03:20
#   Progress:  Solving step 2/90 (2.22% of time interval complete)
#   Stats:     19 iterations in 3.98 s (209.40 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   3%| |  ETA: 0:02:17
#   Progress:  Solving step 3/90 (3.33% of time interval complete)
#   Stats:     25 iterations in 4.14 s (165.78 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   4%| |  ETA: 0:01:44
#   Progress:  Solving step 4/90 (4.44% of time interval complete)
#   Stats:     29 iterations in 4.25 s (146.54 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   5%| |  ETA: 0:01:24
#   Progress:  Solving step 5/90 (5.56% of time interval complete)
#   Stats:     33 iterations in 4.36 s (132.04 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   8%|▏|  ETA: 0:01:00
#   Progress:  Solving step 7/90 (7.78% of time interval complete)
#   Stats:     39 iterations in 4.52 s (115.91 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   9%|▏|  ETA: 0:00:53
#   Progress:  Solving step 8/90 (8.89% of time interval complete)
#   Stats:     43 iterations in 4.63 s (107.68 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  11%|▏|  ETA: 0:00:43
#   Progress:  Solving step 10/90 (11.11% of time interval complete)
#   Stats:     51 iterations in 4.84 s (94.98 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  13%|▏|  ETA: 0:00:36
#   Progress:  Solving step 12/90 (13.33% of time interval complete)
#   Stats:     57 iterations in 5.02 s (88.06 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  14%|▏|  ETA: 0:00:34
#   Progress:  Solving step 13/90 (14.44% of time interval complete)
#   Stats:     61 iterations in 5.13 s (84.16 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  15%|▏|  ETA: 0:00:32
#   Progress:  Solving step 14/90 (15.56% of time interval complete)
#   Stats:     66 iterations in 5.27 s (79.79 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  18%|▏|  ETA: 0:00:28
#   Progress:  Solving step 16/90 (17.78% of time interval complete)
#   Stats:     72 iterations in 5.44 s (75.57 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  20%|▎|  ETA: 0:00:25
#   Progress:  Solving step 18/90 (20.00% of time interval complete)
#   Stats:     78 iterations in 5.61 s (71.97 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  22%|▎|  ETA: 0:00:22
#   Progress:  Solving step 20/90 (22.22% of time interval complete)
#   Stats:     84 iterations in 5.79 s (68.98 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  24%|▎|  ETA: 0:00:20
#   Progress:  Solving step 22/90 (24.44% of time interval complete)
#   Stats:     90 iterations in 5.97 s (66.31 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  25%|▎|  ETA: 0:00:20
#   Progress:  Solving step 23/90 (25.56% of time interval complete)
#   Stats:     93 iterations in 6.10 s (65.58 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  27%|▎|  ETA: 0:00:18
#   Progress:  Solving step 25/90 (27.78% of time interval complete)
#   Stats:     99 iterations in 6.27 s (63.37 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  30%|▎|  ETA: 0:00:17
#   Progress:  Solving step 27/90 (30.00% of time interval complete)
#   Stats:     105 iterations in 6.45 s (61.42 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  32%|▍|  ETA: 0:00:15
#   Progress:  Solving step 29/90 (32.22% of time interval complete)
#   Stats:     111 iterations in 6.62 s (59.64 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  34%|▍|  ETA: 0:00:14
#   Progress:  Solving step 31/90 (34.44% of time interval complete)
#   Stats:     117 iterations in 6.79 s (58.00 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  35%|▍|  ETA: 0:00:14
#   Progress:  Solving step 32/90 (35.56% of time interval complete)
#   Stats:     125 iterations in 7.00 s (55.98 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  36%|▍|  ETA: 0:00:13
#   Progress:  Solving step 33/90 (36.67% of time interval complete)
#   Stats:     130 iterations in 7.14 s (54.90 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  37%|▍|  ETA: 0:00:13
#   Progress:  Solving step 34/90 (37.78% of time interval complete)
#   Stats:     134 iterations in 7.25 s (54.09 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  38%|▍|  ETA: 0:00:13
#   Progress:  Solving step 35/90 (38.89% of time interval complete)
#   Stats:     139 iterations in 7.38 s (53.11 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  40%|▍|  ETA: 0:00:12
#   Progress:  Solving step 36/90 (40.00% of time interval complete)
#   Stats:     144 iterations in 7.53 s (52.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  41%|▍|  ETA: 0:00:12
#   Progress:  Solving step 37/90 (41.11% of time interval complete)
#   Stats:     150 iterations in 7.69 s (51.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  42%|▍|  ETA: 0:00:12
#   Progress:  Solving step 38/90 (42.22% of time interval complete)
#   Stats:     159 iterations in 7.94 s (49.94 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  43%|▍|  ETA: 0:00:11
#   Progress:  Solving step 39/90 (43.33% of time interval complete)
#   Stats:     164 iterations in 8.08 s (49.25 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  44%|▌|  ETA: 0:00:11
#   Progress:  Solving step 40/90 (44.44% of time interval complete)
#   Stats:     175 iterations in 8.37 s (47.82 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  45%|▌|  ETA: 0:00:11
#   Progress:  Solving step 41/90 (45.56% of time interval complete)
#   Stats:     179 iterations in 8.48 s (47.35 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  46%|▌|  ETA: 0:00:11
#   Progress:  Solving step 42/90 (46.67% of time interval complete)
#   Stats:     184 iterations in 8.61 s (46.80 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  47%|▌|  ETA: 0:00:10
#   Progress:  Solving step 43/90 (47.78% of time interval complete)
#   Stats:     188 iterations in 8.73 s (46.42 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  48%|▌|  ETA: 0:00:10
#   Progress:  Solving step 44/90 (48.89% of time interval complete)
#   Stats:     191 iterations in 8.86 s (46.38 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  51%|▌|  ETA: 0:00:09
#   Progress:  Solving step 46/90 (51.11% of time interval complete)
#   Stats:     197 iterations in 9.03 s (45.83 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  53%|▌|  ETA: 0:00:09
#   Progress:  Solving step 48/90 (53.33% of time interval complete)
#   Stats:     204 iterations in 9.22 s (45.19 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  55%|▌|  ETA: 0:00:08
#   Progress:  Solving step 50/90 (55.56% of time interval complete)
#   Stats:     209 iterations in 9.36 s (44.79 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  57%|▋|  ETA: 0:00:08
#   Progress:  Solving step 52/90 (57.78% of time interval complete)
#   Stats:     214 iterations in 9.50 s (44.41 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  58%|▋|  ETA: 0:00:07
#   Progress:  Solving step 53/90 (58.89% of time interval complete)
#   Stats:     218 iterations in 9.61 s (44.08 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  60%|▋|  ETA: 0:00:07
#   Progress:  Solving step 55/90 (61.11% of time interval complete)
#   Stats:     222 iterations in 9.73 s (43.83 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  63%|▋|  ETA: 0:00:06
#   Progress:  Solving step 57/90 (63.33% of time interval complete)
#   Stats:     227 iterations in 9.87 s (43.49 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  65%|▋|  ETA: 0:00:06
#   Progress:  Solving step 59/90 (65.56% of time interval complete)
#   Stats:     232 iterations in 10.01 s (43.16 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  67%|▋|  ETA: 0:00:05
#   Progress:  Solving step 61/90 (67.78% of time interval complete)
#   Stats:     238 iterations in 10.18 s (42.79 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  69%|▊|  ETA: 0:00:05
#   Progress:  Solving step 63/90 (70.00% of time interval complete)
#   Stats:     243 iterations in 10.33 s (42.49 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  71%|▊|  ETA: 0:00:04
#   Progress:  Solving step 65/90 (72.22% of time interval complete)
#   Stats:     248 iterations in 10.47 s (42.23 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  74%|▊|  ETA: 0:00:04
#   Progress:  Solving step 67/90 (74.44% of time interval complete)
#   Stats:     253 iterations in 10.61 s (41.95 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  76%|▊|  ETA: 0:00:04
#   Progress:  Solving step 69/90 (76.67% of time interval complete)
#   Stats:     258 iterations in 10.75 s (41.68 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  77%|▊|  ETA: 0:00:03
#   Progress:  Solving step 70/90 (77.78% of time interval complete)
#   Stats:     262 iterations in 10.86 s (41.46 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  79%|▊|  ETA: 0:00:03
#   Progress:  Solving step 72/90 (80.00% of time interval complete)
#   Stats:     266 iterations in 10.98 s (41.28 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  81%|▉|  ETA: 0:00:03
#   Progress:  Solving step 74/90 (82.22% of time interval complete)
#   Stats:     270 iterations in 11.10 s (41.09 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  84%|▉|  ETA: 0:00:02
#   Progress:  Solving step 76/90 (84.44% of time interval complete)
#   Stats:     275 iterations in 11.24 s (40.87 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  86%|▉|  ETA: 0:00:02
#   Progress:  Solving step 78/90 (86.67% of time interval complete)
#   Stats:     279 iterations in 11.40 s (40.85 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  88%|▉|  ETA: 0:00:02
#   Progress:  Solving step 80/90 (88.89% of time interval complete)
#   Stats:     283 iterations in 11.51 s (40.67 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  90%|▉|  ETA: 0:00:01
#   Progress:  Solving step 82/90 (91.11% of time interval complete)
#   Stats:     287 iterations in 11.62 s (40.48 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  92%|▉|  ETA: 0:00:01
#   Progress:  Solving step 84/90 (93.33% of time interval complete)
#   Stats:     293 iterations in 11.78 s (40.20 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  95%|█|  ETA: 0:00:01
#   Progress:  Solving step 86/90 (95.56% of time interval complete)
#   Stats:     297 iterations in 11.88 s (40.01 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  97%|█|  ETA: 0:00:00
#   Progress:  Solving step 88/90 (97.78% of time interval complete)
#   Stats:     301 iterations in 11.99 s (39.85 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  99%|█|  ETA: 0:00:00
#   Progress:  Solving step 90/90 (100.00% of time interval complete)
#   Stats:     305 iterations in 12.11 s (39.69 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps 100%|█| Time: 0:00:12
#   Progress:  Solved step 90/90
#   Stats:     307 iterations in 12.16 s (39.60 ms each)
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │ 90 steps │ 96 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │  3.41111 │      3.19792 │  307 (0) │
# │ Linearization  │  4.47778 │      4.19792 │  403 (0) │
# │ Linear solver  │  10.8667 │      10.1875 │  978 (0) │
# │ Precond apply  │  21.7333 │       20.375 │ 1956 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬─────────╮
# │ Timing type   │    Each │   Relative │   Total │
# │               │      ms │ Percentage │       s │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Properties    │  2.7476 │     6.94 % │  0.8435 │
# │ Equations     │  5.6195 │    18.63 % │  2.2647 │
# │ Assembly      │  1.9828 │     6.57 % │  0.7991 │
# │ Linear solve  │  2.3410 │     5.91 % │  0.7187 │
# │ Linear setup  │ 10.8919 │    27.50 % │  3.3438 │
# │ Precond apply │  1.0494 │    16.88 % │  2.0527 │
# │ Update        │  1.1384 │     2.87 % │  0.3495 │
# │ Convergence   │  1.3488 │     4.47 % │  0.5436 │
# │ Input/Output  │  0.9256 │     0.73 % │  0.0889 │
# │ Other         │  3.7602 │     9.49 % │  1.1544 │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Total         │ 39.6050 │   100.00 % │ 12.1587 │
# ╰───────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 90 entries:
#
#   wells (26 present):
#     :INJE1
#     :PRODU25
#     :PRODU16
#     :PRODU20
#     :PRODU10
#     :PRODU12
#     :PRODU22
#     :PRODU14
#     :PRODU6
#     :PRODU7
#     :PRODU9
#     :PRODU24
#     :PRODU3
#     :PRODU23
#     :PRODU5
#     :PRODU11
#     :PRODU17
#     :PRODU4
#     :PRODU15
#     :PRODU2
#     :PRODU19
#     :PRODU21
#     :PRODU13
#     :PRODU8
#     :PRODU26
#     :PRODU18
#     Results per well:
#        :wrat => Vector{Float64} of size (90,)
#        :Aqueous_mass_rate => Vector{Float64} of size (90,)
#        :orat => Vector{Float64} of size (90,)
#        :bhp => Vector{Float64} of size (90,)
#        :lrat => Vector{Float64} of size (90,)
#        :mass_rate => Vector{Float64} of size (90,)
#        :rate => Vector{Float64} of size (90,)
#        :Vapor_mass_rate => Vector{Float64} of size (90,)
#        :control => Vector{Symbol} of size (90,)
#        :Liquid_mass_rate => Vector{Float64} of size (90,)
#        :grat => Vector{Float64} of size (90,)
#
#   states (Vector with 90 entries, reservoir variables for each state)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (9000,)
#     :Saturations => Matrix{Float64} of size (3, 9000)
#     :Pressure => Vector{Float64} of size (9000,)
#     :Rs => Vector{Float64} of size (9000,)
#     :ImmiscibleSaturation => Vector{Float64} of size (9000,)
#     :TotalMasses => Matrix{Float64} of size (3, 9000)
#
#   time (report time for each state)
#      Vector{Float64} of length 90
#
#   result (extended states, reports)
#      SimResult with 90 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 31 2024 20:08 after 12 seconds, 69 milliseconds, 868.9 microseconds.

# %% [markdown]
# ## Show the input data
# The input data takes the form of a Dict:

# %%
case.input_data
# Out:
# Dict{String, Any} with 6 entries:
#   "RUNSPEC"  => OrderedDict{String, Any}("TITLE"=>"SPE 9", "DIMENS"=>[24, 25, 1…
#   "GRID"     => OrderedDict{String, Any}("cartDims"=>(24, 25, 15), "CURRENT_BOX…
#   "PROPS"    => OrderedDict{String, Any}("PVTW"=>Any[[2.48211e7, 1.0034, 4.3511…
#   "SUMMARY"  => OrderedDict{String, Any}()
#   "SCHEDULE" => Dict{String, Any}("STEPS"=>OrderedDict{String, Any}[OrderedDict…
#   "SOLUTION" => OrderedDict{String, Any}("EQUIL"=>Any[[2753.87, 2.48211e7, 3032…

# %% [markdown]
# We can also examine the RUNSPEC section

# %%
case.input_data["RUNSPEC"]
# Out:
# OrderedCollections.OrderedDict{String, Any} with 13 entries:
#   "TITLE"    => "SPE 9"
#   "DIMENS"   => [24, 25, 15]
#   "OIL"      => true
#   "WATER"    => true
#   "GAS"      => true
#   "DISGAS"   => true
#   "FIELD"    => true
#   "START"    => DateTime("2015-01-01T00:00:00")
#   "WELLDIMS" => [26, 5, 1, 26, 5, 10, 5, 4, 3, 0, 1, 1, 10, 201]
#   "TABDIMS"  => [1, 1, 40, 20, 1, 20, 20, 1, 1, -1  …  -1, 10, 10, 10, -1, 5, 5…
#   "EQLDIMS"  => [1, 100, 50, 1, 50]
#   "UNIFIN"   => true
#   "UNIFOUT"  => true

# %% [markdown]
# ## Plot the simulation model
# These plot are interactive when run outside of the documentations.

# %%
using GLMakie
plot_reservoir(case.model, states)
# Out:
# Figure()

# %% [markdown]
# ## Plot the well responses

# %%
plot_well_results(ws)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
