# %% [markdown]
# # Example demonstrating compositional flow
# This is a simple conceptual example demonstrating how to solve compositional
# flow. This example uses a two-component water-CO2 system. Note that the
# default Peng-Robinson is not accurate for this system without adjustments to
# the parameters. However, the example demonstrates the conceptual workflow for
# getting started with compositional simulation.
# ## Set up mixture
# We load the external flash package and define a two-component H2O-CO2 system.
# The constructor for each species takes in molecular weight, critical pressure,
# critical temperature, critical volume, acentric factor given as strict SI.
# This means, for instance, that molar masses are given in kg/mole and not
# g/mole or kg/kmol.

# %%
using MultiComponentFlash
h2o = MolecularProperty(0.018015268, 22.064e6, 647.096, 5.595e-05, 0.3442920843)
co2 = MolecularProperty(0.0440098, 7.3773e6, 304.1282, 9.412e-05, 0.22394)

bic = zeros(2, 2)

mixture = MultiComponentMixture([h2o, co2], A_ij = bic, names = ["H2O", "CO2"])
eos = GenericCubicEOS(mixture, PengRobinson())
# Out:
# MultiComponentFlash.GenericCubicEOS{MultiComponentFlash.PengRobinson, Float64, 2, Nothing}(MultiComponentFlash.PengRobinson(), MultiComponentFlash.MultiComponentMixture{Float64, 2}("UnnamedMixture", ["H2O", "CO2"], (MultiComponentFlash.MolecularProperty{Float64}(0.018015268, 2.2064e7, 647.096, 5.595e-5, 0.3442920843), MultiComponentFlash.MolecularProperty{Float64}(0.0440098, 7.3773e6, 304.1282, 9.412e-5, 0.22394)), [0.0 0.0; 0.0 0.0]), 2.414213562373095, -0.41421356237309515, 0.457235529, 0.077796074, nothing)

# %% [markdown]
# ## Set up domain and wells

# %%
using Jutul, JutulDarcy, GLMakie
nx = 50
ny = 1
nz = 20
dims = (nx, ny, nz)
g = CartesianMesh(dims, (100.0, 10.0, 10.0))
nc = number_of_cells(g)
Darcy, bar, kg, meter, Kelvin, day, sec = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day, :second)
K = repeat([0.1, 0.1, 0.001]*Darcy, 1, nc)
res = reservoir_domain(g, porosity = 0.3, permeability = K)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 50x1x20=1000 cells with 17 data fields added:
#   1000 Cells
#     :permeability => 3×1000 Matrix{Float64}
#     :porosity => 1000 Vector{Float64}
#     :rock_thermal_conductivity => 1000 Vector{Float64}
#     :fluid_thermal_conductivity => 1000 Vector{Float64}
#     :rock_density => 1000 Vector{Float64}
#     :cell_centroids => 3×1000 Matrix{Float64}
#     :volumes => 1000 Vector{Float64}
#   1930 Faces
#     :neighbors => 2×1930 Matrix{Int64}
#     :areas => 1930 Vector{Float64}
#     :normals => 3×1930 Matrix{Float64}
#     :face_centroids => 3×1930 Matrix{Float64}
#   3860 HalfFaces
#     :half_face_cells => 3860 Vector{Int64}
#     :half_face_faces => 3860 Vector{Int64}
#   2140 BoundaryFaces
#     :boundary_areas => 2140 Vector{Float64}
#     :boundary_centroids => 3×2140 Matrix{Float64}
#     :boundary_normals => 3×2140 Matrix{Float64}
#     :boundary_neighbors => 2140 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in top layer

# %%
prod = setup_well(g, K, [(nx, ny, 1)], name = :Producer)
# Out:
# MultiSegmentWell [Producer] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in bottom layer

# %%
inj = setup_well(g, K, [(1, 1, nz)], name = :Injector)
# Out:
# MultiSegmentWell [Injector] (2 nodes, 1 segments, 1 perforations)

# %% [markdown]
# ## Define system and realize on grid

# %%
rhoLS = 844.23*kg/meter^3
rhoVS = 126.97*kg/meter^3
rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod]);
push!(model[:Reservoir].output_variables, :Saturations)
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)
T0 = repeat([303.15*Kelvin], 1, nc)
parameters[:Reservoir][:Temperature] = T0
state0 = setup_reservoir_state(model, Pressure = 50*bar, OverallMoleFractions = [1.0, 0.0]);

# %% [markdown]
# ## Define schedule
# 5 year (5*365.24 days) simulation period

# %%
dt0 = repeat([1]*day, 26)
dt1 = repeat([10.0]*day, 180)
dt = append!(dt0, dt1)
rate_target = TotalRateTarget(9.5066e-06*meter^3/sec)
I_ctrl = InjectorControl(rate_target, [0, 1], density = rhoVS)
bhp_target = BottomHolePressureTarget(50*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 4 years, 52.15 weeks as 206 report steps   1%  ETA: 0:19:20
#   Progress:  Solving step 2/206 (0.11% of time interval complete)
#   Stats:     7 iterations in 7.31 s (1.04 s each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps   4%  ETA: 0:04:11
#   Progress:  Solving step 9/206 (0.49% of time interval complete)
#   Stats:     26 iterations in 7.41 s (284.96 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  10%  ETA: 0:01:42
#   Progress:  Solving step 21/206 (1.15% of time interval complete)
#   Stats:     50 iterations in 7.52 s (150.30 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  15%  ETA: 0:01:04
#   Progress:  Solving step 32/206 (4.71% of time interval complete)
#   Stats:     81 iterations in 7.66 s (94.62 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  19%  ETA: 0:00:51
#   Progress:  Solving step 39/206 (8.54% of time interval complete)
#   Stats:     104 iterations in 7.79 s (74.92 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  22%  ETA: 0:00:43
#   Progress:  Solving step 45/206 (11.83% of time interval complete)
#   Stats:     122 iterations in 7.90 s (64.78 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  25%  ETA: 0:00:37
#   Progress:  Solving step 51/206 (15.12% of time interval complete)
#   Stats:     140 iterations in 8.02 s (57.32 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  27%  ETA: 0:00:33
#   Progress:  Solving step 56/206 (17.85% of time interval complete)
#   Stats:     156 iterations in 8.14 s (52.18 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  29%  ETA: 0:00:29
#   Progress:  Solving step 61/206 (20.59% of time interval complete)
#   Stats:     173 iterations in 8.27 s (47.79 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  32%  ETA: 0:00:26
#   Progress:  Solving step 66/206 (23.33% of time interval complete)
#   Stats:     189 iterations in 8.39 s (44.41 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  34%  ETA: 0:00:24
#   Progress:  Solving step 70/206 (25.52% of time interval complete)
#   Stats:     202 iterations in 8.50 s (42.08 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  36%  ETA: 0:00:23
#   Progress:  Solving step 74/206 (27.71% of time interval complete)
#   Stats:     217 iterations in 8.63 s (39.77 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  38%  ETA: 0:00:21
#   Progress:  Solving step 78/206 (29.90% of time interval complete)
#   Stats:     230 iterations in 8.75 s (38.03 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  39%  ETA: 0:00:20
#   Progress:  Solving step 81/206 (31.54% of time interval complete)
#   Stats:     242 iterations in 8.86 s (36.60 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  41%  ETA: 0:00:19
#   Progress:  Solving step 84/206 (33.19% of time interval complete)
#   Stats:     254 iterations in 8.97 s (35.30 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  43%  ETA: 0:00:18
#   Progress:  Solving step 88/206 (35.38% of time interval complete)
#   Stats:     265 iterations in 9.07 s (34.24 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  45%  ETA: 0:00:16
#   Progress:  Solving step 93/206 (38.12% of time interval complete)
#   Stats:     276 iterations in 9.19 s (33.30 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  47%  ETA: 0:00:15
#   Progress:  Solving step 98/206 (40.85% of time interval complete)
#   Stats:     286 iterations in 9.29 s (32.49 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  50%  ETA: 0:00:14
#   Progress:  Solving step 103/206 (43.59% of time interval complete)
#   Stats:     298 iterations in 9.41 s (31.59 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  52%  ETA: 0:00:12
#   Progress:  Solving step 108/206 (46.33% of time interval complete)
#   Stats:     309 iterations in 9.52 s (30.82 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  55%  ETA: 0:00:11
#   Progress:  Solving step 113/206 (49.07% of time interval complete)
#   Stats:     319 iterations in 9.63 s (30.19 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  57%  ETA: 0:00:10
#   Progress:  Solving step 118/206 (51.81% of time interval complete)
#   Stats:     329 iterations in 9.73 s (29.58 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  59%  ETA: 0:00:09
#   Progress:  Solving step 123/206 (54.55% of time interval complete)
#   Stats:     339 iterations in 9.83 s (29.00 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  62%  ETA: 0:00:09
#   Progress:  Solving step 128/206 (57.28% of time interval complete)
#   Stats:     349 iterations in 9.98 s (28.60 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  64%  ETA: 0:00:08
#   Progress:  Solving step 133/206 (60.02% of time interval complete)
#   Stats:     359 iterations in 10.08 s (28.09 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  67%  ETA: 0:00:07
#   Progress:  Solving step 139/206 (63.31% of time interval complete)
#   Stats:     371 iterations in 10.20 s (27.50 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  70%  ETA: 0:00:06
#   Progress:  Solving step 145/206 (66.59% of time interval complete)
#   Stats:     383 iterations in 10.32 s (26.94 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  73%  ETA: 0:00:05
#   Progress:  Solving step 151/206 (69.88% of time interval complete)
#   Stats:     395 iterations in 10.43 s (26.41 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  76%  ETA: 0:00:05
#   Progress:  Solving step 157/206 (73.17% of time interval complete)
#   Stats:     407 iterations in 10.55 s (25.92 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  79%  ETA: 0:00:04
#   Progress:  Solving step 163/206 (76.45% of time interval complete)
#   Stats:     419 iterations in 10.67 s (25.46 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  82%  ETA: 0:00:03
#   Progress:  Solving step 169/206 (79.74% of time interval complete)
#   Stats:     431 iterations in 10.78 s (25.02 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  85%  ETA: 0:00:03
#   Progress:  Solving step 175/206 (83.02% of time interval complete)
#   Stats:     443 iterations in 10.90 s (24.60 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  87%  ETA: 0:00:02
#   Progress:  Solving step 181/206 (86.31% of time interval complete)
#   Stats:     455 iterations in 11.01 s (24.20 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  90%  ETA: 0:00:02
#   Progress:  Solving step 187/206 (89.59% of time interval complete)
#   Stats:     467 iterations in 11.13 s (23.83 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  93%  ETA: 0:00:01
#   Progress:  Solving step 193/206 (92.88% of time interval complete)
#   Stats:     479 iterations in 11.24 s (23.47 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  96%  ETA: 0:00:01
#   Progress:  Solving step 199/206 (96.17% of time interval complete)
#   Stats:     491 iterations in 11.35 s (23.12 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps  99%  ETA: 0:00:00
#   Progress:  Solving step 205/206 (99.45% of time interval complete)
#   Stats:     503 iterations in 11.47 s (22.80 ms each)
#
# Simulating 4 years, 52.15 weeks as 206 report steps 100% Time: 0:00:15
#   Progress:  Solved step 206/206
#   Stats:     507 iterations in 11.50 s (22.69 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │    Total │
# │                │ 206 steps │ 207 ministeps │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┤
# │ Newton         │   2.46117 │       2.44928 │  507 (0) │
# │ Linearization  │   3.46602 │       3.44928 │  714 (0) │
# │ Linear solver  │   10.7136 │       10.6618 │ 2207 (0) │
# │ Precond apply  │   21.4272 │       21.3237 │ 4414 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬─────────╮
# │ Timing type   │    Each │   Relative │   Total │
# │               │      ms │ Percentage │       s │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Properties    │  5.4455 │    24.00 % │  2.7608 │
# │ Equations     │  4.8782 │    30.28 % │  3.4831 │
# │ Assembly      │  2.2389 │    13.90 % │  1.5986 │
# │ Linear solve  │  0.3833 │     1.69 % │  0.1944 │
# │ Linear setup  │  1.0455 │     4.61 % │  0.5300 │
# │ Precond apply │  0.0968 │     3.72 % │  0.4275 │
# │ Update        │  0.5863 │     2.58 % │  0.2973 │
# │ Convergence   │  1.7555 │    10.89 % │  1.2534 │
# │ Input/Output  │  0.1747 │     0.31 % │  0.0362 │
# │ Other         │  1.8214 │     8.03 % │  0.9234 │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Total         │ 22.6916 │   100.00 % │ 11.5046 │
# ╰───────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 206 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :H2O_mass_rate => Vector{Float64} of size (206,)
#        :lrat => Vector{Float64} of size (206,)
#        :orat => Vector{Float64} of size (206,)
#        :control => Vector{Symbol} of size (206,)
#        :bhp => Vector{Float64} of size (206,)
#        :CO2_mass_rate => Vector{Float64} of size (206,)
#        :mass_rate => Vector{Float64} of size (206,)
#        :rate => Vector{Float64} of size (206,)
#        :grat => Vector{Float64} of size (206,)
#
#   states (Vector with 206 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (2, 1000)
#     :OverallMoleFractions => Matrix{Float64} of size (2, 1000)
#     :Saturations => Matrix{Float64} of size (2, 1000)
#     :Pressure => Vector{Float64} of size (1000,)
#     :VaporMassFractions => Matrix{Float64} of size (2, 1000)
#     :TotalMasses => Matrix{Float64} of size (2, 1000)
#
#   time (report time for each state)
#      Vector{Float64} of length 206
#
#   result (extended states, reports)
#      SimResult with 206 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 31 2024 20:08 after 11 seconds, 468 milliseconds, 472.7 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# Note that this example is intended for static publication in the
# documentation. For interactive visualization you can use functions like
# `plot_interactive` to interactively visualize the states.

# %%
z = states[end][:OverallMoleFractions][2, :]
function plot_vertical(x, t)
    data = reshape(x, (nx, nz))
    data = data[:, end:-1:1]
    fig, ax, plot = heatmap(data)
    ax.title = t
    Colorbar(fig[1, 2], plot)
    fig
end
# Out:
# plot_vertical (generic function with 1 method)

# %% [markdown]
# ### Plot final CO2 mole fraction

# %%
plot_vertical(z, "CO2")
# Out:
# Figure()

# %% [markdown]
# ### Plot final vapor saturation

# %%
sg = states[end][:Saturations][2, :]
plot_vertical(sg, "Vapor saturation")
# Out:
# Figure()

# %% [markdown]
# ### Plot final pressure

# %%
p = states[end][:Pressure]
plot_vertical(p./bar, "Pressure [bar]")
# Out:
# Figure()

# %% [markdown]
# ### Plot in interactive viewer

# %%
plot_reservoir(model, states, step = length(dt), key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
