# %% [markdown]
# # Validation: The Egg model (oil-water compressible)
# A two-phase model that is taken from the first member of the EGG ensemble. The
# model is a synthetic case with channelized permeability and water injection
# with fixed controls. For more details, see the paper where the ensemble is
# introduced:
#
# [Jansen, Jan-Dirk, et al. "The egg model–a geological ensemble for reservoir
# simulation." Geoscience Data Journal 1.2 (2014): 192-195.](https://doi.org/10.1002/gdj3.21)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles, HYPRE
egg_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("EGG")
case = setup_case_from_data_file(joinpath(egg_dir, "EGG.DATA"))
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
#  Downloading artifact: EGG
#      Failure artifact: EGG
#  Downloading artifact: EGG
# Simulating 9 years, 44.69 weeks as 135 report steps   1%  ETA: 0:08:40
#   Progress:  Solving step 2/135 (0.14% of time interval complete)
#   Stats:     6 iterations in 6.86 s (1.14 s each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   2%  ETA: 0:06:05
#   Progress:  Solving step 3/135 (0.28% of time interval complete)
#   Stats:     17 iterations in 7.32 s (430.78 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   3%  ETA: 0:04:42
#   Progress:  Solving step 4/135 (0.56% of time interval complete)
#   Stats:     25 iterations in 7.66 s (306.33 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   4%  ETA: 0:03:53
#   Progress:  Solving step 5/135 (0.83% of time interval complete)
#   Stats:     33 iterations in 7.98 s (241.71 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   4%  ETA: 0:03:19
#   Progress:  Solving step 6/135 (1.11% of time interval complete)
#   Stats:     41 iterations in 8.30 s (202.42 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   5%  ETA: 0:02:56
#   Progress:  Solving step 7/135 (1.39% of time interval complete)
#   Stats:     49 iterations in 8.62 s (175.98 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   6%  ETA: 0:02:38
#   Progress:  Solving step 8/135 (1.67% of time interval complete)
#   Stats:     57 iterations in 8.95 s (157.06 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   7%  ETA: 0:02:24
#   Progress:  Solving step 9/135 (1.94% of time interval complete)
#   Stats:     65 iterations in 9.30 s (143.13 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   7%  ETA: 0:02:12
#   Progress:  Solving step 10/135 (2.22% of time interval complete)
#   Stats:     72 iterations in 9.59 s (133.14 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   8%  ETA: 0:02:02
#   Progress:  Solving step 11/135 (2.50% of time interval complete)
#   Stats:     77 iterations in 9.79 s (127.13 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps   9%  ETA: 0:01:52
#   Progress:  Solving step 12/135 (2.92% of time interval complete)
#   Stats:     81 iterations in 9.95 s (122.82 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  10%  ETA: 0:01:45
#   Progress:  Solving step 13/135 (3.33% of time interval complete)
#   Stats:     86 iterations in 10.16 s (118.13 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  10%  ETA: 0:01:39
#   Progress:  Solving step 14/135 (3.75% of time interval complete)
#   Stats:     92 iterations in 10.40 s (113.07 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  11%  ETA: 0:01:33
#   Progress:  Solving step 15/135 (4.17% of time interval complete)
#   Stats:     97 iterations in 10.62 s (109.46 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  12%  ETA: 0:01:28
#   Progress:  Solving step 16/135 (4.58% of time interval complete)
#   Stats:     102 iterations in 10.85 s (106.34 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  12%  ETA: 0:01:24
#   Progress:  Solving step 17/135 (5.00% of time interval complete)
#   Stats:     107 iterations in 11.07 s (103.50 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  13%  ETA: 0:01:20
#   Progress:  Solving step 18/135 (5.42% of time interval complete)
#   Stats:     112 iterations in 11.29 s (100.79 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  14%  ETA: 0:01:17
#   Progress:  Solving step 19/135 (5.83% of time interval complete)
#   Stats:     118 iterations in 11.57 s (98.03 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  15%  ETA: 0:01:14
#   Progress:  Solving step 20/135 (6.25% of time interval complete)
#   Stats:     123 iterations in 11.78 s (95.81 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  15%  ETA: 0:01:11
#   Progress:  Solving step 21/135 (6.67% of time interval complete)
#   Stats:     128 iterations in 12.00 s (93.79 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  16%  ETA: 0:01:08
#   Progress:  Solving step 22/135 (7.08% of time interval complete)
#   Stats:     133 iterations in 12.22 s (91.87 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  17%  ETA: 0:01:06
#   Progress:  Solving step 23/135 (7.50% of time interval complete)
#   Stats:     138 iterations in 12.43 s (90.09 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  18%  ETA: 0:01:03
#   Progress:  Solving step 24/135 (7.92% of time interval complete)
#   Stats:     142 iterations in 12.60 s (88.73 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  18%  ETA: 0:01:01
#   Progress:  Solving step 25/135 (8.33% of time interval complete)
#   Stats:     147 iterations in 12.82 s (87.22 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  19%  ETA: 0:00:59
#   Progress:  Solving step 26/135 (9.17% of time interval complete)
#   Stats:     151 iterations in 13.00 s (86.10 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  20%  ETA: 0:00:58
#   Progress:  Solving step 27/135 (10.00% of time interval complete)
#   Stats:     161 iterations in 13.43 s (83.44 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  21%  ETA: 0:00:57
#   Progress:  Solving step 28/135 (10.83% of time interval complete)
#   Stats:     170 iterations in 13.84 s (81.44 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  21%  ETA: 0:00:56
#   Progress:  Solving step 29/135 (11.67% of time interval complete)
#   Stats:     179 iterations in 14.32 s (79.98 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  22%  ETA: 0:00:55
#   Progress:  Solving step 30/135 (12.50% of time interval complete)
#   Stats:     188 iterations in 14.76 s (78.49 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  23%  ETA: 0:00:54
#   Progress:  Solving step 31/135 (13.33% of time interval complete)
#   Stats:     196 iterations in 15.14 s (77.27 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  24%  ETA: 0:00:53
#   Progress:  Solving step 32/135 (14.17% of time interval complete)
#   Stats:     204 iterations in 15.50 s (76.00 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  24%  ETA: 0:00:53
#   Progress:  Solving step 33/135 (15.00% of time interval complete)
#   Stats:     214 iterations in 15.99 s (74.72 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  25%  ETA: 0:00:52
#   Progress:  Solving step 34/135 (15.83% of time interval complete)
#   Stats:     223 iterations in 16.46 s (73.80 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  26%  ETA: 0:00:51
#   Progress:  Solving step 35/135 (16.67% of time interval complete)
#   Stats:     231 iterations in 16.86 s (73.01 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  26%  ETA: 0:00:51
#   Progress:  Solving step 36/135 (17.50% of time interval complete)
#   Stats:     239 iterations in 17.28 s (72.31 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  27%  ETA: 0:00:50
#   Progress:  Solving step 37/135 (18.33% of time interval complete)
#   Stats:     248 iterations in 17.75 s (71.57 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  28%  ETA: 0:00:49
#   Progress:  Solving step 38/135 (19.17% of time interval complete)
#   Stats:     257 iterations in 18.16 s (70.64 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  29%  ETA: 0:00:48
#   Progress:  Solving step 39/135 (20.00% of time interval complete)
#   Stats:     265 iterations in 18.53 s (69.92 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  29%  ETA: 0:00:48
#   Progress:  Solving step 40/135 (20.83% of time interval complete)
#   Stats:     273 iterations in 18.90 s (69.22 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  30%  ETA: 0:00:47
#   Progress:  Solving step 41/135 (21.67% of time interval complete)
#   Stats:     282 iterations in 19.32 s (68.51 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  31%  ETA: 0:00:46
#   Progress:  Solving step 42/135 (22.50% of time interval complete)
#   Stats:     290 iterations in 19.69 s (67.89 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  32%  ETA: 0:00:45
#   Progress:  Solving step 43/135 (23.33% of time interval complete)
#   Stats:     298 iterations in 20.06 s (67.32 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  32%  ETA: 0:00:44
#   Progress:  Solving step 44/135 (24.17% of time interval complete)
#   Stats:     304 iterations in 20.36 s (66.96 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  33%  ETA: 0:00:43
#   Progress:  Solving step 45/135 (25.00% of time interval complete)
#   Stats:     308 iterations in 20.55 s (66.72 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  34%  ETA: 0:00:42
#   Progress:  Solving step 46/135 (25.83% of time interval complete)
#   Stats:     312 iterations in 20.75 s (66.49 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  35%  ETA: 0:00:41
#   Progress:  Solving step 47/135 (26.67% of time interval complete)
#   Stats:     316 iterations in 20.94 s (66.27 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  35%  ETA: 0:00:40
#   Progress:  Solving step 48/135 (27.50% of time interval complete)
#   Stats:     320 iterations in 21.14 s (66.07 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  36%  ETA: 0:00:40
#   Progress:  Solving step 49/135 (28.33% of time interval complete)
#   Stats:     324 iterations in 21.34 s (65.87 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  37%  ETA: 0:00:39
#   Progress:  Solving step 50/135 (29.17% of time interval complete)
#   Stats:     328 iterations in 21.53 s (65.64 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  38%  ETA: 0:00:38
#   Progress:  Solving step 51/135 (30.00% of time interval complete)
#   Stats:     332 iterations in 21.72 s (65.41 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  38%  ETA: 0:00:37
#   Progress:  Solving step 52/135 (30.83% of time interval complete)
#   Stats:     336 iterations in 21.91 s (65.22 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  39%  ETA: 0:00:36
#   Progress:  Solving step 53/135 (31.67% of time interval complete)
#   Stats:     340 iterations in 22.11 s (65.04 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  40%  ETA: 0:00:35
#   Progress:  Solving step 54/135 (32.50% of time interval complete)
#   Stats:     345 iterations in 22.35 s (64.79 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  40%  ETA: 0:00:35
#   Progress:  Solving step 55/135 (33.33% of time interval complete)
#   Stats:     349 iterations in 22.53 s (64.57 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  41%  ETA: 0:00:34
#   Progress:  Solving step 56/135 (34.17% of time interval complete)
#   Stats:     353 iterations in 22.73 s (64.39 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  42%  ETA: 0:00:33
#   Progress:  Solving step 57/135 (35.00% of time interval complete)
#   Stats:     357 iterations in 22.93 s (64.22 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  43%  ETA: 0:00:32
#   Progress:  Solving step 58/135 (35.83% of time interval complete)
#   Stats:     361 iterations in 23.12 s (64.05 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  43%  ETA: 0:00:32
#   Progress:  Solving step 59/135 (36.67% of time interval complete)
#   Stats:     365 iterations in 23.32 s (63.90 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  44%  ETA: 0:00:31
#   Progress:  Solving step 60/135 (37.50% of time interval complete)
#   Stats:     369 iterations in 23.53 s (63.76 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  45%  ETA: 0:00:30
#   Progress:  Solving step 61/135 (38.33% of time interval complete)
#   Stats:     373 iterations in 23.72 s (63.59 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  46%  ETA: 0:00:30
#   Progress:  Solving step 62/135 (39.17% of time interval complete)
#   Stats:     377 iterations in 23.92 s (63.44 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  46%  ETA: 0:00:29
#   Progress:  Solving step 63/135 (40.00% of time interval complete)
#   Stats:     380 iterations in 24.07 s (63.35 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  47%  ETA: 0:00:28
#   Progress:  Solving step 64/135 (40.83% of time interval complete)
#   Stats:     383 iterations in 24.23 s (63.26 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  48%  ETA: 0:00:28
#   Progress:  Solving step 65/135 (41.67% of time interval complete)
#   Stats:     386 iterations in 24.38 s (63.15 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  49%  ETA: 0:00:27
#   Progress:  Solving step 66/135 (42.50% of time interval complete)
#   Stats:     389 iterations in 24.53 s (63.06 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  49%  ETA: 0:00:26
#   Progress:  Solving step 67/135 (43.33% of time interval complete)
#   Stats:     392 iterations in 24.69 s (62.99 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  50%  ETA: 0:00:26
#   Progress:  Solving step 68/135 (44.17% of time interval complete)
#   Stats:     395 iterations in 24.86 s (62.94 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  51%  ETA: 0:00:25
#   Progress:  Solving step 69/135 (45.00% of time interval complete)
#   Stats:     398 iterations in 25.05 s (62.94 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  51%  ETA: 0:00:25
#   Progress:  Solving step 70/135 (45.83% of time interval complete)
#   Stats:     401 iterations in 25.21 s (62.87 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  52%  ETA: 0:00:24
#   Progress:  Solving step 71/135 (46.67% of time interval complete)
#   Stats:     404 iterations in 25.37 s (62.79 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  53%  ETA: 0:00:24
#   Progress:  Solving step 72/135 (47.50% of time interval complete)
#   Stats:     407 iterations in 25.50 s (62.66 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  54%  ETA: 0:00:23
#   Progress:  Solving step 73/135 (48.33% of time interval complete)
#   Stats:     410 iterations in 25.66 s (62.58 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  54%  ETA: 0:00:22
#   Progress:  Solving step 74/135 (49.17% of time interval complete)
#   Stats:     413 iterations in 25.80 s (62.48 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  55%  ETA: 0:00:22
#   Progress:  Solving step 75/135 (50.00% of time interval complete)
#   Stats:     415 iterations in 25.92 s (62.46 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  56%  ETA: 0:00:21
#   Progress:  Solving step 76/135 (50.83% of time interval complete)
#   Stats:     418 iterations in 26.08 s (62.38 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  57%  ETA: 0:00:21
#   Progress:  Solving step 77/135 (51.67% of time interval complete)
#   Stats:     421 iterations in 26.24 s (62.33 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  57%  ETA: 0:00:20
#   Progress:  Solving step 78/135 (52.50% of time interval complete)
#   Stats:     423 iterations in 26.36 s (62.32 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  58%  ETA: 0:00:20
#   Progress:  Solving step 79/135 (53.33% of time interval complete)
#   Stats:     426 iterations in 26.52 s (62.26 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  59%  ETA: 0:00:19
#   Progress:  Solving step 80/135 (54.17% of time interval complete)
#   Stats:     428 iterations in 26.63 s (62.23 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  60%  ETA: 0:00:19
#   Progress:  Solving step 81/135 (55.00% of time interval complete)
#   Stats:     431 iterations in 26.79 s (62.17 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  60%  ETA: 0:00:18
#   Progress:  Solving step 82/135 (55.83% of time interval complete)
#   Stats:     433 iterations in 26.91 s (62.15 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  61%  ETA: 0:00:18
#   Progress:  Solving step 83/135 (56.67% of time interval complete)
#   Stats:     435 iterations in 27.02 s (62.11 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  62%  ETA: 0:00:17
#   Progress:  Solving step 84/135 (57.50% of time interval complete)
#   Stats:     437 iterations in 27.13 s (62.07 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  62%  ETA: 0:00:17
#   Progress:  Solving step 85/135 (58.33% of time interval complete)
#   Stats:     439 iterations in 27.23 s (62.04 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  63%  ETA: 0:00:16
#   Progress:  Solving step 86/135 (59.17% of time interval complete)
#   Stats:     441 iterations in 27.35 s (62.01 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  64%  ETA: 0:00:16
#   Progress:  Solving step 87/135 (60.00% of time interval complete)
#   Stats:     444 iterations in 27.51 s (61.97 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  65%  ETA: 0:00:16
#   Progress:  Solving step 88/135 (60.83% of time interval complete)
#   Stats:     447 iterations in 27.67 s (61.91 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  65%  ETA: 0:00:15
#   Progress:  Solving step 89/135 (61.67% of time interval complete)
#   Stats:     449 iterations in 27.80 s (61.91 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  66%  ETA: 0:00:15
#   Progress:  Solving step 90/135 (62.50% of time interval complete)
#   Stats:     452 iterations in 27.96 s (61.85 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  67%  ETA: 0:00:14
#   Progress:  Solving step 91/135 (63.33% of time interval complete)
#   Stats:     454 iterations in 28.07 s (61.83 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  68%  ETA: 0:00:14
#   Progress:  Solving step 92/135 (64.17% of time interval complete)
#   Stats:     456 iterations in 28.18 s (61.81 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  68%  ETA: 0:00:14
#   Progress:  Solving step 93/135 (65.00% of time interval complete)
#   Stats:     458 iterations in 28.31 s (61.81 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  69%  ETA: 0:00:13
#   Progress:  Solving step 94/135 (65.83% of time interval complete)
#   Stats:     460 iterations in 28.43 s (61.80 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  70%  ETA: 0:00:13
#   Progress:  Solving step 95/135 (66.67% of time interval complete)
#   Stats:     462 iterations in 28.54 s (61.77 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  71%  ETA: 0:00:12
#   Progress:  Solving step 96/135 (67.50% of time interval complete)
#   Stats:     464 iterations in 28.66 s (61.77 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  71%  ETA: 0:00:12
#   Progress:  Solving step 97/135 (68.33% of time interval complete)
#   Stats:     466 iterations in 28.78 s (61.75 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  72%  ETA: 0:00:12
#   Progress:  Solving step 98/135 (69.17% of time interval complete)
#   Stats:     468 iterations in 28.89 s (61.72 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  73%  ETA: 0:00:11
#   Progress:  Solving step 99/135 (70.00% of time interval complete)
#   Stats:     470 iterations in 29.00 s (61.70 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  74%  ETA: 0:00:11
#   Progress:  Solving step 100/135 (70.83% of time interval complete)
#   Stats:     472 iterations in 29.12 s (61.69 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  74%  ETA: 0:00:10
#   Progress:  Solving step 101/135 (71.67% of time interval complete)
#   Stats:     474 iterations in 29.22 s (61.64 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  75%  ETA: 0:00:10
#   Progress:  Solving step 102/135 (72.50% of time interval complete)
#   Stats:     476 iterations in 29.33 s (61.63 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  76%  ETA: 0:00:10
#   Progress:  Solving step 103/135 (73.33% of time interval complete)
#   Stats:     478 iterations in 29.45 s (61.62 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  76%  ETA: 0:00:09
#   Progress:  Solving step 104/135 (74.17% of time interval complete)
#   Stats:     480 iterations in 29.56 s (61.58 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  77%  ETA: 0:00:09
#   Progress:  Solving step 105/135 (75.00% of time interval complete)
#   Stats:     482 iterations in 29.67 s (61.55 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  78%  ETA: 0:00:09
#   Progress:  Solving step 106/135 (75.83% of time interval complete)
#   Stats:     484 iterations in 29.79 s (61.54 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  79%  ETA: 0:00:08
#   Progress:  Solving step 107/135 (76.67% of time interval complete)
#   Stats:     486 iterations in 29.90 s (61.51 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  79%  ETA: 0:00:08
#   Progress:  Solving step 108/135 (77.50% of time interval complete)
#   Stats:     488 iterations in 30.01 s (61.49 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  80%  ETA: 0:00:08
#   Progress:  Solving step 109/135 (78.33% of time interval complete)
#   Stats:     490 iterations in 30.12 s (61.46 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  81%  ETA: 0:00:07
#   Progress:  Solving step 110/135 (79.17% of time interval complete)
#   Stats:     492 iterations in 30.22 s (61.43 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  82%  ETA: 0:00:07
#   Progress:  Solving step 111/135 (80.00% of time interval complete)
#   Stats:     494 iterations in 30.33 s (61.40 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  82%  ETA: 0:00:07
#   Progress:  Solving step 112/135 (80.83% of time interval complete)
#   Stats:     496 iterations in 30.44 s (61.36 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  83%  ETA: 0:00:06
#   Progress:  Solving step 113/135 (81.67% of time interval complete)
#   Stats:     498 iterations in 30.56 s (61.36 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  84%  ETA: 0:00:06
#   Progress:  Solving step 114/135 (82.50% of time interval complete)
#   Stats:     500 iterations in 30.67 s (61.34 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  85%  ETA: 0:00:06
#   Progress:  Solving step 115/135 (83.33% of time interval complete)
#   Stats:     502 iterations in 30.78 s (61.32 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  85%  ETA: 0:00:05
#   Progress:  Solving step 116/135 (84.17% of time interval complete)
#   Stats:     504 iterations in 30.90 s (61.30 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  86%  ETA: 0:00:05
#   Progress:  Solving step 117/135 (85.00% of time interval complete)
#   Stats:     506 iterations in 31.01 s (61.29 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  87%  ETA: 0:00:05
#   Progress:  Solving step 118/135 (85.83% of time interval complete)
#   Stats:     508 iterations in 31.13 s (61.27 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  88%  ETA: 0:00:05
#   Progress:  Solving step 119/135 (86.67% of time interval complete)
#   Stats:     510 iterations in 31.24 s (61.26 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  88%  ETA: 0:00:04
#   Progress:  Solving step 120/135 (87.50% of time interval complete)
#   Stats:     512 iterations in 31.36 s (61.25 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  89%  ETA: 0:00:04
#   Progress:  Solving step 121/135 (88.33% of time interval complete)
#   Stats:     514 iterations in 31.47 s (61.23 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  90%  ETA: 0:00:04
#   Progress:  Solving step 122/135 (89.17% of time interval complete)
#   Stats:     516 iterations in 31.59 s (61.22 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  90%  ETA: 0:00:03
#   Progress:  Solving step 123/135 (90.00% of time interval complete)
#   Stats:     518 iterations in 31.71 s (61.22 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  91%  ETA: 0:00:03
#   Progress:  Solving step 124/135 (90.83% of time interval complete)
#   Stats:     520 iterations in 31.83 s (61.21 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  92%  ETA: 0:00:03
#   Progress:  Solving step 125/135 (91.67% of time interval complete)
#   Stats:     522 iterations in 31.95 s (61.21 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  93%  ETA: 0:00:03
#   Progress:  Solving step 126/135 (92.50% of time interval complete)
#   Stats:     524 iterations in 32.07 s (61.20 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  93%  ETA: 0:00:02
#   Progress:  Solving step 127/135 (93.33% of time interval complete)
#   Stats:     526 iterations in 32.19 s (61.19 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  94%  ETA: 0:00:02
#   Progress:  Solving step 128/135 (94.17% of time interval complete)
#   Stats:     528 iterations in 32.31 s (61.19 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  95%  ETA: 0:00:02
#   Progress:  Solving step 129/135 (95.00% of time interval complete)
#   Stats:     530 iterations in 32.43 s (61.19 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  96%  ETA: 0:00:02
#   Progress:  Solving step 130/135 (95.83% of time interval complete)
#   Stats:     532 iterations in 32.55 s (61.18 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  96%  ETA: 0:00:01
#   Progress:  Solving step 131/135 (96.67% of time interval complete)
#   Stats:     534 iterations in 32.66 s (61.15 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  97%  ETA: 0:00:01
#   Progress:  Solving step 132/135 (97.50% of time interval complete)
#   Stats:     536 iterations in 32.78 s (61.15 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  98%  ETA: 0:00:01
#   Progress:  Solving step 133/135 (98.33% of time interval complete)
#   Stats:     538 iterations in 32.88 s (61.12 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  99%  ETA: 0:00:01
#   Progress:  Solving step 134/135 (99.17% of time interval complete)
#   Stats:     540 iterations in 33.01 s (61.12 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps  99%  ETA: 0:00:00
#   Progress:  Solving step 135/135 (100.00% of time interval complete)
#   Stats:     542 iterations in 33.12 s (61.11 ms each)
#
# Simulating 9 years, 44.69 weeks as 135 report steps 100% Time: 0:00:34
#   Progress:  Solved step 135/135
#   Stats:     544 iterations in 33.23 s (61.08 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │    Total │
# │                │ 135 steps │ 162 ministeps │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┤
# │ Newton         │   4.02963 │       3.35802 │  544 (0) │
# │ Linearization  │   5.22963 │       4.35802 │  706 (0) │
# │ Linear solver  │   18.5704 │       15.4753 │ 2507 (0) │
# │ Precond apply  │   37.1407 │       30.9506 │ 5014 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬─────────╮
# │ Timing type   │    Each │   Relative │   Total │
# │               │      ms │ Percentage │       s │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Properties    │  1.8707 │     3.06 % │  1.0177 │
# │ Equations     │  4.7916 │    10.18 % │  3.3829 │
# │ Assembly      │  4.1591 │     8.84 % │  2.9363 │
# │ Linear solve  │  2.7746 │     4.54 % │  1.5094 │
# │ Linear setup  │ 21.2050 │    34.72 % │ 11.5355 │
# │ Precond apply │  1.7319 │    26.14 % │  8.6839 │
# │ Update        │  1.5463 │     2.53 % │  0.8412 │
# │ Convergence   │  1.2230 │     2.60 % │  0.8634 │
# │ Input/Output  │  0.6215 │     0.30 % │  0.1007 │
# │ Other         │  4.3302 │     7.09 % │  2.3556 │
# ├───────────────┼─────────┼────────────┼─────────┤
# │ Total         │ 61.0784 │   100.00 % │ 33.2267 │
# ╰───────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 162 entries:
#
#   wells (12 present):
#     :PROD4
#     :INJECT5
#     :INJECT4
#     :INJECT8
#     :INJECT6
#     :INJECT1
#     :INJECT7
#     :INJECT3
#     :PROD2
#     :PROD3
#     :PROD1
#     :INJECT2
#     Results per well:
#        :lrat => Vector{Float64} of size (162,)
#        :wrat => Vector{Float64} of size (162,)
#        :Aqueous_mass_rate => Vector{Float64} of size (162,)
#        :orat => Vector{Float64} of size (162,)
#        :control => Vector{Symbol} of size (162,)
#        :bhp => Vector{Float64} of size (162,)
#        :Liquid_mass_rate => Vector{Float64} of size (162,)
#        :mass_rate => Vector{Float64} of size (162,)
#        :rate => Vector{Float64} of size (162,)
#
#   states (Vector with 162 entries, reservoir variables for each state)
#     :Saturations => Matrix{Float64} of size (2, 18553)
#     :Pressure => Vector{Float64} of size (18553,)
#     :TotalMasses => Matrix{Float64} of size (2, 18553)
#
#   time (report time for each state)
#      Vector{Float64} of length 162
#
#   result (extended states, reports)
#      SimResult with 135 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 31 2024 20:08 after 33 seconds, 125 milliseconds, 984.9 microseconds.

# %% [markdown]
# ## Plot the reservoir solution

# %%
plot_reservoir(case.model, states, step = 135, key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ## Load reference solution (OPM Flow)
# We load a CSV file with the reference solution and set up plotting

# %%
csv_path = joinpath(egg_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response")
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "E100"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Well responses and comparison
# ### Water production rates

# %%
plot_well_comparison(:wrat, prod, "Water surface rate")
# Out:
# Figure()

# %% [markdown]
# ### Oil production rates

# %%
plot_well_comparison(:orat, prod, "Oil surface rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
