# %% [markdown]
# # OLYMPUS_1 model
# Model from the [ISAPP Optimization challenge](https://www.isapp2.com/optimization-challenge/reservoir-model-description.html)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles, HYPRE
olympus_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("OLYMPUS_1")
case = setup_case_from_data_file(joinpath(olympus_dir, "OLYMPUS_1.DATA"), backend = :csr)
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
#  Downloading artifact: OLYMPUS_1
#      Failure artifact: OLYMPUS_1
#  Downloading artifact: OLYMPUS_1
# Parser: GRID/PINCH - PINCH is only partially supported by JutulDarcy solvers.
# Parser: GRID/COORDSYS - Unsupported keyword. It will be ignored.
# Parser: PROPS/ROCKOPTS - ROCKOPTS is not supported by JutulDarcy solvers. It will be ignored in simulations.
# Parser: SCHEDULE/GRUPTREE - Unsupported keyword. It will be ignored.
# Transmissibility: Replaced 6941 negative half-transmissibilities (out of 1130154, 0.61%) with their absolute value.
# Simulating 20 years, 3.6 hours as 20 report steps  10%|▎ |  ETA: 0:07:50
#   Progress:  Solving step 2/20 (10.01% of time interval complete)
#   Stats:     111 iterations in 48.80 s (439.63 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  14%|▎ |  ETA: 0:05:58
#   Progress:  Solving step 3/20 (15.00% of time interval complete)
#   Stats:     137 iterations in 58.98 s (430.51 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  19%|▍ |  ETA: 0:06:09
#   Progress:  Solving step 4/20 (20.00% of time interval complete)
#   Stats:     209 iterations in 86.21 s (412.48 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  24%|▌ |  ETA: 0:06:03
#   Progress:  Solving step 5/20 (25.01% of time interval complete)
#   Stats:     280 iterations in 112.83 s (402.98 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  29%|▋ |  ETA: 0:05:16
#   Progress:  Solving step 6/20 (30.01% of time interval complete)
#   Stats:     313 iterations in 125.65 s (401.45 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  33%|▋ |  ETA: 0:04:35
#   Progress:  Solving step 7/20 (35.00% of time interval complete)
#   Stats:     342 iterations in 136.67 s (399.62 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  38%|▊ |  ETA: 0:04:05
#   Progress:  Solving step 8/20 (40.00% of time interval complete)
#   Stats:     376 iterations in 150.09 s (399.16 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  43%|▉ |  ETA: 0:03:29
#   Progress:  Solving step 9/20 (45.01% of time interval complete)
#   Stats:     391 iterations in 156.11 s (399.27 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  48%|█ |  ETA: 0:02:57
#   Progress:  Solving step 10/20 (50.01% of time interval complete)
#   Stats:     403 iterations in 160.58 s (398.45 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  52%|█ |  ETA: 0:02:30
#   Progress:  Solving step 11/20 (55.00% of time interval complete)
#   Stats:     414 iterations in 164.74 s (397.93 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  57%|█▏|  ETA: 0:02:07
#   Progress:  Solving step 12/20 (60.00% of time interval complete)
#   Stats:     424 iterations in 168.61 s (397.67 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  62%|█▎|  ETA: 0:01:47
#   Progress:  Solving step 13/20 (65.01% of time interval complete)
#   Stats:     435 iterations in 172.86 s (397.37 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  67%|█▍|  ETA: 0:01:28
#   Progress:  Solving step 14/20 (70.01% of time interval complete)
#   Stats:     443 iterations in 176.10 s (397.52 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  71%|█▍|  ETA: 0:01:12
#   Progress:  Solving step 15/20 (75.00% of time interval complete)
#   Stats:     451 iterations in 179.25 s (397.45 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  76%|█▌|  ETA: 0:00:58
#   Progress:  Solving step 16/20 (80.00% of time interval complete)
#   Stats:     463 iterations in 183.90 s (397.20 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  81%|█▋|  ETA: 0:00:46
#   Progress:  Solving step 17/20 (85.01% of time interval complete)
#   Stats:     489 iterations in 193.70 s (396.11 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  86%|█▊|  ETA: 0:00:33
#   Progress:  Solving step 18/20 (90.01% of time interval complete)
#   Stats:     500 iterations in 197.84 s (395.68 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  90%|█▊|  ETA: 0:00:21
#   Progress:  Solving step 19/20 (95.00% of time interval complete)
#   Stats:     510 iterations in 201.74 s (395.57 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  95%|█▉|  ETA: 0:00:10
#   Progress:  Solving step 20/20 (100.00% of time interval complete)
#   Stats:     520 iterations in 205.55 s (395.28 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps 100%|██| Time: 0:03:29
#   Progress:  Solved step 20/20
#   Stats:     528 iterations in 208.68 s (395.23 ms each)
# ╭────────────────┬──────────┬──────────────┬────────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │      Total │
# │                │ 20 steps │ 83 ministeps │   (wasted) │
# ├────────────────┼──────────┼──────────────┼────────────┤
# │ Newton         │     26.4 │      6.36145 │  528 (195) │
# │ Linearization  │    30.55 │      7.36145 │  611 (208) │
# │ Linear solver  │    43.05 │      10.3735 │  861 (282) │
# │ Precond apply  │     86.1 │       20.747 │ 1722 (564) │
# ╰────────────────┴──────────┴──────────────┴────────────╯
# ╭───────────────┬──────────┬────────────┬──────────╮
# │ Timing type   │     Each │   Relative │    Total │
# │               │       ms │ Percentage │        s │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Properties    │  21.1416 │     5.35 % │  11.1628 │
# │ Equations     │  34.8659 │    10.21 % │  21.3031 │
# │ Assembly      │  33.7264 │     9.87 % │  20.6068 │
# │ Linear solve  │  15.4025 │     3.90 % │   8.1325 │
# │ Linear setup  │ 204.8895 │    51.84 % │ 108.1816 │
# │ Precond apply │  18.6643 │    15.40 % │  32.1399 │
# │ Update        │   3.5094 │     0.89 % │   1.8530 │
# │ Convergence   │   2.5969 │     0.76 % │   1.5867 │
# │ Input/Output  │   1.0455 │     0.04 % │   0.0868 │
# │ Other         │   6.8695 │     1.74 % │   3.6271 │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Total         │ 395.2276 │   100.00 % │ 208.6802 │
# ╰───────────────┴──────────┴────────────┴──────────╯
# ReservoirSimResult with 70 entries:
#
#   wells (18 present):
#     :INJ-7
#     :PROD-4
#     :INJ-5
#     :INJ-4
#     :PROD-9
#     :INJ-2
#     :PROD-3
#     :PROD-2
#     :PROD-8
#     :INJ-3
#     :PROD-6
#     :PROD-1
#     :PROD-10
#     :PROD-7
#     :PROD-5
#     :INJ-6
#     :PROD-11
#     :INJ-1
#     Results per well:
#        :lrat => Vector{Float64} of size (70,)
#        :wrat => Vector{Float64} of size (70,)
#        :Aqueous_mass_rate => Vector{Float64} of size (70,)
#        :orat => Vector{Float64} of size (70,)
#        :control => Vector{Symbol} of size (70,)
#        :bhp => Vector{Float64} of size (70,)
#        :Liquid_mass_rate => Vector{Float64} of size (70,)
#        :mass_rate => Vector{Float64} of size (70,)
#        :rate => Vector{Float64} of size (70,)
#
#   states (Vector with 70 entries, reservoir variables for each state)
#     :Saturations => Matrix{Float64} of size (2, 192750)
#     :Pressure => Vector{Float64} of size (192750,)
#     :TotalMasses => Matrix{Float64} of size (2, 192750)
#
#   time (report time for each state)
#      Vector{Float64} of length 70
#
#   result (extended states, reports)
#      SimResult with 20 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 31 2024 20:08 after 3 minutes, 28 seconds, 593.4 milliseconds.

# %% [markdown]
# ## Plot the reservoir

# %%
plot_reservoir(case.model, key = :porosity)
# Out:
# Figure()

# %% [markdown]
# ## Plot the saturations

# %%
plot_reservoir(case.model, states, step = 10, key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ## Load reference and set up plotting

# %%
csv_path = joinpath(olympus_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response"; ylims = missing)
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
        if !ismissing(ylims)
            ylims!(ax, ylims)
        end
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "OPM Flow"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Plot water production rates

# %%
plot_well_comparison(:wrat, prod, "Water surface production rate")
# Out:
# Figure()

# %% [markdown]
# ## Plot oil production rates

# %%
plot_well_comparison(:orat, prod, "Oil surface production rate", ylims = (0, 5))
# Out:
# Figure()

# %% [markdown]
# ## Plot water injection rates

# %%
plot_well_comparison(:wrat, inj, "Water injection rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
