# %% [markdown]
# # Norne: Real field black-oil model
# The Norne model is a real field model. The model has been adapted so that the
# input file only contains features present in JutulDarcy, with the most notable
# omissions being removal of hysteresis and threshold pressures between
# equilibriation reqgions. For more details, see the [OPM data
# webpage](https://opm-project.org/?page_id=559)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles, HYPRE
norne_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("NORNE_NOHYST")
case = setup_case_from_data_file(joinpath(norne_dir, "NORNE_NOHYST.DATA"))
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
# F-4H completion: Removed COMPDAT as (36, 68, 17) is not active in processed mesh.
# Rel. Perm. Scaling: Three-point scaling active.
# Shutting D-1H: Well has no open perforations at step 137, shutting.
# ┌ Warning: Negative saturation in 215 cells for phase 2. Normalizing.
# └ @ JutulDarcy ~/work/JutulDarcy.jl/JutulDarcy.jl/src/init/init.jl:805
# Transmissibility: Replaced 5439 negative half-transmissibilities (out of 273120, 1.99%) with their absolute value.
# Transmissibility: Replaced 2 non-finite half-transmissibilities (out of 273120, 0.0%) with zero.
# Transmissibility: Replaced 120 negative half-transmissibilities (out of 273120, 0.04%) with their absolute value.
# Transmissibility: Replaced 2 non-finite half-transmissibilities (out of 273120, 0.0%) with zero.
# Simulating 9 years, 3.545 weeks as 247 report steps   1%  ETA: 0:19:56
#   Progress:  Solving step 2/247 (0.75% of time interval complete)
#   Stats:     10 iterations in 7.85 s (785.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   1%  ETA: 0:15:09
#   Progress:  Solving step 3/247 (1.24% of time interval complete)
#   Stats:     19 iterations in 9.25 s (487.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:12:22
#   Progress:  Solving step 4/247 (1.69% of time interval complete)
#   Stats:     26 iterations in 10.27 s (395.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:10:39
#   Progress:  Solving step 5/247 (2.63% of time interval complete)
#   Stats:     33 iterations in 11.26 s (341.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   2%  ETA: 0:09:38
#   Progress:  Solving step 6/247 (3.47% of time interval complete)
#   Stats:     41 iterations in 12.43 s (303.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   3%  ETA: 0:08:37
#   Progress:  Solving step 7/247 (4.32% of time interval complete)
#   Stats:     46 iterations in 13.12 s (285.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   3%  ETA: 0:07:58
#   Progress:  Solving step 8/247 (4.35% of time interval complete)
#   Stats:     52 iterations in 14.05 s (270.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:07:13
#   Progress:  Solving step 9/247 (4.41% of time interval complete)
#   Stats:     54 iterations in 14.39 s (266.51 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:06:56
#   Progress:  Solving step 10/247 (5.07% of time interval complete)
#   Stats:     58 iterations in 15.57 s (268.38 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   4%  ETA: 0:06:45
#   Progress:  Solving step 11/247 (5.31% of time interval complete)
#   Stats:     67 iterations in 16.90 s (252.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   5%  ETA: 0:06:33
#   Progress:  Solving step 12/247 (6.07% of time interval complete)
#   Stats:     75 iterations in 18.09 s (241.16 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   5%  ETA: 0:06:33
#   Progress:  Solving step 13/247 (6.10% of time interval complete)
#   Stats:     87 iterations in 19.81 s (227.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:06:08
#   Progress:  Solving step 14/247 (6.25% of time interval complete)
#   Stats:     89 iterations in 20.11 s (225.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:05:52
#   Progress:  Solving step 15/247 (6.64% of time interval complete)
#   Stats:     93 iterations in 20.73 s (222.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   6%  ETA: 0:05:41
#   Progress:  Solving step 16/247 (6.91% of time interval complete)
#   Stats:     98 iterations in 21.57 s (220.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   7%  ETA: 0:05:33
#   Progress:  Solving step 17/247 (6.94% of time interval complete)
#   Stats:     105 iterations in 22.57 s (214.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   7%  ETA: 0:05:17
#   Progress:  Solving step 18/247 (7.16% of time interval complete)
#   Stats:     107 iterations in 22.89 s (213.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:17
#   Progress:  Solving step 19/247 (7.61% of time interval complete)
#   Stats:     113 iterations in 24.37 s (215.66 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:08
#   Progress:  Solving step 20/247 (8.09% of time interval complete)
#   Stats:     118 iterations in 25.14 s (213.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   8%  ETA: 0:05:11
#   Progress:  Solving step 21/247 (8.97% of time interval complete)
#   Stats:     128 iterations in 26.85 s (209.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   9%  ETA: 0:05:05
#   Progress:  Solving step 22/247 (9.00% of time interval complete)
#   Stats:     134 iterations in 27.76 s (207.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps   9%  ETA: 0:04:54
#   Progress:  Solving step 23/247 (9.03% of time interval complete)
#   Stats:     136 iterations in 28.11 s (206.66 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:04:44
#   Progress:  Solving step 24/247 (9.54% of time interval complete)
#   Stats:     138 iterations in 28.46 s (206.24 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:04:43
#   Progress:  Solving step 25/247 (9.84% of time interval complete)
#   Stats:     145 iterations in 29.79 s (205.45 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  10%  ETA: 0:04:36
#   Progress:  Solving step 26/247 (9.93% of time interval complete)
#   Stats:     149 iterations in 30.41 s (204.10 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  11%  ETA: 0:04:35
#   Progress:  Solving step 27/247 (10.30% of time interval complete)
#   Stats:     157 iterations in 31.66 s (201.65 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  11%  ETA: 0:04:44
#   Progress:  Solving step 28/247 (10.42% of time interval complete)
#   Stats:     168 iterations in 34.17 s (203.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:04:39
#   Progress:  Solving step 29/247 (10.87% of time interval complete)
#   Stats:     174 iterations in 35.00 s (201.14 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:04:56
#   Progress:  Solving step 30/247 (11.78% of time interval complete)
#   Stats:     193 iterations in 38.75 s (200.79 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  12%  ETA: 0:05:09
#   Progress:  Solving step 31/247 (12.50% of time interval complete)
#   Stats:     209 iterations in 42.25 s (202.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  13%  ETA: 0:05:11
#   Progress:  Solving step 32/247 (12.71% of time interval complete)
#   Stats:     220 iterations in 44.19 s (200.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  13%  ETA: 0:05:06
#   Progress:  Solving step 33/247 (12.80% of time interval complete)
#   Stats:     225 iterations in 45.07 s (200.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  14%  ETA: 0:05:07
#   Progress:  Solving step 34/247 (13.25% of time interval complete)
#   Stats:     236 iterations in 46.83 s (198.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  14%  ETA: 0:05:24
#   Progress:  Solving step 35/247 (13.32% of time interval complete)
#   Stats:     262 iterations in 51.31 s (195.84 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:20
#   Progress:  Solving step 36/247 (13.65% of time interval complete)
#   Stats:     268 iterations in 52.35 s (195.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:24
#   Progress:  Solving step 37/247 (14.34% of time interval complete)
#   Stats:     280 iterations in 54.95 s (196.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  15%  ETA: 0:05:25
#   Progress:  Solving step 38/247 (14.49% of time interval complete)
#   Stats:     291 iterations in 56.94 s (195.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  16%  ETA: 0:05:39
#   Progress:  Solving step 39/247 (14.61% of time interval complete)
#   Stats:     319 iterations in 61.34 s (192.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  16%  ETA: 0:05:35
#   Progress:  Solving step 40/247 (15.16% of time interval complete)
#   Stats:     326 iterations in 62.45 s (191.56 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:39
#   Progress:  Solving step 41/247 (15.25% of time interval complete)
#   Stats:     341 iterations in 65.16 s (191.09 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:42
#   Progress:  Solving step 42/247 (15.31% of time interval complete)
#   Stats:     353 iterations in 67.70 s (191.78 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  17%  ETA: 0:05:34
#   Progress:  Solving step 43/247 (15.43% of time interval complete)
#   Stats:     356 iterations in 68.21 s (191.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  18%  ETA: 0:05:30
#   Progress:  Solving step 44/247 (16.33% of time interval complete)
#   Stats:     363 iterations in 69.35 s (191.04 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  18%  ETA: 0:05:34
#   Progress:  Solving step 45/247 (16.43% of time interval complete)
#   Stats:     378 iterations in 72.01 s (190.49 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:28
#   Progress:  Solving step 46/247 (16.46% of time interval complete)
#   Stats:     382 iterations in 72.68 s (190.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:20
#   Progress:  Solving step 47/247 (16.82% of time interval complete)
#   Stats:     384 iterations in 73.01 s (190.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  19%  ETA: 0:05:18
#   Progress:  Solving step 48/247 (16.91% of time interval complete)
#   Stats:     391 iterations in 74.38 s (190.24 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  20%  ETA: 0:05:11
#   Progress:  Solving step 49/247 (16.94% of time interval complete)
#   Stats:     393 iterations in 74.75 s (190.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  20%  ETA: 0:05:09
#   Progress:  Solving step 50/247 (17.27% of time interval complete)
#   Stats:     397 iterations in 75.97 s (191.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:07
#   Progress:  Solving step 51/247 (17.90% of time interval complete)
#   Stats:     406 iterations in 77.53 s (190.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:05
#   Progress:  Solving step 52/247 (18.18% of time interval complete)
#   Stats:     414 iterations in 79.03 s (190.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  21%  ETA: 0:05:00
#   Progress:  Solving step 53/247 (18.60% of time interval complete)
#   Stats:     417 iterations in 79.61 s (190.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  22%  ETA: 0:04:56
#   Progress:  Solving step 54/247 (19.11% of time interval complete)
#   Stats:     422 iterations in 80.50 s (190.76 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  22%  ETA: 0:04:55
#   Progress:  Solving step 55/247 (19.23% of time interval complete)
#   Stats:     430 iterations in 82.02 s (190.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:04:50
#   Progress:  Solving step 56/247 (19.99% of time interval complete)
#   Stats:     433 iterations in 82.56 s (190.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:04:50
#   Progress:  Solving step 57/247 (20.05% of time interval complete)
#   Stats:     444 iterations in 84.72 s (190.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  23%  ETA: 0:04:46
#   Progress:  Solving step 58/247 (20.11% of time interval complete)
#   Stats:     447 iterations in 85.26 s (190.73 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  24%  ETA: 0:04:43
#   Progress:  Solving step 59/247 (20.65% of time interval complete)
#   Stats:     450 iterations in 86.37 s (191.93 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  24%  ETA: 0:04:43
#   Progress:  Solving step 60/247 (20.68% of time interval complete)
#   Stats:     461 iterations in 88.32 s (191.58 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:38
#   Progress:  Solving step 61/247 (20.95% of time interval complete)
#   Stats:     464 iterations in 88.85 s (191.49 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:36
#   Progress:  Solving step 62/247 (21.01% of time interval complete)
#   Stats:     471 iterations in 90.12 s (191.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  25%  ETA: 0:04:32
#   Progress:  Solving step 63/247 (21.04% of time interval complete)
#   Stats:     474 iterations in 90.67 s (191.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  26%  ETA: 0:04:27
#   Progress:  Solving step 64/247 (21.32% of time interval complete)
#   Stats:     476 iterations in 91.04 s (191.27 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  26%  ETA: 0:04:25
#   Progress:  Solving step 65/247 (21.41% of time interval complete)
#   Stats:     481 iterations in 92.04 s (191.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:21
#   Progress:  Solving step 66/247 (21.89% of time interval complete)
#   Stats:     484 iterations in 92.55 s (191.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:22
#   Progress:  Solving step 67/247 (22.13% of time interval complete)
#   Stats:     495 iterations in 95.16 s (192.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  27%  ETA: 0:04:19
#   Progress:  Solving step 68/247 (22.16% of time interval complete)
#   Stats:     500 iterations in 95.84 s (191.68 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  28%  ETA: 0:04:16
#   Progress:  Solving step 69/247 (22.25% of time interval complete)
#   Stats:     506 iterations in 96.73 s (191.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  28%  ETA: 0:04:16
#   Progress:  Solving step 70/247 (22.80% of time interval complete)
#   Stats:     519 iterations in 98.84 s (190.44 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:22
#   Progress:  Solving step 71/247 (23.73% of time interval complete)
#   Stats:     543 iterations in 103.02 s (189.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:27
#   Progress:  Solving step 72/247 (24.67% of time interval complete)
#   Stats:     563 iterations in 107.27 s (190.54 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  29%  ETA: 0:04:27
#   Progress:  Solving step 73/247 (25.54% of time interval complete)
#   Stats:     576 iterations in 109.62 s (190.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  30%  ETA: 0:04:27
#   Progress:  Solving step 74/247 (25.57% of time interval complete)
#   Stats:     588 iterations in 111.74 s (190.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  30%  ETA: 0:04:24
#   Progress:  Solving step 75/247 (25.60% of time interval complete)
#   Stats:     592 iterations in 112.36 s (189.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:19
#   Progress:  Solving step 76/247 (26.48% of time interval complete)
#   Stats:     594 iterations in 112.70 s (189.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:23
#   Progress:  Solving step 77/247 (27.39% of time interval complete)
#   Stats:     610 iterations in 116.33 s (190.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  31%  ETA: 0:04:22
#   Progress:  Solving step 78/247 (28.14% of time interval complete)
#   Stats:     621 iterations in 118.37 s (190.62 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  32%  ETA: 0:04:23
#   Progress:  Solving step 79/247 (28.32% of time interval complete)
#   Stats:     634 iterations in 120.88 s (190.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  32%  ETA: 0:04:19
#   Progress:  Solving step 80/247 (28.56% of time interval complete)
#   Stats:     637 iterations in 121.52 s (190.77 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:17
#   Progress:  Solving step 81/247 (29.20% of time interval complete)
#   Stats:     643 iterations in 122.63 s (190.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:15
#   Progress:  Solving step 82/247 (29.23% of time interval complete)
#   Stats:     651 iterations in 124.02 s (190.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  33%  ETA: 0:04:12
#   Progress:  Solving step 83/247 (30.16% of time interval complete)
#   Stats:     654 iterations in 124.60 s (190.52 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  34%  ETA: 0:04:14
#   Progress:  Solving step 84/247 (30.19% of time interval complete)
#   Stats:     670 iterations in 128.16 s (191.28 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  34%  ETA: 0:04:10
#   Progress:  Solving step 85/247 (30.22% of time interval complete)
#   Stats:     673 iterations in 128.63 s (191.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:07
#   Progress:  Solving step 86/247 (30.74% of time interval complete)
#   Stats:     677 iterations in 129.31 s (191.01 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:07
#   Progress:  Solving step 87/247 (30.92% of time interval complete)
#   Stats:     690 iterations in 131.59 s (190.71 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  35%  ETA: 0:04:05
#   Progress:  Solving step 88/247 (30.95% of time interval complete)
#   Stats:     696 iterations in 132.56 s (190.46 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  36%  ETA: 0:04:01
#   Progress:  Solving step 89/247 (31.10% of time interval complete)
#   Stats:     699 iterations in 133.03 s (190.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  36%  ETA: 0:04:01
#   Progress:  Solving step 90/247 (31.34% of time interval complete)
#   Stats:     709 iterations in 135.41 s (190.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  37%  ETA: 0:03:59
#   Progress:  Solving step 91/247 (31.37% of time interval complete)
#   Stats:     716 iterations in 136.62 s (190.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  37%  ETA: 0:03:56
#   Progress:  Solving step 92/247 (31.70% of time interval complete)
#   Stats:     718 iterations in 136.96 s (190.75 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:03:54
#   Progress:  Solving step 93/247 (31.73% of time interval complete)
#   Stats:     727 iterations in 138.59 s (190.64 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:03:51
#   Progress:  Solving step 94/247 (32.00% of time interval complete)
#   Stats:     730 iterations in 139.12 s (190.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  38%  ETA: 0:03:50
#   Progress:  Solving step 95/247 (32.94% of time interval complete)
#   Stats:     740 iterations in 141.00 s (190.55 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  39%  ETA: 0:03:51
#   Progress:  Solving step 96/247 (33.85% of time interval complete)
#   Stats:     751 iterations in 143.74 s (191.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  39%  ETA: 0:03:50
#   Progress:  Solving step 97/247 (34.78% of time interval complete)
#   Stats:     761 iterations in 145.55 s (191.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:03:49
#   Progress:  Solving step 98/247 (35.72% of time interval complete)
#   Stats:     773 iterations in 147.56 s (190.90 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:03:49
#   Progress:  Solving step 99/247 (36.56% of time interval complete)
#   Stats:     787 iterations in 149.89 s (190.46 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  40%  ETA: 0:03:47
#   Progress:  Solving step 100/247 (37.50% of time interval complete)
#   Stats:     795 iterations in 151.42 s (190.47 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  41%  ETA: 0:03:47
#   Progress:  Solving step 101/247 (38.41% of time interval complete)
#   Stats:     804 iterations in 153.68 s (191.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  41%  ETA: 0:03:45
#   Progress:  Solving step 102/247 (39.31% of time interval complete)
#   Stats:     811 iterations in 155.04 s (191.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:03:43
#   Progress:  Solving step 103/247 (39.34% of time interval complete)
#   Stats:     818 iterations in 156.40 s (191.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:03:40
#   Progress:  Solving step 104/247 (39.49% of time interval complete)
#   Stats:     821 iterations in 156.93 s (191.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  42%  ETA: 0:03:38
#   Progress:  Solving step 105/247 (39.52% of time interval complete)
#   Stats:     826 iterations in 157.82 s (191.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  43%  ETA: 0:03:35
#   Progress:  Solving step 106/247 (39.86% of time interval complete)
#   Stats:     829 iterations in 158.31 s (190.96 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  43%  ETA: 0:03:33
#   Progress:  Solving step 107/247 (39.89% of time interval complete)
#   Stats:     836 iterations in 159.64 s (190.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:31
#   Progress:  Solving step 108/247 (40.25% of time interval complete)
#   Stats:     842 iterations in 160.55 s (190.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:35
#   Progress:  Solving step 109/247 (40.28% of time interval complete)
#   Stats:     875 iterations in 166.63 s (190.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  44%  ETA: 0:03:32
#   Progress:  Solving step 110/247 (40.31% of time interval complete)
#   Stats:     879 iterations in 167.27 s (190.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  45%  ETA: 0:03:29
#   Progress:  Solving step 111/247 (40.67% of time interval complete)
#   Stats:     882 iterations in 167.75 s (190.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  45%  ETA: 0:03:29
#   Progress:  Solving step 112/247 (40.70% of time interval complete)
#   Stats:     898 iterations in 170.52 s (189.88 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:26
#   Progress:  Solving step 113/247 (41.12% of time interval complete)
#   Stats:     900 iterations in 170.86 s (189.85 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:27
#   Progress:  Solving step 114/247 (41.18% of time interval complete)
#   Stats:     913 iterations in 173.84 s (190.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  46%  ETA: 0:03:24
#   Progress:  Solving step 115/247 (41.46% of time interval complete)
#   Stats:     917 iterations in 174.44 s (190.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  47%  ETA: 0:03:23
#   Progress:  Solving step 116/247 (41.64% of time interval complete)
#   Stats:     929 iterations in 176.33 s (189.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  47%  ETA: 0:03:21
#   Progress:  Solving step 117/247 (42.12% of time interval complete)
#   Stats:     936 iterations in 177.58 s (189.72 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:20
#   Progress:  Solving step 118/247 (42.39% of time interval complete)
#   Stats:     946 iterations in 179.40 s (189.64 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:18
#   Progress:  Solving step 119/247 (43.03% of time interval complete)
#   Stats:     952 iterations in 180.34 s (189.43 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  48%  ETA: 0:03:17
#   Progress:  Solving step 120/247 (43.96% of time interval complete)
#   Stats:     964 iterations in 183.18 s (190.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  49%  ETA: 0:03:17
#   Progress:  Solving step 121/247 (44.87% of time interval complete)
#   Stats:     980 iterations in 186.00 s (189.80 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  49%  ETA: 0:03:16
#   Progress:  Solving step 122/247 (45.71% of time interval complete)
#   Stats:     989 iterations in 187.67 s (189.76 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:14
#   Progress:  Solving step 123/247 (45.80% of time interval complete)
#   Stats:     997 iterations in 189.13 s (189.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:12
#   Progress:  Solving step 124/247 (46.74% of time interval complete)
#   Stats:     1002 iterations in 189.91 s (189.53 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  50%  ETA: 0:03:12
#   Progress:  Solving step 125/247 (47.07% of time interval complete)
#   Stats:     1018 iterations in 193.00 s (189.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:06
#   Progress:  Solving step 128/247 (48.52% of time interval complete)
#   Stats:     1036 iterations in 195.93 s (189.13 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:05
#   Progress:  Solving step 129/247 (49.43% of time interval complete)
#   Stats:     1046 iterations in 197.49 s (188.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  52%  ETA: 0:03:03
#   Progress:  Solving step 130/247 (50.36% of time interval complete)
#   Stats:     1055 iterations in 198.91 s (188.54 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  53%  ETA: 0:03:01
#   Progress:  Solving step 131/247 (51.27% of time interval complete)
#   Stats:     1063 iterations in 200.27 s (188.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  53%  ETA: 0:03:00
#   Progress:  Solving step 132/247 (51.48% of time interval complete)
#   Stats:     1070 iterations in 202.18 s (188.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:02:58
#   Progress:  Solving step 133/247 (51.57% of time interval complete)
#   Stats:     1074 iterations in 202.84 s (188.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:02:55
#   Progress:  Solving step 134/247 (51.69% of time interval complete)
#   Stats:     1079 iterations in 203.65 s (188.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  54%  ETA: 0:02:53
#   Progress:  Solving step 135/247 (52.20% of time interval complete)
#   Stats:     1084 iterations in 204.41 s (188.57 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  55%  ETA: 0:02:52
#   Progress:  Solving step 136/247 (52.60% of time interval complete)
#   Stats:     1095 iterations in 206.28 s (188.38 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  55%  ETA: 0:02:50
#   Progress:  Solving step 137/247 (53.14% of time interval complete)
#   Stats:     1103 iterations in 207.72 s (188.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:02:50
#   Progress:  Solving step 138/247 (53.17% of time interval complete)
#   Stats:     1114 iterations in 210.52 s (188.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:02:47
#   Progress:  Solving step 139/247 (53.56% of time interval complete)
#   Stats:     1116 iterations in 210.89 s (188.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  56%  ETA: 0:02:47
#   Progress:  Solving step 140/247 (54.05% of time interval complete)
#   Stats:     1132 iterations in 213.76 s (188.83 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  57%  ETA: 0:02:45
#   Progress:  Solving step 141/247 (54.23% of time interval complete)
#   Stats:     1139 iterations in 214.92 s (188.69 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  57%  ETA: 0:02:43
#   Progress:  Solving step 142/247 (54.44% of time interval complete)
#   Stats:     1142 iterations in 215.37 s (188.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:41
#   Progress:  Solving step 143/247 (54.98% of time interval complete)
#   Stats:     1149 iterations in 216.48 s (188.41 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:40
#   Progress:  Solving step 144/247 (55.43% of time interval complete)
#   Stats:     1166 iterations in 219.34 s (188.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  58%  ETA: 0:02:39
#   Progress:  Solving step 145/247 (55.89% of time interval complete)
#   Stats:     1176 iterations in 221.67 s (188.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  59%  ETA: 0:02:38
#   Progress:  Solving step 146/247 (56.58% of time interval complete)
#   Stats:     1185 iterations in 223.25 s (188.40 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  59%  ETA: 0:02:36
#   Progress:  Solving step 147/247 (56.82% of time interval complete)
#   Stats:     1193 iterations in 224.64 s (188.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:34
#   Progress:  Solving step 148/247 (56.85% of time interval complete)
#   Stats:     1200 iterations in 225.84 s (188.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:32
#   Progress:  Solving step 149/247 (57.16% of time interval complete)
#   Stats:     1203 iterations in 226.28 s (188.10 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  60%  ETA: 0:02:32
#   Progress:  Solving step 150/247 (57.40% of time interval complete)
#   Stats:     1220 iterations in 229.30 s (187.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  61%  ETA: 0:02:31
#   Progress:  Solving step 151/247 (57.76% of time interval complete)
#   Stats:     1231 iterations in 231.88 s (188.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  61%  ETA: 0:02:30
#   Progress:  Solving step 152/247 (58.15% of time interval complete)
#   Stats:     1244 iterations in 234.16 s (188.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:28
#   Progress:  Solving step 153/247 (58.61% of time interval complete)
#   Stats:     1250 iterations in 235.38 s (188.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:27
#   Progress:  Solving step 154/247 (58.76% of time interval complete)
#   Stats:     1267 iterations in 238.17 s (187.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  62%  ETA: 0:02:25
#   Progress:  Solving step 155/247 (58.79% of time interval complete)
#   Stats:     1271 iterations in 238.76 s (187.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  63%  ETA: 0:02:23
#   Progress:  Solving step 156/247 (59.54% of time interval complete)
#   Stats:     1273 iterations in 239.08 s (187.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  63%  ETA: 0:02:22
#   Progress:  Solving step 157/247 (60.45% of time interval complete)
#   Stats:     1289 iterations in 241.59 s (187.42 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  64%  ETA: 0:02:20
#   Progress:  Solving step 158/247 (61.38% of time interval complete)
#   Stats:     1298 iterations in 243.68 s (187.74 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  64%  ETA: 0:02:19
#   Progress:  Solving step 159/247 (61.44% of time interval complete)
#   Stats:     1307 iterations in 245.28 s (187.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:17
#   Progress:  Solving step 160/247 (62.29% of time interval complete)
#   Stats:     1310 iterations in 245.75 s (187.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:15
#   Progress:  Solving step 161/247 (62.56% of time interval complete)
#   Stats:     1321 iterations in 247.47 s (187.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  65%  ETA: 0:02:13
#   Progress:  Solving step 162/247 (63.22% of time interval complete)
#   Stats:     1327 iterations in 248.48 s (187.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  66%  ETA: 0:02:12
#   Progress:  Solving step 163/247 (63.50% of time interval complete)
#   Stats:     1340 iterations in 250.85 s (187.20 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  66%  ETA: 0:02:11
#   Progress:  Solving step 164/247 (63.56% of time interval complete)
#   Stats:     1344 iterations in 252.22 s (187.67 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:08
#   Progress:  Solving step 165/247 (64.16% of time interval complete)
#   Stats:     1347 iterations in 252.71 s (187.61 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:09
#   Progress:  Solving step 166/247 (64.19% of time interval complete)
#   Stats:     1388 iterations in 259.43 s (186.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  67%  ETA: 0:02:07
#   Progress:  Solving step 167/247 (64.43% of time interval complete)
#   Stats:     1391 iterations in 259.85 s (186.81 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  68%  ETA: 0:02:06
#   Progress:  Solving step 168/247 (64.49% of time interval complete)
#   Stats:     1406 iterations in 262.41 s (186.64 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  68%  ETA: 0:02:04
#   Progress:  Solving step 169/247 (64.52% of time interval complete)
#   Stats:     1409 iterations in 262.93 s (186.61 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:02
#   Progress:  Solving step 170/247 (64.61% of time interval complete)
#   Stats:     1411 iterations in 263.94 s (187.06 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:02:00
#   Progress:  Solving step 171/247 (65.07% of time interval complete)
#   Stats:     1416 iterations in 264.79 s (187.00 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  69%  ETA: 0:01:59
#   Progress:  Solving step 172/247 (65.73% of time interval complete)
#   Stats:     1426 iterations in 266.62 s (186.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  70%  ETA: 0:02:01
#   Progress:  Solving step 173/247 (66.00% of time interval complete)
#   Stats:     1482 iterations in 275.90 s (186.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  70%  ETA: 0:01:59
#   Progress:  Solving step 174/247 (66.52% of time interval complete)
#   Stats:     1485 iterations in 276.49 s (186.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:01:57
#   Progress:  Solving step 175/247 (66.91% of time interval complete)
#   Stats:     1494 iterations in 277.83 s (185.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:01:55
#   Progress:  Solving step 176/247 (67.12% of time interval complete)
#   Stats:     1498 iterations in 278.49 s (185.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  71%  ETA: 0:01:53
#   Progress:  Solving step 177/247 (67.15% of time interval complete)
#   Stats:     1502 iterations in 279.11 s (185.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  72%  ETA: 0:01:51
#   Progress:  Solving step 178/247 (67.42% of time interval complete)
#   Stats:     1504 iterations in 280.08 s (186.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  72%  ETA: 0:01:49
#   Progress:  Solving step 179/247 (67.84% of time interval complete)
#   Stats:     1511 iterations in 281.16 s (186.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:48
#   Progress:  Solving step 180/247 (68.39% of time interval complete)
#   Stats:     1524 iterations in 283.44 s (185.99 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:47
#   Progress:  Solving step 181/247 (68.42% of time interval complete)
#   Stats:     1534 iterations in 285.30 s (185.99 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  73%  ETA: 0:01:45
#   Progress:  Solving step 182/247 (68.78% of time interval complete)
#   Stats:     1538 iterations in 285.97 s (185.94 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  74%  ETA: 0:01:44
#   Progress:  Solving step 183/247 (69.66% of time interval complete)
#   Stats:     1550 iterations in 288.80 s (186.32 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  74%  ETA: 0:01:42
#   Progress:  Solving step 184/247 (70.59% of time interval complete)
#   Stats:     1561 iterations in 290.67 s (186.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:40
#   Progress:  Solving step 185/247 (71.50% of time interval complete)
#   Stats:     1570 iterations in 292.36 s (186.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:39
#   Progress:  Solving step 186/247 (72.43% of time interval complete)
#   Stats:     1578 iterations in 293.80 s (186.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  75%  ETA: 0:01:37
#   Progress:  Solving step 187/247 (73.34% of time interval complete)
#   Stats:     1586 iterations in 295.32 s (186.21 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  76%  ETA: 0:01:36
#   Progress:  Solving step 188/247 (73.40% of time interval complete)
#   Stats:     1594 iterations in 297.33 s (186.53 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  76%  ETA: 0:01:34
#   Progress:  Solving step 189/247 (74.06% of time interval complete)
#   Stats:     1597 iterations in 297.83 s (186.49 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:32
#   Progress:  Solving step 190/247 (74.28% of time interval complete)
#   Stats:     1608 iterations in 299.70 s (186.38 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:31
#   Progress:  Solving step 191/247 (74.70% of time interval complete)
#   Stats:     1614 iterations in 300.68 s (186.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  77%  ETA: 0:01:29
#   Progress:  Solving step 192/247 (74.73% of time interval complete)
#   Stats:     1618 iterations in 301.48 s (186.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  78%  ETA: 0:01:27
#   Progress:  Solving step 193/247 (75.21% of time interval complete)
#   Stats:     1620 iterations in 301.87 s (186.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  78%  ETA: 0:01:25
#   Progress:  Solving step 194/247 (75.79% of time interval complete)
#   Stats:     1629 iterations in 303.53 s (186.33 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:23
#   Progress:  Solving step 195/247 (76.12% of time interval complete)
#   Stats:     1633 iterations in 304.29 s (186.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:23
#   Progress:  Solving step 196/247 (77.05% of time interval complete)
#   Stats:     1671 iterations in 311.30 s (186.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  79%  ETA: 0:01:22
#   Progress:  Solving step 197/247 (77.96% of time interval complete)
#   Stats:     1694 iterations in 315.23 s (186.09 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  80%  ETA: 0:01:21
#   Progress:  Solving step 198/247 (78.89% of time interval complete)
#   Stats:     1702 iterations in 316.52 s (185.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  80%  ETA: 0:01:19
#   Progress:  Solving step 199/247 (79.23% of time interval complete)
#   Stats:     1709 iterations in 317.72 s (185.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:17
#   Progress:  Solving step 200/247 (79.65% of time interval complete)
#   Stats:     1713 iterations in 319.02 s (186.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:15
#   Progress:  Solving step 201/247 (79.83% of time interval complete)
#   Stats:     1717 iterations in 319.68 s (186.18 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  81%  ETA: 0:01:14
#   Progress:  Solving step 202/247 (80.68% of time interval complete)
#   Stats:     1725 iterations in 320.82 s (185.99 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  82%  ETA: 0:01:12
#   Progress:  Solving step 203/247 (81.34% of time interval complete)
#   Stats:     1737 iterations in 322.67 s (185.77 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  82%  ETA: 0:01:10
#   Progress:  Solving step 204/247 (81.37% of time interval complete)
#   Stats:     1744 iterations in 323.86 s (185.70 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:09
#   Progress:  Solving step 205/247 (81.61% of time interval complete)
#   Stats:     1746 iterations in 324.15 s (185.65 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:07
#   Progress:  Solving step 206/247 (82.31% of time interval complete)
#   Stats:     1750 iterations in 324.78 s (185.59 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  83%  ETA: 0:01:05
#   Progress:  Solving step 207/247 (82.52% of time interval complete)
#   Stats:     1757 iterations in 325.90 s (185.49 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  84%  ETA: 0:01:03
#   Progress:  Solving step 208/247 (83.45% of time interval complete)
#   Stats:     1760 iterations in 327.03 s (185.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  84%  ETA: 0:01:02
#   Progress:  Solving step 209/247 (83.48% of time interval complete)
#   Stats:     1773 iterations in 328.97 s (185.54 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:01:00
#   Progress:  Solving step 210/247 (84.21% of time interval complete)
#   Stats:     1776 iterations in 329.41 s (185.48 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:00:59
#   Progress:  Solving step 211/247 (84.36% of time interval complete)
#   Stats:     1786 iterations in 330.93 s (185.29 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  85%  ETA: 0:00:57
#   Progress:  Solving step 212/247 (84.63% of time interval complete)
#   Stats:     1793 iterations in 332.05 s (185.19 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  86%  ETA: 0:00:55
#   Progress:  Solving step 213/247 (84.81% of time interval complete)
#   Stats:     1800 iterations in 333.27 s (185.15 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  86%  ETA: 0:00:54
#   Progress:  Solving step 214/247 (85.21% of time interval complete)
#   Stats:     1804 iterations in 334.64 s (185.50 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  87%  ETA: 0:00:52
#   Progress:  Solving step 215/247 (85.30% of time interval complete)
#   Stats:     1812 iterations in 335.88 s (185.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  87%  ETA: 0:00:50
#   Progress:  Solving step 216/247 (85.36% of time interval complete)
#   Stats:     1814 iterations in 336.20 s (185.34 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:48
#   Progress:  Solving step 217/247 (85.39% of time interval complete)
#   Stats:     1816 iterations in 336.51 s (185.30 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:47
#   Progress:  Solving step 218/247 (86.23% of time interval complete)
#   Stats:     1819 iterations in 336.93 s (185.23 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  88%  ETA: 0:00:45
#   Progress:  Solving step 219/247 (86.62% of time interval complete)
#   Stats:     1829 iterations in 338.76 s (185.22 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  89%  ETA: 0:00:44
#   Progress:  Solving step 220/247 (87.14% of time interval complete)
#   Stats:     1835 iterations in 339.78 s (185.17 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  89%  ETA: 0:00:42
#   Progress:  Solving step 221/247 (88.07% of time interval complete)
#   Stats:     1840 iterations in 340.55 s (185.08 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:40
#   Progress:  Solving step 222/247 (88.98% of time interval complete)
#   Stats:     1848 iterations in 342.45 s (185.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:39
#   Progress:  Solving step 223/247 (89.01% of time interval complete)
#   Stats:     1856 iterations in 343.85 s (185.26 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  90%  ETA: 0:00:37
#   Progress:  Solving step 224/247 (89.86% of time interval complete)
#   Stats:     1858 iterations in 344.19 s (185.25 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  91%  ETA: 0:00:36
#   Progress:  Solving step 225/247 (89.92% of time interval complete)
#   Stats:     1869 iterations in 345.97 s (185.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  91%  ETA: 0:00:34
#   Progress:  Solving step 226/247 (90.43% of time interval complete)
#   Stats:     1872 iterations in 346.41 s (185.05 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:32
#   Progress:  Solving step 227/247 (90.85% of time interval complete)
#   Stats:     1881 iterations in 348.21 s (185.12 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:31
#   Progress:  Solving step 228/247 (91.55% of time interval complete)
#   Stats:     1887 iterations in 349.30 s (185.11 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  92%  ETA: 0:00:29
#   Progress:  Solving step 229/247 (91.70% of time interval complete)
#   Stats:     1893 iterations in 350.34 s (185.07 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  93%  ETA: 0:00:28
#   Progress:  Solving step 230/247 (92.63% of time interval complete)
#   Stats:     1898 iterations in 351.10 s (184.98 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  93%  ETA: 0:00:26
#   Progress:  Solving step 231/247 (93.36% of time interval complete)
#   Stats:     1911 iterations in 353.44 s (184.95 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:25
#   Progress:  Solving step 232/247 (93.54% of time interval complete)
#   Stats:     1921 iterations in 355.22 s (184.92 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:23
#   Progress:  Solving step 233/247 (94.47% of time interval complete)
#   Stats:     1926 iterations in 355.95 s (184.82 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  94%  ETA: 0:00:22
#   Progress:  Solving step 234/247 (95.38% of time interval complete)
#   Stats:     1938 iterations in 358.25 s (184.86 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  95%  ETA: 0:00:20
#   Progress:  Solving step 235/247 (96.32% of time interval complete)
#   Stats:     1947 iterations in 360.38 s (185.09 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  95%  ETA: 0:00:19
#   Progress:  Solving step 236/247 (96.74% of time interval complete)
#   Stats:     1954 iterations in 361.52 s (185.02 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:17
#   Progress:  Solving step 237/247 (96.77% of time interval complete)
#   Stats:     1958 iterations in 362.21 s (184.99 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:15
#   Progress:  Solving step 238/247 (97.25% of time interval complete)
#   Stats:     1960 iterations in 362.53 s (184.97 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  96%  ETA: 0:00:14
#   Progress:  Solving step 239/247 (97.64% of time interval complete)
#   Stats:     1972 iterations in 364.61 s (184.89 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  97%  ETA: 0:00:12
#   Progress:  Solving step 240/247 (98.16% of time interval complete)
#   Stats:     1980 iterations in 366.12 s (184.91 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  97%  ETA: 0:00:11
#   Progress:  Solving step 241/247 (98.43% of time interval complete)
#   Stats:     1984 iterations in 367.03 s (185.00 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:09
#   Progress:  Solving step 242/247 (98.58% of time interval complete)
#   Stats:     1987 iterations in 367.65 s (185.03 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:08
#   Progress:  Solving step 243/247 (99.09% of time interval complete)
#   Stats:     1990 iterations in 368.89 s (185.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  98%  ETA: 0:00:06
#   Progress:  Solving step 244/247 (99.34% of time interval complete)
#   Stats:     2000 iterations in 370.74 s (185.37 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:05
#   Progress:  Solving step 245/247 (99.40% of time interval complete)
#   Stats:     2004 iterations in 371.46 s (185.36 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:03
#   Progress:  Solving step 246/247 (99.58% of time interval complete)
#   Stats:     2007 iterations in 372.00 s (185.35 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps  99%  ETA: 0:00:02
#   Progress:  Solving step 247/247 (100.00% of time interval complete)
#   Stats:     2015 iterations in 373.39 s (185.31 ms each)
#
# Simulating 9 years, 3.545 weeks as 247 report steps 100% Time: 0:06:18
#   Progress:  Solved step 247/247
#   Stats:     2021 iterations in 374.61 s (185.36 ms each)
# ╭────────────────┬───────────┬───────────────┬─────────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │       Total │
# │                │ 247 steps │ 468 ministeps │    (wasted) │
# ├────────────────┼───────────┼───────────────┼─────────────┤
# │ Newton         │   8.18219 │       4.31838 │   2021 (75) │
# │ Linearization  │   10.0769 │       5.31838 │   2489 (80) │
# │ Linear solver  │   28.8057 │        15.203 │  7115 (285) │
# │ Precond apply  │   57.6113 │        30.406 │ 14230 (570) │
# ╰────────────────┴───────────┴───────────────┴─────────────╯
# ╭───────────────┬──────────┬────────────┬──────────╮
# │ Timing type   │     Each │   Relative │    Total │
# │               │       ms │ Percentage │        s │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Properties    │  18.6171 │    10.04 % │  37.6251 │
# │ Equations     │  26.9132 │    17.88 % │  66.9870 │
# │ Assembly      │   4.8334 │     3.21 % │  12.0303 │
# │ Linear solve  │  12.5504 │     6.77 % │  25.3643 │
# │ Linear setup  │  57.6873 │    31.12 % │ 116.5860 │
# │ Precond apply │   6.4677 │    24.57 % │  92.0360 │
# │ Update        │   3.1921 │     1.72 % │   6.4512 │
# │ Convergence   │   2.0556 │     1.37 % │   5.1164 │
# │ Input/Output  │   7.6130 │     0.95 % │   3.5629 │
# │ Other         │   4.3775 │     2.36 % │   8.8469 │
# ├───────────────┼──────────┼────────────┼──────────┤
# │ Total         │ 185.3569 │   100.00 % │ 374.6063 │
# ╰───────────────┴──────────┴────────────┴──────────╯
# ReservoirSimResult with 463 entries:
#
#   wells (36 present):
#     :B-4H
#     :F-4H
#     :D-4H
#     :F-2H
#     :D-2H
#     :B-1H
#     :C-4H
#     :C-1H
#     :B-2H
#     :E-1H
#     :B-4BH
#     :D-3AH
#     :D-3BH
#     :C-3H
#     :E-3H
#     :K-3H
#     :E-4AH
#     :D-1H
#     :B-1AH
#     :E-3CH
#     :E-4H
#     :E-2H
#     :E-2AH
#     :C-4AH
#     :B-1BH
#     :C-2H
#     :B-4DH
#     :D-3H
#     :E-3AH
#     :D-4AH
#     :B-3H
#     :F-3H
#     :E-3BH
#     :D-1CH
#     :F-1H
#     :B-4AH
#     Results per well:
#        :wrat => Vector{Float64} of size (463,)
#        :Aqueous_mass_rate => Vector{Float64} of size (463,)
#        :orat => Vector{Float64} of size (463,)
#        :bhp => Vector{Float64} of size (463,)
#        :lrat => Vector{Float64} of size (463,)
#        :mass_rate => Vector{Float64} of size (463,)
#        :rate => Vector{Float64} of size (463,)
#        :Vapor_mass_rate => Vector{Float64} of size (463,)
#        :control => Vector{Symbol} of size (463,)
#        :Liquid_mass_rate => Vector{Float64} of size (463,)
#        :grat => Vector{Float64} of size (463,)
#
#   states (Vector with 463 entries, reservoir variables for each state)
#     :Rv => Vector{Float64} of size (44417,)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (44417,)
#     :Saturations => Matrix{Float64} of size (3, 44417)
#     :Pressure => Vector{Float64} of size (44417,)
#     :Rs => Vector{Float64} of size (44417,)
#     :ImmiscibleSaturation => Vector{Float64} of size (44417,)
#     :TotalMasses => Matrix{Float64} of size (3, 44417)
#
#   time (report time for each state)
#      Vector{Float64} of length 463
#
#   result (extended states, reports)
#      SimResult with 247 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Aug. 31 2024 20:08 after 6 minutes, 11 seconds, 43.37 milliseconds.

# %% [markdown]
# ## Plot the reservoir solution

# %%
fig = plot_reservoir(case.model, states, step = 247, key = :Saturations)
ax = fig.current_axis[]
ax.azimuth[] = -3.0
ax.elevation[] = 0.5
fig
# Out:
# Figure()

# %% [markdown]
# ## Plot the reservoir static properties

# %%
fig = plot_reservoir(case.model, key = :porosity)
ax = fig.current_axis[]
ax.azimuth[] = -3.0
ax.elevation[] = 0.5
fig
# Out:
# Figure()

# %% [markdown]
# ## Load reference and set up plotting

# %%
csv_path = joinpath(norne_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat] + well[:grat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response")
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :grat
        ys = si_unit(:day)/1e6
        yl = "Surface gas rate / 10⁶ m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        grat_ref = data[:, findfirst(x -> x == "$well_name:grat", vec(header))]
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = grat_ref + orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "OPM Flow"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Injector bhp

# %%
plot_well_comparison(:bhp, inj, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Gas injection rates

# %%
plot_well_comparison(:grat, inj, "Gas surface injection rate")
# Out:
# Figure()

# %% [markdown]
# ## Water injection rates

# %%
plot_well_comparison(:wrat, inj, "Water surface injection rate")
# Out:
# Figure()

# %% [markdown]
# ## Producer bhp

# %%
plot_well_comparison(:bhp, prod, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Oil production rates

# %%
plot_well_comparison(:orat, prod, "Oil surface production rate")
# Out:
# Figure()

# %% [markdown]
# ## Gas production rates

# %%
plot_well_comparison(:grat, prod, "Gas surface production rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
