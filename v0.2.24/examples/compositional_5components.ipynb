# %% [markdown]
# # A more complex compositional model
# This example sets up a more complex compositional simulation with five
# different components. Other than that, the example is similar to the others
# that include wells and is therefore not commented in great detail.

# %%
using MultiComponentFlash

n2_ch4 = MolecularProperty(0.0161594, 4.58e6, 189.515, 9.9701e-05, 0.00854)
co2 = MolecularProperty(0.04401, 7.3866e6, 304.200, 9.2634e-05, 0.228)
c2_5 = MolecularProperty(0.0455725, 4.0955e6, 387.607, 2.1708e-04, 0.16733)
c6_13 = MolecularProperty(0.117740, 3.345e6, 597.497, 3.8116e-04, 0.38609)
c14_24 = MolecularProperty(0.248827, 1.768e6, 698.515, 7.2141e-04, 0.80784)

bic = [0.11883 0.00070981 0.00077754 0.01 0.011;
       0.00070981 0.15 0.15 0.15 0.15;
       0.00077754 0.15 0 0 0;
       0.01 0.15 0 0 0;
       0.011 0.15 0 0 0]

mixture = MultiComponentMixture([n2_ch4, co2, c2_5, c6_13, c14_24], A_ij = bic, names = ["N2-CH4", "CO2", "C2-5", "C6-13", "C14-24"])
eos = GenericCubicEOS(mixture, PengRobinson())

using Jutul, JutulDarcy, GLMakie
Darcy, bar, kg, meter, Kelvin, day = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day)
nx = ny = 20
nz = 2

dims = (nx, ny, nz)
g = CartesianMesh(dims, (1000.0, 1000.0, 1.0))
nc = number_of_cells(g)
K = repeat([0.05*Darcy], 1, nc)
res = reservoir_domain(g, porosity = 0.25, permeability = K, temperature = 387.45*Kelvin)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 20x20x2=800 cells with 18 data fields added:
#   800 Cells
#     :permeability => 1×800 Matrix{Float64}
#     :porosity => 800 Vector{Float64}
#     :rock_thermal_conductivity => 800 Vector{Float64}
#     :fluid_thermal_conductivity => 800 Vector{Float64}
#     :rock_density => 800 Vector{Float64}
#     :temperature => 800 Vector{Float64}
#     :cell_centroids => 3×800 Matrix{Float64}
#     :volumes => 800 Vector{Float64}
#   1920 Faces
#     :neighbors => 2×1920 Matrix{Int64}
#     :areas => 1920 Vector{Float64}
#     :normals => 3×1920 Matrix{Float64}
#     :face_centroids => 3×1920 Matrix{Float64}
#   3840 HalfFaces
#     :half_face_cells => 3840 Vector{Int64}
#     :half_face_faces => 3840 Vector{Int64}
#   960 BoundaryFaces
#     :boundary_areas => 960 Vector{Float64}
#     :boundary_centroids => 3×960 Matrix{Float64}
#     :boundary_normals => 3×960 Matrix{Float64}
#     :boundary_neighbors => 960 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in all layers

# %%
prod = setup_vertical_well(g, K, nx, ny, name = :Producer)
# Out:
# MultiSegmentWell [Producer] (3 nodes, 2 segments, 2 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in all layers

# %%
inj = setup_vertical_well(g, K, 1, 1, name = :Injector)

rhoLS = 1000.0*kg/meter^3
rhoVS = 100.0*kg/meter^3

rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
# Out:
# (LiquidPhase(), VaporPhase())

# %% [markdown]
# Define system and realize on grid

# %%
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod], block_backend = true);
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)

push!(model[:Reservoir].output_variables, :Saturations)

state0 = setup_reservoir_state(model, Pressure = 225*bar, OverallMoleFractions = [0.463, 0.01640, 0.20520, 0.19108, 0.12432]);

dt = repeat([2.0]*day, 365)
rate_target = TotalRateTarget(0.0015)
I_ctrl = InjectorControl(rate_target, [0, 1, 0, 0, 0], density = rhoVS)
bhp_target = BottomHolePressureTarget(100*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:55:21
#   Progress:  Solving step 2/365 (0.55% of time interval complete)
#   Stats:     9 iterations in 13.35 s (1.48 s each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:37:01
#   Progress:  Solving step 3/365 (0.82% of time interval complete)
#   Stats:     15 iterations in 13.46 s (897.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   1%| |  ETA: 0:22:15
#   Progress:  Solving step 5/365 (1.37% of time interval complete)
#   Stats:     22 iterations in 13.60 s (618.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   2%| |  ETA: 0:15:54
#   Progress:  Solving step 7/365 (1.92% of time interval complete)
#   Stats:     28 iterations in 13.71 s (489.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   2%| |  ETA: 0:12:23
#   Progress:  Solving step 9/365 (2.47% of time interval complete)
#   Stats:     34 iterations in 13.83 s (406.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   3%| |  ETA: 0:10:08
#   Progress:  Solving step 11/365 (3.01% of time interval complete)
#   Stats:     40 iterations in 13.96 s (348.93 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   4%| |  ETA: 0:08:35
#   Progress:  Solving step 13/365 (3.56% of time interval complete)
#   Stats:     45 iterations in 14.07 s (312.62 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   4%| |  ETA: 0:06:58
#   Progress:  Solving step 16/365 (4.38% of time interval complete)
#   Stats:     51 iterations in 14.21 s (278.67 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   5%| |  ETA: 0:06:11
#   Progress:  Solving step 18/365 (4.93% of time interval complete)
#   Stats:     55 iterations in 14.32 s (260.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   5%| |  ETA: 0:05:35
#   Progress:  Solving step 20/365 (5.48% of time interval complete)
#   Stats:     60 iterations in 14.46 s (241.08 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   6%| |  ETA: 0:05:05
#   Progress:  Solving step 22/365 (6.03% of time interval complete)
#   Stats:     64 iterations in 14.59 s (227.94 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   7%|▏|  ETA: 0:04:40
#   Progress:  Solving step 24/365 (6.58% of time interval complete)
#   Stats:     68 iterations in 14.72 s (216.43 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   7%|▏|  ETA: 0:04:18
#   Progress:  Solving step 26/365 (7.12% of time interval complete)
#   Stats:     72 iterations in 14.85 s (206.27 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   8%|▏|  ETA: 0:04:00
#   Progress:  Solving step 28/365 (7.67% of time interval complete)
#   Stats:     76 iterations in 14.99 s (197.23 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   8%|▏|  ETA: 0:03:44
#   Progress:  Solving step 30/365 (8.22% of time interval complete)
#   Stats:     80 iterations in 15.13 s (189.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   9%|▏|  ETA: 0:03:31
#   Progress:  Solving step 32/365 (8.77% of time interval complete)
#   Stats:     84 iterations in 15.27 s (181.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps   9%|▏|  ETA: 0:03:18
#   Progress:  Solving step 34/365 (9.32% of time interval complete)
#   Stats:     88 iterations in 15.41 s (175.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  10%|▏|  ETA: 0:03:14
#   Progress:  Solving step 35/365 (9.59% of time interval complete)
#   Stats:     90 iterations in 15.56 s (172.90 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  10%|▏|  ETA: 0:03:03
#   Progress:  Solving step 37/365 (10.14% of time interval complete)
#   Stats:     94 iterations in 15.70 s (167.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:02:54
#   Progress:  Solving step 39/365 (10.68% of time interval complete)
#   Stats:     98 iterations in 15.85 s (161.69 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  11%|▏|  ETA: 0:02:46
#   Progress:  Solving step 41/365 (11.23% of time interval complete)
#   Stats:     102 iterations in 15.99 s (156.75 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  12%|▏|  ETA: 0:02:38
#   Progress:  Solving step 43/365 (11.78% of time interval complete)
#   Stats:     106 iterations in 16.13 s (152.20 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  12%|▏|  ETA: 0:02:31
#   Progress:  Solving step 45/365 (12.33% of time interval complete)
#   Stats:     110 iterations in 16.28 s (148.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  13%|▏|  ETA: 0:02:25
#   Progress:  Solving step 47/365 (12.88% of time interval complete)
#   Stats:     114 iterations in 16.43 s (144.09 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  13%|▏|  ETA: 0:02:19
#   Progress:  Solving step 49/365 (13.42% of time interval complete)
#   Stats:     118 iterations in 16.57 s (140.44 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  14%|▏|  ETA: 0:02:14
#   Progress:  Solving step 51/365 (13.97% of time interval complete)
#   Stats:     122 iterations in 16.72 s (137.02 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  14%|▏|  ETA: 0:02:09
#   Progress:  Solving step 53/365 (14.52% of time interval complete)
#   Stats:     126 iterations in 16.86 s (133.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  15%|▏|  ETA: 0:02:04
#   Progress:  Solving step 55/365 (15.07% of time interval complete)
#   Stats:     130 iterations in 17.01 s (130.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  16%|▏|  ETA: 0:02:00
#   Progress:  Solving step 57/365 (15.62% of time interval complete)
#   Stats:     134 iterations in 17.16 s (128.08 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  16%|▏|  ETA: 0:01:56
#   Progress:  Solving step 59/365 (16.16% of time interval complete)
#   Stats:     138 iterations in 17.31 s (125.45 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  17%|▏|  ETA: 0:01:52
#   Progress:  Solving step 61/365 (16.71% of time interval complete)
#   Stats:     142 iterations in 17.46 s (122.97 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  17%|▏|  ETA: 0:01:48
#   Progress:  Solving step 63/365 (17.26% of time interval complete)
#   Stats:     146 iterations in 17.61 s (120.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  18%|▏|  ETA: 0:01:45
#   Progress:  Solving step 65/365 (17.81% of time interval complete)
#   Stats:     150 iterations in 17.76 s (118.40 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  18%|▏|  ETA: 0:01:42
#   Progress:  Solving step 67/365 (18.36% of time interval complete)
#   Stats:     154 iterations in 17.91 s (116.30 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  19%|▎|  ETA: 0:01:39
#   Progress:  Solving step 69/365 (18.90% of time interval complete)
#   Stats:     158 iterations in 18.06 s (114.30 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  19%|▎|  ETA: 0:01:36
#   Progress:  Solving step 71/365 (19.45% of time interval complete)
#   Stats:     162 iterations in 18.21 s (112.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  20%|▎|  ETA: 0:01:33
#   Progress:  Solving step 73/365 (20.00% of time interval complete)
#   Stats:     166 iterations in 18.36 s (110.59 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  20%|▎|  ETA: 0:01:31
#   Progress:  Solving step 75/365 (20.55% of time interval complete)
#   Stats:     170 iterations in 18.51 s (108.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  21%|▎|  ETA: 0:01:29
#   Progress:  Solving step 77/365 (21.10% of time interval complete)
#   Stats:     174 iterations in 18.71 s (107.52 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  22%|▎|  ETA: 0:01:26
#   Progress:  Solving step 79/365 (21.64% of time interval complete)
#   Stats:     178 iterations in 18.85 s (105.91 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  22%|▎|  ETA: 0:01:24
#   Progress:  Solving step 81/365 (22.19% of time interval complete)
#   Stats:     182 iterations in 18.99 s (104.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  23%|▎|  ETA: 0:01:22
#   Progress:  Solving step 83/365 (22.74% of time interval complete)
#   Stats:     186 iterations in 19.14 s (102.89 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  23%|▎|  ETA: 0:01:20
#   Progress:  Solving step 85/365 (23.29% of time interval complete)
#   Stats:     190 iterations in 19.28 s (101.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  24%|▎|  ETA: 0:01:18
#   Progress:  Solving step 87/365 (23.84% of time interval complete)
#   Stats:     194 iterations in 19.42 s (100.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  24%|▎|  ETA: 0:01:16
#   Progress:  Solving step 89/365 (24.38% of time interval complete)
#   Stats:     198 iterations in 19.57 s (98.83 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  25%|▎|  ETA: 0:01:14
#   Progress:  Solving step 91/365 (24.93% of time interval complete)
#   Stats:     202 iterations in 19.71 s (97.59 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  25%|▎|  ETA: 0:01:13
#   Progress:  Solving step 93/365 (25.48% of time interval complete)
#   Stats:     206 iterations in 19.86 s (96.40 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  26%|▎|  ETA: 0:01:11
#   Progress:  Solving step 95/365 (26.03% of time interval complete)
#   Stats:     210 iterations in 20.00 s (95.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:10
#   Progress:  Solving step 97/365 (26.58% of time interval complete)
#   Stats:     214 iterations in 20.15 s (94.18 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:09
#   Progress:  Solving step 98/365 (26.85% of time interval complete)
#   Stats:     217 iterations in 20.26 s (93.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  27%|▎|  ETA: 0:01:07
#   Progress:  Solving step 100/365 (27.40% of time interval complete)
#   Stats:     221 iterations in 20.41 s (92.36 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  28%|▎|  ETA: 0:01:06
#   Progress:  Solving step 102/365 (27.95% of time interval complete)
#   Stats:     225 iterations in 20.56 s (91.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  28%|▎|  ETA: 0:01:05
#   Progress:  Solving step 104/365 (28.49% of time interval complete)
#   Stats:     229 iterations in 20.70 s (90.41 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  29%|▎|  ETA: 0:01:03
#   Progress:  Solving step 106/365 (29.04% of time interval complete)
#   Stats:     233 iterations in 20.85 s (89.49 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  30%|▎|  ETA: 0:01:02
#   Progress:  Solving step 108/365 (29.59% of time interval complete)
#   Stats:     237 iterations in 21.00 s (88.60 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  30%|▎|  ETA: 0:01:01
#   Progress:  Solving step 110/365 (30.14% of time interval complete)
#   Stats:     241 iterations in 21.15 s (87.75 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  31%|▎|  ETA: 0:00:59
#   Progress:  Solving step 112/365 (30.68% of time interval complete)
#   Stats:     245 iterations in 21.30 s (86.93 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  31%|▎|  ETA: 0:00:58
#   Progress:  Solving step 114/365 (31.23% of time interval complete)
#   Stats:     249 iterations in 21.45 s (86.13 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  32%|▍|  ETA: 0:00:57
#   Progress:  Solving step 116/365 (31.78% of time interval complete)
#   Stats:     252 iterations in 21.56 s (85.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  33%|▍|  ETA: 0:00:55
#   Progress:  Solving step 119/365 (32.60% of time interval complete)
#   Stats:     255 iterations in 21.68 s (85.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  33%|▍|  ETA: 0:00:53
#   Progress:  Solving step 122/365 (33.42% of time interval complete)
#   Stats:     258 iterations in 21.83 s (84.60 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  34%|▍|  ETA: 0:00:52
#   Progress:  Solving step 125/365 (34.25% of time interval complete)
#   Stats:     261 iterations in 21.94 s (84.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  35%|▍|  ETA: 0:00:50
#   Progress:  Solving step 128/365 (35.07% of time interval complete)
#   Stats:     264 iterations in 22.05 s (83.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  36%|▍|  ETA: 0:00:49
#   Progress:  Solving step 131/365 (35.89% of time interval complete)
#   Stats:     267 iterations in 22.16 s (82.99 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  37%|▍|  ETA: 0:00:47
#   Progress:  Solving step 134/365 (36.71% of time interval complete)
#   Stats:     270 iterations in 22.27 s (82.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  37%|▍|  ETA: 0:00:46
#   Progress:  Solving step 137/365 (37.53% of time interval complete)
#   Stats:     273 iterations in 22.38 s (81.98 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  38%|▍|  ETA: 0:00:44
#   Progress:  Solving step 140/365 (38.36% of time interval complete)
#   Stats:     276 iterations in 22.49 s (81.49 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  39%|▍|  ETA: 0:00:43
#   Progress:  Solving step 143/365 (39.18% of time interval complete)
#   Stats:     279 iterations in 22.60 s (81.01 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  40%|▍|  ETA: 0:00:42
#   Progress:  Solving step 146/365 (40.00% of time interval complete)
#   Stats:     282 iterations in 22.71 s (80.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  41%|▍|  ETA: 0:00:40
#   Progress:  Solving step 149/365 (40.82% of time interval complete)
#   Stats:     285 iterations in 22.83 s (80.09 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  42%|▍|  ETA: 0:00:39
#   Progress:  Solving step 152/365 (41.64% of time interval complete)
#   Stats:     288 iterations in 22.94 s (79.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  42%|▍|  ETA: 0:00:38
#   Progress:  Solving step 155/365 (42.47% of time interval complete)
#   Stats:     291 iterations in 23.05 s (79.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  43%|▍|  ETA: 0:00:37
#   Progress:  Solving step 158/365 (43.29% of time interval complete)
#   Stats:     295 iterations in 23.20 s (78.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  44%|▍|  ETA: 0:00:36
#   Progress:  Solving step 160/365 (43.84% of time interval complete)
#   Stats:     299 iterations in 23.35 s (78.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  44%|▌|  ETA: 0:00:36
#   Progress:  Solving step 162/365 (44.38% of time interval complete)
#   Stats:     303 iterations in 23.50 s (77.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  45%|▌|  ETA: 0:00:35
#   Progress:  Solving step 164/365 (44.93% of time interval complete)
#   Stats:     307 iterations in 23.65 s (77.04 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  45%|▌|  ETA: 0:00:35
#   Progress:  Solving step 166/365 (45.48% of time interval complete)
#   Stats:     311 iterations in 23.80 s (76.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  46%|▌|  ETA: 0:00:34
#   Progress:  Solving step 168/365 (46.03% of time interval complete)
#   Stats:     315 iterations in 23.95 s (76.04 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  46%|▌|  ETA: 0:00:33
#   Progress:  Solving step 170/365 (46.58% of time interval complete)
#   Stats:     319 iterations in 24.11 s (75.57 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  47%|▌|  ETA: 0:00:33
#   Progress:  Solving step 172/365 (47.12% of time interval complete)
#   Stats:     323 iterations in 24.26 s (75.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  48%|▌|  ETA: 0:00:32
#   Progress:  Solving step 174/365 (47.67% of time interval complete)
#   Stats:     327 iterations in 24.41 s (74.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  48%|▌|  ETA: 0:00:32
#   Progress:  Solving step 176/365 (48.22% of time interval complete)
#   Stats:     331 iterations in 24.57 s (74.22 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  49%|▌|  ETA: 0:00:31
#   Progress:  Solving step 178/365 (48.77% of time interval complete)
#   Stats:     335 iterations in 24.72 s (73.79 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  49%|▌|  ETA: 0:00:31
#   Progress:  Solving step 180/365 (49.32% of time interval complete)
#   Stats:     339 iterations in 24.91 s (73.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  50%|▌|  ETA: 0:00:30
#   Progress:  Solving step 182/365 (49.86% of time interval complete)
#   Stats:     343 iterations in 25.06 s (73.06 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  50%|▌|  ETA: 0:00:30
#   Progress:  Solving step 184/365 (50.41% of time interval complete)
#   Stats:     347 iterations in 25.21 s (72.66 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  51%|▌|  ETA: 0:00:29
#   Progress:  Solving step 186/365 (50.96% of time interval complete)
#   Stats:     351 iterations in 25.36 s (72.26 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  51%|▌|  ETA: 0:00:29
#   Progress:  Solving step 188/365 (51.51% of time interval complete)
#   Stats:     355 iterations in 25.51 s (71.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  52%|▌|  ETA: 0:00:28
#   Progress:  Solving step 190/365 (52.05% of time interval complete)
#   Stats:     359 iterations in 25.66 s (71.49 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  52%|▌|  ETA: 0:00:28
#   Progress:  Solving step 192/365 (52.60% of time interval complete)
#   Stats:     363 iterations in 25.82 s (71.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  53%|▌|  ETA: 0:00:27
#   Progress:  Solving step 194/365 (53.15% of time interval complete)
#   Stats:     367 iterations in 25.97 s (70.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  54%|▌|  ETA: 0:00:27
#   Progress:  Solving step 196/365 (53.70% of time interval complete)
#   Stats:     371 iterations in 26.12 s (70.42 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  54%|▌|  ETA: 0:00:26
#   Progress:  Solving step 198/365 (54.25% of time interval complete)
#   Stats:     375 iterations in 26.28 s (70.08 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  55%|▌|  ETA: 0:00:26
#   Progress:  Solving step 200/365 (54.79% of time interval complete)
#   Stats:     379 iterations in 26.44 s (69.76 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  55%|▌|  ETA: 0:00:26
#   Progress:  Solving step 202/365 (55.34% of time interval complete)
#   Stats:     383 iterations in 26.60 s (69.45 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  56%|▌|  ETA: 0:00:25
#   Progress:  Solving step 204/365 (55.89% of time interval complete)
#   Stats:     387 iterations in 26.76 s (69.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  56%|▋|  ETA: 0:00:25
#   Progress:  Solving step 206/365 (56.44% of time interval complete)
#   Stats:     391 iterations in 26.93 s (68.87 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  57%|▋|  ETA: 0:00:24
#   Progress:  Solving step 208/365 (56.99% of time interval complete)
#   Stats:     395 iterations in 27.09 s (68.59 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  57%|▋|  ETA: 0:00:24
#   Progress:  Solving step 210/365 (57.53% of time interval complete)
#   Stats:     399 iterations in 27.26 s (68.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  58%|▋|  ETA: 0:00:24
#   Progress:  Solving step 212/365 (58.08% of time interval complete)
#   Stats:     403 iterations in 27.42 s (68.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  58%|▋|  ETA: 0:00:23
#   Progress:  Solving step 214/365 (58.63% of time interval complete)
#   Stats:     407 iterations in 27.59 s (67.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  59%|▋|  ETA: 0:00:23
#   Progress:  Solving step 216/365 (59.18% of time interval complete)
#   Stats:     411 iterations in 27.77 s (67.56 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  60%|▋|  ETA: 0:00:22
#   Progress:  Solving step 218/365 (59.73% of time interval complete)
#   Stats:     415 iterations in 27.94 s (67.33 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  60%|▋|  ETA: 0:00:22
#   Progress:  Solving step 220/365 (60.27% of time interval complete)
#   Stats:     419 iterations in 28.12 s (67.12 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:22
#   Progress:  Solving step 222/365 (60.82% of time interval complete)
#   Stats:     423 iterations in 28.30 s (66.91 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:21
#   Progress:  Solving step 223/365 (61.10% of time interval complete)
#   Stats:     425 iterations in 28.43 s (66.90 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  61%|▋|  ETA: 0:00:21
#   Progress:  Solving step 225/365 (61.64% of time interval complete)
#   Stats:     429 iterations in 28.62 s (66.71 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  62%|▋|  ETA: 0:00:21
#   Progress:  Solving step 227/365 (62.19% of time interval complete)
#   Stats:     433 iterations in 28.81 s (66.54 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:20
#   Progress:  Solving step 229/365 (62.74% of time interval complete)
#   Stats:     437 iterations in 29.01 s (66.38 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:20
#   Progress:  Solving step 230/365 (63.01% of time interval complete)
#   Stats:     439 iterations in 29.11 s (66.31 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:20
#   Progress:  Solving step 231/365 (63.29% of time interval complete)
#   Stats:     441 iterations in 29.22 s (66.25 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  63%|▋|  ETA: 0:00:20
#   Progress:  Solving step 232/365 (63.56% of time interval complete)
#   Stats:     443 iterations in 29.32 s (66.19 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:20
#   Progress:  Solving step 233/365 (63.84% of time interval complete)
#   Stats:     445 iterations in 29.43 s (66.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:19
#   Progress:  Solving step 234/365 (64.11% of time interval complete)
#   Stats:     447 iterations in 29.54 s (66.10 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:19
#   Progress:  Solving step 235/365 (64.38% of time interval complete)
#   Stats:     449 iterations in 29.66 s (66.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  64%|▋|  ETA: 0:00:19
#   Progress:  Solving step 236/365 (64.66% of time interval complete)
#   Stats:     451 iterations in 29.77 s (66.00 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:19
#   Progress:  Solving step 237/365 (64.93% of time interval complete)
#   Stats:     453 iterations in 29.88 s (65.96 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:19
#   Progress:  Solving step 238/365 (65.21% of time interval complete)
#   Stats:     455 iterations in 29.99 s (65.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  65%|▋|  ETA: 0:00:19
#   Progress:  Solving step 239/365 (65.48% of time interval complete)
#   Stats:     457 iterations in 30.11 s (65.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:18
#   Progress:  Solving step 240/365 (65.75% of time interval complete)
#   Stats:     459 iterations in 30.22 s (65.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:18
#   Progress:  Solving step 241/365 (66.03% of time interval complete)
#   Stats:     461 iterations in 30.34 s (65.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:18
#   Progress:  Solving step 242/365 (66.30% of time interval complete)
#   Stats:     463 iterations in 30.45 s (65.77 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  66%|▋|  ETA: 0:00:18
#   Progress:  Solving step 243/365 (66.58% of time interval complete)
#   Stats:     465 iterations in 30.57 s (65.74 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:18
#   Progress:  Solving step 244/365 (66.85% of time interval complete)
#   Stats:     467 iterations in 30.69 s (65.71 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:18
#   Progress:  Solving step 245/365 (67.12% of time interval complete)
#   Stats:     469 iterations in 30.81 s (65.68 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:18
#   Progress:  Solving step 246/365 (67.40% of time interval complete)
#   Stats:     471 iterations in 30.93 s (65.66 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  67%|▋|  ETA: 0:00:17
#   Progress:  Solving step 247/365 (67.67% of time interval complete)
#   Stats:     473 iterations in 31.04 s (65.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:17
#   Progress:  Solving step 248/365 (67.95% of time interval complete)
#   Stats:     475 iterations in 31.16 s (65.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:17
#   Progress:  Solving step 249/365 (68.22% of time interval complete)
#   Stats:     477 iterations in 31.28 s (65.58 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  68%|▋|  ETA: 0:00:17
#   Progress:  Solving step 250/365 (68.49% of time interval complete)
#   Stats:     479 iterations in 31.40 s (65.55 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▋|  ETA: 0:00:17
#   Progress:  Solving step 251/365 (68.77% of time interval complete)
#   Stats:     481 iterations in 31.52 s (65.53 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:17
#   Progress:  Solving step 252/365 (69.04% of time interval complete)
#   Stats:     483 iterations in 31.63 s (65.50 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:16
#   Progress:  Solving step 253/365 (69.32% of time interval complete)
#   Stats:     485 iterations in 31.75 s (65.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  69%|▊|  ETA: 0:00:16
#   Progress:  Solving step 254/365 (69.59% of time interval complete)
#   Stats:     487 iterations in 31.86 s (65.43 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:16
#   Progress:  Solving step 255/365 (69.86% of time interval complete)
#   Stats:     489 iterations in 31.97 s (65.39 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:16
#   Progress:  Solving step 256/365 (70.14% of time interval complete)
#   Stats:     491 iterations in 32.08 s (65.34 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:16
#   Progress:  Solving step 257/365 (70.41% of time interval complete)
#   Stats:     493 iterations in 32.19 s (65.29 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  70%|▊|  ETA: 0:00:16
#   Progress:  Solving step 258/365 (70.68% of time interval complete)
#   Stats:     495 iterations in 32.29 s (65.24 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  71%|▊|  ETA: 0:00:15
#   Progress:  Solving step 259/365 (70.96% of time interval complete)
#   Stats:     497 iterations in 32.40 s (65.18 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  71%|▊|  ETA: 0:00:15
#   Progress:  Solving step 261/365 (71.51% of time interval complete)
#   Stats:     501 iterations in 32.60 s (65.06 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  72%|▊|  ETA: 0:00:15
#   Progress:  Solving step 263/365 (72.05% of time interval complete)
#   Stats:     505 iterations in 32.79 s (64.93 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  72%|▊|  ETA: 0:00:15
#   Progress:  Solving step 264/365 (72.33% of time interval complete)
#   Stats:     507 iterations in 32.92 s (64.93 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  73%|▊|  ETA: 0:00:14
#   Progress:  Solving step 266/365 (72.88% of time interval complete)
#   Stats:     511 iterations in 33.10 s (64.78 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  73%|▊|  ETA: 0:00:14
#   Progress:  Solving step 268/365 (73.42% of time interval complete)
#   Stats:     515 iterations in 33.28 s (64.62 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  74%|▊|  ETA: 0:00:14
#   Progress:  Solving step 270/365 (73.97% of time interval complete)
#   Stats:     519 iterations in 33.46 s (64.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  74%|▊|  ETA: 0:00:13
#   Progress:  Solving step 272/365 (74.52% of time interval complete)
#   Stats:     523 iterations in 33.63 s (64.30 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  75%|▊|  ETA: 0:00:13
#   Progress:  Solving step 274/365 (75.07% of time interval complete)
#   Stats:     527 iterations in 33.80 s (64.14 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  75%|▊|  ETA: 0:00:13
#   Progress:  Solving step 276/365 (75.62% of time interval complete)
#   Stats:     531 iterations in 33.97 s (63.97 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  76%|▊|  ETA: 0:00:12
#   Progress:  Solving step 278/365 (76.16% of time interval complete)
#   Stats:     535 iterations in 34.13 s (63.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  77%|▊|  ETA: 0:00:12
#   Progress:  Solving step 280/365 (76.71% of time interval complete)
#   Stats:     539 iterations in 34.30 s (63.63 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  77%|▊|  ETA: 0:00:12
#   Progress:  Solving step 282/365 (77.26% of time interval complete)
#   Stats:     543 iterations in 34.46 s (63.46 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  78%|▊|  ETA: 0:00:11
#   Progress:  Solving step 284/365 (77.81% of time interval complete)
#   Stats:     547 iterations in 34.62 s (63.29 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  78%|▊|  ETA: 0:00:11
#   Progress:  Solving step 286/365 (78.36% of time interval complete)
#   Stats:     551 iterations in 34.78 s (63.13 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  79%|▊|  ETA: 0:00:11
#   Progress:  Solving step 288/365 (78.90% of time interval complete)
#   Stats:     555 iterations in 34.95 s (62.97 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  79%|▊|  ETA: 0:00:11
#   Progress:  Solving step 290/365 (79.45% of time interval complete)
#   Stats:     559 iterations in 35.11 s (62.80 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  80%|▊|  ETA: 0:00:10
#   Progress:  Solving step 292/365 (80.00% of time interval complete)
#   Stats:     563 iterations in 35.27 s (62.64 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  80%|▊|  ETA: 0:00:10
#   Progress:  Solving step 294/365 (80.55% of time interval complete)
#   Stats:     567 iterations in 35.42 s (62.48 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  81%|▊|  ETA: 0:00:10
#   Progress:  Solving step 296/365 (81.10% of time interval complete)
#   Stats:     571 iterations in 35.58 s (62.32 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  81%|▉|  ETA: 0:00:09
#   Progress:  Solving step 298/365 (81.64% of time interval complete)
#   Stats:     575 iterations in 35.74 s (62.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  82%|▉|  ETA: 0:00:09
#   Progress:  Solving step 300/365 (82.19% of time interval complete)
#   Stats:     579 iterations in 35.90 s (62.00 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  83%|▉|  ETA: 0:00:09
#   Progress:  Solving step 302/365 (82.74% of time interval complete)
#   Stats:     583 iterations in 36.05 s (61.84 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  83%|▉|  ETA: 0:00:08
#   Progress:  Solving step 304/365 (83.29% of time interval complete)
#   Stats:     587 iterations in 36.21 s (61.68 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  84%|▉|  ETA: 0:00:08
#   Progress:  Solving step 306/365 (83.84% of time interval complete)
#   Stats:     591 iterations in 36.36 s (61.52 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  84%|▉|  ETA: 0:00:08
#   Progress:  Solving step 308/365 (84.38% of time interval complete)
#   Stats:     595 iterations in 36.51 s (61.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  84%|▉|  ETA: 0:00:08
#   Progress:  Solving step 309/365 (84.66% of time interval complete)
#   Stats:     597 iterations in 36.63 s (61.35 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  85%|▉|  ETA: 0:00:07
#   Progress:  Solving step 311/365 (85.21% of time interval complete)
#   Stats:     601 iterations in 36.77 s (61.18 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  86%|▉|  ETA: 0:00:07
#   Progress:  Solving step 313/365 (85.75% of time interval complete)
#   Stats:     605 iterations in 36.92 s (61.02 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  86%|▉|  ETA: 0:00:07
#   Progress:  Solving step 315/365 (86.30% of time interval complete)
#   Stats:     609 iterations in 37.06 s (60.85 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  87%|▉|  ETA: 0:00:07
#   Progress:  Solving step 317/365 (86.85% of time interval complete)
#   Stats:     613 iterations in 37.20 s (60.69 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  87%|▉|  ETA: 0:00:06
#   Progress:  Solving step 319/365 (87.40% of time interval complete)
#   Stats:     617 iterations in 37.35 s (60.53 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  88%|▉|  ETA: 0:00:06
#   Progress:  Solving step 321/365 (87.95% of time interval complete)
#   Stats:     621 iterations in 37.49 s (60.37 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  88%|▉|  ETA: 0:00:06
#   Progress:  Solving step 323/365 (88.49% of time interval complete)
#   Stats:     625 iterations in 37.63 s (60.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  89%|▉|  ETA: 0:00:05
#   Progress:  Solving step 325/365 (89.04% of time interval complete)
#   Stats:     629 iterations in 37.77 s (60.05 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  89%|▉|  ETA: 0:00:05
#   Progress:  Solving step 327/365 (89.59% of time interval complete)
#   Stats:     633 iterations in 37.91 s (59.90 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  90%|▉|  ETA: 0:00:05
#   Progress:  Solving step 329/365 (90.14% of time interval complete)
#   Stats:     637 iterations in 38.06 s (59.74 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  90%|▉|  ETA: 0:00:05
#   Progress:  Solving step 331/365 (90.68% of time interval complete)
#   Stats:     641 iterations in 38.20 s (59.59 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  91%|▉|  ETA: 0:00:04
#   Progress:  Solving step 333/365 (91.23% of time interval complete)
#   Stats:     645 iterations in 38.34 s (59.45 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  92%|▉|  ETA: 0:00:04
#   Progress:  Solving step 335/365 (91.78% of time interval complete)
#   Stats:     649 iterations in 38.49 s (59.30 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  92%|▉|  ETA: 0:00:04
#   Progress:  Solving step 337/365 (92.33% of time interval complete)
#   Stats:     653 iterations in 38.63 s (59.16 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  93%|▉|  ETA: 0:00:03
#   Progress:  Solving step 339/365 (92.88% of time interval complete)
#   Stats:     657 iterations in 38.78 s (59.02 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  93%|▉|  ETA: 0:00:03
#   Progress:  Solving step 341/365 (93.42% of time interval complete)
#   Stats:     661 iterations in 38.92 s (58.88 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  94%|▉|  ETA: 0:00:03
#   Progress:  Solving step 343/365 (93.97% of time interval complete)
#   Stats:     665 iterations in 39.07 s (58.74 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  94%|█|  ETA: 0:00:03
#   Progress:  Solving step 345/365 (94.52% of time interval complete)
#   Stats:     669 iterations in 39.21 s (58.61 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  95%|█|  ETA: 0:00:02
#   Progress:  Solving step 347/365 (95.07% of time interval complete)
#   Stats:     673 iterations in 39.35 s (58.47 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  95%|█|  ETA: 0:00:02
#   Progress:  Solving step 349/365 (95.62% of time interval complete)
#   Stats:     677 iterations in 39.50 s (58.34 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  96%|█|  ETA: 0:00:02
#   Progress:  Solving step 351/365 (96.16% of time interval complete)
#   Stats:     681 iterations in 39.64 s (58.21 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  96%|█|  ETA: 0:00:02
#   Progress:  Solving step 353/365 (96.71% of time interval complete)
#   Stats:     685 iterations in 39.78 s (58.07 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  97%|█|  ETA: 0:00:02
#   Progress:  Solving step 354/365 (96.99% of time interval complete)
#   Stats:     687 iterations in 39.89 s (58.06 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  97%|█|  ETA: 0:00:01
#   Progress:  Solving step 356/365 (97.53% of time interval complete)
#   Stats:     691 iterations in 40.03 s (57.92 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  98%|█|  ETA: 0:00:01
#   Progress:  Solving step 358/365 (98.08% of time interval complete)
#   Stats:     695 iterations in 40.16 s (57.79 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  98%|█|  ETA: 0:00:01
#   Progress:  Solving step 360/365 (98.63% of time interval complete)
#   Stats:     699 iterations in 40.30 s (57.65 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  99%|█|  ETA: 0:00:01
#   Progress:  Solving step 362/365 (99.18% of time interval complete)
#   Stats:     703 iterations in 40.43 s (57.51 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps  99%|█|  ETA: 0:00:00
#   Progress:  Solving step 364/365 (99.73% of time interval complete)
#   Stats:     707 iterations in 40.56 s (57.38 ms each)
#
# Simulating 1 year, 52.11 weeks as 365 report steps 100%|█| Time: 0:00:45
#   Progress:  Solved step 365/365
#   Stats:     711 iterations in 40.70 s (57.24 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │ Time per │    Total │
# │                │ 365 steps │ 367 ministeps │       ms │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┼──────────┤
# │ Newton         │   1.94795 │       1.93733 │  57.2390 │  711 (0) │
# │ Linearization  │   2.95342 │       2.93733 │  37.7523 │ 1078 (0) │
# │ Linear solver  │   4.75068 │        4.7248 │  23.4700 │ 1734 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │ 33.1312 │    57.88 % │ 23.5563 │
# │ Equations      │  4.5821 │    12.14 % │  4.9396 │
# │ Assembly       │  3.6429 │     9.65 % │  3.9271 │
# │ Linear solve   │  5.0368 │     8.80 % │  3.5812 │
# │ Preconditioner │  2.3908 │     4.18 % │  1.6999 │
# │ Update         │  0.9975 │     1.74 % │  0.7092 │
# │ Convergence    │  1.2537 │     3.32 % │  1.3514 │
# │ Input/Output   │  0.3111 │     0.28 % │  0.1142 │
# │ Other          │  1.1506 │     2.01 % │  0.8181 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 57.2390 │   100.00 % │ 40.6969 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 365 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :orat => Vector{Float64} of size (365,)
#        :N2-CH4_mass_rate => Vector{Float64} of size (365,)
#        :C6-13_mass_rate => Vector{Float64} of size (365,)
#        :C14-24_mass_rate => Vector{Float64} of size (365,)
#        :C2-5_mass_rate => Vector{Float64} of size (365,)
#        :bhp => Vector{Float64} of size (365,)
#        :lrat => Vector{Float64} of size (365,)
#        :CO2_mass_rate => Vector{Float64} of size (365,)
#        :mass_rate => Vector{Float64} of size (365,)
#        :rate => Vector{Float64} of size (365,)
#        :control => Vector{Symbol} of size (365,)
#        :grat => Vector{Float64} of size (365,)
#
#   states (Vector with 365 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (5, 800)
#     :OverallMoleFractions => Matrix{Float64} of size (5, 800)
#     :Saturations => Matrix{Float64} of size (2, 800)
#     :Pressure => Vector{Float64} of size (800,)
#     :VaporMassFractions => Matrix{Float64} of size (5, 800)
#     :TotalMasses => Matrix{Float64} of size (5, 800)
#
#   time (report time for each state)
#      Vector{Float64} of length 365
#
#   result (extended states, reports)
#      SimResult with 365 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 05 2024 14:06 after 40 seconds, 582 milliseconds, 776.1 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# ### CO2 mole fraction

# %%
sg = states[end][:OverallMoleFractions][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Gas saturation

# %%
sg = states[end][:Saturations][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Pressure

# %%
p = states[end][:Pressure]
fig, ax, p = plot_cell_data(g, p)
fig
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
