# %% [markdown]
# # The SPE9 model
# [Killough, J. E. 1995. Ninth SPE comparative solution project: A reexamination
# of black-oil simulation. In SPE Reservoir Simulation Symposium,  12-15
# February 1995, San Antonio, Texas. SPE 29110-MS]
# (http://dx.doi.org/10.2118/29110-MS)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles
spe9_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("SPE9")
case = setup_case_from_data_file(joinpath(spe9_dir, "SPE9.DATA"))
ws, states = simulate_reservoir(case, output_substates = true)
#
csv_path = joinpath(spe9_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
#
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat] + well[:grat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response")
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :grat
        ys = si_unit(:day)/1e6
        yl = "Surface gas rate / 10⁶ m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        grat_ref = data[:, findfirst(x -> x == "$well_name:grat", vec(header))]
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = grat_ref + orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "E100"])
    fig
end
# Out:
# Simulating 2 years, 24.22 weeks as 90 report steps   2%| |  ETA: 0:00:26
#   Progress:  Solving step 2/90 (2.22% of time interval complete)
#   Stats:     19 iterations in 576.07 ms (30.32 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   3%| |  ETA: 0:00:22
#   Progress:  Solving step 3/90 (3.33% of time interval complete)
#   Stats:     25 iterations in 752.35 ms (30.09 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   4%| |  ETA: 0:00:19
#   Progress:  Solving step 4/90 (4.44% of time interval complete)
#   Stats:     29 iterations in 874.64 ms (30.16 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   5%| |  ETA: 0:00:17
#   Progress:  Solving step 5/90 (5.56% of time interval complete)
#   Stats:     33 iterations in 995.37 ms (30.16 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   8%|▏|  ETA: 0:00:15
#   Progress:  Solving step 7/90 (7.78% of time interval complete)
#   Stats:     39 iterations in 1.22 s (31.31 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   9%|▏|  ETA: 0:00:14
#   Progress:  Solving step 8/90 (8.89% of time interval complete)
#   Stats:     43 iterations in 1.34 s (31.23 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  11%|▏|  ETA: 0:00:13
#   Progress:  Solving step 10/90 (11.11% of time interval complete)
#   Stats:     51 iterations in 1.58 s (30.96 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  13%|▏|  ETA: 0:00:12
#   Progress:  Solving step 12/90 (13.33% of time interval complete)
#   Stats:     57 iterations in 1.76 s (30.91 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  14%|▏|  ETA: 0:00:11
#   Progress:  Solving step 13/90 (14.44% of time interval complete)
#   Stats:     61 iterations in 1.88 s (30.84 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  15%|▏|  ETA: 0:00:11
#   Progress:  Solving step 14/90 (15.56% of time interval complete)
#   Stats:     66 iterations in 2.03 s (30.77 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  18%|▏|  ETA: 0:00:10
#   Progress:  Solving step 16/90 (17.78% of time interval complete)
#   Stats:     72 iterations in 2.21 s (30.76 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  20%|▎|  ETA: 0:00:10
#   Progress:  Solving step 18/90 (20.00% of time interval complete)
#   Stats:     78 iterations in 2.41 s (30.84 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  22%|▎|  ETA: 0:00:09
#   Progress:  Solving step 20/90 (22.22% of time interval complete)
#   Stats:     84 iterations in 2.60 s (30.90 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  24%|▎|  ETA: 0:00:09
#   Progress:  Solving step 22/90 (24.44% of time interval complete)
#   Stats:     90 iterations in 2.78 s (30.88 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  26%|▎|  ETA: 0:00:08
#   Progress:  Solving step 24/90 (26.67% of time interval complete)
#   Stats:     96 iterations in 2.96 s (30.88 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  29%|▎|  ETA: 0:00:08
#   Progress:  Solving step 26/90 (28.89% of time interval complete)
#   Stats:     102 iterations in 3.15 s (30.89 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  31%|▎|  ETA: 0:00:08
#   Progress:  Solving step 28/90 (31.11% of time interval complete)
#   Stats:     108 iterations in 3.34 s (30.90 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  33%|▍|  ETA: 0:00:07
#   Progress:  Solving step 30/90 (33.33% of time interval complete)
#   Stats:     114 iterations in 3.52 s (30.92 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  35%|▍|  ETA: 0:00:07
#   Progress:  Solving step 32/90 (35.56% of time interval complete)
#   Stats:     125 iterations in 3.87 s (30.93 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  36%|▍|  ETA: 0:00:07
#   Progress:  Solving step 33/90 (36.67% of time interval complete)
#   Stats:     130 iterations in 4.03 s (31.01 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  37%|▍|  ETA: 0:00:07
#   Progress:  Solving step 34/90 (37.78% of time interval complete)
#   Stats:     134 iterations in 4.15 s (31.00 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  38%|▍|  ETA: 0:00:07
#   Progress:  Solving step 35/90 (38.89% of time interval complete)
#   Stats:     139 iterations in 4.44 s (31.94 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  40%|▍|  ETA: 0:00:07
#   Progress:  Solving step 36/90 (40.00% of time interval complete)
#   Stats:     144 iterations in 4.60 s (31.94 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  41%|▍|  ETA: 0:00:07
#   Progress:  Solving step 37/90 (41.11% of time interval complete)
#   Stats:     150 iterations in 4.78 s (31.89 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  42%|▍|  ETA: 0:00:07
#   Progress:  Solving step 38/90 (42.22% of time interval complete)
#   Stats:     159 iterations in 5.06 s (31.83 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  43%|▍|  ETA: 0:00:07
#   Progress:  Solving step 39/90 (43.33% of time interval complete)
#   Stats:     164 iterations in 5.22 s (31.81 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  44%|▌|  ETA: 0:00:07
#   Progress:  Solving step 40/90 (44.44% of time interval complete)
#   Stats:     175 iterations in 5.55 s (31.70 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  45%|▌|  ETA: 0:00:07
#   Progress:  Solving step 41/90 (45.56% of time interval complete)
#   Stats:     179 iterations in 5.67 s (31.68 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  46%|▌|  ETA: 0:00:07
#   Progress:  Solving step 42/90 (46.67% of time interval complete)
#   Stats:     184 iterations in 5.83 s (31.66 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  47%|▌|  ETA: 0:00:07
#   Progress:  Solving step 43/90 (47.78% of time interval complete)
#   Stats:     188 iterations in 5.95 s (31.64 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  49%|▌|  ETA: 0:00:06
#   Progress:  Solving step 45/90 (50.00% of time interval complete)
#   Stats:     194 iterations in 6.14 s (31.67 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  52%|▌|  ETA: 0:00:06
#   Progress:  Solving step 47/90 (52.22% of time interval complete)
#   Stats:     200 iterations in 6.33 s (31.66 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  53%|▌|  ETA: 0:00:06
#   Progress:  Solving step 48/90 (53.33% of time interval complete)
#   Stats:     204 iterations in 6.46 s (31.69 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  55%|▌|  ETA: 0:00:05
#   Progress:  Solving step 50/90 (55.56% of time interval complete)
#   Stats:     209 iterations in 6.63 s (31.71 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  57%|▋|  ETA: 0:00:05
#   Progress:  Solving step 52/90 (57.78% of time interval complete)
#   Stats:     214 iterations in 6.79 s (31.73 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  58%|▋|  ETA: 0:00:05
#   Progress:  Solving step 53/90 (58.89% of time interval complete)
#   Stats:     218 iterations in 6.91 s (31.70 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  60%|▋|  ETA: 0:00:05
#   Progress:  Solving step 55/90 (61.11% of time interval complete)
#   Stats:     222 iterations in 7.04 s (31.72 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  63%|▋|  ETA: 0:00:04
#   Progress:  Solving step 57/90 (63.33% of time interval complete)
#   Stats:     227 iterations in 7.20 s (31.73 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  65%|▋|  ETA: 0:00:04
#   Progress:  Solving step 59/90 (65.56% of time interval complete)
#   Stats:     231 iterations in 7.33 s (31.74 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  67%|▋|  ETA: 0:00:04
#   Progress:  Solving step 61/90 (67.78% of time interval complete)
#   Stats:     237 iterations in 8.13 s (34.32 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  69%|▊|  ETA: 0:00:04
#   Progress:  Solving step 63/90 (70.00% of time interval complete)
#   Stats:     242 iterations in 8.29 s (34.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  71%|▊|  ETA: 0:00:03
#   Progress:  Solving step 65/90 (72.22% of time interval complete)
#   Stats:     247 iterations in 8.44 s (34.18 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  74%|▊|  ETA: 0:00:03
#   Progress:  Solving step 67/90 (74.44% of time interval complete)
#   Stats:     252 iterations in 8.60 s (34.12 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  76%|▊|  ETA: 0:00:03
#   Progress:  Solving step 69/90 (76.67% of time interval complete)
#   Stats:     257 iterations in 8.75 s (34.05 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  78%|▊|  ETA: 0:00:03
#   Progress:  Solving step 71/90 (78.89% of time interval complete)
#   Stats:     262 iterations in 8.90 s (33.97 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  80%|▊|  ETA: 0:00:02
#   Progress:  Solving step 73/90 (81.11% of time interval complete)
#   Stats:     266 iterations in 9.02 s (33.93 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  82%|▉|  ETA: 0:00:02
#   Progress:  Solving step 75/90 (83.33% of time interval complete)
#   Stats:     270 iterations in 9.15 s (33.89 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  85%|▉|  ETA: 0:00:02
#   Progress:  Solving step 77/90 (85.56% of time interval complete)
#   Stats:     275 iterations in 9.30 s (33.84 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  87%|▉|  ETA: 0:00:01
#   Progress:  Solving step 79/90 (87.78% of time interval complete)
#   Stats:     279 iterations in 9.43 s (33.79 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  89%|▉|  ETA: 0:00:01
#   Progress:  Solving step 81/90 (90.00% of time interval complete)
#   Stats:     283 iterations in 9.55 s (33.74 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  91%|▉|  ETA: 0:00:01
#   Progress:  Solving step 83/90 (92.22% of time interval complete)
#   Stats:     289 iterations in 9.73 s (33.65 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  93%|▉|  ETA: 0:00:01
#   Progress:  Solving step 85/90 (94.44% of time interval complete)
#   Stats:     293 iterations in 9.85 s (33.62 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  96%|█|  ETA: 0:00:00
#   Progress:  Solving step 87/90 (96.67% of time interval complete)
#   Stats:     297 iterations in 9.97 s (33.58 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  98%|█|  ETA: 0:00:00
#   Progress:  Solving step 89/90 (98.89% of time interval complete)
#   Stats:     301 iterations in 10.09 s (33.54 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps 100%|█| Time: 0:00:10
#   Progress:  Solved step 90/90
#   Stats:     305 iterations in 10.22 s (33.51 ms each)
# ╭────────────────┬──────────┬──────────────┬──────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │ Time per │    Total │
# │                │ 90 steps │ 96 ministeps │       ms │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┼──────────┤
# │ Newton         │  3.38889 │      3.17708 │  33.5061 │  305 (0) │
# │ Linearization  │  4.45556 │      4.17708 │  25.4847 │  401 (0) │
# │ Linear solver  │  12.4889 │      11.7083 │   9.0919 │ 1124 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │  2.6579 │     7.93 % │  0.8107 │
# │ Equations      │  3.6722 │    14.41 % │  1.4725 │
# │ Assembly       │  1.9141 │     7.51 % │  0.7675 │
# │ Linear solve   │  9.5346 │    28.46 % │  2.9081 │
# │ Preconditioner │ 10.1574 │    30.32 % │  3.0980 │
# │ Update         │  0.6223 │     1.86 % │  0.1898 │
# │ Convergence    │  0.4131 │     1.62 % │  0.1656 │
# │ Input/Output   │  0.2881 │     0.27 % │  0.0277 │
# │ Other          │  2.5555 │     7.63 % │  0.7794 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 33.5061 │   100.00 % │ 10.2193 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Producer BHP

# %%
plot_well_comparison(:bhp, prod, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Producer water rate

# %%
plot_well_comparison(:wrat, prod, "Water surface rate")
# Out:
# Figure()

# %% [markdown]
# ## Injector water rate

# %%
plot_well_comparison(:wrat, inj, "Water surface rate")
# Out:
# Figure()

# %% [markdown]
# ## Oil produciton rate

# %%
plot_well_comparison(:orat, prod, "Oil surface rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
