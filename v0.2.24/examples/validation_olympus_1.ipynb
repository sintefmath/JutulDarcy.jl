# %% [markdown]
# # OLYMPUS_1 model
# Model from the [ISAPP Optimization challenge](https://www.isapp2.com/optimization-challenge/reservoir-model-description.html)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles, HYPRE
olympus_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("OLYMPUS_1")
case = setup_case_from_data_file(joinpath(olympus_dir, "OLYMPUS_1.DATA"), backend = :csr)
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
#  Downloading artifact: OLYMPUS_1
#      Failure artifact: OLYMPUS_1
#  Downloading artifact: OLYMPUS_1
# Parser: GRID/PINCH - PINCH is only partially supported by JutulDarcy solvers.
# Parser: GRID/COORDSYS - Unsupported keyword. It will be ignored.
# Parser: PROPS/ROCKOPTS - ROCKOPTS is not supported by JutulDarcy solvers. It will be ignored in simulations.
# Parser: SCHEDULE/GRUPTREE - Unsupported keyword. It will be ignored.
# Transmissibility: Replaced 6357 negative half-transmissibilities (out of 1104454, 0.58%) with their absolute value.
# Simulating 20 years, 3.6 hours as 20 report steps  10%|▎ |  ETA: 0:10:27
#   Progress:  Solving step 2/20 (10.01% of time interval complete)
#   Stats:     132 iterations in 65.21 s (494.03 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  14%|▎ |  ETA: 0:16:29
#   Progress:  Solving step 3/20 (15.00% of time interval complete)
#   Stats:     340 iterations in 164.01 s (482.39 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  19%|▍ |  ETA: 0:13:53
#   Progress:  Solving step 4/20 (20.00% of time interval complete)
#   Stats:     405 iterations in 195.26 s (482.14 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  24%|▌ |  ETA: 0:12:52
#   Progress:  Solving step 5/20 (25.01% of time interval complete)
#   Stats:     500 iterations in 240.48 s (480.96 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  29%|▋ |  ETA: 0:10:53
#   Progress:  Solving step 6/20 (30.01% of time interval complete)
#   Stats:     540 iterations in 260.39 s (482.21 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  33%|▋ |  ETA: 0:09:00
#   Progress:  Solving step 7/20 (35.00% of time interval complete)
#   Stats:     557 iterations in 269.06 s (483.06 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  38%|▊ |  ETA: 0:07:44
#   Progress:  Solving step 8/20 (40.00% of time interval complete)
#   Stats:     588 iterations in 284.77 s (484.31 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  43%|▉ |  ETA: 0:06:45
#   Progress:  Solving step 9/20 (45.01% of time interval complete)
#   Stats:     624 iterations in 302.89 s (485.40 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  48%|█ |  ETA: 0:05:41
#   Progress:  Solving step 10/20 (50.01% of time interval complete)
#   Stats:     636 iterations in 309.07 s (485.96 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  52%|█ |  ETA: 0:04:47
#   Progress:  Solving step 11/20 (55.00% of time interval complete)
#   Stats:     648 iterations in 315.03 s (486.16 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  57%|█▏|  ETA: 0:04:00
#   Progress:  Solving step 12/20 (60.00% of time interval complete)
#   Stats:     656 iterations in 319.07 s (486.39 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  62%|█▎|  ETA: 0:03:20
#   Progress:  Solving step 13/20 (65.01% of time interval complete)
#   Stats:     665 iterations in 323.96 s (487.15 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  67%|█▍|  ETA: 0:02:45
#   Progress:  Solving step 14/20 (70.01% of time interval complete)
#   Stats:     676 iterations in 329.16 s (486.92 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  71%|█▍|  ETA: 0:02:14
#   Progress:  Solving step 15/20 (75.00% of time interval complete)
#   Stats:     684 iterations in 333.75 s (487.94 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  76%|█▌|  ETA: 0:01:46
#   Progress:  Solving step 16/20 (80.00% of time interval complete)
#   Stats:     692 iterations in 337.81 s (488.17 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  81%|█▋|  ETA: 0:01:21
#   Progress:  Solving step 17/20 (85.01% of time interval complete)
#   Stats:     700 iterations in 341.99 s (488.56 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  86%|█▊|  ETA: 0:00:59
#   Progress:  Solving step 18/20 (90.01% of time interval complete)
#   Stats:     727 iterations in 355.28 s (488.69 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  90%|█▊|  ETA: 0:00:38
#   Progress:  Solving step 19/20 (95.00% of time interval complete)
#   Stats:     734 iterations in 358.71 s (488.71 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps  95%|█▉|  ETA: 0:00:18
#   Progress:  Solving step 20/20 (100.00% of time interval complete)
#   Stats:     742 iterations in 362.82 s (488.98 ms each)
#
# Simulating 20 years, 3.6 hours as 20 report steps 100%|██| Time: 0:06:07
#   Progress:  Solved step 20/20
#   Stats:     749 iterations in 366.42 s (489.21 ms each)
# ╭────────────────┬──────────┬───────────────┬──────────┬─────────────╮
# │ Iteration type │ Avg/step │  Avg/ministep │ Time per │       Total │
# │                │ 20 steps │ 107 ministeps │       ms │    (wasted) │
# ├────────────────┼──────────┼───────────────┼──────────┼─────────────┤
# │ Newton         │    37.45 │           7.0 │ 489.2057 │   749 (360) │
# │ Linearization  │     42.8 │           8.0 │ 428.0550 │   856 (384) │
# │ Linear solver  │    117.6 │       21.9813 │ 155.7887 │ 2352 (1089) │
# ╰────────────────┴──────────┴───────────────┴──────────┴─────────────╯
# ╭────────────────┬──────────┬────────────┬──────────╮
# │ Timing type    │     Each │   Relative │    Total │
# │                │       ms │ Percentage │        s │
# ├────────────────┼──────────┼────────────┼──────────┤
# │ Properties     │  63.5706 │    12.99 % │  47.6144 │
# │ Equations      │  34.2900 │     8.01 % │  29.3523 │
# │ Assembly       │  31.9772 │     7.47 % │  27.3725 │
# │ Linear solve   │ 159.0968 │    32.52 % │ 119.1635 │
# │ Preconditioner │ 181.5471 │    37.11 % │ 135.9788 │
# │ Update         │   3.4042 │     0.70 % │   2.5498 │
# │ Convergence    │   1.8031 │     0.42 % │   1.5434 │
# │ Input/Output   │   0.1589 │     0.00 % │   0.0170 │
# │ Other          │   3.7697 │     0.77 % │   2.8235 │
# ├────────────────┼──────────┼────────────┼──────────┤
# │ Total          │ 489.2057 │   100.00 % │ 366.4151 │
# ╰────────────────┴──────────┴────────────┴──────────╯
# ReservoirSimResult with 83 entries:
#
#   wells (18 present):
#     :INJ-7
#     :PROD-4
#     :INJ-5
#     :INJ-4
#     :PROD-9
#     :INJ-2
#     :PROD-3
#     :PROD-2
#     :PROD-8
#     :INJ-3
#     :PROD-6
#     :PROD-1
#     :PROD-10
#     :PROD-7
#     :PROD-5
#     :INJ-6
#     :PROD-11
#     :INJ-1
#     Results per well:
#        :lrat => Vector{Float64} of size (83,)
#        :wrat => Vector{Float64} of size (83,)
#        :Aqueous_mass_rate => Vector{Float64} of size (83,)
#        :orat => Vector{Float64} of size (83,)
#        :control => Vector{Symbol} of size (83,)
#        :bhp => Vector{Float64} of size (83,)
#        :Liquid_mass_rate => Vector{Float64} of size (83,)
#        :mass_rate => Vector{Float64} of size (83,)
#        :rate => Vector{Float64} of size (83,)
#
#   states (Vector with 83 entries, reservoir variables for each state)
#     :Saturations => Matrix{Float64} of size (2, 192750)
#     :Pressure => Vector{Float64} of size (192750,)
#     :TotalMasses => Matrix{Float64} of size (2, 192750)
#
#   time (report time for each state)
#      Vector{Float64} of length 83
#
#   result (extended states, reports)
#      SimResult with 20 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 05 2024 14:06 after 6 minutes, 6 seconds, 398.1 milliseconds.

# %% [markdown]
# ## Plot the reservoir

# %%
plot_reservoir(case.model, key = :porosity)
# Out:
# Figure()

# %% [markdown]
# ## Plot the saturations

# %%
plot_reservoir(case.model, states, step = 10, key = :Saturations)
# Out:
# Figure()

# %% [markdown]
# ## Load reference and set up plotting

# %%
csv_path = joinpath(olympus_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response"; ylims = missing)
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
        if !ismissing(ylims)
            ylims!(ax, ylims)
        end
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "OPM Flow"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Plot water production rates

# %%
plot_well_comparison(:wrat, prod, "Water surface production rate")
# Out:
# Figure()

# %% [markdown]
# ## Plot oil production rates

# %%
plot_well_comparison(:orat, prod, "Oil surface production rate", ylims = (0, 5))
# Out:
# Figure()

# %% [markdown]
# ## Plot water injection rates

# %%
plot_well_comparison(:wrat, inj, "Water injection rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
