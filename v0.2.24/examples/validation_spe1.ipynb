# %% [markdown]
# # The SPE1 model (gas injection)
# [Odeh, A.S. 1981. Comparison of Solutions to a Three-Dimensional Black-Oil
# Reservoir Simulation Problem. J Pet Technol 33 (1): 13–25.
# SPE-9723-PA](http://dx.doi.org/10.2118/9723-PA)

# %%
using Jutul, JutulDarcy, GLMakie, DelimitedFiles
spe1_dir = JutulDarcy.GeoEnergyIO.test_input_file_path("SPE1")
case = setup_case_from_data_file(joinpath(spe1_dir, "SPE1.DATA"))
ws, states = simulate_reservoir(case, output_substates = true)
# Out:
# Simulating 9 years, 51.83 weeks as 120 report steps   2%  ETA: 0:00:06
#   Progress:  Solving step 2/120 (1.62% of time interval complete)
#   Stats:     22 iterations in 105.45 ms (4.79 ms each)
#
# Simulating 9 years, 51.83 weeks as 120 report steps  20%  ETA: 0:00:01
#   Progress:  Solving step 24/120 (20.00% of time interval complete)
#   Stats:     96 iterations in 206.28 ms (2.15 ms each)
#
# Simulating 9 years, 51.83 weeks as 120 report steps  38%  ETA: 0:00:01
#   Progress:  Solving step 46/120 (38.33% of time interval complete)
#   Stats:     170 iterations in 309.00 ms (1.82 ms each)
#
# Simulating 9 years, 51.83 weeks as 120 report steps  60%  ETA: 0:00:00
#   Progress:  Solving step 73/120 (60.85% of time interval complete)
#   Stats:     238 iterations in 410.84 ms (1.73 ms each)
#
# Simulating 9 years, 51.83 weeks as 120 report steps  83%  ETA: 0:00:00
#   Progress:  Solving step 100/120 (83.29% of time interval complete)
#   Stats:     303 iterations in 514.70 ms (1.70 ms each)
#
# Simulating 9 years, 51.83 weeks as 120 report steps 100% Time: 0:00:00
#   Progress:  Solved step 120/120
#   Stats:     351 iterations in 591.65 ms (1.69 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │ Time per │    Total │
# │                │ 120 steps │ 126 ministeps │       ms │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┼──────────┤
# │ Newton         │     2.925 │       2.78571 │   1.6856 │  351 (0) │
# │ Linearization  │     3.975 │       3.78571 │   1.2404 │  477 (0) │
# │ Linear solver  │   8.84167 │       8.42063 │   0.5576 │ 1061 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────┴──────────╯
# ╭────────────────┬────────┬────────────┬──────────╮
# │ Timing type    │   Each │   Relative │    Total │
# │                │     ms │ Percentage │       ms │
# ├────────────────┼────────┼────────────┼──────────┤
# │ Properties     │ 0.1095 │     6.49 % │  38.4262 │
# │ Equations      │ 0.1571 │    12.66 % │  74.9244 │
# │ Assembly       │ 0.0940 │     7.58 % │  44.8576 │
# │ Linear solve   │ 0.3799 │    22.54 % │ 133.3342 │
# │ Preconditioner │ 0.4008 │    23.78 % │ 140.6711 │
# │ Update         │ 0.0709 │     4.21 % │  24.8979 │
# │ Convergence    │ 0.0666 │     5.37 % │  31.7579 │
# │ Input/Output   │ 0.0259 │     0.55 % │   3.2600 │
# │ Other          │ 0.2835 │    16.82 % │  99.5215 │
# ├────────────────┼────────┼────────────┼──────────┤
# │ Total          │ 1.6856 │   100.00 % │ 591.6508 │
# ╰────────────────┴────────┴────────────┴──────────╯
# ReservoirSimResult with 126 entries:
#
#   wells (2 present):
#     :INJ
#     :PROD
#     Results per well:
#        :wrat => Vector{Float64} of size (126,)
#        :Aqueous_mass_rate => Vector{Float64} of size (126,)
#        :orat => Vector{Float64} of size (126,)
#        :bhp => Vector{Float64} of size (126,)
#        :lrat => Vector{Float64} of size (126,)
#        :mass_rate => Vector{Float64} of size (126,)
#        :rate => Vector{Float64} of size (126,)
#        :Vapor_mass_rate => Vector{Float64} of size (126,)
#        :control => Vector{Symbol} of size (126,)
#        :Liquid_mass_rate => Vector{Float64} of size (126,)
#        :grat => Vector{Float64} of size (126,)
#
#   states (Vector with 126 entries, reservoir variables for each state)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (300,)
#     :Saturations => Matrix{Float64} of size (3, 300)
#     :Pressure => Vector{Float64} of size (300,)
#     :Rs => Vector{Float64} of size (300,)
#     :ImmiscibleSaturation => Vector{Float64} of size (300,)
#     :TotalMasses => Matrix{Float64} of size (3, 300)
#
#   time (report time for each state)
#      Vector{Float64} of length 126
#
#   result (extended states, reports)
#      SimResult with 120 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 05 2024 14:06 after 588 milliseconds, 390 microseconds, 837 nanoseconds.

# %% [markdown]
# # Load reference

# %%
csv_path = joinpath(spe1_dir, "REFERENCE.CSV")
data, header = readdlm(csv_path, ',', header = true)
time_ref = data[:, 1]
time_jutul = deepcopy(ws.time)
wells = deepcopy(ws.wells)
wnames = collect(keys(wells))
nw = length(wnames)
day = si_unit(:day)
cmap = :tableau_hue_circle

inj = Symbol[]
prod = Symbol[]
for (wellname, well) in pairs(wells)
    qts = well[:wrat] + well[:orat] + well[:grat]
    if sum(qts) > 0
        push!(inj, wellname)
    else
        push!(prod, wellname)
    end
end

function plot_well_comparison(response, well_names, reponse_name = "$response")
    fig = Figure(size = (1000, 400))
    if response == :bhp
        ys = 1/si_unit(:bar)
        yl = "Bottom hole pressure / Bar"
    elseif response == :wrat
        ys = si_unit(:day)
        yl = "Surface water rate / m³/day"
    elseif response == :grat
        ys = si_unit(:day)/1e6
        yl = "Surface gas rate / 10⁶ m³/day"
    elseif response == :orat
        ys = si_unit(:day)/(1000*si_unit(:stb))
        yl = "Surface oil rate / 10³ stb/day"
    else
        error("$response not ready.")
    end
    welltypes = []
    ax = Axis(fig[1:4, 1], xlabel = "Time / days", ylabel = yl)
    i = 1
    linehandles = []
    linelabels = []
    for well_name in well_names
        well = wells[well_name]
        label_in_csv = "$well_name:$response"
        ref_pos = findfirst(x -> x == label_in_csv, vec(header))
        qoi = copy(well[response]).*ys
        qoi_ref = data[:, ref_pos].*ys
        tot_rate = copy(well[:rate])
        @. qoi[tot_rate == 0] = NaN
        grat_ref = data[:, findfirst(x -> x == "$well_name:grat", vec(header))]
        orat_ref = data[:, findfirst(x -> x == "$well_name:orat", vec(header))]
        wrat_ref = data[:, findfirst(x -> x == "$well_name:wrat", vec(header))]
        tot_rate_ref = grat_ref + orat_ref + wrat_ref
        @. qoi_ref[tot_rate_ref == 0] = NaN
        crange = (1, max(length(well_names), 2))
        lh = lines!(ax, time_jutul./day, abs.(qoi),
            color = i,
            colorrange = crange,
            label = "$well_name", colormap = cmap
        )
        push!(linehandles, lh)
        push!(linelabels, "$well_name")
        lines!(ax, time_ref./day, abs.(qoi_ref),
            color = i,
            colorrange = crange,
            linestyle = :dash,
            colormap = cmap
        )
        i += 1
    end
    l1 = LineElement(color = :black, linestyle = nothing)
    l2 = LineElement(color = :black, linestyle = :dash)

    Legend(fig[1:3, 2], linehandles, linelabels, nbanks = 3)
    Legend(fig[4, 2], [l1, l2], ["JutulDarcy.jl", "OPM Flow"])
    fig
end
# Out:
# plot_well_comparison (generic function with 2 methods)

# %% [markdown]
# ## Injector BHP

# %%
plot_well_comparison(:bhp, inj, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Producer BHP

# %%
plot_well_comparison(:bhp, prod, "Bottom hole pressure")
# Out:
# Figure()

# %% [markdown]
# ## Producer oil rate

# %%
plot_well_comparison(:orat, prod, "Oil surface rate")
# Out:
# Figure()

# %% [markdown]
# ## Producer gas rate

# %%
plot_well_comparison(:grat, prod, "Gas surface rate")
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
