# %% [markdown]
# # Simulating Eclipse/DATA input files
# The DATA format is commonly used in reservoir simulation. JutulDarcy can set
# up cases on this format and includes a fully featured grid builder for
# corner-point grids. Once a case has been set up, it uses the same types as a
# regular JutulDarcy simulation, allowing modification and use of the case in
# differentiable workflows.
#
# We begin by loading the SPE9 dataset via the GeoEnergyIO package.

# %%
using JutulDarcy
pth = JutulDarcy.GeoEnergyIO.test_input_file_path("SPE9", "SPE9.DATA")
# Out:
# "/home/runner/.julia/artifacts/c1063fdc96b21cbc18ea8a3bd1a1281aa04ffa3f/SPE9.DATA"

# %% [markdown]
# ## Set up and run a simulation
# If we do not need the case, we could also have done:
# ws, states = simulate_data_file(pth)

# %%
case = setup_case_from_data_file(pth)
ws, states = simulate_reservoir(case)
# Out:
# Simulating 2 years, 24.22 weeks as 90 report steps   2%| |  ETA: 0:02:17
#   Progress:  Solving step 2/90 (2.22% of time interval complete)
#   Stats:     19 iterations in 2.58 s (135.70 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   3%| |  ETA: 0:01:35
#   Progress:  Solving step 3/90 (3.33% of time interval complete)
#   Stats:     25 iterations in 2.75 s (110.09 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   4%| |  ETA: 0:01:13
#   Progress:  Solving step 4/90 (4.44% of time interval complete)
#   Stats:     29 iterations in 2.87 s (99.07 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   5%| |  ETA: 0:01:00
#   Progress:  Solving step 5/90 (5.56% of time interval complete)
#   Stats:     33 iterations in 2.99 s (90.65 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   8%|▏|  ETA: 0:00:44
#   Progress:  Solving step 7/90 (7.78% of time interval complete)
#   Stats:     39 iterations in 3.17 s (81.27 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps   9%|▏|  ETA: 0:00:39
#   Progress:  Solving step 8/90 (8.89% of time interval complete)
#   Stats:     43 iterations in 3.29 s (76.54 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  11%|▏|  ETA: 0:00:33
#   Progress:  Solving step 10/90 (11.11% of time interval complete)
#   Stats:     51 iterations in 3.53 s (69.24 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  13%|▏|  ETA: 0:00:28
#   Progress:  Solving step 12/90 (13.33% of time interval complete)
#   Stats:     57 iterations in 3.72 s (65.27 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  14%|▏|  ETA: 0:00:26
#   Progress:  Solving step 13/90 (14.44% of time interval complete)
#   Stats:     61 iterations in 3.87 s (63.40 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  15%|▏|  ETA: 0:00:25
#   Progress:  Solving step 14/90 (15.56% of time interval complete)
#   Stats:     66 iterations in 4.02 s (60.86 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  18%|▏|  ETA: 0:00:22
#   Progress:  Solving step 16/90 (17.78% of time interval complete)
#   Stats:     72 iterations in 4.20 s (58.34 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  20%|▎|  ETA: 0:00:20
#   Progress:  Solving step 18/90 (20.00% of time interval complete)
#   Stats:     78 iterations in 4.39 s (56.30 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  22%|▎|  ETA: 0:00:18
#   Progress:  Solving step 20/90 (22.22% of time interval complete)
#   Stats:     84 iterations in 4.58 s (54.52 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  24%|▎|  ETA: 0:00:17
#   Progress:  Solving step 22/90 (24.44% of time interval complete)
#   Stats:     90 iterations in 4.76 s (52.90 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  26%|▎|  ETA: 0:00:15
#   Progress:  Solving step 24/90 (26.67% of time interval complete)
#   Stats:     96 iterations in 4.94 s (51.51 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  29%|▎|  ETA: 0:00:14
#   Progress:  Solving step 26/90 (28.89% of time interval complete)
#   Stats:     102 iterations in 5.13 s (50.28 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  31%|▎|  ETA: 0:00:13
#   Progress:  Solving step 28/90 (31.11% of time interval complete)
#   Stats:     108 iterations in 5.31 s (49.18 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  33%|▍|  ETA: 0:00:12
#   Progress:  Solving step 30/90 (33.33% of time interval complete)
#   Stats:     114 iterations in 5.52 s (48.43 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  35%|▍|  ETA: 0:00:12
#   Progress:  Solving step 32/90 (35.56% of time interval complete)
#   Stats:     125 iterations in 5.86 s (46.84 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  36%|▍|  ETA: 0:00:11
#   Progress:  Solving step 33/90 (36.67% of time interval complete)
#   Stats:     130 iterations in 6.01 s (46.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  37%|▍|  ETA: 0:00:11
#   Progress:  Solving step 34/90 (37.78% of time interval complete)
#   Stats:     134 iterations in 6.13 s (45.75 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  38%|▍|  ETA: 0:00:11
#   Progress:  Solving step 35/90 (38.89% of time interval complete)
#   Stats:     139 iterations in 6.28 s (45.19 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  40%|▍|  ETA: 0:00:11
#   Progress:  Solving step 36/90 (40.00% of time interval complete)
#   Stats:     144 iterations in 6.43 s (44.67 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  41%|▍|  ETA: 0:00:10
#   Progress:  Solving step 37/90 (41.11% of time interval complete)
#   Stats:     150 iterations in 6.61 s (44.07 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  42%|▍|  ETA: 0:00:10
#   Progress:  Solving step 38/90 (42.22% of time interval complete)
#   Stats:     159 iterations in 6.88 s (43.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  43%|▍|  ETA: 0:00:10
#   Progress:  Solving step 39/90 (43.33% of time interval complete)
#   Stats:     164 iterations in 7.03 s (42.86 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  44%|▌|  ETA: 0:00:10
#   Progress:  Solving step 40/90 (44.44% of time interval complete)
#   Stats:     175 iterations in 7.35 s (42.01 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  45%|▌|  ETA: 0:00:10
#   Progress:  Solving step 41/90 (45.56% of time interval complete)
#   Stats:     179 iterations in 7.50 s (41.88 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  46%|▌|  ETA: 0:00:10
#   Progress:  Solving step 42/90 (46.67% of time interval complete)
#   Stats:     184 iterations in 7.65 s (41.57 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  47%|▌|  ETA: 0:00:09
#   Progress:  Solving step 43/90 (47.78% of time interval complete)
#   Stats:     188 iterations in 7.77 s (41.33 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  49%|▌|  ETA: 0:00:09
#   Progress:  Solving step 45/90 (50.00% of time interval complete)
#   Stats:     194 iterations in 7.96 s (41.04 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  52%|▌|  ETA: 0:00:08
#   Progress:  Solving step 47/90 (52.22% of time interval complete)
#   Stats:     200 iterations in 8.14 s (40.71 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  53%|▌|  ETA: 0:00:08
#   Progress:  Solving step 48/90 (53.33% of time interval complete)
#   Stats:     204 iterations in 8.27 s (40.53 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  55%|▌|  ETA: 0:00:07
#   Progress:  Solving step 50/90 (55.56% of time interval complete)
#   Stats:     209 iterations in 8.43 s (40.31 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  57%|▋|  ETA: 0:00:07
#   Progress:  Solving step 52/90 (57.78% of time interval complete)
#   Stats:     214 iterations in 8.58 s (40.10 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  58%|▋|  ETA: 0:00:07
#   Progress:  Solving step 53/90 (58.89% of time interval complete)
#   Stats:     218 iterations in 8.70 s (39.89 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  60%|▋|  ETA: 0:00:06
#   Progress:  Solving step 55/90 (61.11% of time interval complete)
#   Stats:     222 iterations in 8.82 s (39.73 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  63%|▋|  ETA: 0:00:06
#   Progress:  Solving step 57/90 (63.33% of time interval complete)
#   Stats:     227 iterations in 8.97 s (39.53 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  65%|▋|  ETA: 0:00:05
#   Progress:  Solving step 59/90 (65.56% of time interval complete)
#   Stats:     231 iterations in 9.10 s (39.40 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  67%|▋|  ETA: 0:00:05
#   Progress:  Solving step 61/90 (67.78% of time interval complete)
#   Stats:     237 iterations in 9.31 s (39.26 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  69%|▊|  ETA: 0:00:04
#   Progress:  Solving step 63/90 (70.00% of time interval complete)
#   Stats:     242 iterations in 9.46 s (39.09 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  71%|▊|  ETA: 0:00:04
#   Progress:  Solving step 65/90 (72.22% of time interval complete)
#   Stats:     247 iterations in 9.61 s (38.91 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  74%|▊|  ETA: 0:00:04
#   Progress:  Solving step 67/90 (74.44% of time interval complete)
#   Stats:     252 iterations in 9.77 s (38.76 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  76%|▊|  ETA: 0:00:03
#   Progress:  Solving step 69/90 (76.67% of time interval complete)
#   Stats:     257 iterations in 9.92 s (38.60 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  78%|▊|  ETA: 0:00:03
#   Progress:  Solving step 71/90 (78.89% of time interval complete)
#   Stats:     262 iterations in 10.07 s (38.44 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  80%|▊|  ETA: 0:00:03
#   Progress:  Solving step 73/90 (81.11% of time interval complete)
#   Stats:     266 iterations in 10.19 s (38.32 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  82%|▉|  ETA: 0:00:02
#   Progress:  Solving step 75/90 (83.33% of time interval complete)
#   Stats:     270 iterations in 10.32 s (38.21 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  85%|▉|  ETA: 0:00:02
#   Progress:  Solving step 77/90 (85.56% of time interval complete)
#   Stats:     275 iterations in 10.47 s (38.08 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  87%|▉|  ETA: 0:00:02
#   Progress:  Solving step 79/90 (87.78% of time interval complete)
#   Stats:     279 iterations in 10.59 s (37.97 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  89%|▉|  ETA: 0:00:01
#   Progress:  Solving step 81/90 (90.00% of time interval complete)
#   Stats:     283 iterations in 10.71 s (37.86 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  91%|▉|  ETA: 0:00:01
#   Progress:  Solving step 83/90 (92.22% of time interval complete)
#   Stats:     289 iterations in 10.90 s (37.71 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  92%|▉|  ETA: 0:00:01
#   Progress:  Solving step 84/90 (93.33% of time interval complete)
#   Stats:     291 iterations in 11.05 s (37.97 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  95%|█|  ETA: 0:00:01
#   Progress:  Solving step 86/90 (95.56% of time interval complete)
#   Stats:     295 iterations in 11.18 s (37.88 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  97%|█|  ETA: 0:00:00
#   Progress:  Solving step 88/90 (97.78% of time interval complete)
#   Stats:     299 iterations in 11.30 s (37.79 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps  99%|█|  ETA: 0:00:00
#   Progress:  Solving step 90/90 (100.00% of time interval complete)
#   Stats:     303 iterations in 11.43 s (37.71 ms each)
#
# Simulating 2 years, 24.22 weeks as 90 report steps 100%|█| Time: 0:00:12
#   Progress:  Solved step 90/90
#   Stats:     305 iterations in 11.49 s (37.67 ms each)
# ╭────────────────┬──────────┬──────────────┬──────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │ Time per │    Total │
# │                │ 90 steps │ 96 ministeps │       ms │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┼──────────┤
# │ Newton         │  3.38889 │      3.17708 │  37.6748 │  305 (0) │
# │ Linearization  │  4.45556 │      4.17708 │  28.6554 │  401 (0) │
# │ Linear solver  │  12.4889 │      11.7083 │  10.2232 │ 1124 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │  2.5504 │     6.77 % │  0.7779 │
# │ Equations      │  5.3629 │    18.72 % │  2.1505 │
# │ Assembly       │  2.7592 │     9.63 % │  1.1065 │
# │ Linear solve   │ 10.5887 │    28.11 % │  3.2296 │
# │ Preconditioner │ 10.5818 │    28.09 % │  3.2275 │
# │ Update         │  1.2175 │     3.23 % │  0.3713 │
# │ Convergence    │  0.5319 │     1.86 % │  0.2133 │
# │ Input/Output   │  0.2855 │     0.24 % │  0.0274 │
# │ Other          │  1.2686 │     3.37 % │  0.3869 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 37.6748 │   100.00 % │ 11.4908 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 90 entries:
#
#   wells (26 present):
#     :INJE1
#     :PRODU25
#     :PRODU16
#     :PRODU20
#     :PRODU10
#     :PRODU12
#     :PRODU22
#     :PRODU14
#     :PRODU6
#     :PRODU7
#     :PRODU9
#     :PRODU24
#     :PRODU3
#     :PRODU23
#     :PRODU5
#     :PRODU11
#     :PRODU17
#     :PRODU4
#     :PRODU15
#     :PRODU2
#     :PRODU19
#     :PRODU21
#     :PRODU13
#     :PRODU8
#     :PRODU26
#     :PRODU18
#     Results per well:
#        :wrat => Vector{Float64} of size (90,)
#        :Aqueous_mass_rate => Vector{Float64} of size (90,)
#        :orat => Vector{Float64} of size (90,)
#        :bhp => Vector{Float64} of size (90,)
#        :lrat => Vector{Float64} of size (90,)
#        :mass_rate => Vector{Float64} of size (90,)
#        :rate => Vector{Float64} of size (90,)
#        :Vapor_mass_rate => Vector{Float64} of size (90,)
#        :control => Vector{Symbol} of size (90,)
#        :Liquid_mass_rate => Vector{Float64} of size (90,)
#        :grat => Vector{Float64} of size (90,)
#
#   states (Vector with 90 entries, reservoir variables for each state)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (9000,)
#     :Saturations => Matrix{Float64} of size (3, 9000)
#     :Pressure => Vector{Float64} of size (9000,)
#     :Rs => Vector{Float64} of size (9000,)
#     :ImmiscibleSaturation => Vector{Float64} of size (9000,)
#     :TotalMasses => Matrix{Float64} of size (3, 9000)
#
#   time (report time for each state)
#      Vector{Float64} of length 90
#
#   result (extended states, reports)
#      SimResult with 90 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Jun. 05 2024 14:06 after 11 seconds, 463 milliseconds, 420.1 microseconds.

# %% [markdown]
# ## Show the input data
# The input data takes the form of a Dict:

# %%
case.input_data
# Out:
# Dict{String, Any} with 6 entries:
#   "RUNSPEC"  => OrderedDict{String, Any}("TITLE"=>"SPE 9", "DIMENS"=>[24, 25, 1…
#   "GRID"     => OrderedDict{String, Any}("cartDims"=>(24, 25, 15), "CURRENT_BOX…
#   "PROPS"    => OrderedDict{String, Any}("PVTW"=>Any[[2.48211e7, 1.0034, 4.3511…
#   "SUMMARY"  => OrderedDict{String, Any}()
#   "SCHEDULE" => Dict{String, Any}("STEPS"=>OrderedDict{String, Any}[OrderedDict…
#   "SOLUTION" => OrderedDict{String, Any}("EQUIL"=>Any[[2753.87, 2.48211e7, 3032…

# %% [markdown]
# We can also examine the RUNSPEC section

# %%
case.input_data["RUNSPEC"]
# Out:
# OrderedCollections.OrderedDict{String, Any} with 13 entries:
#   "TITLE"    => "SPE 9"
#   "DIMENS"   => [24, 25, 15]
#   "OIL"      => true
#   "WATER"    => true
#   "GAS"      => true
#   "DISGAS"   => true
#   "FIELD"    => true
#   "START"    => DateTime("2015-01-01T00:00:00")
#   "WELLDIMS" => [26, 5, 1, 26, 5, 10, 5, 4, 3, 0, 1, 1, 10, 201]
#   "TABDIMS"  => [1, 1, 40, 20, 1, 20, 20, 1, 1, -1  …  -1, 10, 10, 10, -1, 5, 5…
#   "EQLDIMS"  => [1, 100, 50, 1, 50]
#   "UNIFIN"   => true
#   "UNIFOUT"  => true

# %% [markdown]
# ## Plot the simulation model
# These plot are interactive when run outside of the documentations.

# %%
using GLMakie
plot_reservoir(case.model, states)
# Out:
# Figure()

# %% [markdown]
# ## Plot the well responses

# %%
plot_well_results(ws)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
