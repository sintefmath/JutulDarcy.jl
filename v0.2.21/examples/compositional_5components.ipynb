# %% [markdown]
# # A more complex compositional model
# This example sets up a more complex compositional simulation with five
# different components. Other than that, the example is similar to the others
# that include wells and is therefore not commented in great detail.

# %%
using MultiComponentFlash

n2_ch4 = MolecularProperty(0.0161594, 4.58e6, 189.515, 9.9701e-05, 0.00854)
co2 = MolecularProperty(0.04401, 7.3866e6, 304.200, 9.2634e-05, 0.228)
c2_5 = MolecularProperty(0.0455725, 4.0955e6, 387.607, 2.1708e-04, 0.16733)
c6_13 = MolecularProperty(0.117740, 3.345e6, 597.497, 3.8116e-04, 0.38609)
c14_24 = MolecularProperty(0.248827, 1.768e6, 698.515, 7.2141e-04, 0.80784)

bic = [0.11883 0.00070981 0.00077754 0.01 0.011;
       0.00070981 0.15 0.15 0.15 0.15;
       0.00077754 0.15 0 0 0;
       0.01 0.15 0 0 0;
       0.011 0.15 0 0 0]

mixture = MultiComponentMixture([n2_ch4, co2, c2_5, c6_13, c14_24], A_ij = bic, names = ["N2-CH4", "CO2", "C2-5", "C6-13", "C14-24"])
eos = GenericCubicEOS(mixture, PengRobinson())

using Jutul, JutulDarcy, GLMakie
Darcy, bar, kg, meter, Kelvin, day = si_units(:darcy, :bar, :kilogram, :meter, :Kelvin, :day)
nx = ny = 20
nz = 2

dims = (nx, ny, nz)
g = CartesianMesh(dims, (1000.0, 1000.0, 1.0))
nc = number_of_cells(g)
K = repeat([0.05*Darcy], 1, nc)
res = reservoir_domain(g, porosity = 0.25, permeability = K)
# Out:
# DataDomain wrapping CartesianMesh (3D) with 20x20x2=800 cells with 17 data fields added:
#   800 Cells
#     :permeability => 1×800 Matrix{Float64}
#     :porosity => 800 Vector{Float64}
#     :rock_thermal_conductivity => 800 Vector{Float64}
#     :fluid_thermal_conductivity => 800 Vector{Float64}
#     :rock_density => 800 Vector{Float64}
#     :cell_centroids => 3×800 Matrix{Float64}
#     :volumes => 800 Vector{Float64}
#   1920 Faces
#     :neighbors => 2×1920 Matrix{Int64}
#     :areas => 1920 Vector{Float64}
#     :normals => 3×1920 Matrix{Float64}
#     :face_centroids => 3×1920 Matrix{Float64}
#   3840 HalfFaces
#     :half_face_cells => 3840 Vector{Int64}
#     :half_face_faces => 3840 Vector{Int64}
#   960 BoundaryFaces
#     :boundary_areas => 960 Vector{Float64}
#     :boundary_centroids => 3×960 Matrix{Float64}
#     :boundary_normals => 3×960 Matrix{Float64}
#     :boundary_neighbors => 960 Vector{Int64}

# %% [markdown]
# Set up a vertical well in the first corner, perforated in all layers

# %%
prod = setup_vertical_well(g, K, nx, ny, name = :Producer)
# Out:
# MultiSegmentWell [Producer] (3 nodes, 2 segments, 2 perforations)

# %% [markdown]
# Set up an injector in the opposite corner, perforated in all layers

# %%
inj = setup_vertical_well(g, K, 1, 1, name = :Injector)

rhoLS = 1000.0*kg/meter^3
rhoVS = 100.0*kg/meter^3

rhoS = [rhoLS, rhoVS]
L, V = LiquidPhase(), VaporPhase()
# Out:
# (LiquidPhase(), VaporPhase())

# %% [markdown]
# Define system and realize on grid

# %%
sys = MultiPhaseCompositionalSystemLV(eos, (L, V))
model, parameters = setup_reservoir_model(res, sys, wells = [inj, prod], reference_densities = rhoS, block_backend = true);
kr = BrooksCoreyRelativePermeabilities(sys, 2.0, 0.0, 1.0)
model = replace_variables!(model, RelativePermeabilities = kr)

push!(model[:Reservoir].output_variables, :Saturations)

parameters[:Reservoir][:Temperature] = 387.45*Kelvin
state0 = setup_reservoir_state(model, Pressure = 225*bar, OverallMoleFractions = [0.463, 0.01640, 0.20520, 0.19108, 0.12432]);

dt = repeat([2.0]*day, 365)
rate_target = TotalRateTarget(0.0015)
I_ctrl = InjectorControl(rate_target, [0, 1, 0, 0, 0], density = rhoVS)
bhp_target = BottomHolePressureTarget(100*bar)
P_ctrl = ProducerControl(bhp_target)

controls = Dict()
controls[:Injector] = I_ctrl
controls[:Producer] = P_ctrl
forces = setup_reservoir_forces(model, control = controls)
ws, states = simulate_reservoir(state0, model, dt, parameters = parameters, forces = forces)
# Out:
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps   1%  ETA: 0:59:07
#   Progress:  Solving step 2/365 (0.55% of time interval complete)
#   Stats:     8 iterations in 14.13 s (1.77 s each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps   2%  ETA: 0:13:14
#   Progress:  Solving step 9/365 (2.47% of time interval complete)
#   Stats:     33 iterations in 14.67 s (444.49 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps   5%  ETA: 0:05:56
#   Progress:  Solving step 20/365 (5.48% of time interval complete)
#   Stats:     57 iterations in 15.20 s (266.68 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps   8%  ETA: 0:04:05
#   Progress:  Solving step 29/365 (7.95% of time interval complete)
#   Stats:     75 iterations in 15.74 s (209.88 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  10%  ETA: 0:03:12
#   Progress:  Solving step 37/365 (10.14% of time interval complete)
#   Stats:     91 iterations in 16.24 s (178.48 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  12%  ETA: 0:02:38
#   Progress:  Solving step 45/365 (12.33% of time interval complete)
#   Stats:     107 iterations in 16.76 s (156.67 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  14%  ETA: 0:02:14
#   Progress:  Solving step 53/365 (14.52% of time interval complete)
#   Stats:     123 iterations in 17.29 s (140.57 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  17%  ETA: 0:01:56
#   Progress:  Solving step 61/365 (16.71% of time interval complete)
#   Stats:     139 iterations in 17.81 s (128.16 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  19%  ETA: 0:01:42
#   Progress:  Solving step 69/365 (18.90% of time interval complete)
#   Stats:     155 iterations in 18.34 s (118.29 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  21%  ETA: 0:01:31
#   Progress:  Solving step 77/365 (21.10% of time interval complete)
#   Stats:     171 iterations in 18.85 s (110.25 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  23%  ETA: 0:01:22
#   Progress:  Solving step 85/365 (23.29% of time interval complete)
#   Stats:     187 iterations in 19.37 s (103.58 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  25%  ETA: 0:01:14
#   Progress:  Solving step 93/365 (25.48% of time interval complete)
#   Stats:     203 iterations in 19.89 s (97.96 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  28%  ETA: 0:01:08
#   Progress:  Solving step 101/365 (27.67% of time interval complete)
#   Stats:     219 iterations in 20.40 s (93.16 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  30%  ETA: 0:01:02
#   Progress:  Solving step 109/365 (29.86% of time interval complete)
#   Stats:     235 iterations in 20.92 s (89.02 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  34%  ETA: 0:00:52
#   Progress:  Solving step 124/365 (33.97% of time interval complete)
#   Stats:     250 iterations in 21.42 s (85.68 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  38%  ETA: 0:00:45
#   Progress:  Solving step 139/365 (38.08% of time interval complete)
#   Stats:     265 iterations in 21.93 s (82.74 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  42%  ETA: 0:00:38
#   Progress:  Solving step 154/365 (42.19% of time interval complete)
#   Stats:     280 iterations in 22.43 s (80.10 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  46%  ETA: 0:00:33
#   Progress:  Solving step 169/365 (46.30% of time interval complete)
#   Stats:     295 iterations in 22.93 s (77.74 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  50%  ETA: 0:00:29
#   Progress:  Solving step 184/365 (50.41% of time interval complete)
#   Stats:     310 iterations in 23.45 s (75.65 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  54%  ETA: 0:00:25
#   Progress:  Solving step 198/365 (54.25% of time interval complete)
#   Stats:     335 iterations in 24.33 s (72.64 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  56%  ETA: 0:00:24
#   Progress:  Solving step 206/365 (56.44% of time interval complete)
#   Stats:     351 iterations in 24.90 s (70.95 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  58%  ETA: 0:00:22
#   Progress:  Solving step 213/365 (58.36% of time interval complete)
#   Stats:     365 iterations in 25.42 s (69.64 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  60%  ETA: 0:00:21
#   Progress:  Solving step 220/365 (60.27% of time interval complete)
#   Stats:     379 iterations in 25.97 s (68.53 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  62%  ETA: 0:00:20
#   Progress:  Solving step 226/365 (61.92% of time interval complete)
#   Stats:     391 iterations in 26.48 s (67.73 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  63%  ETA: 0:00:19
#   Progress:  Solving step 232/365 (63.56% of time interval complete)
#   Stats:     403 iterations in 27.05 s (67.13 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  65%  ETA: 0:00:18
#   Progress:  Solving step 237/365 (64.93% of time interval complete)
#   Stats:     413 iterations in 27.57 s (66.76 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  66%  ETA: 0:00:17
#   Progress:  Solving step 242/365 (66.30% of time interval complete)
#   Stats:     423 iterations in 28.12 s (66.48 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  67%  ETA: 0:00:16
#   Progress:  Solving step 247/365 (67.67% of time interval complete)
#   Stats:     433 iterations in 28.67 s (66.22 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  69%  ETA: 0:00:16
#   Progress:  Solving step 252/365 (69.04% of time interval complete)
#   Stats:     443 iterations in 29.22 s (65.96 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  70%  ETA: 0:00:15
#   Progress:  Solving step 257/365 (70.41% of time interval complete)
#   Stats:     453 iterations in 29.72 s (65.62 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  72%  ETA: 0:00:14
#   Progress:  Solving step 263/365 (72.05% of time interval complete)
#   Stats:     465 iterations in 30.28 s (65.12 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  73%  ETA: 0:00:13
#   Progress:  Solving step 269/365 (73.70% of time interval complete)
#   Stats:     477 iterations in 30.78 s (64.54 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  75%  ETA: 0:00:12
#   Progress:  Solving step 276/365 (75.62% of time interval complete)
#   Stats:     491 iterations in 31.34 s (63.83 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  77%  ETA: 0:00:11
#   Progress:  Solving step 283/365 (77.53% of time interval complete)
#   Stats:     505 iterations in 31.87 s (63.10 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  79%  ETA: 0:00:10
#   Progress:  Solving step 290/365 (79.45% of time interval complete)
#   Stats:     519 iterations in 32.39 s (62.40 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  81%  ETA: 0:00:09
#   Progress:  Solving step 298/365 (81.64% of time interval complete)
#   Stats:     535 iterations in 32.95 s (61.59 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  84%  ETA: 0:00:08
#   Progress:  Solving step 306/365 (83.84% of time interval complete)
#   Stats:     551 iterations in 33.50 s (60.80 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  86%  ETA: 0:00:07
#   Progress:  Solving step 314/365 (86.03% of time interval complete)
#   Stats:     567 iterations in 34.04 s (60.03 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  88%  ETA: 0:00:05
#   Progress:  Solving step 322/365 (88.22% of time interval complete)
#   Stats:     583 iterations in 34.57 s (59.30 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  90%  ETA: 0:00:04
#   Progress:  Solving step 330/365 (90.41% of time interval complete)
#   Stats:     599 iterations in 35.09 s (58.58 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  92%  ETA: 0:00:03
#   Progress:  Solving step 338/365 (92.60% of time interval complete)
#   Stats:     615 iterations in 35.60 s (57.89 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  95%  ETA: 0:00:02
#   Progress:  Solving step 346/365 (94.79% of time interval complete)
#   Stats:     631 iterations in 36.12 s (57.24 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  97%  ETA: 0:00:01
#   Progress:  Solving step 354/365 (96.99% of time interval complete)
#   Stats:     647 iterations in 36.63 s (56.61 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps  99%  ETA: 0:00:00
#   Progress:  Solving step 363/365 (99.45% of time interval complete)
#   Stats:     665 iterations in 37.19 s (55.92 ms each)
#
# Simulating 1 year, 52 weeks, 18.18 hours as 365 report steps 100% Time: 0:00:42
#   Progress:  Solved step 365/365
#   Stats:     671 iterations in 37.39 s (55.72 ms each)
# ╭────────────────┬───────────┬───────────────┬──────────┬──────────╮
# │ Iteration type │  Avg/step │  Avg/ministep │ Time per │    Total │
# │                │ 365 steps │ 367 ministeps │       ms │ (wasted) │
# ├────────────────┼───────────┼───────────────┼──────────┼──────────┤
# │ Newton         │   1.83836 │       1.82834 │  55.7180 │  671 (0) │
# │ Linearization  │   2.84384 │       2.82834 │  36.0181 │ 1038 (0) │
# │ Linear solver  │   4.83836 │       4.81199 │  21.1703 │ 1766 (0) │
# ╰────────────────┴───────────┴───────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │ 28.5526 │    51.24 % │ 19.1588 │
# │ Equations      │  5.0321 │    13.97 % │  5.2233 │
# │ Assembly       │  3.8933 │    10.81 % │  4.0413 │
# │ Linear solve   │  5.7855 │    10.38 % │  3.8821 │
# │ Preconditioner │  2.7329 │     4.90 % │  1.8338 │
# │ Update         │  1.2548 │     2.25 % │  0.8419 │
# │ Convergence    │  1.4012 │     3.89 % │  1.4544 │
# │ Input/Output   │  0.1327 │     0.13 % │  0.0487 │
# │ Other          │  1.3449 │     2.41 % │  0.9024 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 55.7180 │   100.00 % │ 37.3868 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 365 entries:
#
#   wells (2 present):
#     :Producer
#     :Injector
#     Results per well:
#        :lrat => Vector{Float64} of size (365,)
#        :orat => Vector{Float64} of size (365,)
#        :control => Vector{Symbol} of size (365,)
#        :bhp => Vector{Float64} of size (365,)
#        :mass_rate => Vector{Float64} of size (365,)
#        :rate => Vector{Float64} of size (365,)
#        :grat => Vector{Float64} of size (365,)
#
#   states (Vector with 365 entries, reservoir variables for each state)
#     :LiquidMassFractions => Matrix{Float64} of size (5, 800)
#     :OverallMoleFractions => Matrix{Float64} of size (5, 800)
#     :Saturations => Matrix{Float64} of size (2, 800)
#     :Pressure => Vector{Float64} of size (800,)
#     :VaporMassFractions => Matrix{Float64} of size (5, 800)
#     :TotalMasses => Matrix{Float64} of size (5, 800)
#
#   time (report time for each state)
#      Vector{Float64} of length 365
#
#   result (extended states, reports)
#      SimResult with 365 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Apr. 12 2024 13:04 after 37 seconds, 338 milliseconds, 48 microseconds.

# %% [markdown]
# ## Once the simulation is done, we can plot the states
# ### CO2 mole fraction

# %%
sg = states[end][:OverallMoleFractions][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Gas saturation

# %%
sg = states[end][:Saturations][2, :]
fig, ax, p = plot_cell_data(g, sg)
fig
# Out:
# Figure()

# %% [markdown]
# ### Pressure

# %%
p = states[end][:Pressure]
fig, ax, p = plot_cell_data(g, p)
fig
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
