# %% [markdown]
# # Simulating Eclipse/DATA input files
# The DATA format is commonly used in reservoir simulation. JutulDarcy can set
# up cases on this format and includes a fully featured grid builder for
# corner-point grids. Once a case has been set up, it uses the same types as a
# regular JutulDarcy simulation, allowing modification and use of the case in
# differentiable workflows.
#
# We begin by loading the SPE9 dataset via the GeoEnergyIO package.

# %%
using JutulDarcy
pth = JutulDarcy.GeoEnergyIO.test_input_file_path("spe9", "SPE9_CP.DATA", base = "opm-tests")
# Out:
# "/home/runner/.julia/packages/GeoEnergyIO/63GkJ/src/../test/data/opm-tests/spe9/SPE9_CP.DATA"

# %% [markdown]
# ## Set up and run a simulation
# If we do not need the case, we could also have done:
# ws, states = simulate_data_file(pth)

# %%
case = setup_case_from_data_file(pth)
ws, states = simulate_reservoir(case)
# Out:
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps   2%  ETA: 0:04:47
#   Progress:  Solving step 2/90 (2.22% of time interval complete)
#   Stats:     18 iterations in 5.10 s (283.60 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps   4%  ETA: 0:02:32
#   Progress:  Solving step 4/90 (4.44% of time interval complete)
#   Stats:     28 iterations in 5.62 s (200.88 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps   9%  ETA: 0:01:18
#   Progress:  Solving step 8/90 (8.89% of time interval complete)
#   Stats:     43 iterations in 6.13 s (142.64 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  13%  ETA: 0:00:53
#   Progress:  Solving step 12/90 (13.33% of time interval complete)
#   Stats:     57 iterations in 6.65 s (116.66 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  19%  ETA: 0:00:37
#   Progress:  Solving step 17/90 (18.89% of time interval complete)
#   Stats:     75 iterations in 7.24 s (96.59 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  24%  ETA: 0:00:29
#   Progress:  Solving step 22/90 (24.44% of time interval complete)
#   Stats:     90 iterations in 7.75 s (86.13 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  30%  ETA: 0:00:23
#   Progress:  Solving step 27/90 (30.00% of time interval complete)
#   Stats:     105 iterations in 8.30 s (79.03 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  35%  ETA: 0:00:19
#   Progress:  Solving step 32/90 (35.56% of time interval complete)
#   Stats:     125 iterations in 9.02 s (72.13 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  38%  ETA: 0:00:18
#   Progress:  Solving step 35/90 (38.89% of time interval complete)
#   Stats:     142 iterations in 9.62 s (67.76 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  42%  ETA: 0:00:16
#   Progress:  Solving step 38/90 (42.22% of time interval complete)
#   Stats:     164 iterations in 10.40 s (63.41 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  44%  ETA: 0:00:16
#   Progress:  Solving step 40/90 (44.44% of time interval complete)
#   Stats:     178 iterations in 10.91 s (61.27 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  47%  ETA: 0:00:14
#   Progress:  Solving step 43/90 (47.78% of time interval complete)
#   Stats:     194 iterations in 11.44 s (58.97 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  53%  ETA: 0:00:12
#   Progress:  Solving step 48/90 (53.33% of time interval complete)
#   Stats:     209 iterations in 11.99 s (57.35 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  58%  ETA: 0:00:10
#   Progress:  Solving step 53/90 (58.89% of time interval complete)
#   Stats:     224 iterations in 12.50 s (55.80 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  64%  ETA: 0:00:08
#   Progress:  Solving step 58/90 (64.44% of time interval complete)
#   Stats:     239 iterations in 13.03 s (54.51 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  71%  ETA: 0:00:06
#   Progress:  Solving step 65/90 (72.22% of time interval complete)
#   Stats:     254 iterations in 13.53 s (53.27 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  80%  ETA: 0:00:04
#   Progress:  Solving step 73/90 (81.11% of time interval complete)
#   Stats:     270 iterations in 14.07 s (52.11 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  88%  ETA: 0:00:02
#   Progress:  Solving step 80/90 (88.89% of time interval complete)
#   Stats:     285 iterations in 14.58 s (51.16 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  97%  ETA: 0:00:01
#   Progress:  Solving step 88/90 (97.78% of time interval complete)
#   Stats:     302 iterations in 15.13 s (50.11 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps 100% Time: 0:00:16
#   Progress:  Solved step 90/90
#   Stats:     308 iterations in 15.32 s (49.75 ms each)
# ╭────────────────┬──────────┬──────────────┬──────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │ Time per │    Total │
# │                │ 90 steps │ 98 ministeps │       ms │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┼──────────┤
# │ Newton         │  3.42222 │      3.14286 │  49.7515 │  308 (0) │
# │ Linearization  │  4.51111 │      4.14286 │  37.7425 │  406 (0) │
# │ Linear solver  │  17.5556 │      16.1224 │   9.6984 │ 1580 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │  2.5138 │     5.05 % │  0.7742 │
# │ Equations      │  9.1126 │    24.14 % │  3.6997 │
# │ Assembly       │  3.1683 │     8.39 % │  1.2863 │
# │ Linear solve   │ 13.7961 │    27.73 % │  4.2492 │
# │ Preconditioner │ 10.9773 │    22.06 % │  3.3810 │
# │ Update         │  2.2071 │     4.44 % │  0.6798 │
# │ Convergence    │  1.6095 │     4.26 % │  0.6535 │
# │ Input/Output   │  0.4284 │     0.27 % │  0.0420 │
# │ Other          │  1.8108 │     3.64 % │  0.5577 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 49.7515 │   100.00 % │ 15.3235 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 90 entries:
#
#   wells (26 present):
#     :INJE1
#     :PRODU25
#     :PRODU16
#     :PRODU20
#     :PRODU10
#     :PRODU12
#     :PRODU22
#     :PRODU14
#     :PRODU6
#     :PRODU7
#     :PRODU9
#     :PRODU24
#     :PRODU3
#     :PRODU23
#     :PRODU5
#     :PRODU11
#     :PRODU17
#     :PRODU4
#     :PRODU15
#     :PRODU2
#     :PRODU19
#     :PRODU21
#     :PRODU13
#     :PRODU8
#     :PRODU26
#     :PRODU18
#     Results per well:
#        :lrat => Vector{Float64} of size (90,)
#        :wrat => Vector{Float64} of size (90,)
#        :orat => Vector{Float64} of size (90,)
#        :control => Vector{Symbol} of size (90,)
#        :bhp => Vector{Float64} of size (90,)
#        :mass_rate => Vector{Float64} of size (90,)
#        :rate => Vector{Float64} of size (90,)
#        :grat => Vector{Float64} of size (90,)
#
#   states (Vector with 90 entries, reservoir variables for each state)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (9000,)
#     :Saturations => Matrix{Float64} of size (3, 9000)
#     :Pressure => Vector{Float64} of size (9000,)
#     :Rs => Vector{Float64} of size (9000,)
#     :ImmiscibleSaturation => Vector{Float64} of size (9000,)
#     :TotalMasses => Matrix{Float64} of size (3, 9000)
#
#   time (report time for each state)
#      Vector{Float64} of length 90
#
#   result (extended states, reports)
#      SimResult with 90 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Apr. 12 2024 13:04 after 15 seconds, 281 milliseconds, 484.9 microseconds.

# %% [markdown]
# ## Show the input data
# The input data takes the form of a Dict:

# %%
case.input_data
# Out:
# Dict{String, Any} with 6 entries:
#   "RUNSPEC"  => OrderedDict{String, Any}("TITLE"=>"SPE 9", "DIMENS"=>[24, 25, 1…
#   "GRID"     => OrderedDict{String, Any}("cartDims"=>(24, 25, 15), "CURRENT_BOX…
#   "PROPS"    => OrderedDict{String, Any}("PVTW"=>Any[[2.48211e7, 1.0034, 4.3511…
#   "SUMMARY"  => OrderedDict{String, Any}()
#   "SCHEDULE" => Dict{String, Any}("STEPS"=>OrderedDict{String, Any}[OrderedDict…
#   "SOLUTION" => OrderedDict{String, Any}("EQUIL"=>Any[[2753.87, 2.48211e7, 3032…

# %% [markdown]
# We can also examine the RUNSPEC section

# %%
case.input_data["RUNSPEC"]
# Out:
# OrderedCollections.OrderedDict{String, Any} with 14 entries:
#   "TITLE"    => "SPE 9"
#   "DIMENS"   => [24, 25, 15]
#   "OIL"      => true
#   "WATER"    => true
#   "GAS"      => true
#   "DISGAS"   => true
#   "FIELD"    => true
#   "START"    => DateTime("2015-01-01T00:00:00")
#   "WELLDIMS" => [26, 5, 1, 26, 5, 10, 5, 4, 3, 0, 1, 1, 10, 201]
#   "TABDIMS"  => [1, 1, 40, 20, 1, 20, 20, 1, 1, -1  …  -1, 10, 10, 10, -1, 5, 5…
#   "EQLDIMS"  => [1, 100, 50, 1, 50]
#   "UNIFIN"   => true
#   "UNIFOUT"  => true
#   "MINPV"    => 2.83168e-8

# %% [markdown]
# ## Plot the simulation model
# These plot are interactive when run outside of the documentations.

# %%
using GLMakie
plot_reservoir(case.model, states)
# Out:
# Figure()

# %% [markdown]
# ## Plot the well responses

# %%
plot_well_results(ws)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
